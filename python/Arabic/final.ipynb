# %%
import urllib
# %pip install requests_html
import requests
# !pip install requests
from requests_html import HTMLSession

def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        return response
    except requests.exceptions.RequestException as e:
        print(e)
# Out:
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests_html in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (0.10.0)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests_html) (2.28.1)
# Requirement already satisfied: pyquery in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: bs4 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: w3lib in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests_html) (2.1.1)
# Requirement already satisfied: fake-useragent in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests_html) (1.1.3)
# Requirement already satisfied: parse in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.64.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (6.1.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: certifi>=2021 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2022.6.15)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.11)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from bs4->requests_html) (4.12.1)
# Requirement already satisfied: lxml>=2.1 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyquery->requests_html) (4.9.2)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pyquery->requests_html) (1.2.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests->requests_html) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests->requests_html) (3.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.15.0)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
def scrape_google(query):
    
    # query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.com/search?q=" + query)
    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.')

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
links = scrape_google("سيارات")
for link in links:
  print(link)
# Out:
# https://www.olx.com.eg/vehicles/cars-for-sale/
# https://poki.com/ar/%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA
# https://www.skynewsarabia.com/business/1615818-%D9%88%D9%83%D8%A7%D9%84%D8%A9-%D8%A7%D9%84%D8%B7%D8%A7%D9%82%D8%A9-%D9%86%D9%85%D9%88-%D9%83%D8%A8%D9%8A%D8%B1-%D8%A8%D8%B3%D9%88%D9%82-%D8%A7%D9%84%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA-%D8%A7%D9%84%D9%83%D9%87%D8%B1%D8%A8%D8%A7%D9%8A%D9%94%D9%8A%D8%A9-2023
# https://www.shift-eg.com/news/local-news/details/19087/%D8%A3%D9%88%D9%84-%D8%B3%D9%8A%D8%A7%D8%B1%D8%A9-%D9%83%D9%87%D8%B1%D8%A8%D8%A7%D8%A6%D9%8A%D8%A9-%D9%85%D8%B5%D8%B1%D9%8A%D8%A9-100-%D8%A8%D8%A7%D9%84%D8%A3%D8%B3%D9%88%D8%A7%D9%82-%D8%AE%D9%84%D8%A7%D9%84-%D8%B4%D9%87%D8%B1-%D8%B5%D9%88%D8%B1
# https://www.contactcars.com/ar/usedcars
# https://www.contactcars.com/ar/newcars
# https://www.masrawy.com/channel/autos
# https://eg.hatla2ee.com/ar/car/all-prices
# https://egypt.yallamotor.com/ar/new-cars
# https://eg.hatla2ee.com/ar/car
# https://www.masrawy.com/autos/autos_news/details/2023/4/27/2404507/-%D8%A7%D9%84%D8%AD%D9%82-%D8%A7%D8%B4%D8%AA%D8%B1%D9%8A-%D8%AA%D8%B9%D8%B1%D9%81-%D8%B9%D9%84%D9%89-%D8%A3%D8%B1%D8%AE%D8%B5-5-%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA-%D9%81%D9%89-%D9%85%D8%B5%D8%B1-%D9%82%D8%A8%D9%84-%D8%A7%D9%84%D8%AA%D8%B9%D9%88%D9%8A%D9%85-%D8%A7%D9%84%D9%85%D8%AA%D9%88%D9%82%D8%B9
# https://www.almasryalyoum.com/news/details/2873252

# %%
from nltk.tokenize import  word_tokenize
import nltk
nltk.download('punkt')
# # EXAMPLE_TEXT = """
# # أبو عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك
# # وجغرافيا مسلم. يكنى باسم الخوارزمي وأبي جعفر. قيل أنه ولد حوالي 164هـ 781م (وهو غير مؤكد) وقيل أنه توفي بعد 232هـ أي (بعد 847م). يعتبر
# # من أوائل علماء الرياضيات المسلمين حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره. اتصل بالخليفة العباسي المأمون وعمل في بيت الحكمة في 
# # بغداد وكسب ثقة الخليفة إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل فيها أكثر من سبعين جغرافيا. قبل وفاته في 850 م/232 هـ
# # كان الخوارزمي قد ترك العديد من المؤلفات في علوم الرياضيات والفلك والجغرافيا ومن أهمها

# # """
# EXAMPLE_TEXT=links
# print(word_tokenize(EXAMPLE_TEXT))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# links=scrape_google('cars')
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup

def get_text(url):
    try:
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req,timeout=5).read()
        soup = BeautifulSoup(webpage, "html.parser")
        texts = soup.findAll(text=True)
        res=u" ".join(t.strip() for t in texts if t.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]'])
        return(res)
    except:
        return False
get_text('https://en.wikipedia.org/wiki/Machine_learning')
text=[]
for i in links:
  t=get_text(i)
  if t:
    text.append(t)

    word_tokens = word_tokenize(t)
# word_tokens = 

    filtered_sentence = [w for w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)

    filtered_sentence = [w for w in word_tokens if not w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)
    filtered_sentence = [w for w in word_tokens if not w.lower() in word_tokens]

    print(word_tokens)
    print('---------------------------------')
    print(filtered_sentence)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20504\2319652481.py:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# []
# ---------------------------------
# []
# ['ماذا', 'ستلعب', 'اليوم؟', 'ألعاب', 'سيارات', 'Crazy', 'Cars', 'Merge', 'Round', 'Racers', 'Smash', 'Karts', 'City', 'Car', 'Driving', ':', 'Stunt', 'Master', 'Rocket', 'Soccer', 'Derby', 'Cyber', 'Cars', 'Punk', 'Racing', 'Drive', 'Mad', 'Blumgi', 'Rocket', 'Extreme', 'Car', 'Parking', '!', 'Top', 'Speed', '3D', 'ألعاب', 'سباق', 'سيارات', 'ألعاب', 'شاحنات', 'Drifting', 'Games', 'ألعاب', 'درايفر', 'City', 'Rider', '3D', 'Car', 'Simulator', 'Parking', 'Fury', '3D', ':', 'Beach', 'City', 'Adventure', 'Drivers', 'Car', 'Rush', 'Offroader', 'V5', 'Real', 'Cars', 'in', 'City', 'Traffic', 'Rush', '!', '3D', 'City', 'Racer', 'Merge', 'Cyber', 'Racers', 'Merge', 'Gangster', 'Cars', '18', 'Wheeler', 'Cargo', 'Simulator', '2', 'Grand', 'Prix', 'Hero', 'Cars', 'Thief', ':', 'Tank', 'Edition', 'Cars', 'Thief', 'Flying', 'Car', 'Simulator', 'Neon', 'Car', 'Maze', 'TinyTownRacing', 'Off-Road', 'Rain', 'Cargo', 'Simulator', 'Rally', 'Champion', 'Burnout', 'Drift', ':', 'Hilltop', 'Brain', 'For', 'Monster', 'Truck', 'Super', 'Tunnel', 'Rush', 'Truck', 'Traffic', 'BoxRob', '3', 'Fortride', ':', 'Open', 'World', 'Go', 'Kart', 'Go', '!', 'Ultra', '!', 'Car', 'Simulator', 'Arena', 'Stock', 'Car', 'Hero', 'Sling', 'Drift', 'Extreme', 'Off', 'Road', 'Cars', '3', ':', 'Cargo', 'Mad', 'Cars', 'Racing', 'and', 'Crash', 'Burnin', "'", 'Rubber', 'Crash', 'n', "'", 'Burn', 'Neon', 'Flytron', ':', 'Cyberpunk', 'Racer', 'Demolition', 'Derby', 'Crash', 'Racing', 'Death', 'Chase', 'Mad', 'Truck', 'Challenge', 'Special', 'Parking', 'Fury', '3D', 'BoxRob', 'Dubai', 'Police', 'Parking', '2', 'Burnout', 'Drift', ':', 'Seaport', 'Max', 'Sports', 'Car', 'Challenge', 'Freeway', 'Fury', 'Monster', 'Truck', 'Shadow', 'Racer', 'Burnout', 'Extreme', 'Drift', '2', 'Moving', 'Truck', ':', 'Bounty', 'Parking', 'Fury', '3D', ':', 'Night', 'Thief', 'Rally', 'Point', '3', 'Midnight', 'Drive', 'Super', 'Racing', 'GT', ':', 'Drag', 'Pro', 'Burnin', "'", 'Rubber', '5', 'XS', 'Monster', 'Tracks', 'Bumper', 'Cars', 'Soccer', 'BoxRob', '2', 'Stunt', 'Car', 'Challenge', '3', 'School', 'Bus', 'Demolition', 'Derby', 'Blocky', 'Cars', 'Freeway', 'Fury', '2', 'Shift', 'to', 'Drift', 'Parking', 'Fury', '3D', ':', 'Bounty', 'Hunter', 'Moving', 'Truck', ':', 'Construction', 'Extreme', 'Off', 'Road', 'Cars', 'Blood', 'Drift', 'Truck', 'Loader', '5', 'Slot', 'Car', 'Racing', 'Freeway', 'Fury', '3', '3D', 'Arena', 'Racing', 'Noob', 'Drive', 'Zombie', 'Derby', '2', 'Zombie', 'Derby', 'Rally', 'Point', 'Infinite', '8', 'Skiddy', 'Taxi', 'Zombie', 'Derby', ':', 'Pixel', 'Survival', 'Cartoon', 'Mini', 'Racing', 'Real', 'Simulator', 'Monster', 'Truck', 'Zombie', 'Derby', ':', 'Blocky', 'Roads', 'Just', 'Park', 'It', '11', 'Monster', 'Truck', ':', 'Forest', 'Delivery', '18', 'Wheeler', 'Cargo', 'Simulator', 'Super', 'Star', 'Car', 'Rally', 'Point', '5', 'Hard', 'Truck', 'Desert', 'Worms', 'Moving', 'Truck', 'CATS', '-', 'Crash', 'Arena', 'Turbo', 'Stars', 'Monsters', "'", 'Wheels', 'Special', 'Rally', 'Point', '2', 'Truck', 'Loader', 'Just', 'Park', 'It', '12', 'Truck', 'Loader', '4', '2', 'Player', 'City', 'Racing', 'Truck', 'Loader', '2', 'Mad', 'Day', 'Survival', 'Race', 'Color', 'Crash', 'Turn', 'Right', 'Jamming', 'Car', 'Escape', 'Cartoon', 'Racers', ':', 'North', 'Pole', 'SocCar', 'Gear', 'Madness', 'Rally', 'Point', '4', 'Mad', 'Car', 'Racing', 'Dead', 'Paradise', ':', 'Race', 'Shooter', 'Car', 'Eats', 'Car', ':', 'Winter', 'Adventure', 'Operation', 'Desert', 'Road', 'Toy', 'Car', 'Simulator', 'Color', 'Car', '2', 'Player', 'City', 'Racing', '2', '3D', 'Monster', 'Truck', ':', 'Skyroads', 'Electric', 'Highway', 'Monster', 'Truck', 'Racing', 'Arena', 'Mad', 'Day', '2', 'Crazy', 'Platez', 'Car', 'Eats', 'Car', ':', 'Sea', 'Adventure', 'Wild', 'Race', 'Rally', 'Racer', 'Franky', 'Valet', 'Parking', 'Smash', 'Car', 'Idle', '2', 'Hole', 'N', "'", 'Fun', 'Parking', 'Block', 'Car', 'Eats', 'Car', ':', 'Dungeon', 'Adventure', 'Rocking', 'Wheels', 'Subway', 'Surfers', 'Temple', 'Run', '2', 'Venge. ...
# ---------------------------------
# ['Crazy', 'Cars', 'Merge', 'Round', 'Racers', 'Smash', 'Karts', 'City', 'Car', 'Driving', 'Stunt', 'Master', 'Rocket', 'Soccer', 'Derby', 'Cyber', 'Cars', 'Punk', 'Racing', 'Drive', 'Mad', 'Blumgi', 'Rocket', 'Extreme', 'Car', 'Parking', 'Top', 'Speed', '3D', 'Drifting', 'Games', 'City', 'Rider', '3D', 'Car', 'Simulator', 'Parking', 'Fury', '3D', 'Beach', 'City', 'Adventure', 'Drivers', 'Car', 'Rush', 'Offroader', 'V5', 'Real', 'Cars', 'City', 'Traffic', 'Rush', '3D', 'City', 'Racer', 'Merge', 'Cyber', 'Racers', 'Merge', 'Gangster', 'Cars', 'Wheeler', 'Cargo', 'Simulator', 'Grand', 'Prix', 'Hero', 'Cars', 'Thief', 'Tank', 'Edition', 'Cars', 'Thief', 'Flying', 'Car', 'Simulator', 'Neon', 'Car', 'Maze', 'TinyTownRacing', 'Off-Road', 'Rain', 'Cargo', 'Simulator', 'Rally', 'Champion', 'Burnout', 'Drift', 'Hilltop', 'Brain', 'For', 'Monster', 'Truck', 'Super', 'Tunnel', 'Rush', 'Truck', 'Traffic', 'BoxRob', 'Fortride', 'Open', 'Go', 'Kart', 'Go', 'Ultra', 'Car', 'Simulator', 'Arena', 'Stock', 'Car', 'Hero', 'Sling', 'Drift', 'Extreme', 'Off', 'Road', 'Cars', 'Cargo', 'Mad', 'Cars', 'Racing', 'Crash', 'Burnin', 'Rubber', 'Crash', 'Burn', 'Neon', 'Flytron', 'Cyberpunk', 'Racer', 'Demolition', 'Derby', 'Crash', 'Racing', 'Death', 'Chase', 'Mad', 'Truck', 'Challenge', 'Special', 'Parking', 'Fury', '3D', 'BoxRob', 'Dubai', 'Police', 'Parking', 'Burnout', 'Drift', 'Seaport', 'Max', 'Sports', 'Car', 'Challenge', 'Freeway', 'Fury', 'Monster', 'Truck', 'Shadow', 'Racer', 'Burnout', 'Extreme', 'Drift', 'Moving', 'Truck', 'Bounty', 'Parking', 'Fury', '3D', 'Night', 'Thief', 'Rally', 'Point', 'Midnight', 'Drive', 'Super', 'Racing', 'GT', 'Drag', 'Pro', 'Burnin', 'Rubber', 'XS', 'Monster', 'Tracks', 'Bumper', 'Cars', 'Soccer', 'BoxRob', 'Stunt', 'Car', 'Challenge', 'School', 'Bus', 'Demolition', 'Derby', 'Blocky', 'Cars', 'Freeway', 'Fury', 'Shift', 'Drift', 'Parking', 'Fury', '3D', 'Bounty', 'Hunter', 'Moving', 'Truck', 'Construction', 'Extreme', 'Off', 'Road', 'Cars', 'Blood', 'Drift', 'Truck', 'Loader', 'Slot', 'Car', 'Racing', 'Freeway', 'Fury', '3D', 'Arena', 'Racing', 'Noob', 'Drive', 'Zombie', 'Derby', 'Zombie', 'Derby', 'Rally', 'Point', 'Infinite', 'Skiddy', 'Taxi', 'Zombie', 'Derby', 'Pixel', 'Survival', 'Cartoon', 'Mini', 'Racing', 'Real', 'Simulator', 'Monster', 'Truck', 'Zombie', 'Derby', 'Blocky', 'Roads', 'Just', 'Park', 'It', 'Monster', 'Truck', 'Forest', 'Delivery', 'Wheeler', 'Cargo', 'Simulator', 'Super', 'Star', 'Car', 'Rally', 'Point', 'Hard', 'Truck', 'Desert', 'Worms', 'Moving', 'Truck', 'CATS', 'Crash', 'Arena', 'Turbo', 'Stars', 'Monsters', 'Wheels', 'Special', 'Rally', 'Point', 'Truck', 'Loader', 'Just', 'Park', 'It', 'Truck', 'Loader', 'Player', 'City', 'Racing', 'Truck', 'Loader', 'Mad', 'Day', 'Survival', 'Race', 'Color', 'Crash', 'Turn', 'Right', 'Jamming', 'Car', 'Escape', 'Cartoon', 'Racers', 'North', 'Pole', 'SocCar', 'Gear', 'Madness', 'Rally', 'Point', 'Mad', 'Car', 'Racing', 'Dead', 'Paradise', 'Race', 'Shooter', 'Car', 'Eats', 'Car', 'Winter', 'Adventure', 'Operation', 'Desert', 'Road', 'Toy', 'Car', 'Simulator', 'Color', 'Car', 'Player', 'City', 'Racing', '3D', 'Monster', 'Truck', 'Skyroads', 'Electric', 'Highway', 'Monster', 'Truck', 'Racing', 'Arena', 'Mad', 'Day', 'Crazy', 'Platez', 'Car', 'Eats', 'Car', 'Sea', 'Adventure', 'Wild', 'Race', 'Rally', 'Racer', 'Franky', 'Valet', 'Parking', 'Smash', 'Car', 'Idle', 'Hole', 'Fun', 'Parking', 'Block', 'Car', 'Eats', 'Car', 'Dungeon', 'Adventure', 'Rocking', 'Wheels', 'Subway', 'Surfers', 'Temple', 'Run', 'Venge.io', 'Stickman', 'Hook', 'Who', 'Narrow.One', 'Repuls.io', 'Brain', 'Test', 'Tricky', 'Stories', 'SchoolBreak.io', 'Friday', 'Night', 'Funkin', 'Idle', 'Ants', 'Moto', 'X3M', 'Stick', 'Merge', 'Parkour', 'Race', 'Mad', 'GunZ', 'Gold', 'Digger', 'FRVR', 'Like', 'King', 'Sushi', 'Party', 'EvoWorld', 'FlyOrDie', 'Uno', 'Online', 'Crossy', 'Road', 'Where', 'My', 'Cat', 'Combat', 'Online', 'Fury', 'Wars', 'Raft', 'Wars', 'Multiplayer', 'Temple', 'Boom', 'Impo ...
# ['المزيد', '°C', '°C', '{', '{', 'weatherDataItem.maxTemperature', '|', 'decimalNumber', ':', 'null', ':', "'floor", "'", '}', '}', '°C', 'تسجيل', 'الدخول', 'راديو', 'مباشر', 'دخول', '°C', 'مباشر', 'راديو', 'عاجل', 'الإشعارات', 'الرئيسية', 'أخبار', 'آخر', 'الأخبار', 'الأكثر', 'قراءة', 'تقارير', 'مصورة', 'اخترنا', 'لكم', 'تقارير', 'خاصة', 'شرق', 'أوسط', 'آخر', 'الأخبار', 'من', 'مصر', 'نافذة', 'مغاربية', 'بيئة', 'ومناخ', 'كوب', '28', 'صحة', 'غذاء', 'أوبئة', 'عالم', 'آخر', 'الأخبار', 'الولايات', 'المتحدة', 'رياضة', 'علوم', 'آخر', 'الأخبار', 'تكنولوجيا', 'الذكاء', 'الاصطناعي', 'منوعات', 'فيديو', 'أحدث', 'الفيديوهات', 'نجوم', 'على', 'سكاي', 'الأكثر', 'تفاعلا', 'سوشيال', 'فيديو', 'برامجنا', 'حديث', 'الصور', 'إنفوغرافيك', 'مقالات', 'رأي', 'ملفات', 'مزيد', 'رياضة', 'علوم', 'منوعات', 'فيديو', 'برامجنا', 'حديث', 'الصور', 'إنفوغرافيك', 'مقالات', 'رأي', 'ملفات', 'عاجل', 'مباشر', 'راديو', '[', 'if', 'lte', 'IE', '10', ']', '>', '<', 'div', 'style=', "''", 'position', ':', 'fixed', ';', 'top', ':', '0', ';', 'left', ':', '0', ';', 'width', ':', '100', '%', ';', 'height', ':', '100', '%', ';', 'background', ':', '#', 'f5f5f5', ';', 'z-index', ':', '100000', ';', 'overflow', ':', 'auto', ';', "''", '>', '<', 'div', 'style=', "''", 'width', ':', '100', '%', ';', "''", '>', '<', 'img', 'style=', "''", 'width', ':', '100', '%', ';', 'max-height', ':', '100px', "''", 'src=', "''", 'https', ':', '//www.skynewsarabia.com/asset/1643193804/16.2/assets/img/not-supported/notsupported-header.jpg', "''", 'alt=', "''", "''", 'role=', "''", 'presentation', "''", '>', '<', '/div', '>', '<', 'div', 'style=', "''", 'text-align', ':', 'center', ';', 'width', ':', '100', '%', ';', "''", '>', '<', 'img', 'style=', "''", 'width:100', '%', ';', 'max-width', ':', '640px', ';', "''", 'src=', "''", 'https', ':', '//www.skynewsarabia.com/asset/1643193804/16.2/assets/img/not-supported/not-supported.jpg', "''", 'alt=', "''", "''", 'role=', "''", 'presentation', "''", '>', '<', '/div', '>', '<', 'div', 'style=', "''", 'width', ':', '100', '%', ';', 'position', ':', 'fixed', ';', 'bottom', ':', '0', ';', 'background-color', ':', '#', '4d535d', "''", '>', '<', 'img', 'src=', "''", 'https', ':', '//www.skynewsarabia.com/asset/1643193804/16.2/assets/img/not-supported/notsupported-footer.jpg', "''", 'alt=', "''", "''", 'role=', "''", 'presentation', "''", '>', '<', '/div', '>', '<', '/div', '>', '<', '!', '[', 'endif', ']', 'الرئيسية', 'الأخبار', 'العاجلة', 'أخبار', 'شرق', 'أوسط', 'صحة', 'عالم', 'رياضة', 'علوم', 'منوعات', 'فيديو', 'برامجنا', 'حديث', 'الصور', 'البث', 'المباشر', 'راديو', 'إنفوغرافيك', 'مقالات', 'رأي', 'ملفات', '{', '{', 'promoBar.promoMessage', '}', '}', '{', '{', 'promoBar.description', '}', '}', '{', '{', 'btnText', '}', '}', 'X', 'لم', 'تفعّل', 'خدمة', 'إشعارات', 'الأخبار', 'العاجلة', 'اضغط', 'للمزيد', 'إشترك', 'شكرًا', 'للاشتراك', 'بخدمة', 'الأخبار', 'العاجلة', 'www.skynewsarabia.com', 'وكالة', 'الطاقة', ':', '``', 'نمو', 'كبير', "''", 'بسوق', 'السيارات', 'الكهربائية', 'في', '2023', 'l', '26', 'أبريل', '2023', '-', '14:48', 'بتوقيت', 'أبوظبي', 'سكاي', 'نيوز', 'عربية', '-', 'أبوظبي', 'مصنع', 'سيارات', 'مرسيدس', 'في', 'ألمانيا', 'أعلنت', 'وكالة', 'الطاقة', 'الدولية،', 'الأربعاء،', 'أن', 'مبيعات', 'السيارات', 'الكهربائية', 'ستواصل', '``', 'نموها', 'الكبير', "''", 'هذا', 'العام', 'لتصل', 'إلى', 'ما', 'يقارب', 'خُمس', 'السوق', 'العالمية', '.', 'وقالت', 'الوكالة', 'في', 'تقرير', 'حول', 'هذا', 'الموضوع', 'إن', 'التوجه', 'الحالي', 'نحو', 'استخدام', 'السيارات', 'الكهربائية', 'سيكون', 'له', 'تداعيات', 'كبيرة', 'على', 'قطاع', 'الطاقة،', 'حيث', 'سينخفض', 'الطلب', 'على', 'النفط', 'بخمسة', 'ملايين', 'برميل', 'يوميًا', 'بحلول', 'عام', '2030', '.', 'وتوقعات', 'الطلب', 'على', 'النفط', 'عام', '2023', 'هو', '101.9', 'مليون', 'برميل', 'يوميا', '.', 'ووفقا', 'لهذه', 'الدراسة', 'بيعت', 'أكثر', 'من', '10', 'ملايين', 'سيارة', 'كهربائية', 'في', 'العالم', 'في', '2022', 'و', "''", 'يتوقع', 'أن', 'تزداد', 'المبيعات', 'بدرجة', 'أكبر', 'هذا', 'العام', 'بنسبة', '35', 'بالمئة', 'لتبلغ', ' ...
# ---------------------------------
# ['°C', '°C', 'weatherDataItem.maxTemperature', 'decimalNumber', '°C', '°C', 'IE', 'promoBar.promoMessage', 'promoBar.description', 'btnText', 'X', ':article.mediaAsset.caption', 'article.match.roundName', 'sidebarWidgetTitle', 'sidebarWidgetTitle', 'breakingNewsWidgetTitle', 'radioWidgetTitle', 'pollWidgetTitle', 'breakingNewsWidgetTitle', 'pollWidgetTitle', 'radioWidgetTitle', 'sidebarWidgetTitle', 'sidebarWidgetTitle', 'SKY', 'Sky', 'International', 'AG']
# ['Google', 'Tag', 'Manager', '(', 'noscript', ')', 'End', 'Google', 'Tag', 'Manager', '(', 'noscript', ')', 'alarm', 'message', 'when', 'added', 'more', 'than', '3', 'cars', 'to', 'compare', 'add', 'class', 'showMsg', 'to', 'body', 'tag', 'متابعة', 'Tab', '1', 'سيارات', 'جديدة', 'Tab', '2', 'سيارات', 'مستعملة', 'Tab', '3', 'موتوسيكلات', 'New', 'Car', 'Content', 'لا', 'توجد', 'سيارات', 'جديدة', 'في', 'قائمة', 'المقارنات', 'قارن', 'Used', 'Car', 'Content', 'لا', 'توجد', 'سيارات', 'مستعملة', 'في', 'قائمة', 'المقارنات', 'قارن', 'Scooter', 'Content', 'لا', 'توجد', 'موتوسيكلات', 'مستعملة', 'في', 'قائمة', 'المقارنات', 'قارن', 'notification', 'خدمة', 'الاشعارات', 'تلقى', 'آخر', 'الأخبار', 'والمستجدات', 'من', 'موقع', 'شيفت', 'اشترك', 'لاحقا', '--', '--', '--', '--', 'Header', '--', '--', '--', '--', 'First', 'Level', 'Menu', 'Item', '1', 'HP', 'الرئيسية', 'Item', '5', 'Experiments', 'تجارب', 'قيادة', 'Item', '2', 'News', 'أخبار', 'Second', 'Level', 'Menu', 'الكل', 'عالمية', 'محلية', 'Item', '3', 'Reports', 'تقارير', 'Second', 'Level', 'Menu', 'سيارات', 'جديدة', 'تغطيات', 'صحفية', 'تكنولوجيا', 'رياضة', 'سيارات', 'Item', '4', 'Events', 'مالتيميديا', 'Second', 'Level', 'Menu', 'صور', 'Item', '7', 'Video', 'فيديو', 'Item', '4', 'Cars', 'Prices', 'أسعار', 'السيارات', 'Item', '4', 'Cars', 'Prices', 'سيارات', 'مستعملة', 'Comparison', 'sell', 'your', 'car', 'بيع', 'عربيتك', 'المقارنة', 'سيارات', 'جديدة', 'سيارات', 'مستعملة', 'موتوسيكلات', 'before', 'login', 'لتتمكن', 'من', 'إضافة', 'إعلان', 'يرجى', 'الدخول', 'على', 'حسابك', 'اذا', 'كنت', 'مشتركاً', 'او', 'تسجيل', 'حساب', 'جديد', 'اذا', 'كنت', 'مستخدم', 'جديد', 'دخول', 'مستخدم', 'جديد', 'login', 'before', 'add', 'photo', 'دخول', 'مستخدم', 'جديد', 'login', 'تسجيل', 'الدخول', 'هنا', 'تسجيل', 'باستخدام', 'الفيسبوك', 'تسجيل', 'باستخدام', 'جوجل', 'Login', 'Form', 'ينبغي', 'إدخال', 'بريد', 'الكتروني', 'صالح', 'يجب', 'أن', 'تحتوي', 'كلمة', 'المرور', 'على', '8', 'أحرف', 'على', 'الأقل', 'وتحتوي', 'على', 'أحرف', 'كبيرة', 'وصغيرة', 'تذكرني', 'نسيت', 'كلمة', 'السر', 'دخول', '--', '--', 'Remember', 'Popup', '--', '--', '-', 'البريد', 'الالكتروني', 'ينبغي', 'إدخال', 'بريد', 'الكتروني', 'صالح', 'متابعة', 'New', 'User', 'مستخدم', 'جديد', 'اضغط', 'هنا', 'new', 'user', 'مستخدم', 'جديد', 'Register', 'Form', 'الأسم', '*', 'هذه', 'المساحة', 'مطلوبة', 'البريد', 'الالكتروني', '*', 'ينبغي', 'إدخال', 'بريد', 'الكتروني', 'صالح', 'كلمة', 'المرور', '*', 'يجب', 'أن', 'تحتوي', 'كلمة', 'المرور', 'على', '8', 'أحرف', 'على', 'الأقل', 'وتحتوي', 'على', 'أحرف', 'كبيرة', 'وصغيرة', 'تأكيد', 'كلمة', 'المرور', '*', 'يجب', 'أن', 'يتطابق', 'تأكيد', 'كلمة', 'المرور', 'مع', 'كلمة', 'المرور', 'التي', 'تم', 'إدخالها', 'رقم', 'المنزل', 'الموبايل', '*', 'يجب', 'عليك', 'إدخال', 'رقم', 'هاتف', 'محمول', 'صالح', 'موافق', 'علي', 'جميع', 'الشروط', 'والاحكام', '*', 'أضف', 'حسابك', 'Loader', 'error', 'Message', 'يجب', 'الموافقة', 'علي', 'الشروط', 'والاحكام', 'أولا', 'مستخدم', 'مسجل؟', 'تسجيل', 'الدخول', 'هنا', 'Social', 'Media', '--', '--', '--', '--', 'Header', '--', '--', '--', '--', '--', '--', '--', '--', 'Header', 'Mob', '--', '--', '--', '--', '--', '--', '--', '--', 'Content', '--', '--', '--', '--', 'Sponsor', 'Start', ':', 'Defining', 'Ads', 'Slots-', 'End', ':', 'Defining', 'Ads', 'Slots-', 'News', 'Article', 'Template', 'bread', 'crumb', 'الرئيسية', 'الأخبار', 'محلية', 'Leaderboard', 'Start', ':', 'Defining', 'Ads', 'Slots-', 'اعلان', '/96551095/V3_Shift/Desktop/LeaderBoard', 'End', ':', 'Defining', 'Ads', 'Slots-', 'أول', 'سيارة', 'كهربائية', 'مصرية', '100', '%', 'بالأسواق', 'خلال', 'شهر', '..', 'صور', '25', 'أبريل', '2023', 'Light', 'Gallery', 'slider', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'عرض', '9', 'صورة', 'Next', 'Album', 'إعادة', 'الألبوم', 'الألبوم', 'التالى', '30', 'صورة', 'ترصد', 'عزاء', 'فريد', 'الطوبجي', 'رجل', 'BMW', 'مع', 'البافارية', 'ألبومات', 'ذات', 'صلة', 'بعد', 'الكشف', 'عن', 'موعد', 'طرحها', '..', ' ...
# ---------------------------------
# ['Google', 'Manager', 'End', 'Google', 'Manager', 'showMsg', 'Tab', 'Tab', 'Tab', 'Content', 'Content', 'Scooter', 'Content', 'Header', 'First', 'Level', 'Menu', 'Item', 'HP', 'Item', 'Experiments', 'Item', 'News', 'Second', 'Level', 'Menu', 'Item', 'Reports', 'Second', 'Level', 'Menu', 'Item', 'Events', 'Second', 'Level', 'Menu', 'Item', 'Video', 'Item', 'Prices', 'Item', 'Prices', 'Comparison', 'Form', 'Remember', 'Popup', 'Register', 'Form', 'Loader', 'Social', 'Media', 'Header', 'Header', 'Mob', 'Content', 'Sponsor', 'Start', 'Defining', 'Ads', 'Slots-', 'End', 'Defining', 'Ads', 'Slots-', 'News', 'Template', 'Leaderboard', 'Start', 'Defining', 'Ads', 'Slots-', '/96551095/V3_Shift/Desktop/LeaderBoard', 'End', 'Defining', 'Ads', 'Slots-', 'Light', 'Next', 'Album', 'BMW', 'News', 'Feed', 'Google', 'News', 'Facebook', 'Twitter', 'Second', 'Listing', 'Item', 'COP-27', 'Item', 'Start', 'Defining', 'Ads', 'Slots-', 'End', 'Defining', 'Ads', 'Slots-', 'Eletre', 'Item', 'Seagull', 'Seagull', 'Item', 'Item', 'فورمولا-E', 'F-150', 'Lightning', 'BMW', 'XE', 'ShowCase', 'Start', 'Defining', 'Ads', 'Slots-', '/96551095/V3_Shift/Desktop/MediumRectangle', 'End', 'Defining', 'Ads', 'Slots-', 'BMW', 'Eletre', 'Seagull', 'Brands', 'Start', 'Defining', 'Ads', 'Slots-', '/96551095/V3_Shift/Desktop/MediumRectangle2', 'End', 'Defining', 'Ads', 'Slots-', 'Global', 'News', 'E', 'F-150', 'Lightning', 'E-', 'Sports', 'Reports', 'فورمولا-E', 'Facebook', 'Comments', 'Interscroller', 'Start', 'Defining', 'Ads', 'Slots-', 'End', 'Defining', 'Ads', 'Slots-', 'Footer', 'Quick', 'Links', 'Social', 'Media', 'Breaking', 'News', 'Hyperlink1', 'Close', 'Start', 'Defining', 'Ads', 'Slots-', 'End', 'Defining', 'Ads', 'Slots-', 'Lazyload']
# ['English', 'أضف', 'إعلان', 'عربيات', 'للبيع', 'عربيات', 'للبيع', 'كل', 'العربيات', 'عربيات', 'جديدة', 'عربيات', 'مستعملة', 'عربيات', 'كهرباء', 'عربيات', 'مستوردة', 'عربيات', 'ينفع', 'تتقسط', 'كتالوج', 'العربيات', 'الجديدة', 'تسعير', 'تقسيط', 'تأمين', 'صيانة', 'التجار', 'والمعارض', 'أخبار', 'أضف', 'إعلان', 'القائمة', 'إغلاق', 'تسجيل', 'دخول', '/', 'تسجيل', 'حساب', 'عربيات', 'للبيع', 'كل', 'العربيات', 'عربيات', 'جديدة', 'عربيات', 'مستعملة', 'عربيات', 'كهرباء', 'عربيات', 'مستوردة', 'عربيات', 'ينفع', 'تتقسط', 'كتالوج', 'العربيات', 'الجديدة', 'سعر', 'عربيتك', 'تقسيط', 'العربية', 'تأمين', 'صيانة', 'عربيتك', 'التجار', 'والمعارض', 'الأخبار', 'أضف', 'إعلان', 'اللغة', 'English', 'سياسة', 'الخصوصية', 'بحث', 'مفصل', 'إختر', 'الماركة', 'الاحدث', 'حدد', 'السعر', 'ترتيب', 'حسب', 'إغلاق', 'الاحدث', 'الاقل', 'سعراً', 'الاعلى', 'سعراً', 'السنة', 'الاحدث', 'أولاً', 'السنة', ':', 'الاقدم', 'أولاً', 'الكيلومترات', ':', 'الاقل', 'أولاً', 'الكيلومترات', ':', 'الاكثر', 'أولاً', 'الحالة', 'إغلاق', 'الكل', 'جديد', 'مستعمل', 'السعر', 'إغلاق', 'جنيه', 'جنيه', 'الأسعار', 'المقترحة', 'أقل', 'من', '200,000', 'جنيه', 'من', '200,000', 'جنيه', 'إلى', '250,000', 'جنيه', 'من', '250,000', 'جنيه', 'إلى', '350,000', 'جنيه', 'من', '350,000', 'جنيه', 'إلى', '500,000', 'جنيه', 'من', '500,000', 'جنيه', 'إلى', '650,000', 'جنيه', 'من', '650,000', 'جنيه', 'إلى', '800,000', 'جنيه', 'من', '800,000', 'جنيه', 'إلى', '1,000,000', 'جنيه', 'أكثر', 'من', '1,000,000', 'جنيه', 'تأكيد', 'بحث', 'مفصل', 'إعادة', 'الضبط', 'ترتيب', 'حسب', 'الاحدث', 'ترتيب', 'حسب', 'إغلاق', 'الاحدث', 'الاقل', 'سعراً', 'الاعلى', 'سعراً', 'السنة', 'الاحدث', 'أولاً', 'السنة', ':', 'الاقدم', 'أولاً', 'الكيلومترات', ':', 'الاقل', 'أولاً', 'الكيلومترات', ':', 'الاكثر', 'أولاً', 'الحالة', 'الكل', 'جديد', 'عربيات', 'جديدة', 'مستعمل', 'عربيات', 'مستعملة', 'الماركة', 'والموديل', 'أستون', 'مارتن', 'ألفا', 'روميو', 'أوبل', 'أودى', 'إم', 'جي', 'عرض', 'الكل', '89', 'ماركة', 'إختر', 'الماركة', 'إغلاق', 'أستون', 'مارتن', 'ألفا', 'روميو', 'أوبل', 'أودى', 'إم', 'جي', 'اسبيرانزا', 'انفينيتى', 'ايجل', 'ايسوزو', 'بايك', 'بروتون', 'بريليانس', 'بنتلي', 'بورش', 'بونتياك', 'بويك', 'بي', 'ام', 'دبليو', 'بي', 'واى', 'دى', 'بيجو', 'بيرودوا', 'بيستون', 'تسلا', 'تويوتا', 'جاجوار', 'جاك', 'جريت', 'وول', 'جي', 'إم', 'سي', 'جيب', 'جيتور', 'جيلي', 'جين', 'بى', 'داتشيا', 'دايهاتسو', 'دايو', 'دودج', 'دونج', 'فينج', 'دي', 'اس', 'رولز', 'رويس', 'رينج', 'روفر', 'رينو', 'زوتي', 'ساب', 'سامسونج', 'سانج', 'يونج', 'ساوايست', 'سايبا', 'ستروين', 'سكودا', 'سمارت', 'سوبارو', 'سوزوكي', 'سيات', 'سينوفا', 'شانا', 'شانجان', 'شانجي', 'شيري', 'شيفروليه', 'فاو', 'فورثينج', 'فورد', 'فولفو', 'فولكس', 'فاجن', 'فيات', 'فيراري', 'كاديلاك', 'كايي', 'كرايسلر', 'كوبرا', 'كومودو', 'كيا', 'لادا', 'لامبورجيني', 'لاند', 'روفر', 'لانشيا', 'لكزس', 'لنكولن', 'ليفان', 'مابل', 'مازدا', 'مازيراتي', 'ماهيندرا', 'مرسيدس', 'ميتسوبيشي', 'ميركوري', 'ميني', 'نصر', 'نيسان', 'هافال', 'هافي', 'هامر', 'هاوتاي', 'هايما', 'هوندا', 'هيونداى', 'مسح', 'الكل', 'تطبيق', 'مكان', 'تواجد', 'العربية', 'القاهرة', 'الجيزة', 'الفيوم', 'القليوبية', 'الإسكندرية', 'عرض', 'الكل', 'مثال', ':', 'منطقة', 'مصر', 'الجديدة', '|', 'محافظة', 'القاهرة', 'إختر', 'المحافظة', 'إغلاق', 'القاهرة', 'الجيزة', 'الفيوم', 'القليوبية', 'الإسكندرية', 'الإسماعيلية', 'الغربية', 'السويس', 'الشرقية', 'الدقهلية', 'بني', 'سويف', 'المنوفية', 'أسيوط', 'المنيا', 'مرسى', 'مطروح', 'شمال', 'سيناء', 'أسوان', 'الاقصر', 'كفر', 'الشيخ', 'قنا', 'جنوب', 'سيناء', 'حلوان', 'سوهاج', 'دمياط', 'بورسعيد', 'الوادي', 'الجديد', 'البحيرة', 'البحر', 'الاحمر', 'الساحل', 'الشمالى', 'المنصورة', 'الغردقة', 'شرم', 'الشيخ', 'القصير', 'نويبع', 'رأس', 'سدر', 'سفاجا', 'دهب', 'العين', 'السخنة', 'مرسى', 'علم', 'رأس', 'البر', 'الجونة', 'واحة', 'سيوة', 'سانت', 'كاترين', 'طابا', 'الواحات', 'البحرية', 'الطور', 'مسح', 'الكل', 'تطبيق', 'السعر', '(', 'جنيه', ')', 'جنيه', 'جنيه', 'السنة', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', ...
# ---------------------------------
# ['English', 'English', 'SUV', 'Please', 'JavaScript']
# ['English', 'أضف', 'إعلان', 'عربيات', 'للبيع', 'عربيات', 'للبيع', 'كل', 'العربيات', 'عربيات', 'جديدة', 'عربيات', 'مستعملة', 'عربيات', 'كهرباء', 'عربيات', 'مستوردة', 'عربيات', 'ينفع', 'تتقسط', 'كتالوج', 'العربيات', 'الجديدة', 'تسعير', 'تقسيط', 'تأمين', 'صيانة', 'التجار', 'والمعارض', 'أخبار', 'أضف', 'إعلان', 'القائمة', 'إغلاق', 'تسجيل', 'دخول', '/', 'تسجيل', 'حساب', 'عربيات', 'للبيع', 'كل', 'العربيات', 'عربيات', 'جديدة', 'عربيات', 'مستعملة', 'عربيات', 'كهرباء', 'عربيات', 'مستوردة', 'عربيات', 'ينفع', 'تتقسط', 'كتالوج', 'العربيات', 'الجديدة', 'سعر', 'عربيتك', 'تقسيط', 'العربية', 'تأمين', 'صيانة', 'عربيتك', 'التجار', 'والمعارض', 'الأخبار', 'أضف', 'إعلان', 'اللغة', 'English', 'سياسة', 'الخصوصية', 'بحث', 'مفصل', 'إختر', 'الماركة', 'حدد', 'السعر', 'ترتيب', 'حسب', 'إغلاق', 'الاحدث', 'الاقل', 'سعراً', 'الاعلى', 'سعراً', 'السنة', 'الاحدث', 'أولاً', 'السنة', ':', 'الاقدم', 'أولاً', 'الكيلومترات', ':', 'الاقل', 'أولاً', 'الكيلومترات', ':', 'الاكثر', 'أولاً', 'الحالة', 'إغلاق', 'الكل', 'جديد', 'مستعمل', 'السعر', 'إغلاق', 'جنيه', 'جنيه', 'الأسعار', 'المقترحة', 'أقل', 'من', '200,000', 'جنيه', 'من', '200,000', 'جنيه', 'إلى', '250,000', 'جنيه', 'من', '250,000', 'جنيه', 'إلى', '350,000', 'جنيه', 'من', '350,000', 'جنيه', 'إلى', '500,000', 'جنيه', 'من', '500,000', 'جنيه', 'إلى', '650,000', 'جنيه', 'من', '650,000', 'جنيه', 'إلى', '800,000', 'جنيه', 'من', '800,000', 'جنيه', 'إلى', '1,000,000', 'جنيه', 'أكثر', 'من', '1,000,000', 'جنيه', 'تأكيد', 'بحث', 'مفصل', 'إعادة', 'الضبط', 'ترتيب', 'حسب', 'الاحدث', 'ترتيب', 'حسب', 'إغلاق', 'الاحدث', 'الاقل', 'سعراً', 'الاعلى', 'سعراً', 'السنة', 'الاحدث', 'أولاً', 'السنة', ':', 'الاقدم', 'أولاً', 'الكيلومترات', ':', 'الاقل', 'أولاً', 'الكيلومترات', ':', 'الاكثر', 'أولاً', 'الحالة', 'الكل', 'جديد', 'عربيات', 'جديدة', 'مستعمل', 'عربيات', 'مستعملة', 'الماركة', 'والموديل', 'ألفا', 'روميو', 'أوبل', 'أودى', 'إم', 'جي', 'بايك', 'عرض', 'الكل', '46', 'ماركة', 'إختر', 'الماركة', 'إغلاق', 'ألفا', 'روميو', 'أوبل', 'أودى', 'إم', 'جي', 'بايك', 'بروتون', 'بريليانس', 'بورش', 'بي', 'ام', 'دبليو', 'بي', 'واى', 'دى', 'بيجو', 'بيستون', 'تويوتا', 'جاجوار', 'جاك', 'جيب', 'جيتور', 'جيلي', 'دونج', 'فينج', 'دي', 'اس', 'رينج', 'روفر', 'رينو', 'سانج', 'يونج', 'ستروين', 'سكودا', 'سوبارو', 'سوزوكي', 'سيات', 'شانجان', 'شيري', 'شيفروليه', 'فورثينج', 'فورد', 'فولفو', 'فولكس', 'فاجن', 'فيات', 'كايي', 'كرايسلر', 'كوبرا', 'كيا', 'لادا', 'لاند', 'روفر', 'لكزس', 'مازدا', 'مازيراتي', 'مرسيدس', 'ميتسوبيشي', 'ميني', 'نيسان', 'هافال', 'هوندا', 'هيونداى', 'مسح', 'الكل', 'تطبيق', 'السعر', '(', 'جنيه', ')', 'جنيه', 'جنيه', 'ناقل', 'الحركة', 'الكل', 'مانيوال', 'اتوماتيك', 'Dual', 'Clutch', 'CVT', 'PDK', 'شكل', 'العربية', 'سيدان', 'هاتشباك', 'SUV', 'كوبيه', 'فان', 'ستيشن', 'كابورليه', 'بيك', 'أب', 'نوع', 'الوقود', 'بنزين', 'ديزل', 'غاز', 'طبيعي', 'هجين', 'كهرباء', 'سعة', 'المحرك', '(', 'سي', 'سي', ')', 'من', '800', 'إلى', '1200', 'من', '1300', 'إلى', '1400', 'من', '1500', 'إلى', '1600', 'من', '1800', 'إلى', '2000', 'من', '2200', 'إلى', '3000', 'أكثر', 'من', '3000', 'الكماليات', 'والمواصفات', 'الإضافية', 'عجلة', 'قيادة', 'متعددة', 'الوظائف', 'برنامج', 'التحكم', 'في', 'ثبات', 'السيارة', 'الإلكتروني', '(', 'ESP', ')', 'جهاز', 'ملاحة', 'حساسات', 'ركن', 'خلفية', 'تحكم', 'في', 'ناقل', 'الحركة', 'عن', 'طريق', 'عجلة', 'القيادة', 'مثل', ':', 'فتحة', 'السقف', 'او', 'الوسائد', 'الهوائية', 'الكماليات', 'والمواصفات', 'الإضافية', 'إغلاق', 'عجلة', 'قيادة', 'متعددة', 'الوظائف', 'برنامج', 'التحكم', 'في', 'ثبات', 'السيارة', 'الإلكتروني', '(', 'ESP', ')', 'جهاز', 'ملاحة', 'حساسات', 'ركن', 'خلفية', 'تحكم', 'في', 'ناقل', 'الحركة', 'عن', 'طريق', 'عجلة', 'القيادة', 'مسح', 'الكل', 'تطبيق', 'عربيات', 'يمكنك', 'تقسيطها', 'مع', 'كونتكت', 'إعادة', 'الضبط', 'عرض', 'الكل', 'مواصفات', 'وأسعار', 'العربيات', 'الجديدة', 'من', 'الوكيل', 'في', 'مصر', 'التجار', 'والمعارض', 'شركة', 'المهندس', 'اوتوموتيف', 'خالد', 'عبود', 'أوتوموتيف', 'الليثى', 'أوتو', 'جروب', 'سيارات', 'القرش', 'روابط', 'سريعة', 'عربيات', 'جديدة', 'عربيات', 'مستعملة', 'معارض', 'أخبار', 'تقييمات', 'خدمات', 'حجز', 'صيانة', 'تقسيط' ...
# ---------------------------------
# ['English', 'English', 'Dual', 'Clutch', 'CVT', 'PDK', 'SUV', 'ESP', 'ESP', 'Please', 'JavaScript']
# ['الخميس', '27', 'أبريل', '2023', 'مصراوي', 'لايف', 'الأكثر', 'قراءة', 'الآن', 'أرشيف', 'مصراوى', 'مواقيت', 'الصلاة', '30', 'القاهرة', '-', 'مصر', '30', '16', 'الرطوبة', ':', '22', '%', 'الرياح', ':', 'شمال', 'شرق', 'المزيد', 'أسعار', 'العملات', 'سعر', 'صرف', 'الدولار', 'مقابل', 'الجنيه', 'المصري', 'الخميس', '27', 'أبريل', '2023', '30.93', 'جنيه', 'المزيد', 'أسعار', 'الذهب', 'سعر', 'جرام', 'الذهب', 'عيار', '21', 'الخميس', '27', 'أبريل', '2023', '2655', 'جنيه', 'المزيد', 'سوق', 'مصراوي', 'للإعــلان', 'أكثر', 'الكلمات', 'انتشاراً', 'أحداث', 'السودان', 'مسلسلات', 'رمضان', '2023', 'الطقس', 'سعر', 'الدولار', 'زيادة', 'الأجور', 'سعر', 'الفائدة', 'سعر', 'الذهب', 'أمازون', 'محاكمة', 'ترامب', 'تم', 'إكتشاف', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", 'عزيزي', 'المستخدم', 'العائد', 'من', 'الإعلانات', 'يمثل', 'مصدر', 'الربح', 'الأساسي', 'للموقع', 'والعاملين', 'به', 'مما', 'يساعدنا', 'على', 'البقاء', 'مستقلين', 'وحياديين', 'حيث', 'أننا', 'غير', 'تابعين', 'لأي', 'جهة', 'حكومية', 'أو', 'حزب', '.', 'لمساعدتنا', 'على', 'الإستمرار', 'في', 'إنتاج', 'محتوى', 'مهني', 'صحفي', 'حيادي', 'غير', 'موجه', 'أو', 'ممول', 'نرجو', 'إلغاء', 'تفعيل', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", '.', 'شكرا', 'لتفهمك', 'أخبار', 'السيارات', 'نصائح', '``', 'العربية', 'تلتت', "''", '..', 'ما', 'معنى', 'ذلك', 'وأين', 'سبب', 'المشكلة؟', 'أخبار', 'السيارات', '``', 'سيطرت', 'على', 'قلوب', 'المصريين', "''", '..', '5', 'سيارات', 'يابانية', 'وفرنسية', '``', 'أتوماتيك', "''", 'تبدأ', 'أخبار', 'السيارات', 'للمقبلين', 'على', 'الشراء', '..', 'ابتعد', 'عن', 'شراء', 'هذه', 'السيارات', '«', 'لو', 'ببلاش', '»', 'أخبار', 'السيارات', '``', 'وفر', 'على', 'نفسك', "''", '..', 'هذه', 'السيارات', 'ستجنبك', 'المخالفات', 'المرورية', 'أخبار', 'السيارات', 'زيوت', 'الطعام', 'المستعملة', 'فرصة', 'واعدة', 'لإنتاج', 'وقود', 'سيارات', 'صديق', 'للبيئة', 'نصائح', 'أبرزها', '``', 'الكركرة', "''", '..', 'ظهور', 'هذه', 'العلامات', 'بالسيارة', 'دليل', 'على', 'تلف', 'البوجيهات', 'إعلان', 'إعلان', 'مقالات', 'مصراوي', 'المزيد', 'موسم', 'الإكراه', 'الدرامي', 'في', 'رمضان', '!', 'علاء', 'الغطريفي', '25', 'أبريل', ',', '2023', 'خط', 'أحمر', '..', 'لو', 'أنها', 'أنصتت', 'سليمان', 'جودة', '23', 'أبريل', ',', '2023', 'نجوم', 'بلا', 'قيمة', 'د', '.', 'أحمد', 'عبدالعال', 'عمر', '23', 'أبريل', ',', '2023', 'ملفات', 'تفاعلية', 'المزيد', 'أجنبي', 'بطلة', 'فيلم', '``', 'كليوباترا', "''", 'تواصل', 'استفزاز', 'مهاجمين', '``', 'نتفليكس', "''", ':', '``', 'أسبوعين', 'بأمر', 'مدارس', 'أولياء', 'أمور', 'الثانوية', 'العامة', '2023', 'عن', 'قرار', 'تقليل', 'عدد', 'الأسئلة', 'الاختيارية', ':', 'مصراوى', 'TV', 'المزيد', 'أحدث', 'موضوعات', 'السيارات', 'نصائح', '``', 'العربية', 'تلتت', "''", '..', 'ما', 'معنى', 'ذلك', 'وأين', 'سبب', 'المشكلة؟', 'أخبار', 'السيارات', '``', 'سيطرت', 'على', 'قلوب', 'المصريين', "''", '..', '5', 'سيارات', 'يابانية', 'وفرنسية', '``', 'أتوماتيك', "''", 'تبدأ', 'أخبار', 'السيارات', 'قبل', '``', 'التعويم', 'المتوقع', "''", '..', 'تعرف', 'على', 'أسعار', '5', 'موتوسيكلات', 'بالأسواق', 'اليوم', 'أخبار', 'السيارات', 'للمقبلين', 'على', 'الشراء', '..', 'ابتعد', 'عن', 'شراء', 'هذه', 'السيارات', '«', 'لو', 'ببلاش', '»', 'أخبار', 'السيارات', '``', 'وفر', 'على', 'نفسك', "''", '..', 'هذه', 'السيارات', 'ستجنبك', 'المخالفات', 'المرورية', 'أخبار', 'السيارات', 'هل', 'تتراجع', 'أسعار', 'السيارات', 'بمصر', 'مجددا؟', 'أخبار', 'السيارات', 'ماكلارين', 'تطلق', 'سيارتها', '750S', 'السوبر', 'رياضية', 'مقابل', 'هذا', 'السعر', 'أخبار', 'السيارات', 'زيوت', 'الطعام', 'المستعملة', 'فرصة', 'واعدة', 'لإنتاج', 'وقود', 'سيارات', 'صديق', 'للبيئة', 'أخبار', 'السيارات', 'تويوتا', 'تسجل', 'مستوى', 'قياسيا', 'في', 'الإنتاج', 'خلال', 'العام', 'الماضي', 'أخبار', 'السيارات', '«', 'الحق', 'اشتري', '»', '..', 'تعرف', 'على', 'أرخص', '5', 'سيارات', 'فى', 'مصر', 'قبل', 'التعويم', 'المتوقع', 'برعاية', 'أخبار', 'الاقتصاد', 'والـ', 'Startups', 'المزيد', 'إعلان', 'نصائح', 'المزيد', '``', 'العربية', 'تلتت', "''", '..', 'ما', 'معنى', 'ذلك', 'وأين', 'سبب', 'المشكلة؟', 'أبرزها', '``', 'الكركرة', "''", '..', 'ظهور', 'هذه', 'العلامات', 'بالسيارة', ' ...
# ---------------------------------
# ['AD', 'Block', 'AD', 'Block', 'TV', '750S', 'Startups', 'Q2', 'Cross', 'Media', 'TV']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'مشاركة', 'send', 'أسعار', 'السيارات', 'الرسمية', 'محدثة', 'يوميا', 'في', 'مصر', 'لعام', '2022', '-', '2023', 'كل', 'الماركات', 'والموديلات', 'الجديدة', 'ومواصفات', 'وصور', 'السيارات', 'الجديدة', 'في', 'مصر', 'والمعارض', 'المتاحة', 'بها', 'من', 'خلال', 'موقعنا', 'سوق', 'السيارات', 'أفضل', 'خدمة', 'مجانية', 'لبيع', 'وشراء', 'السيارات', '.', 'أنظر', 'أيضا', 'أسعار', 'السيارات', 'المستعملة', 'كل', 'الماركات', 'آخر', 'تحديث', '(', '2023-04-27', ')', 'لا', 'يوجد', 'نتائج', 'شيفروليه', 'كيا', 'بيجو', 'هيونداي', 'فيات', 'سكودا', 'اوبل', 'دى', 'اس', 'بى', 'واى', 'دى\u202c', 'رينو', 'تويوتا', 'هوندا', 'استون', 'مارتن', 'بروتون', 'بيستون', 'ميتسوبيشي', 'جاك', 'سوزوكى', 'بايك', 'فورد', 'كاي', 'ي', 'مازدا', 'مينى', 'فولفو', 'دونج', 'فنج', 'بريليانس', 'سيات', 'كوبرا', 'نيسان', 'ام', 'جى', 'فولكس', 'فاغن', 'دفسك', 'الفاروميو', 'فورثينج', 'بورش', 'سوبارو', 'شانجى', 'بي', 'ام', 'دبليو', 'سانج', 'يونج', 'اودي', 'شانجان', 'مرسيدس', 'هافال', 'سيتروين', 'لكزس', 'جاكوار', 'ساوايست', 'لاند', 'روفر', 'جيب', 'مازيراتي', 'لادا', 'جيتور', 'جيلي', 'شيرى', 'أختر', 'متوسط', 'السعر', 'أقل', 'من', '150,000', '150,000', '-', '175,000', '175,000', '-', '200,000', '20 ...
# ---------------------------------
# ['English', 'CC', 'M50', 'CC', 'CC', 'Comfort', 'CC', 'Comfort', 'Accessories', 'CC', 'CC', 'E1', 'CC', 'F3', 'CC', 'E2', 'CC', 'CC', 'Midline', 'CC', 'F3', 'CC', 'Super', 'Saloon', 'CC', 'L3', 'GLX-i', 'AT', 'CC', 'Luxury', 'CC', 'Luxury', 'Accessories', 'CC', 'L3', 'GS-i', 'AT', 'CC', 'CC', 'CC', 'E1', 'CC', 'Comfort', 'CC', 'C3', 'Live', 'CC', 'CC', 'L1', 'CC', 'V6', 'Deluxe', 'CC', 'BASIC', 'CC', 'GA', 'CC', 'Active', 'CC', 'CC', 'GL', 'CC', 'V6', 'Grand', 'Deluxe', 'CC', 'Luxury', 'CC', 'C3', 'Feel', 'CC', 'LX', 'CC', 'High', 'Line', 'CC', 'GL', 'Alloy', 'CC', 'RB', 'TINTED', 'GLASS', 'CC', 'DX3', 'Highline', 'CC', 'L1', 'CC', 'DX3', 'Highline', 'Two', 'Tone', 'CC', 'C3', 'Feel', 'CC', 'CC', 'Active', 'CC', 'F3', 'CC', 'RB', 'SR', 'TINTED', 'GLASS', 'CC', 'Premium', 'SV', 'CC', 'LX-S', 'CC', 'Allure', 'CC', 'RB', 'DAB', 'ABS', 'TINTED', 'GLASS', 'CC', 'Premium', 'SV', 'CC', 'Hatla2ee.com']
# ['Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'AdWords', ':', '830020857', 'مصر', 'الإمارات', 'السعودية', 'قطر', 'عُمان', 'الكويت', 'البحرين', 'EN', 'جديد', 'مستعمل', 'تجارب', 'القيادة', 'أخبار', 'السيارات', 'فيديوهات', 'السيارات', 'خدمات', 'استيراد', 'السيارات', 'المزيد', 'أعلن', 'معنا', 'شركات', 'السيارات', 'بيع', 'سيارتك', 'دخول', '|', 'تسجيل', 'sidebar', 'دخول', '|', 'تسجيل', 'بيع', 'سيارتك', 'مجاني', 'دليل', 'شراء', 'السيارات', 'سيارات', 'مستعملة', 'استيراد', 'السيارات', 'جديد', 'أخبار', 'السيارات', 'فيديوهات', 'السيارات', 'المزيد', 'مصر', 'EN', 'single', 'items', 'sideoverlay', 'سيارات', 'مستعملة', 'ابحث', 'عن', 'سيارات', 'مستعملة', 'تصفح', 'السيارات', 'المستعملة', 'سيارات', 'مستعملة', 'للتصدير', 'دليل', 'شراء', 'السيارات', 'تصفح', 'دليل', 'السيارات', 'الجديدة', 'ابحث', 'عن', 'سيارات', 'جديدة', 'قارن', 'بين', 'السيارات', 'الجديدة', 'أسعار', 'السيارات', 'قاموس', 'السيارات', 'أخبار', 'السيارات', 'آخر', 'المشاركات', 'أخبار', 'السيارات', 'القيادات', 'الاولى', 'إطلاقات', 'السيارات', 'الجديدة', 'تجارب', 'القيادة', 'المزيد', 'أعلن', 'معنا', 'شركات', 'السيارات', 'اختر', 'الدولة', 'الإمارات', 'السعودية', 'قطر', 'عُمان', 'الكويت', 'البحرين', 'ابحث', 'عن', 'سيارات', 'مستعملة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'تصفح', 'السيارات', 'المستعملة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'سيارات', 'مستعملة', 'للاستيراد', 'جديد', 'حمل', 'الأن', 'تطبيق', 'يلاموتور', 'الجديد', '!', 'وتواصل', 'بسهولة', 'مع', 'البائعين', 'عبر', 'الهاتف', 'أو', 'الرسائل', 'النصية', 'أو', 'الواتساب', 'هل', 'تريد', 'بيع', 'سيارتك؟', 'تصفح', 'دليل', 'السيارات', 'الجديدة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'ابحث', 'عن', 'سيارات', 'جديدة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'قارن', 'بين', 'السيارات', 'الجديدة', 'مقارنة', 'بين', 'أكثر', 'السيارات', 'شهرة', 'VS', 'ميتسوبيشي', 'باجيرو', '2020', 'من', '1,650,000', 'ج.م', 'تويوتا', 'فورتشنر', '2020', 'من', '739,900', 'ج.م', 'قارن', 'VS', 'تويوتا', 'لاند', 'كروزر', '2020', 'TBD', 'نيسان', 'باترول', '2020', 'من', '3,500,000', 'ج.م', 'قارن', 'VS', 'رينو', 'داستر', '2018', 'من', '210,000', 'ج.م', 'دايهتسو', 'تيريوس', '2018', 'TBD', 'قارن', 'VS', 'ميتسوبيشي', 'باجيرو', '2018', 'من', '1,000,000', 'ج.م', 'تويوتا', 'فورتشنر', '2018', 'من', '1,000,000', 'ج.م', 'قارن', 'اعرض', 'جميع', 'مقارنات', 'السيارات', 'الجديدة', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'الجديدة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'اعرض', 'جميع', 'أسعار', 'السيارات', 'جديد', 'حمل', 'الأن', 'تطبيق', 'يل ...
# ---------------------------------
# ['Global', 'Google', 'AdWords', 'EN', 'EN', 'VS', 'VS', 'TBD', 'VS', 'TBD', 'VS', 'AUX', 'ABS', 'READ', 'MORE', 'Tab', 'Container', 'Browse', 'Make', 'Paid', 'Full', 'Banner', 'Sell', 'FREE', 'Spotlight', 'TBD', 'TBD', 'TBD', 'TBD', 'TBD', 'modelsCards', 'H2', 'Z100', 'S-Presso', 'modelsCards', 'Z560', 'modelsCards', 'HR-V', 'C5', 'Aircross', 'modelsCards', 'Crossback', 'VS', 'VS', 'TBD', 'VS', 'TBD', 'VS', 'VS', 'TBD', 'VS', 'VS', 'VS', 'VS', 'VS', 'VS', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'Venue', 'Z', 'ZS', 'GT', 'Crossland', 'X', 'Grandland', 'X', 'Crossland', 'Kamiq', 'Scala', 'Video', 'Section', 'Popular', 'Subscribe', 'Now', 'Toyota', 'LandCruiser', 'Opel', 'Mokka', 'SUV', 'Hyundai', 'Veloster', 'N', 'Lotus', 'Exige', 'Ford', 'Mustang', 'Mach', 'Changan', 'CS75', 'Plus', 'McLaren', 'GT', 'News', 'Latest', 'News', 'UAE', 'JETOUR', 'Anas', 'Assaf', 'Anas', 'Assaf', 'Anas', 'Assaf', 'HONGQI', 'H9', 'Anas', 'Assaf', 'Make', 'Modal', 'Popover', 'Footer', 'Footer', 'Footer', 'DEKSTOP', 'YALLAMOTOR.COM', 'EN', 'YallaMotor.com', 'Facebook', 'Pixel', 'Code', 'End', 'Facebook', 'Pixel', 'Code']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'سيارات', 'للبيع', 'سوق', 'السيارات', ':', 'سيارات', 'مستعملة', 'للبيع', 'في', 'مصر', 'سيارات', 'للبيع', '،', 'سوق', 'السيارات', 'المستعملة', 'يحتوي', 'علي', 'أكثر', 'من', '17157', 'سيارة', 'للبيع', 'في', 'مصر', '،', 'تستطيع', 'البحث', 'عن', 'أي', 'ماركة', 'و', 'موديل', 'أو', 'مدينة', 'أو', 'عدد', 'الكيلوميترات', 'أو', 'السعر', 'بسهولة', 'وسرعة', '.', 'إخترماركة', 'الاسعار', 'نوع', 'السيارة', 'slow_motion_video', 'سيارات', 'حالة', 'خاصة', 'السعة', 'اللترية', 'ابحث', 'عن', 'سيارة', 'للبيع', 'هيونداي', '(', '1803', ')', 'شيفروليه', '(', '1288', ')', 'فيات', '(', '1134', ')', 'نيسان', '(', '1131', ')', 'كيا', '(', '1090', ')', 'رينو', '(', '804', ')', 'تويوتا', '(', '720', ')', 'ميتسوبيشي', '(', '668', ')', 'مرسيدس', '(', '600', ')', 'اوبل', '(', '543', ')', 'سكودا', '(', '520', ')', 'بيجو', '(', '515', ')', 'موديلات', 'أخرى', '10,000', 'جنيه', '20,000', 'جنيه', '30,000', 'جنيه', '50,000', 'جنيه', '75,000', 'جنيه', '100,000', 'جنيه', '120,000', 'جنيه', '150,000', 'جنيه', '200,000', 'جنيه', '250,000', 'جنيه', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'سيدان', '(', '11451', ')', 'SUV', '(', '2322', ')', 'هاتشباك', '(', '1846', ')', '4x4', '(', '50 ...
# ---------------------------------
# ['English', 'SUV', 'SUV', 'PLUS', 'XD', 'XD', 'HIGHLINE', 'TINTED', 'GLASS', 'F3', 'F3', 'F3', 'F3', 'Highline', 'HIGHLINE', 'TINTED', 'GLASS', 'A5', 'A5', 'Comfort', 'CS', 'CS', 'C', 'C', 'K3', 'K3', 'E', 'E', 'AMG', 'F3', 'F3', 'LX', 'Grand', 'I10', 'I10', 'Ambition', 'Hatla2ee.com']
# ['الخميس', '27', 'أبريل', '2023', 'مصراوي', 'لايف', 'الأكثر', 'قراءة', 'الآن', 'أرشيف', 'مصراوى', 'مواقيت', 'الصلاة', '30', 'القاهرة', '-', 'مصر', '30', '16', 'الرطوبة', ':', '22', '%', 'الرياح', ':', 'شمال', 'شرق', 'المزيد', 'أسعار', 'العملات', 'سعر', 'صرف', 'الدولار', 'مقابل', 'الجنيه', 'المصري', 'الخميس', '27', 'أبريل', '2023', '30.93', 'جنيه', 'المزيد', 'أسعار', 'الذهب', 'سعر', 'جرام', 'الذهب', 'عيار', '21', 'الخميس', '27', 'أبريل', '2023', '2655', 'جنيه', 'المزيد', 'سوق', 'مصراوي', 'للإعــلان', 'أكثر', 'الكلمات', 'انتشاراً', 'أحداث', 'السودان', 'مسلسلات', 'رمضان', '2023', 'الطقس', 'سعر', 'الدولار', 'زيادة', 'الأجور', 'سعر', 'الفائدة', 'سعر', 'الذهب', 'أمازون', 'محاكمة', 'ترامب', 'تم', 'إكتشاف', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", 'عزيزي', 'المستخدم', 'العائد', 'من', 'الإعلانات', 'يمثل', 'مصدر', 'الربح', 'الأساسي', 'للموقع', 'والعاملين', 'به', 'مما', 'يساعدنا', 'على', 'البقاء', 'مستقلين', 'وحياديين', 'حيث', 'أننا', 'غير', 'تابعين', 'لأي', 'جهة', 'حكومية', 'أو', 'حزب', '.', 'لمساعدتنا', 'على', 'الإستمرار', 'في', 'إنتاج', 'محتوى', 'مهني', 'صحفي', 'حيادي', 'غير', 'موجه', 'أو', 'ممول', 'نرجو', 'إلغاء', 'تفعيل', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", '.', 'شكرا', 'لتفهمك', 'إعلان', 'الرئيسية', 'سيارات', 'أخبار', 'السيارات', '«', 'الحق', 'اشتري', '»', '..', 'تعرف', 'على', 'أرخص', '5', 'سيارات', 'فى', 'مصر', 'قبل', 'التعويم', 'المتوقع', '10:30', 'ص', 'الخميس', '27', 'أبريل', '2023', 'أرخص', 'سيارات', 'فى', 'مصر', '-', 'أرشيفية', 'تابع', 'صفحتنا', 'على', 'أخبار', 'جوجل', 'تابع', 'صفحتنا', 'على', 'فيسبوك', 'تابع', 'صفحتنا', 'على', 'يوتيوب', 'كتب', '-', 'محمد', 'جمال', ':', 'يتوقع', 'مراقبون', 'وخبراء', 'أن', 'تتخذ', 'المجموعة', 'الاقتصادية', 'بمجلس', 'الوزراء', 'خلال', 'الأيام', 'القليلة', 'المقبلة،', 'قرارًا', 'بتحرير', 'جديد', 'لأسعار', 'الجنيه', 'أمام', 'الدولار', 'الأمريكي،', 'ليكون', 'التعويم', 'الرابع', 'للعملة', 'المصرية', 'منذ', 'شهر', 'مارس', 'من', 'عام', '2022', 'المنقضي', '.', 'الزيادة', 'المرتقبة', 'بأسعار', 'الدولار', 'قد', 'تصل', 'إلى', '15', '%', 'ومن', 'المتوقع', 'أن', 'تقود', 'أسعار', 'غالبية', 'السلع', 'المتوفرة', 'بالسوق', 'نحو', 'الزيادة،', 'الأمر', 'الذي', 'يدفع', 'البعض', 'للإسراع', 'بشراء', 'احتياجاتهم', 'قبل', 'الإعلان', 'رسميًا', 'عن', 'تحرير', 'الأسعار', '.', 'وتوالت', 'خلال', 'الأسابيع', 'الماضية', 'التقارير', 'الصادرة', 'عن', 'مؤسسات', 'اقتصادية', 'كبرى', 'تتحدث', 'عن', 'اقتراب', 'التعويم،', 'ومن', 'بين', 'تلك', 'المؤسسات', 'موديز', 'وإتش', 'إس', 'بي', 'سي', 'اللذين', 'توقعا', 'أن', 'يتراوح', 'سعر', 'الدولار', 'الواحد', 'ما', 'بين', '35', 'و37', 'جنيه', '.', 'أما', 'ستاندرد', 'أند', 'بورز', 'الأمريكية', 'فقد', 'ذهبت', 'بتوقعاتها', 'إلى', 'سقف', 'أعلى،', 'إذ', 'توقعت', 'أن', 'يصل', 'الدولار', 'إلى', '40', 'جنيهًا', 'بنهاية', 'يونيو', 'القادم', 'مقابل', '30.90', 'جنيه', 'بالبنوك', 'المصرية', 'اليوم', '.', 'ويرصد', 'التقرير', 'التالي', 'أسعار', 'ومواصفات', 'أرخص', '5', 'سيارات', 'بالسوق', 'المصري', 'جديدة', 'ورخيصة', 'بنفس', 'الوقت،', 'رغم', 'كافة', 'الأزمات', 'والصعوبات', 'التي', 'يمر', 'بها', 'قطاع', 'السيارات', 'فى', 'مصر؛', 'والتي', 'تتنوع', 'مابين', 'هاتشباك', 'وسيدان', 'عائلية', 'وتبدأ', 'من', '300', 'ألف', '.', 'ومن', 'خلال', 'الصفحات', 'التالية', 'يمكن', 'التعرف', 'على', 'السيارات', 'الـ', '5', ':', '1', '2', '3', '4', '5', '6', 'التالى', 'سوق', 'مصراوى', 'أفضل', 'شنطة', 'لاب', 'توب', 'وهارد', 'ديسك', 'خارجي', 'بخصومات', 'حتى', '49', '%', 'تفاصيل', 'أفضل', 'جراب', 'للهاتف', 'الذكي', '2023', 'يبدأ', 'من', '39', 'جنيها', 'تفاصيل', 'أحدث', 'صيحات', 'الساعة', 'الرجالية', 'لتواكب', 'موضة', 'تبدأ', 'من', '115', 'جنيها', 'تفاصيل', 'أفضل', 'بودي', 'سبلاش', 'للجسم', 'بروائح', 'الربيع', 'يبدأ', 'من', '36', 'جنيها', 'تفاصيل', '``', 'اعملها', 'بنفسك', "''", '..', 'كيف', 'تتأكد', 'إذا', 'كانت', 'السيارة', '``', 'فبريكة', 'أم', 'رشة', "''", 'قبل', 'الشراء', 'تفاصيل', 'أفضل', 'سماعات', 'سلكية', 'للرد', 'على', 'المكالمات', 'وسماع', 'الموسيقى', 'تبدأ', 'من', '48', 'جنيها', 'تفاصيل', 'تعويم', 'الجنيه', 'عالم', 'السيارات', 'أرخص', 'سيارات', 'بمصر', 'سوزوكي', 'شانجان', 'فيديو', 'قد', 'يعجبك', ':',  ...
# ---------------------------------
# ['AD', 'Block', 'AD', 'Block', '750S', '750S', 'El', 'Market', 'Cross', 'Media', 'TV']
# ['<', '!', '[', 'endif', ']', '[', 'if', 'lt', 'IE', '9', ']', '>', '<', 'link', 'rel=', "''", 'stylesheet', "''", 'href=', "''", '/content/css/ie_8.css', "''", '>', '<', 'script', 'src=', "''", 'http', ':', '//html5shim.googlecode.com/svn/trunk/html5.js', "''", '>', '<', '/script', '>', '<', '!', '[', 'endif', ']', 'Google', 'Tag', 'Manager', 'End', 'Google', 'Tag', 'Manager', 'Start', ':', 'GPT', 'Sync', 'add', 'Fix', 'rejected', 'ad', 'requests', 'from', 'all', 'other', 'domains', 'sticky', 'Anchour', 'Ad', '/6419244/Sticky', 'Google', 'Tag', 'Manager', '(', 'noscript', ')', 'End', 'Google', 'Tag', 'Manager', '(', 'noscript', ')', 'عدد', 'اليوم', 'independent', 'زى', 'النهاردة', 'start_menu_wrap', 'الرئيسية', 'أخبار', 'سياسة', 'اقتصاد', 'رأي', 'حوادث', 'ملاعب', 'محافظات', 'أسوان', 'أسيوط', 'الإسكندرية', 'الإسماعيلية', 'الأقصر', 'البحر', 'الأحمر', 'البحيرة', 'الجيزة', 'الدقهلية', 'السويس', 'الشرقية', 'الغربية', 'الفيوم', 'القاهرة', 'القليوبية', 'المنوفية', 'المنيا', 'الوادي', 'الجديد', 'بني', 'سويف', 'بورسعيد', 'جنوب', 'سيناء', 'دمياط', 'سوهاج', 'شمال', 'سيناء', 'قنا', 'كفر', 'الشيخ', 'مرسى', 'مطروح', 'خدماتي', 'خدمات', 'حكومية', 'اخبار', 'الملاعب', 'أسعار', 'الذهب', 'والعملات', 'اسواقي', 'فرص', 'ووظائف', 'عروض', 'فنيه', 'وترفيه', 'جامعات', 'ومدارس', 'مواقيت', 'الصلاة', 'وفتاوي', 'خدمات', 'السفارات', 'أخبار', 'الطقس', 'مواعيد', 'السفر', 'أخبار', 'الجريدة', 'الرسمية', 'المزيد', 'هو', 'و', 'هي', 'عرب', 'وعالم', 'المصري', 'أوتو', 'تحقيقات', 'وحوارات', 'فنون', 'ثقافة', 'علوم', 'وتكنولوجيا', 'منوعات', 'وسط', 'الناس', 'سياحة', 'وطيران', 'اعترافات', 'جريئة', 'فيروس', 'كورونا', 'المصري', 'Fact', 'صحتك', 'بالدنيا', 'خدماتي', 'توك', 'شو', 'بث', 'مباشر', 'معلومة', 'كأس', 'العالم', '٢٠٢٢', 'السكوت', 'ممنوع', 'زي', 'النهاردة', 'شكاوى', 'المواطنين', 'pdf', 'أيقونة', 'camera_icon', 'paint_icon', 'End', 'Top', 'Bar', 'start_internal_menu_wrap', 'مشاركة', 'x', 'AMAY-Take-Over-Page', '/6419244/Almasryamayotp', 'AMAY-Take-Over-Home-Page-Left', '/6419244/AMAY-Take-Over-Home-Page-Left', 'AMAY-Take-Over-Home-Page', '/6419244/AMAY-Take-Over-Home-Page', 'Start', 'ads_wrap', 'AMAY_MAIN_BANNER', '/6419244/AMAY_MAIN_BANNER', 'End', 'ads_wrap', 'Start', 'article_slider', 'End', 'article_slider', 'Start', 'Inner', 'Pages', 'Start', 'Content', 'الشروط', 'اللازمة', 'للحصول', 'على', 'سيارات', 'معاقين', '2023', '(', 'الأسعار', 'والتفاصيل', ')', 'سيارات', 'معاقين', 'معفاة', 'من', 'الجمارك', '2023', 'الخميس', '27-04-2023', '16:55', '|', 'كتب', ':', 'حنان', 'الوالي', '|', 'Custom', 'Sharing', 'Buttons', 'BEGIN', 'Custom', 'Sharing', 'Buttons', 'END', 'الأسعار', 'والتفاصيل', '..', 'الشروط', 'اللازمة', 'للحصول', 'على', 'سيارات', 'معاقين', '2023', 'تصوير', ':', 'آخرون', 'سيارات', 'المعاقين', '2023', '..', 'ازدادت', 'معدلات', 'البحث', 'الفترة', 'الأخيرة', 'عن', 'سيارات', 'معفاة', 'من', 'الجمارك', '،', 'خاصة', 'من', 'قبل', 'ذوي', 'الإعاقة', 'في', 'مصر،', 'وقد', 'منحت', 'الدولة', 'مجموعة', 'من', 'الامتيازات', 'للمعاقين', 'في', 'حالة', 'الحصول', 'على', 'سيارات', 'المعاقين', '.', 'ويأتي', 'ذلك', 'وفقا', 'لقرار', 'أعلنته', 'وزارة', 'التضامن', 'الاجتماعي', 'في', 'تصريحات', 'سابقة،', 'ويحاول', 'الكثير', 'معرفة', 'شروط', 'الحصول', 'على', 'سيارات', 'معاقين', '.', 'وهو', 'ما', 'تقدمه', 'بوابة', '«', 'المصري', 'اليوم', '»', 'لقرائها', 'خلال', 'السطور', 'التالية', '.', 'أخبار', 'متعلقة', 'خطوات', 'وشروط', 'الحصول', 'على', 'سيارات', 'المعاقين', '2023', 'بالتفاصيل', 'والأسعار', '..', 'الشروط', 'اللازمة', 'للحصول', 'على', 'سيارات', 'معاقين', '2022', 'نشرة', 'أخبار', 'المصري', 'اليوم', 'الاقتصادية', ':', 'شروط', 'الحصول', 'على', 'سيارة', 'معاقين', 'معفاه', 'من', 'الجمارك', '2022', 'في', 'ضوء', 'قرارات', '«', 'التضامن', '»', '..', 'والمركزي', 'الصيني', 'يقدم', 'قروضًا', 'ميسرة', 'لشراء', 'سندات', 'المطورين', 'شروط', 'الحصول', 'على', 'سيارة', 'معاقين', '2023', 'الأسعار', 'والتفاصيل', '..', 'الشروط', 'اللازمة', 'للحصول', 'على', 'سيارات', 'معاقين', '2023', 'يحصل', 'المتقدم', 'على', 'سيارة', 'معاقين', 'معفاة', 'من', 'الجمارك', 'في', 'ضوء', 'توافر', 'مجموعة', 'من', 'الشروط', 'منها', ': ...
# ---------------------------------
# ['IE', 'Tag', 'Manager', 'Tag', 'Manager', 'GPT', 'Sync', 'Fix', 'Anchour', '/6419244/Sticky', 'Tag', 'Manager', 'Tag', 'Manager', 'Fact', 'Top', 'Bar', 'AMAY-Take-Over-Page', '/6419244/Almasryamayotp', 'AMAY-Take-Over-Home-Page-Left', '/6419244/AMAY-Take-Over-Home-Page-Left', 'AMAY-Take-Over-Home-Page', '/6419244/AMAY-Take-Over-Home-Page', 'AMAY_MAIN_BANNER', '/6419244/AMAY_MAIN_BANNER', 'Pages', 'Custom', 'BEGIN', 'Custom', 'Octavia', 'A4', 'أفانتيHD', 'A5', 'XD', 'googletag.defineSlot', "'/6419244/AFF_Desktop", '.addService', '.enableSingleRequest', 'googletag.enableServices', '/6419244/AFF_Desktop', 'Tags', 'Tags', 'start-Desktop_video', '/6419244/Desktop_video', 'end-Desktop_video', 'Custom', 'BEGIN', 'Custom', 'Opt', 'Opt', 'ReTabs', 'ReTabs', 'SeeAlso', 'SeeAlso', 'FB', 'FB', 'CommentSript', 'Sidbar', 'ADS', 'AMAY_SHOWCASE_1', '/6419244/AMAY_SHOWCASE_1', 'ADS', 'TopNews', 'TopNews', 'Speakol', 'Join', 'Join', 'VIO', 'VIO', 'Photo', 'Photo', 'ADS', 'AMAY_SHOWCASE_2', '/6419244/AMAY_SHOWCASE_2', 'ADS', 'newsTabs', 'newsTabs', 'E-Class', 'BMW', 'ADS', 'AMAY_SHOWCASE_1', '/6419244/Half_page', 'Sidbar', 'Off', 'Pages', 'Analytics', 'Targets', 'Analytics', 'Targets', 'Fact', 'SERVER_IP', 'Ex', 'S248', 'To', 'Top']

# %%
stop_words = set(nltk.corpus.stopwords.words("arabic"))
from nltk.stem.isri import ISRIStemmer
import re
st = ISRIStemmer()

# w=filtered_sentence
for word in word_tokens:
    if word not  in stop_words:
    #won't take the input correctly, input = output of tokenization# w= 'كلمات'
        print(word+"-->"+st.stem(word))
        u=st.stem(word)

# import nltk

# from nltk.stem.porter import *
# p_stemmer = PorterStemmer()




# for word in  filtered_sentence:
#     print(word+' --> '+p_stemmer.stem(word))

# from nltk.stem.snowball import SnowballStemmer
# s_stemmer = SnowballStemmer(language='english')



# for word in filtered_sentence:
#     print(word+' --> '+s_stemmer.stem(word))
# u=p_stemmer.stem(word)
# Out:
# <--><
# !-->!
# [-->[
# endif-->endif
# ]-->]
# [-->[
# if-->if
# lt-->lt
# IE-->IE
# 9-->9
# ]-->]
# >-->>
# <--><
# link-->link
# rel=-->rel=
# ''-->''
# stylesheet-->stylesheet
# ''-->''
# href=-->href=
# ''-->''
# /content/css/ie_8.css-->/content/css/ie_8.css
# ''-->''
# >-->>
# <--><
# script-->script
# src=-->src=
# ''-->''
# http-->http
# :-->:
# //html5shim.googlecode.com/svn/trunk/html5.js-->//html5shim.googlecode.com/svn/trunk/html5.js
# ''-->''
# >-->>
# <--><
# /script-->/script
# >-->>
# <--><
# !-->!
# [-->[
# endif-->endif
# ]-->]
# Google-->Google
# Tag-->Tag
# Manager-->Manager
# End-->End
# Google-->Google
# Tag-->Tag
# Manager-->Manager
# Start-->Start
# :-->:
# GPT-->GPT
# Sync-->Sync
# add-->add
# Fix-->Fix
# rejected-->rejected
# ad-->ad
# requests-->requests
# from-->from
# all-->all
# other-->other
# domains-->domains
# sticky-->sticky
# Anchour-->Anchour
# Ad-->Ad
# /6419244/Sticky-->/6419244/Sticky
# Google-->Google
# Tag-->Tag
# Manager-->Manager
# (-->(
# noscript-->noscript
# )-->)
# End-->End
# Google-->Google
# Tag-->Tag
# Manager-->Manager
# (-->(
# noscript-->noscript
# )-->)
# عدد-->عدد
# اليوم-->اليوم
# independent-->independent
# زى-->زى
# النهاردة-->هرد
# start_menu_wrap-->start_menu_wrap
# الرئيسية-->رئس
# أخبار-->خبر
# سياسة-->سيس
# اقتصاد-->قصد
# رأي-->رأي
# حوادث-->حدث
# ملاعب-->لعب
# محافظات-->حفظ
# أسوان-->اسو
# أسيوط-->سيط
# الإسكندرية-->اسكندرية
# الإسماعيلية-->اسماعيلية
# الأقصر-->قصر
# البحر-->بحر
# الأحمر-->حمر
# البحيرة-->بحر
# الجيزة-->جيز
# الدقهلية-->دقهل
# السويس-->سوس
# الشرقية-->شرق
# الغربية-->غرب
# الفيوم-->فيم
# القاهرة-->قهر
# القليوبية-->قليوب
# المنوفية-->وفي
# المنيا-->نيا
# الوادي-->ودي
# الجديد-->جدد
# بني-->بني
# سويف-->سوف
# بورسعيد-->رسعيد
# جنوب-->جنب
# سيناء-->ينء
# دمياط-->دمياط
# سوهاج-->وهج
# سيناء-->ينء
# قنا-->قنا
# كفر-->كفر
# الشيخ-->شيخ
# مرسى-->رسى
# مطروح-->طرح
# خدماتي-->خدم
# خدمات-->خدم
# حكومية-->حكم
# اخبار-->خبر
# الملاعب-->لعب
# أسعار-->سعر
# الذهب-->ذهب
# والعملات-->عمل
# اسواقي-->سوق
# فرص-->فرص
# ووظائف-->وظف
# عروض-->عرض
# فنيه-->فنه
# وترفيه-->ترف
# جامعات-->جمع
# ومدارس-->درس
# مواقيت-->وقي
# الصلاة-->صلة
# وفتاوي-->فتو
# خدمات-->خدم
# السفارات-->سفر
# أخبار-->خبر
# الطقس-->طقس
# مواعيد-->مواعيد
# السفر-->سفر
# أخبار-->خبر
# الجريدة-->جرد
# الرسمية-->رسم
# المزيد-->زيد
# عرب-->عرب
# وعالم-->علم
# المصري-->صري
# أوتو-->وتو
# تحقيقات-->حقق
# وحوارات-->حور
# فنون-->فنن
# ثقافة-->ثقف
# علوم-->علم
# وتكنولوجيا-->وتكنولوج
# منوعات-->نوع
# وسط-->وسط
# الناس-->ناس
# سياحة-->سيح
# وطيران-->وطر
# اعترافات-->عرف
# جريئة-->جرئ
# فيروس-->يرس
# كورونا-->كورو
# المصري-->صري
# Fact-->Fact
# صحتك-->صحت
# بالدنيا-->دنا
# خدماتي-->خدم
# توك-->توك
# شو-->شو
# بث-->بث
# مباشر-->بشر
# معلومة-->علم
# كأس-->كأس
# العالم-->علم
# ٢٠٢٢-->٢٠٢٢
# السكوت-->سكت
# ممنوع-->منع
# زي-->زي
# النهاردة-->هرد
# شكاوى-->شكوى
# المواطنين-->وطن
# pdf-->pdf
# أيقونة-->يقو
# camera_icon-->camera_icon
# paint_icon-->paint_icon
# End-->End
# Top-->Top
# Bar-->Bar
# start_internal_menu_wrap-->start_internal_menu_wrap
# مشاركة-->شرك
# x-->x
# AMAY-Take-Over-Page-->AMAY-Take-Over-Page
# /6419244/Almasryamayotp-->/6419244/Almasryamayotp
# AMAY-Take-Over-Home-Page-Left-->AMAY-Take-Over-Home-Page-Left
# /6419244/AMAY-Take-Over-Home-Page-Left-->/6419244/AMAY-Take-Over-Home-Page-Left
# AMAY-Take-Over-Home-Page-->AMAY-Take-Over-Home-Page
# /6419244/AMAY-Take-Over-Home-Page-->/6419244/AMAY-Take-Over-Home-Page
# Start-->Start
# ads_wrap-->ads_wrap
# AMAY_MAIN_BANNER-->AMAY_MAIN_BANNER
# /6419244/AMAY_MAIN_BANNER-->/6419244/AMAY_MAIN_BANNER
# End-->End
# ads_wrap-->ads_wrap
# Start-->Start
# article_slider-->article_slider
# End-->End
# article_slider-->article_slider
# Start-->Start
# Inner-->Inner
# Pages-->Pages
# Start-->Start
# Content-->Content
# الشروط-->شرط
# اللازمة-->لزم
# للحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# 2023-->2023
# (-->(
# الأسعار-->سعر
# والتفاصيل-->فصل
# )-->)
# سيارات-->سير
# معاقين-->عاق
# معفاة-->عفة
# الجمارك-->جمر
# 2023-->2023
# الخميس-->خمس
# 27-04-2023-->27-04-2023
# 16:55-->16:55
# |-->|
# كتب-->كتب
# :-->:
# حنان-->حنن
# الوالي-->ولي
# |-->|
# Custom-->Custom
# Sharing-->Sharing
# Buttons-->Buttons
# BEGIN-->BEGIN
# Custom-->Custom
# Sharing-->Sharing
# Buttons-->Buttons
# END-->END
# الأسعار-->سعر
# والتفاصيل-->فصل
# ..-->..
# الشروط-->شرط
# اللازمة-->لزم
# للحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# 2023-->2023
# تصوير-->صور
# :-->:
# آخرون-->اخر
# سيارات-->سير
# المعاقين-->عاق
# 2023-->2023
# ..-->..
# ازدادت-->زدد
# معدلات-->عدل
# البحث-->بحث
# الفترة-->فتر
# الأخيرة-->خير
# سيارات-->سير
# معفاة-->عفة
# الجمارك-->جمر
# ،-->،
# ذوي-->ذوي
# الإعاقة-->عقة
# مصر،-->صر،
# وقد-->وقد
# منحت-->نحت
# الدولة-->دول
# مجموعة-->جمع
# الامتيازات-->ميز
# للمعاقين-->عاق
# حالة-->حلة
# الحصول-->حصل
# سيارات-->سير
# المعاقين-->عاق
# .-->.
# ويأتي-->ويأ
# وفقا-->وفق
# لقرار-->قرر
# أعلنته-->اعل
# وزارة-->وزر
# التضامن-->ضمن
# الاجتماعي-->جمع
# تصريحات-->صرح
# سابقة،-->قة،
# ويحاول-->حول
# الكثير-->كثر
# معرفة-->عرف
# شروط-->شرط
# الحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# .-->.
# تقدمه-->قدم
# بوابة-->بوب
# «-->«
# المصري-->صري
# اليوم-->اليوم
# »-->»
# لقرائها-->قرئ
# خلال-->خلل
# السطور-->سطر
# التالية-->الي
# .-->.
# أخبار-->خبر
# متعلقة-->تعلق
# خطوات-->خطو
# وشروط-->شرط
# الحصول-->حصل
# سيارات-->سير
# المعاقين-->عاق
# 2023-->2023
# بالتفاصيل-->فصل
# والأسعار-->سعر
# ..-->..
# الشروط-->شرط
# اللازمة-->لزم
# للحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# 2022-->2022
# نشرة-->نشر
# أخبار-->خبر
# المصري-->صري
# اليوم-->اليوم
# الاقتصادية-->اقتصادية
# :-->:
# شروط-->شرط
# الحصول-->حصل
# سيارة-->سير
# معاقين-->عاق
# معفاه-->عفه
# الجمارك-->جمر
# 2022-->2022
# ضوء-->ضوء
# قرارات-->قرر
# «-->«
# التضامن-->ضمن
# »-->»
# ..-->..
# والمركزي-->ركز
# الصيني-->صين
# يقدم-->قدم
# قروضًا-->قرض
# ميسرة-->يسر
# لشراء-->شرء
# سندات-->سند
# المطورين-->طور
# شروط-->شرط
# الحصول-->حصل
# سيارة-->سير
# معاقين-->عاق
# 2023-->2023
# الأسعار-->سعر
# والتفاصيل-->فصل
# ..-->..
# الشروط-->شرط
# اللازمة-->لزم
# للحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# 2023-->2023
# يحصل-->حصل
# المتقدم-->تقدم
# سيارة-->سير
# معاقين-->عاق
# معفاة-->عفة
# الجمارك-->جمر
# ضوء-->ضوء
# توافر-->وفر
# مجموعة-->جمع
# الشروط-->شرط
# :-->:
# --->-
# يبدأ-->بدأ
# سن-->سن
# الفرد-->فرد
# المتقدم-->تقدم
# 18-->18
# سنة-->سنة
# فأكثر-->أكثر
# .-->.
# --->-
# يكون-->يكون
# مصري-->صري
# الجنسية-->جنس
# .-->.
# --->-
# تكون-->تكون
# السيارة-->سير
# مسجلة-->سجل
# باسم-->بسم
# الشخص-->شخص
# صاحب-->صحب
# الإعاقة-->عقة
# .-->.
# --->-
# سعة-->سعة
# السيارك-->سير
# اللترية-->لتر
# تزيد-->تزد
# 1600-->1600
# cc-->cc
# .-->.
# --->-
# يلزم-->لزم
# تكون-->تكون
# التجهيزات-->جهز
# الخاصة-->خصة
# بالسيارات-->سير
# مطابقة-->طبق
# وفقا-->وفق
# للقانون-->قان
# الصادر-->صدر
# القومسيون-->قومس
# الطبي-->طبي
# .-->.
# --->-
# يمكن-->يمكن
# بيع-->بيع
# السيارة-->سير
# تمضي-->تمض
# فترة-->فتر
# 5-->5
# سنوات-->سنو
# تاريخ-->ارخ
# حصولها-->حصل
# إعفاء-->عفء
# الجمارك-->جمر
# يسمح-->سمح
# ببيعها-->ببع
# .-->.
# --->-
# ضرورة-->ضرر
# اجتياز-->جيز
# الكشف-->كشف
# الطبي-->طبي
# لمعرفة-->عرف
# قدرة-->قدر
# الفرد-->فرد
# المعاق-->عاق
# قيادة-->قيد
# السيارة-->سير
# .-->.
# --->-
# توافر-->وفر
# تقرير-->قرر
# اجتماعي-->جمع
# وزارة-->وزر
# الشؤون-->شؤن
# الاجتماعية،-->اجتماعية،
# لتحديد-->حدد
# الوضع-->وضع
# المالي-->الي
# للشخص-->شخص
# المعاق-->عاق
# ومدى-->مدى
# قدرته-->قدر
# الإنفاق-->فاق
# مستلزمات-->لزم
# السيارة-->سير
# المجهزة-->جهز
# .-->.
# --->-
# توافر-->وفر
# تقرير-->قرر
# المجلس-->جلس
# الأعلى،-->على،
# محددا-->حدد
# نسبة-->نسب
# الإعاقة-->عقة
# ونوع-->ونع
# الإصابة،-->صابة،
# تحديد-->حدد
# نسبة-->نسب
# احتياج-->حيج
# المعاق-->عاق
# للسيارة-->سير
# الخاصة-->خصة
# ونوع-->ونع
# التجهيزات-->جهز
# يجب-->يجب
# تتواجد-->وجد
# السيارة-->سير
# وفقًا-->وفق
# لحالة-->لحل
# المعاق-->عاق
# الصحية-->صحة
# .-->.
# اقرأ-->قرأ
# :-->:
# أبرزها-->برز
# سيارة-->سير
# معفاة-->عفة
# جمركيًا-->جمر
# ..-->..
# 8-->8
# مزايا-->مزا
# للحصول-->حصل
# بطاقة-->بطق
# الخدمات-->خدم
# المتكاملة-->كامل
# لذوي-->لذي
# الإعاقة-->عقة
# السيارات-->سير
# المعفاة-->عفة
# الجمارك-->جمر
# للمعاقين-->عاق
# 2022-->2022
# وضعت-->وضع
# الدولة-->دول
# مجموعة-->جمع
# الضوابط-->ضبط
# ليتمكن-->يتم
# المتقدمين-->تقدم
# إجراء-->جرء
# الكشف-->كشف
# الطبي-->طبي
# لتسهيل-->سهل
# الحصول-->حصل
# سيارة-->سير
# المعاقين-->عاق
# معفاة-->عفة
# الجمارك،-->جمارك،
# أنشأت-->شأت
# المجالس-->جلس
# الطبية-->طبة
# المتخصصة،-->متخصصة،
# موقع-->وقع
# إلكترونى-->الكترونى
# جديد-->جدد
# يستقبل-->قبل
# طلبات-->طلب
# ذوي-->ذوي
# الإعاقة-->عقة
# الراغبين-->رغب
# الحصول-->حصل
# سيارة-->سير
# معاقين-->عاق
# ،-->،
# سيارة-->سير
# معفاة-->عفة
# الجمارك-->جمر
# ..-->..
# اضغط-->ضغط
# هنـــــــــــــــــا-->هنـــــــــــــــــا
# --->-
# التوجه-->توج
# وزارة-->وزر
# التضامن-->ضمن
# لاستخراج-->لاستخراج
# بطاقة-->بطق
# الخدمات-->خدم
# المتكاملة-->كامل
# الأسعار-->سعر
# والتفاصيل-->فصل
# ..-->..
# الشروط-->شرط
# اللازمة-->لزم
# للحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# 2023-->2023
# --->-
# يجب-->يجب
# يجيب-->يجب
# المتقدم-->تقدم
# للحصول-->حصل
# سيارة-->سير
# معاقين-->عاق
# معفاة-->عفة
# الجمارك-->جمر
# البيانات-->بين
# الموجودة-->وجد
# الموقع،-->وقع،
# ومنها-->ومن
# :-->:
# (-->(
# البيانات-->بين
# الشخصية-->شخص
# :-->:
# الرقم-->رقم
# القومي-->قوم
# –-->–
# رقم-->رقم
# بطاقة-->بطق
# الخدمات-->خدم
# المتكاملة--->متكاملة-
# الحالة-->حلة
# الاجتماعية-->اجتماعية
# -العنوان--->-العنوان-
# الوظيفة-->وظف
# –-->–
# التليفون--->ون-
# تحديد-->حدد
# نوع-->نوع
# الاعاقة-->عقة
# طبقا-->طبق
# للقانون-->قان
# (-->(
# حركية-->حرك
# –-->–
# سمعية-->سمع
# –-->–
# بصرية-->بصر
# –-->–
# ذهنية-->ذهن
# –-->–
# نفسيه-->نفس
# –-->–
# امراض-->مرض
# دم-->دم
# –-->–
# امراض-->مرض
# قلب-->قلب
# )-->)
# .-->.
# --->-
# مكان-->كان
# الكشف-->كشف
# الطبي-->طبي
# (-->(
# الادارة-->درة
# العامة-->عمة
# للمجالس-->جلس
# الطبية-->طبة
# –-->–
# المجلس-->جلس
# الطبي-->طبي
# العام-->عام
# بالاسكندرية-->اسكندرية
# –-->–
# المجلس-->جلس
# الطبي-->طبي
# العام-->عام
# بسوهاج-->وهج
# )-->)
# .-->.
# --->-
# اذا-->اذا
# المتقدم-->تقدم
# كامل-->كمل
# الأهلية-->هلي
# بسبب-->سبب
# مرض-->مرض
# ما،-->ما،
# يقوم-->يقم
# بتحديد-->حدد
# البيانات-->بين
# التالية-->الي
# :-->:
# (-->(
# اسم-->اسم
# ولي-->ولي
# الأمر-->امر
# –-->–
# الرقم-->رقم
# القومي-->قوم
# –-->–
# صفته-->صفت
# بالنسبة-->نسب
# لحامل-->حمل
# الطلب-->طلب
# ذوى-->ذوى
# الإعاقة-->عقة
# .-->.
# --->-
# اختيار-->خير
# تاريخ-->ارخ
# الكشف-->كشف
# الطبي-->طبي
# .-->.
# --->-
# اختيار-->خير
# الجمرك-->جمر
# يرغب-->رغب
# المعاق-->عاق
# الحصول-->حصل
# السيارة-->سير
# .-->.
# --->-
# ذلك،-->ذلك،
# يظهر-->ظهر
# بيان-->بين
# يوضح-->وضح
# كافة-->كفة
# بياناتك-->بين
# الشخصية-->شخص
# قمت-->قمت
# بتسجيلها-->سجل
# الخطوات-->خطو
# السابقة،-->قة،
# ويحدد-->حدد
# مكان-->كان
# وموعد-->وعد
# الكشف-->كشف
# الطبي-->طبي
# والمستندات-->سند
# المطلوبة-->طلب
# وفقا-->وفق
# لكل-->لكل
# إعاقة-->عقة
# الإعاقات-->اعق
# .-->.
# --->-
# يمكن-->يمكن
# الحجز-->حجز
# لمن-->لمن
# سبق-->سبق
# الحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# مجهزة-->جهز
# طبيا-->طبا
# مرور-->رور
# 5-->5
# سنوات-->سنو
# تاريخ-->ارخ
# الإفراج-->فرج
# الجمركي-->جمر
# السيارة-->سير
# .-->.
# اقرأ-->قرأ
# :-->:
# تبدأ-->بدأ
# 25-->25
# ..-->..
# أسعار-->سعر
# سيارات-->سير
# المعاقين-->عاق
# 2022-->2022
# رفع-->رفع
# الفائدة-->فئد
# مصر-->مصر
# أسعار-->سعر
# سيارات-->سير
# المعاقين-->عاق
# 2022-->2022
# الأتوماتيك-->اتوماتيك
# :-->:
# الأسعار-->سعر
# والتفاصيل-->فصل
# ..-->..
# الشروط-->شرط
# اللازمة-->لزم
# للحصول-->حصل
# سيارات-->سير
# معاقين-->عاق
# 2023-->2023
# سيارة-->سير
# سكودا-->سكد
# فابيا-->فاب
# هاتشباك،-->هاتشباك،
# تأتى-->أتى
# بسعر-->سعر
# يبدأ-->بدأ
# 75.000-->75.000
# مصري-->صري
# ويصل-->يصل
# 100.000-->100.000
# مصري-->صري
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# سكودا-->سكد
# Octavia-->Octavia
# A4-->A4
# 100.000-->100.000
# 115.000-->115.000
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# هيونداي-->هيوند
# أفانتيHD-->افانتيHD
# 11-->11
# 5-->5
# .-->.
# --->-
# سعر-->سعر
# سيارات-->سير
# سكودا-->سكد
# اوكتافيا-->كتف
# A5-->A5
# 120-->120
# ويصل-->يصل
# 150-->150
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# أيو-->ايو
# لاسيتي-->لسي
# أوبترا-->بتر
# أتوماتيك-->اتوماتيك
# :-->:
# 90-->90
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# دايو-->ديو
# جنترا-->جنتر
# أتوماتيك-->اتوماتيك
# :-->:
# 78-->78
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# كيا-->كيا
# سيراتو-->رتو
# أتوماتيك-->اتوماتيك
# :-->:
# 70-->70
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# هيونداي-->هيوند
# ماتريكس-->ماتريكس
# سعة-->سعة
# محرك-->حرك
# 1600-->1600
# سي-->سي
# سي،-->سي،
# يبدأ-->بدأ
# 60-->60
# ويصل-->يصل
# سعر-->سعر
# السيارة-->سير
# 70-->70
# .-->.
# --->-
# وسجل-->سجل
# سعر-->سعر
# سيارة-->سير
# هيونداي-->هيوند
# لافيتا-->لفي
# أتوماتيك-->اتوماتيك
# :-->:
# 69-->69
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# هيونداي-->هيوند
# أفانتي-->فنت
# و130-->130
# أتوماتيك-->اتوماتيك
# :-->:
# 68-->68
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# كيا-->كيا
# مورنينج-->مورنينج
# أوتوماتيك-->اوتوماتيك
# :-->:
# 65-->65
# .-->.
# --->-
# سعر-->سعر
# سيارة-->سير
# هيونداي-->هيوند
# أفانتي-->فنت
# XD-->XD
# أتوماتيك-->اتوماتيك
# :-->:
# 63-->63
# .-->.
# <--><
# script-->script
# >-->>
# window.googletag-->window.googletag
# =-->=
# window.googletag-->window.googletag
# ||-->||
# {-->{
# cmd-->cmd
# :-->:
# [-->[
# ]-->]
# }-->}
# ;-->;
# googletag.cmd.push-->googletag.cmd.push
# (-->(
# function-->function
# (-->(
# )-->)
# {-->{
# googletag.defineSlot-->googletag.defineSlot
# (-->(
# '/6419244/AFF_Desktop-->'/6419244/AFF_Desktop
# '-->'
# ,-->,
# [-->[
# 600-->600
# ,-->,
# 100-->100
# ]-->]
# ,-->,
# 'div-gpt-ad-1653487842777-0-->'div-gpt-ad-1653487842777-0
# '-->'
# )-->)
# .addService-->.addService
# (-->(
# googletag.pubads-->googletag.pubads
# (-->(
# )-->)
# )-->)
# ;-->;
# googletag.pubads-->googletag.pubads
# (-->(
# )-->)
# .enableSingleRequest-->.enableSingleRequest
# (-->(
# )-->)
# ;-->;
# googletag.enableServices-->googletag.enableServices
# (-->(
# )-->)
# ;-->;
# }-->}
# )-->)
# ;-->;
# <--><
# /script-->/script
# >-->>
# /6419244/AFF_Desktop-->/6419244/AFF_Desktop
# <--><
# div-->div
# id='div-gpt-ad-1653487842777-0-->id='div-gpt-ad-1653487842777-0
# '-->'
# style='min-width-->style='min-width
# :-->:
# 600px-->600px
# ;-->;
# min-height-->min-height
# :-->:
# 100px-->100px
# ;-->;
# '-->'
# >-->>
# <--><
# script-->script
# >-->>
# googletag.cmd.push-->googletag.cmd.push
# (-->(
# function-->function
# (-->(
# )-->)
# {-->{
# googletag.display-->googletag.display
# (-->(
# 'div-gpt-ad-1653487842777-0-->'div-gpt-ad-1653487842777-0
# '-->'
# )-->)
# ;-->;
# }-->}
# )-->)
# ;-->;
# <--><
# /script-->/script
# >-->>
# <--><
# /div-->/div
# >-->>
# Tags-->Tags
# start-->start
# سيارات-->سير
# المعاقين-->عاق
# اسعار-->سعر
# سيارات-->سير
# المعاقين-->عاق
# الحصول-->حصل
# سيارات-->سير
# المعاقين-->عاق
# شروط-->شرط
# الحصول-->حصل
# سيارات-->سير
# المعاقين-->عاق
# اسعار-->سعر
# سيارات-->سير
# المعاقين-->عاق
# 2023-->2023
# سيارات-->سير
# المعاقين-->عاق
# 2023-->2023
# سيارة-->سير
# معفاة-->عفة
# الجمارك-->جمر
# حجز-->حجز
# سيارات-->سير
# المعاقين-->عاق
# 2023-->2023
# سياراة-->سير
# معفاة-->عفة
# الجمارك-->جمر
# 2023-->2023
# وزارة-->وزر
# التضامن-->ضمن
# بطاقة-->بطق
# الخدمات-->خدم
# المتكاملة-->كامل
# Tags-->Tags
# end-->end
# start-Desktop_video-->start-Desktop_video
# /6419244/Desktop_video-->/6419244/Desktop_video
# end-Desktop_video-->end-Desktop_video
# Custom-->Custom
# Sharing-->Sharing
# Buttons-->Buttons
# BEGIN-->BEGIN
# Custom-->Custom
# Sharing-->Sharing
# Buttons-->Buttons
# END-->END
# Opt-->Opt
# start-->start
# طباعه-->طبع
# أرسل-->رسل
# لصديق-->صدق
# Opt-->Opt
# end-->end
# ReTabs-->ReTabs
# start-->start
# ReTabs-->ReTabs
# end-->end
# يعجبك-->عجب
# أيضا‎-->يض‎
# SeeAlso-->SeeAlso
# start-->start
# يحدث-->حدث
# بث-->بث
# مباشر-->بشر
# الاتحاد-->تحد
# ضد-->ضد
# الشباب-->شبب
# الدوري-->دور
# السعودي-->سعد
# القوات-->قوت
# البحرية-->بحر
# تنقذ-->نقذ
# لنشًا-->لنش
# سياحيًا-->سيح
# بنطاق-->نطق
# قاعدة-->قعد
# البحر-->بحر
# الأحمر-->حمر
# التوقيت-->وقت
# الصيفي-->صيف
# 2023-->2023
# ..-->..
# قدم-->قدم
# ساعتك-->سعت
# 60-->60
# دقيقة-->دقق
# بداية-->بدي
# الموعد-->وعد
# بسمة-->بسم
# بوسيل-->وسل
# وتامر-->تمر
# حسني-->حسن
# ..-->..
# شائعات-->شئع
# انفصال-->فصل
# متكررة-->تكرر
# «-->«
# متهورة-->تهر
# بحبك-->بحب
# »-->»
# الطلاق-->طلق
# (-->(
# القصة-->قصة
# الكاملة-->كمل
# )-->)
# SeeAlso-->SeeAlso
# end-->end
# Comments-->Comments
# start-->start
# <--><
# div-->div
# class=-->class=
# ''-->''
# section-container-->section-container
# auto-->auto
# comments-->comments
# ''-->''
# id=-->id=
# ''-->''
# comments-->comments
# ''-->''
# data-section=-->data-section=
# ''-->''
# tabs-->tabs
# ''-->''
# >-->>
# <--><
# section-->section
# class=-->class=
# ''-->''
# active-->active
# ''-->''
# >-->>
# <--><
# p-->p
# class=-->class=
# ''-->''
# title-->title
# facebook-->facebook
# ''-->''
# data-section-title-->data-section-title
# >-->>
# <--><
# a-->a
# href=-->href=
# ''-->''
# #-->#
# panel2-->panel2
# ''-->''
# >-->>
# <--><
# /a-->/a
# >-->>
# <--><
# /p-->/p
# >-->>
# <--><
# div-->div
# class=-->class=
# ''-->''
# content-->content
# ''-->''
# data-section-content-->data-section-content
# >-->>
# FB-->FB
# start-->start
# <--><
# div-->div
# id=-->id=
# ''-->''
# 2873252-->2873252
# ''-->''
# >-->>
# <--><
# div-->div
# class=-->class=
# ''-->''
# fb-comments-->fb-comments
# ''-->''
# id=-->id=
# ''-->''
# 2873252-->2873252
# ''-->''
# data-href=-->data-href=
# ''-->''
# https-->https
# :-->:
# //www.almasryalyoum.com/news/details/2873252-->//www.almasryalyoum.com/news/details/2873252
# ''-->''
# data-numposts=-->data-numposts=
# ''-->''
# 15-->15
# ''-->''
# width=-->width=
# ''-->''
# 100-->100
# %-->%
# ''-->''
# >-->>
# <--><
# /div-->/div
# >-->>
# <--><
# /div-->/div
# >-->>
# FB-->FB
# end-->end
# <--><
# /div-->/div
# >-->>
# <--><
# /section-->/section
# >-->>
# <--><
# /div-->/div
# >-->>
# Comments-->Comments
# end-->end
# CommentSript-->CommentSript
# start-->start
# End-->End
# Content-->Content
# Start-->Start
# Sidbar-->Sidbar
# ADS-->ADS
# start-->start
# AMAY_SHOWCASE_1-->AMAY_SHOWCASE_1
# /6419244/AMAY_SHOWCASE_1-->/6419244/AMAY_SHOWCASE_1
# ADS-->ADS
# end-->end
# TopNews-->TopNews
# start-->start
# أهم-->اهم
# الاخبار-->خبر
# هالة-->هلة
# صدقي-->صدق
# :-->:
# تعدد-->عدد
# الزواج-->زوج
# حلال-->حلل
# يمكن-->يمكن
# ننكره-->نكر
# المصريين-->صري
# العائدين-->عئد
# السودان-->سود
# :-->:
# الرئيس-->رئس
# السيسي-->سيس
# إنسان-->انس
# وبطل-->بطل
# عيار-->عير
# 24-->24
# يسجل-->سجل
# 3062-->3062
# جنيهًا-->جني
# ..-->..
# أسعار-->سعر
# الذهب-->ذهب
# خلال-->خلل
# تعاملات-->عمل
# اليوم-->اليوم
# الخميس-->خمس
# (-->(
# آخر-->اخر
# تحديث-->حدث
# )-->)
# «-->«
# بسبب-->سبب
# ورقة-->ورق
# زواج-->زوج
# عرفي-->عرف
# »-->»
# ..-->..
# أمين-->امن
# شرطة-->شرط
# يقتل-->قتل
# فتاة-->فتة
# البحيرة-->بحر
# يتنحر-->نحر
# TopNews-->TopNews
# end-->end
# Speakol-->Speakol
# will-->will
# render-->render
# the-->the
# widget-->widget
# here-->here
# يعجبك-->عجب
# Join-->Join
# start-->start
# start-->start
# of-->of
# subscribe-->subscribe
# tabs-->tabs
# mobile-->mobile
# start-->start
# الأخبار-->خبر
# العاجلة-->عجل
# اشترك-->شرك
# فى-->فى
# خدمة-->خدم
# الأخبار-->خبر
# العاجلة-->عجل
# <--><
# form-->form
# action=-->action=
# ''-->''
# ''-->''
# method=-->method=
# ''-->''
# post-->post
# ''-->''
# name=-->name=
# ''-->''
# form1-->form1
# ''-->''
# >-->>
# <--><
# input-->input
# type=-->type=
# ''-->''
# text-->text
# ''-->''
# class=-->class=
# ''-->''
# search_word-->search_word
# right-->right
# ''-->''
# placeholder=-->placeholder=
# ''-->''
# أضف-->اضف
# رقم-->رقم
# الموبايل-->موبايل
# ''-->''
# name=-->name=
# ''-->''
# ''-->''
# /-->/
# >-->>
# <--><
# a-->a
# href=-->href=
# ''-->''
# #-->#
# ''-->''
# class=-->class=
# ''-->''
# add_no-->add_no
# ''-->''
# >-->>
# أضف-->اضف
# رقمك-->رقم
# <--><
# /a-->/a
# >-->>
# <--><
# /form-->/form
# >-->>
# mobile-->mobile
# end-->end
# newsletter-->newsletter
# start-->start
# النشرة-->نشر
# البريدية-->برد
# اشترك-->شرك
# فى-->فى
# النشرة-->نشر
# البريدية-->برد
# newsletter-->newsletter
# end-->end
# start-->start
# of-->of
# subscribe-->subscribe
# tabs-->tabs
# Join-->Join
# end-->end
# latest-->latest
# VIO-->VIO
# start-->start
# أحدث-->حدث
# الفيديوهات-->يدو
# طريق-->طرق
# الحوادث-->حدث
# فقط-->فقط
# ..-->..
# تؤثر-->ٔثر
# حركة-->حرك
# المرور-->رور
# علي-->علي
# صحتك-->صحت
# ؟-->؟
# سعرها-->سعر
# يصل-->يصل
# إلى-->ٕلى
# 3-->3
# آلاف-->ٓلف
# ..-->..
# تعرّف-->عرف
# نظارة-->نظر
# شركة-->شرك
# آبل-->ٓبل
# الجديدة-->جدد
# حجم-->حجم
# خريطة-->خرط
# العالم-->علم
# نعرفها-->عرف
# خاطئ-->خطئ
# ..-->..
# ذلك؟-->ذلك؟
# latest-->latest
# VIO-->VIO
# end-->end
# lt-->lt
# Photo-->Photo
# start-->start
# ألبومات-->لبم
# الصور-->صور
# الأسبوع-->سبع
# صور-->صور
# اجتماع-->جمع
# مجلس-->جلس
# الوزراء-->زرء
# الأسبوعي-->سبع
# برئاسة-->رئس
# «-->«
# مدبولي-->دبل
# »-->»
# طقس-->طقس
# شديد-->شدد
# الحرارة-->حرر
# المنصورة-->نصر
# lt-->lt
# Photo-->Photo
# end-->end
# ADS-->ADS
# start-->start
# AMAY_SHOWCASE_2-->AMAY_SHOWCASE_2
# /6419244/AMAY_SHOWCASE_2-->/6419244/AMAY_SHOWCASE_2
# ADS-->ADS
# end-->end
# newsTabs-->newsTabs
# start-->start
# الأخبار-->خبر
# 19:58-->19:58
# «-->«
# عاوزه-->عوز
# تجهض-->جهض
# لسوء-->لسء
# خلق-->خلق
# زوجها-->زوج
# »-->»
# ..-->..
# الإفتاء-->فاء
# ترد-->ترد
# :-->:
# طفلك-->طفل
# يكون-->يكون
# نافعًا-->نفع
# للناس-->ناس
# 19:56-->19:56
# الهند-->هند
# تتهم-->تهم
# الصين-->صين
# بانتهاك-->بنت
# اتفاقيات-->تفق
# حدودية-->حدد
# خلفية-->خلف
# النزاع-->نزع
# حول-->حول
# منطقة-->نطق
# «-->«
# لداخ-->لدخ
# »-->»
# 19:53-->19:53
# بث-->بث
# مباشر-->بشر
# الاتحاد-->تحد
# ضد-->ضد
# الشباب-->شبب
# الدوري-->دور
# السعودي-->سعد
# 19:53-->19:53
# سفير-->سفر
# مصر-->مصر
# بالمغرب-->غرب
# يكشف-->كشف
# تفاصيل-->فصل
# حضور-->حضر
# جماهير-->جماهير
# الأهلي-->اهل
# مباراة-->برا
# الرجاء-->رجء
# 19:44-->19:44
# التوقيت-->وقت
# الصيفي-->صيف
# 2023-->2023
# ..-->..
# قدم-->قدم
# ساعتك-->سعت
# 60-->60
# دقيقة-->دقق
# بداية-->بدي
# الموعد-->وعد
# المزيد-->زيد
# الأكثر-->كثر
# قراءة-->قرء
# 26-04-2023-->26-04-2023
# قتلته-->قتل
# وادعت-->ودع
# وفاته-->وفت
# بمنشط-->نشط
# جنسي-->جنس
# أثناء-->ثنء
# العلاقة-->علق
# ..-->..
# اعترافات-->عرف
# صادمة-->صدم
# لزوجة-->لزج
# موظف-->وظف
# روض-->روض
# الفرج-->فرج
# 25-04-2023-->25-04-2023
# تريثوا-->ترث
# شراء-->شرء
# الذهب-->ذهب
# ..-->..
# «-->«
# التموين-->تمو
# »-->»
# :-->:
# الأسعار-->سعر
# ستعود-->تعد
# لوضعها-->وضع
# الصحيح-->صحح
# (-->(
# تفاصيل-->فصل
# مهمة-->همة
# )-->)
# 26-04-2023-->26-04-2023
# ارتفاع-->رفع
# عيار-->عير
# 21-->21
# ..-->..
# أسعار-->سعر
# الذهب-->ذهب
# تقفز-->قفز
# 360-->360
# دفعة-->دفع
# واحدة-->وحد
# اليوم-->اليوم
# بالصاغة-->صغة
# 09:03-->09:03
# سعر-->سعر
# الذهب-->ذهب
# اليوم-->اليوم
# الخميس-->خمس
# 27-4-2023-->27-4-2023
# وعيار-->عير
# 21-->21
# الصاغة-->صغة
# خلال-->خلل
# بداية-->بدي
# التعاملات-->عمل
# 26-04-2023-->26-04-2023
# التوقيت-->وقت
# الصيفي-->صيف
# 2023-->2023
# ..-->..
# مواقيت-->وقي
# الصلاة-->صلة
# تغيير-->غير
# الساعة-->سعة
# مصر-->مصر
# newsTabs-->newsTabs
# end-->end
# LT-->LT
# articles-->articles
# start-->start
# أحدث-->حدث
# المقالات-->قال
# حسن-->حسن
# إسميك-->اسم
# حول-->حول
# الدين-->دين
# والدنيا-->دنا
# ..-->..
# جدل-->جدل
# الغاية-->غية
# والوسيلة-->وسل
# !-->!
# أحمد-->حمد
# بهاء-->بهء
# الدين-->دين
# جيل-->جيل
# E-Class-->E-Class
# الجديد-->جدد
# ..-->..
# وأسئلة-->أسئل
# الاستيراد-->يرد
# الشخصى-->شخصى
# !-->!
# خالد-->خلد
# أباظة-->بظة
# رحيل-->رحل
# الطوبجى-->طوبجى
# ..-->..
# رجل-->رجل
# BMW-->BMW
# !-->!
# حبيبة-->حبب
# محمدي-->حمد
# فى-->فى
# اليومِ-->اليوم
# العالمى-->عالمى
# للكِتاب-->كتب
# :-->:
# صداقةُ-->صدق
# الكُتبِ-->كتب
# عافيةٌ-->عفي
# للرُّوح-->روح
# !-->!
# LT-->LT
# articles-->articles
# end-->end
# ADS-->ADS
# start-->start
# AMAY_SHOWCASE_1-->AMAY_SHOWCASE_1
# /6419244/Half_page-->/6419244/Half_page
# End-->End
# Sidbar-->Sidbar
# End-->End
# Off-->Off
# inner-->inner
# Pages-->Pages
# Google-->Google
# Analytics-->Analytics
# Targets-->Targets
# End-->End
# of-->of
# Google-->Google
# Analytics-->Analytics
# Targets-->Targets
# Start-->Start
# notification-->notification
# خبر-->خبر
# مهم-->مهم
# عاجل-->عجل
# يحدث-->حدث
# End-->End
# notification-->notification
# Start-->Start
# footer_wrap-->footer_wrap
# الرئيسية-->رئس
# أخبار-->خبر
# سياسة-->سيس
# اقتصاد-->قصد
# رأي-->رأي
# حوادث-->حدث
# ملاعب-->لعب
# عرب-->عرب
# وعالم-->علم
# المصري-->صري
# أوتو-->وتو
# تحقيقات-->حقق
# وحوارات-->حور
# فنون-->فنن
# ثقافة-->ثقف
# علوم-->علم
# وتكنولوجيا-->وتكنولوج
# منوعات-->نوع
# وسط-->وسط
# الناس-->ناس
# سياحة-->سيح
# وطيران-->وطر
# اعترافات-->عرف
# جريئة-->جرئ
# فيروس-->يرس
# كورونا-->كورو
# المصري-->صري
# Fact-->Fact
# صحتك-->صحت
# بالدنيا-->دنا
# خدماتي-->خدم
# توك-->توك
# شو-->شو
# بث-->بث
# مباشر-->بشر
# معلومة-->علم
# كأس-->كأس
# العالم-->علم
# ٢٠٢٢-->٢٠٢٢
# السكوت-->سكت
# ممنوع-->منع
# زي-->زي
# النهاردة-->هرد
# logo-->logo
# حقوق-->حقق
# النشر-->نشر
# محفوظة-->حفظ
# مؤسسة-->ؤسس
# المصري-->صري
# اليوم-->اليوم
# ويحظر-->حظر
# نشر-->نشر
# توزيع-->وزع
# طبع-->طبع
# مادة-->ادة
# مسبق-->سبق
# المؤسسة-->ؤسس
# يتم-->يتم
# تطويره-->طور
# بواسطة-->بسط
# End-->End
# footer_wrap-->footer_wrap
# Start-->Start
# footer_info-->footer_info
# face-->face
# twitter-->twitter
# google-->google
# rss-->rss
# mob-->mob
# NewsLetter-->NewsLetter
# tv_icon-->tv_icon
# camera_icon-->camera_icon
# paint_icon-->paint_icon
# نسخة-->نسخ
# الموبايل-->موبايل
# الموقع-->وقع
# الإعلانات-->علن
# حقوق-->حقق
# النشر-->نشر
# سياسة-->سيس
# النشر-->نشر
# اتصل-->تصل
# SERVER_IP-->SERVER_IP
# [-->[
# Ex-->Ex
# :-->:
# S248-->S248
# ]-->]
# End-->End
# footer_info-->footer_info
# To-->To
# Top-->Top
# Script-->Script
# of-->of
# the-->the
# social-->social
# buttons-->buttons
# sharing-->sharing

# %%
import pandas as pd
def tf_idf_analysis(keyword):
    v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
    x = v.fit_transform(text)

    f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
    d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
    tf=pd.DataFrame((f>0).sum(axis=0))


    d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

    d.columns=['word','average_tfidf','max_tfidf','frequency']

    d['frequency']=round((d['frequency']/len(text))*100)

    return(d)

x= tf_idf_analysis(u)
x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
# print(x)
#######################################################################
# import pandas as pd
# # documentA = 'ذهب محمد الي الجامعة ليدرس الفيزياء و الكيمياء'
# # documentB=u
# documentA=u
# bagOfWordsA = documentA.split(' ')
# # bagOfWordsB = documentB.split(' ')
# uniqueWords = set(bagOfWordsA)
# uniqueWords
# numOfWordsA = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsA[word] += 1
# numOfWordsA
# numOfWordsB = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsB[word] += 1

# numOfWordsB    
# def computeTF(wordDict, bagOfWords):
#     tfDict = {}
#     bagOfWordsCount = len(bagOfWords)
#     for word, count in wordDict.items():
#         tfDict[word] = count / float(bagOfWordsCount)
#     return tfDict
# tfB = computeTF(numOfWordsB, bagOfWordsA)
# print(tfB)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['آمين', 'أب', 'أخ', 'أفعل', 'أفعله', 'ؤلاء', 'إل', 'إم', 'ات', 'اتان', 'ارتد', 'ان', 'انفك', 'برح', 'تان', 'تبد', 'تحو', 'تعل', 'حد', 'حم', 'حي', 'خب', 'ذار', 'سيما', 'صه', 'ظل', 'ظن', 'عد', 'قط', 'مر', 'مكان', 'مكانكن', 'نب', 'هات', 'هب', 'واها', 'وراء'] not in stop_words.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#              word  average_tfidf  max_tfidf  frequency
# 9059       عربيات       0.063959   0.411258       17.0
# 1558           cc       0.038834   0.400356       25.0
# 3191         span       0.029288   0.351462        8.0
# 3250        start       0.030690   0.304101       17.0
# 1503          car       0.033963   0.293697       25.0
# 1908          end       0.028809   0.277584       25.0
# 3461        truck       0.022335   0.268019        8.0
# 5414     السيارات       0.080729   0.266335       75.0
# 3227         star       0.022639   0.258877       17.0
# 4308     اتوماتيك       0.028317   0.258732       33.0
# 3968        ألعاب       0.021765   0.242965       17.0
# 3726        أخبار       0.042627   0.231304       83.0
# 5635       الطاقة       0.017129   0.205543        8.0
# 5958   الكهربائية       0.023734   0.200485       25.0
# 1628        class       0.023706   0.196641       25.0
# 8518       سيارات       0.069812   0.181009       83.0
# 2973      reviews       0.015010   0.180124        8.0
# 2914       racing       0.014890   0.178679        8.0
# 10421         مصر       0.032766   0.174965       83.0
# 2169         gray       0.014278   0.171338        8.0
# 4219        إغلاق       0.026432   0.164503       17.0
# 2779      parking       0.013649   0.163789        8.0
# 5239      الدولية       0.013458   0.161498        8.0
# 1687      compare       0.013345   0.160142        8.0
# 1530         cars       0.016592   0.158145       25.0
# 8909          صور       0.029456   0.150028       33.0
# 1282        after       0.012455   0.149466        8.0
# 1999     favorite       0.012455   0.149466        8.0
# 1778     defining       0.012455   0.149466        8.0
# 3158        slots       0.012455   0.149466        8.0
# 10607         ملف       0.012240   0.146884        8.0
# 6676       بالمئة       0.012235   0.146817        8.0
# 3798        أسعار       0.042427   0.146464       67.0
# 7635        جنيها       0.013458   0.145724       17.0
# 4084         أولا       0.022775   0.145315       25.0

# %%
import urllib
# %pip install requests_html
import requests
# !pip install requests
from requests_html import HTMLSession
import mysql.connector

# Connect to the database
mysql = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="seopro"
)

# Create a cursor object
mycursor = mysql.cursor()

# Execute an SQL query to select the last row from the table
mycursor.execute("SELECT uid, niche FROM given_niche_ar ORDER BY id DESC LIMIT 1")

# Fetch the last row from the table
niche_arr = mycursor.fetchone()

# # Convert niche[0] to a string
# niche= str(niche_arr[0])

# # Print the last row as a string
# print(niche)

# Extract the id and niche values from the row
uid = niche_arr[0]
niche = niche_arr[1]

# Print the niche and id values
print(niche)
print(uid)
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        return response
    except requests.exceptions.RequestException as e:
        print(e)
# Out:
# Requirement already satisfied: requests_html in c:\users\lenovo\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: bs4 in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: w3lib in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.21.0)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (2.28.1)
# Requirement already satisfied: pyquery in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: parse in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: fake-useragent in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.1.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.11)
# Requirement already satisfied: certifi>=2021 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2022.9.14)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.64.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\anaconda3\lib\site-packages (from bs4->requests_html) (4.11.1)
# Requirement already satisfied: importlib-resources>=5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fake-useragent->requests_html) (5.10.1)
# Requirement already satisfied: lxml>=2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pyquery->requests_html) (4.9.1)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\lenovo\anaconda3\lib\site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->requests_html) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: six>=1.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from w3lib->requests_html) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# سيارات
# 5

# %%
def scrape_google(query):
    
    # query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.com/search?q=" + query)
    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.')

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
links = scrape_google(niche)
for link in links:
  print(link)
# Out:
# https://eg.hatla2ee.com/ar/car/disabled
# https://www.olx.com.eg/vehicles/cars-for-sale/
# https://egypt.yallamotor.com/ar/new-cars
# https://poki.com/ar/%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA
# https://elmasria-auto.com/
# https://eg.hatla2ee.com/ar/car/all-prices
# https://www.masrawy.com/channel/autos
# https://eg.hatla2ee.com/ar/car/insurance
# https://www.contactcars.com/ar/usedcars
# https://www.shift-eg.com/ar/used-car/search
# https://eg.hatla2ee.com/ar/car
# https://www.elbalad.news/category/17
# https://eg.hatla2ee.com/ar/imported-car

# %%
from nltk.tokenize import  word_tokenize
import nltk
nltk.download('punkt')
# # EXAMPLE_TEXT = """
# # أبو عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك
# # وجغرافيا مسلم. يكنى باسم الخوارزمي وأبي جعفر. قيل أنه ولد حوالي 164هـ 781م (وهو غير مؤكد) وقيل أنه توفي بعد 232هـ أي (بعد 847م). يعتبر
# # من أوائل علماء الرياضيات المسلمين حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره. اتصل بالخليفة العباسي المأمون وعمل في بيت الحكمة في 
# # بغداد وكسب ثقة الخليفة إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل فيها أكثر من سبعين جغرافيا. قبل وفاته في 850 م/232 هـ
# # كان الخوارزمي قد ترك العديد من المؤلفات في علوم الرياضيات والفلك والجغرافيا ومن أهمها

# # """
# EXAMPLE_TEXT=links
# print(word_tokenize(EXAMPLE_TEXT))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# links=scrape_google('cars')
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup

def get_text(url):
    try:
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req,timeout=5).read()
        soup = BeautifulSoup(webpage, "html.parser")
        texts = soup.findAll(text=True)
        res=u" ".join(t.strip() for t in texts if t.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]'])
        return(res)
    except:
        return False
get_text('https://en.wikipedia.org/wiki/Machine_learning')
text=[]
for i in links:
  t=get_text(i)
  if t:
    text.append(t)

    word_tokens = word_tokenize(t)
# word_tokens = 

    filtered_sentence = [w for w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)

    filtered_sentence = [w for w in word_tokens if not w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)
    filtered_sentence = [w for w in word_tokens if not w.lower() in word_tokens]

    print(word_tokens)
    print('---------------------------------')
    print(filtered_sentence)
# Out:
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'سيارات', 'للبيع', '/', 'سيارات', 'مستعملة', 'سيارات', 'المعاقين', 'للبيع', 'في', 'مصر', 'سيارات', 'المعاقين،', 'هي', 'سيارات', 'معدة', 'ومجهزة', 'للمعاقين', 'تراعي', 'حالتهم', 'وتسهل', 'إنتقالهم', '.', 'ابحث', 'عن', 'سيارة', 'للبيع', 'إختر', 'ماركة', 'اسبيرانزا', 'استون', 'مارتن', 'اكسييد', 'الفاروميو', 'ام', 'جى', 'امجيراند', 'انفينيتي', 'اوبل', 'اودي', 'ايسوزو', 'بايك', 'بروتون', 'بريليانس', 'بنتلى', 'بوجاتى', 'بورش', 'بونتياك', 'بويك', 'بى', 'واى', 'دى\u202c', 'بي', 'ام', 'دبليو', 'بيجو', 'بيرودوا', 'بيستون', 'تاتا', 'تسلا', 'تويوتا', 'جاك', 'جاكوار', 'جريت', 'وول', 'جون', 'واى', 'جى', 'ام', 'سى', 'جي', 'أي', 'سي', 'جيب', 'جيتور', 'جيلي', 'جينيسيس\u200e', 'داتسون', 'دايهاتسو', 'دايو', 'دفسك', 'دودج', 'دوماى', 'دونج', 'فنج', 'دى', 'اس', 'رولز', 'رويس', 'رينو', 'زد', 'ان', 'اى', 'زوتى', 'ساب', 'سانج', 'يونج', 'ساوايست', 'سايبا', 'سايون', 'سكودا', 'سمارت', 'سوبارو', 'سوزوكى', 'سوكون', 'سيات', 'سيتروين', 'سينوفا', 'شانا', 'شانجان', 'شانجى', 'شيرى', 'شيفروليه', 'غاز', 'فاو', 'فوتون', 'فورثينج', 'فورد', 'فولفو', 'فولكس', 'فاغن', 'فيات', 'فيرارى', 'كاديلاك', 'كارى', 'كاي', 'ي', 'كرايسلر', 'كوبرا', 'كيا', 'كيتون', 'كينبو', 'لادا', 'لاند', 'روفر', 'لاندويند', 'لانشيا', 'لكزس', 'لمبرجيني', 'ل ...
# ---------------------------------
# ['English', 'SUV', 'C', 'C', 'K3', 'K3', 'GDI', 'GDI', 'E', 'E', 'C', 'C', 'K3', 'K3', 'E', 'E', 'C', 'AMG', 'C', 'AMG', 'C', 'C', 'E', 'E', 'Hatla2ee.com']
# ['فقط', 'في', 'سيارات', 'للبيع', 'تسجيل', 'الدخول', 'بيع', 'عربيات', 'وقطع', 'غيار', 'سيارات', 'للبيع', 'سيارات', 'للإيجار', 'كاوتش،', 'بطاريات،', 'زيوت،', 'و', 'كماليات', 'قطع', 'غيار', 'سيارات', 'موتوسيكلات', 'و', 'إكسسواراتها', 'مركبات', 'بحرية', 'أتوبيسات،', 'شاحنات', 'نقل', 'ثقيل،', 'و', 'وسائل', 'نقل', 'أخرى', 'عقارات', 'شقق', 'و', 'دوبلكس', 'للبيع', 'شقق', 'و', 'دوبلكس', 'للإيجار', 'فلل', 'للبيع', 'فلل', 'للإيجار', 'عقارات', 'مصايف', 'للبيع', 'عقارات', 'مصايف', 'للإيجار', 'عقار', 'تجارى', 'للبيع', 'عقار', 'تجارى', 'للإيجار', 'مبانى', 'و', 'أراضى', 'موبايلات', 'و', 'تابلت', 'موبايلات', 'تابلت', 'إكسسوارات', 'موبايل', 'و', 'تابلت', 'خطوط', 'موبايل', 'وظائف', 'محاسبة', 'و', 'بنوك', 'هندسة', 'مصممين', 'خدمة', 'عملاء', 'عمال', 'و', 'فنيين', 'إدارة', 'و', 'أعمال', 'إستشارية', 'سائقين', '-', 'توصيل', 'تعليم', 'موارد', 'بشرية', 'سياحة', 'و', 'سفر', 'تكنولوجيا', 'و', 'معلومات', 'تسويق', 'و', 'علاقات', 'عامة', 'طب', '-', 'صحة', '-', 'تمريض', 'مبيعات', 'سكرتارية', 'حراسات', 'و', 'أمن', 'محامين', '-', 'شئون', 'قانونية', 'وظيفة', 'أخرى', 'المزيد', 'من', 'الفئات', 'الكترونيات', 'وأجهزة', 'منزلية', 'تلفزيونات', 'وصوتيات', ',', 'كمبيوتر', 'و', 'إكسسوارات', ',', 'أجهزة', 'وألعاب', 'فيديو', 'أثاث', 'منزل', '-', 'ديكور', 'الحمام', ',', 'غرفة', 'نوم', ',', 'غرفة', 'سفرة', 'الموضة', 'والجمال', 'ملابس', 'حريمي', ',', 'ملابس', 'رجالي', ',', 'إكسسوارات', '-', 'مستحضرات', 'تجميل-', 'عناية', 'شخصية', 'حريمي', 'حيوانات', 'أليفة', 'و', 'إكسسواراتها', 'طيور', '-', 'حمام', ',', 'قطط', ',', 'كلاب', 'مستلزمات', 'أطفال', 'عناية', '-', 'صحة', 'الطفل', 'و', 'الأم', ',', 'ملابس', 'أطفال', ',', 'أدوات', 'تغذية', 'للطفل', 'هوايات،', 'رياضة', 'و', 'كتب', 'تحف', '-', 'مقتنيات', ',', 'دراجات', ',', 'كتب', 'تجارة', '-', 'صناعة', '-', 'زراعة', 'زراعة', ',', 'أعمال', 'بناء', ',', 'معدات', 'صناعية', 'خدمات', 'خدمات', 'شركات', ',', 'سيارات', ',', 'حفلات', '-', 'مناسبات', 'كل', 'ما', 'في', 'الكترونيات', 'وأجهزة', 'منزلية', 'تلفزيونات', 'وصوتيات', 'تليفزيونات', 'دي', 'في', 'دي', 'ومسارح', 'منزلية', 'صوتيات', 'منزلية', 'مشغلات', 'MP3', 'وصوتيات', 'ريسيفرات', 'كمبيوتر', 'و', 'إكسسوارات', 'كمبيوتر', 'لاب', 'توب', 'اكسسوارات', 'و', 'قطع', 'غيار', 'كمبيوتر', 'أجهزة', 'وألعاب', 'فيديو', 'أجهزة', 'ألعاب', 'فيديو', 'ألعاب', 'فيديو', 'و', 'إكسسواراتها', 'كاميرات', 'وتصوير', 'كاميرات', 'كاميرات', 'مراقبة', 'اكسسوارات', 'الكاميرا', 'مناظير/تلسكوبات', 'أجهزة', 'منزلية', 'ثلاجات', 'وديب', 'فريزر', 'بوتاجازات', 'وأفران', 'ومايكروويف', 'غسالات', 'أطباق', 'معدات', 'وأدوات', 'طبخ', 'غسالات', 'ومجففات', 'مبردات', 'مياه', 'و', 'غلايات', 'تكييفات', 'ومراوح', 'أجهزة', 'نظافة', 'أجهزة', 'منزلية', 'أخرى', 'سخانات', 'كل', 'ما', 'في', 'أثاث', 'منزل', '-', 'ديكور', 'الحمام', 'غرفة', 'نوم', 'غرفة', 'سفرة', 'أقمشة', '-', 'ستائر', '-', 'سجاد', 'حديقة', 'و', 'أماكن', 'خارجية', 'ديكورات', 'منزل', 'مطبخ', '-', 'أدوات', 'مطبخ', 'إضاءة', 'غرفة', 'معيشة', 'أثاث', 'متعدد/أخر', 'كل', 'ما', 'في', 'الموضة', 'والجمال', 'ملابس', 'حريمي', 'ملابس', 'رجالي', 'إكسسوارات', '-', 'مستحضرات', 'تجميل-', 'عناية', 'شخصية', 'حريمي', 'إكسسوارات', '-', 'عناية', 'شخصية', 'رجالي', 'كل', 'ما', 'في', 'حيوانات', 'أليفة', 'و', 'إكسسواراتها', 'طيور', '-', 'حمام', 'قطط', 'كلاب', 'حيوانات', 'أليفة', 'أخرى', 'إكسسوارات', '-', 'منتجات', 'عناية', 'بالحيوان', 'كل', 'ما', 'في', 'مستلزمات', 'أطفال', 'عناية', '-', 'صحة', 'الطفل', 'و', 'الأم', 'ملابس', 'أطفال', 'أدوات', 'تغذية', 'للطفل', 'سراير', '-', 'عربات', '-', 'أدوات', 'تنقل', 'بالطفل', 'ألعاب', 'أطفال', 'مستلزمات', 'أطفال', 'أخرى', 'كل', 'ما', 'في', 'هوايات،', 'رياضة', 'و', 'كتب', 'تحف', '-', 'مقتنيات', 'دراجات', 'كتب', 'ألعاب', 'لوحية', '-', 'ورقية', 'أفلام', '-', 'موسيقى', 'آلات', 'موسيقية', 'أدوات', 'رياضية', 'أدوات', 'دراسة', 'تذاكر', '-', 'قسائم', 'شنط', 'سفر', 'منتجات', 'أخرى', 'كل', 'ما', 'في', 'تجارة', '-', 'صناعة', '-', 'زراعة', 'زراعة', 'أعمال', 'بناء', 'معدات', 'صناعية', 'مستلزمات', 'طبية', 'أثاث', 'و', 'مستلزمات', 'المكتب', 'معدات', 'مطاعم', 'مشروع', 'كامل', 'للبيع', 'تجارة،', 'صناعة', 'وزراعة', 'أخرى', 'كل', 'ما', 'في', 'خدمات', 'خدمات', 'شركات', 'سيارات', 'حفلات', '-' ...
# ---------------------------------
# ['MP3', 'SUV', '4X4', 'ABS', 'EBD', 'Mohamed', 'Fahmi', 'Cars', 'Allam', 'Automotive', 'Car', 'Accident', 'El', 'Masria', 'Auto', 'A200', 'BMW', 'G23', 'Series', 'M///440i', 'x-Drive', 'Convertible', 'A5', 'CAYENNE', 'PLATINUM', 'EDITION', 'AUDI', 'Q7', 'Range', 'Rover', 'Velar', 'SE', 'P250', 'Used', 'RANGE', 'ROVER', 'VELAR', 'BRAND', 'NEW', 'Chery', 'Tiggo', 'E180', 'Amg', 'Mercedes-Benz', 'E200', 'All', 'New', 'BMW', 'X4', 'Bmw', 'LEXUS', 'LX570', 'VIP', 'BLACK', 'EDITION', 'BMW740', 'Grand', 'Mercides', 'Benz', 'E300e', 'Hybride', 'Q3', 'H6', 'Chrysler', 'Country', 'Limited', 'BMW', 'X1', 'Volkswagen', 'Tiguan', 'R', 'C4', 'Benz', 'C180', 'AMG', 'Seat', 'Ibiza', 'CN7', 'GLC200', 'Audi', 'Q8', 'S-line', 'Plus', 'MG6', 'NiSSAN', 'SUNNY', 'VW', 'ID4', 'PRO', 'XV', 'Dubizzle', 'Group']
# ['Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'AdWords', ':', '830020857', 'مصر', 'الإمارات', 'السعودية', 'قطر', 'عمان', 'الكويت', 'البحرين', 'EN', 'جديد', 'مستعمل', 'تجارب', 'القيادة', 'أخبار', 'السيارات', 'فيديوهات', 'السيارات', 'خدمات', 'استيراد', 'السيارات', 'المزيد', 'أعلن', 'معنا', 'شركات', 'السيارات', 'بيع', 'سيارتك', 'دخول', '|', 'تسجيل', 'sidebar', 'دخول', '|', 'تسجيل', 'بيع', 'سيارتك', 'مجاني', 'دليل', 'شراء', 'السيارات', 'سيارات', 'مستعملة', 'استيراد', 'السيارات', 'جديد', 'أخبار', 'السيارات', 'فيديوهات', 'السيارات', 'المزيد', 'مصر', 'EN', 'single', 'items', 'sideoverlay', 'سيارات', 'مستعملة', 'ابحث', 'عن', 'سيارات', 'مستعملة', 'تصفح', 'السيارات', 'المستعملة', 'سيارات', 'مستعملة', 'للتصدير', 'دليل', 'شراء', 'السيارات', 'تصفح', 'دليل', 'السيارات', 'الجديدة', 'ابحث', 'عن', 'سيارات', 'جديدة', 'قارن', 'بين', 'السيارات', 'الجديدة', 'أسعار', 'السيارات', 'قاموس', 'السيارات', 'أخبار', 'السيارات', 'آخر', 'المشاركات', 'أخبار', 'السيارات', 'القيادات', 'الاولى', 'إطلاقات', 'السيارات', 'الجديدة', 'تجارب', 'القيادة', 'المزيد', 'أعلن', 'معنا', 'شركات', 'السيارات', 'اختر', 'الدولة', 'الإمارات', 'السعودية', 'قطر', 'عمان', 'الكويت', 'البحرين', 'ابحث', 'عن', 'سيارات', 'مستعملة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'تصفح', 'السيارات', 'المستعملة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'سيارات', 'مستعملة', 'للاستيراد', 'جديد', 'حمل', 'الأن', 'تطبيق', 'يلاموتور', 'الجديد', '!', 'وتواصل', 'بسهولة', 'مع', 'البائعين', 'عبر', 'الهاتف', 'أو', 'الرسائل', 'النصية', 'أو', 'الواتساب', 'هل', 'تريد', 'بيع', 'سيارتك؟', 'تصفح', 'دليل', 'السيارات', 'الجديدة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'ابحث', 'عن', 'سيارات', 'جديدة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'قارن', 'بين', 'السيارات', 'الجديدة', 'مقارنة', 'بين', 'أكثر', 'السيارات', 'شهرة', 'VS', 'ميتسوبيشي', 'باجيرو', '2020', 'من', '1,650,000', 'ج.م', 'تويوتا', 'فورتشنر', '2020', 'من', '739,900', 'ج.م', 'قارن', 'VS', 'تويوتا', 'لاند', 'كروزر', '2020', 'TBD', 'نيسان', 'باترول', '2020', 'من', '3,500,000', 'ج.م', 'قارن', 'VS', 'رينو', 'داستر', '2018', 'من', '210,000', 'ج.م', 'دايهتسو', 'تيريوس', '2018', 'TBD', 'قارن', 'VS', 'ميتسوبيشي', 'باجيرو', '2018', 'من', '1,000,000', 'ج.م', 'تويوتا', 'فورتشنر', '2018', 'من', '1,000,000', 'ج.م', 'قارن', 'اعرض', 'جميع', 'مقارنات', 'السيارات', 'الجديدة', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'الجديدة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'اعرض', 'جميع', 'أسعار', 'السيارات', 'جديد', 'حمل', 'الأن', 'تطبيق', 'يلام ...
# ---------------------------------
# ['Global', 'Google', 'AdWords', 'EN', 'EN', 'VS', 'VS', 'TBD', 'VS', 'TBD', 'VS', 'AUX', 'ABS', 'READ', 'MORE', 'Tab', 'Container', 'Browse', 'Make', 'Paid', 'Full', 'Banner', 'Sell', 'FREE', 'Spotlight', 'TBD', 'TBD', 'TBD', 'TBD', 'TBD', 'modelsCards', 'H2', 'Z100', 'S-Presso', 'modelsCards', 'Z560', 'modelsCards', 'HR-V', 'C5', 'Aircross', 'modelsCards', 'Crossback', 'VS', 'VS', 'TBD', 'VS', 'TBD', 'VS', 'VS', 'TBD', 'VS', 'VS', 'VS', 'VS', 'VS', 'VS', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'Venue', 'Z', 'ZS', 'GT', 'Crossland', 'X', 'Grandland', 'X', 'Crossland', 'S-Presso', 'Video', 'Section', 'Popular', 'Subscribe', 'Now', 'Toyota', 'LandCruiser', 'Opel', 'Mokka', 'SUV', 'Hyundai', 'Veloster', 'N', 'Lotus', 'Exige', 'Ford', 'Mustang', 'Mach', 'Changan', 'CS75', 'Plus', 'McLaren', 'GT', 'News', 'Latest', 'News', 'UAE', 'JETOUR', 'Anas', 'Assaf', 'Anas', 'Assaf', 'Anas', 'Assaf', 'HONGQI', 'H9', 'Anas', 'Assaf', 'Make', 'Modal', 'Popover', 'Footer', 'Footer', 'Footer', 'DEKSTOP', 'YALLAMOTOR.COM', 'EN', 'YallaMotor.com', 'Facebook', 'Pixel', 'Code', 'End', 'Facebook', 'Pixel', 'Code']
# ['ماذا', 'ستلعب', 'اليوم؟', 'ألعاب', 'سيارات', 'Crazy', 'Cars', 'City', 'Car', 'Driving', ':', 'Stunt', 'Master', 'Rocket', 'Soccer', 'Derby', 'Smash', 'Karts', 'Merge', 'Round', 'Racers', 'City', 'Rider', 'Offroader', 'V5', 'Blumgi', 'Rocket', 'Extreme', 'Car', 'Parking', '!', 'Drive', 'Mad', 'ألعاب', 'سباق', 'سيارات', 'ألعاب', 'شاحنات', 'Drifting', 'Games', 'ألعاب', 'درايفر', 'Cyber', 'Cars', 'Punk', 'Racing', 'Top', 'Speed', '3D', '3D', 'Car', 'Simulator', 'Merge', 'Cyber', 'Racers', 'Parking', 'Fury', '3D', ':', 'Beach', 'City', 'Traffic', 'Rush', '!', 'Off-Road', 'Rain', 'Cargo', 'Simulator', 'Burnin', "'", 'Rubber', 'Crash', 'n', "'", 'Burn', 'Super', 'Tunnel', 'Rush', 'Cars', 'Thief', 'Real', 'Cars', 'in', 'City', 'Car', 'Rush', 'Neon', 'Car', 'Maze', 'Demolition', 'Derby', 'Crash', 'Racing', 'Adventure', 'Drivers', '3D', 'City', 'Racer', 'Grand', 'Prix', 'Hero', 'Mad', 'Cars', 'Racing', 'and', 'Crash', 'Rally', 'Champion', 'Flying', 'Car', 'Simulator', 'Extreme', 'Off', 'Road', 'Cars', '3', ':', 'Cargo', 'Burnout', 'Drift', ':', 'Hilltop', 'Merge', 'Gangster', 'Cars', 'Go', 'Kart', 'Go', '!', 'Ultra', '!', 'Cars', 'Thief', ':', 'Tank', 'Edition', 'Dubai', 'Police', 'Parking', '2', 'Burnout', 'Extreme', 'Drift', '2', 'Truck', 'Traffic', 'Brain', 'For', 'Monster', 'Truck', '18', 'Wheeler', 'Cargo', 'Simulator', '2', 'Burnout', 'Drift', ':', 'Seaport', 'Max', 'Freeway', 'Fury', 'Car', 'Simulator', 'Arena', 'BoxRob', '3', 'Monster', 'Truck', ':', 'Forest', 'Delivery', 'Parking', 'Fury', '3D', ':', 'Night', 'Thief', 'Sling', 'Drift', 'Stock', 'Car', 'Hero', 'Fortride', ':', 'Open', 'World', 'TinyTownRacing', 'BoxRob', 'Extreme', 'Off', 'Road', 'Cars', 'Neon', 'Flytron', ':', 'Cyberpunk', 'Racer', 'BoxRob', '2', 'Burnin', "'", 'Rubber', '5', 'XS', 'Bumper', 'Cars', 'Soccer', 'School', 'Bus', 'Demolition', 'Derby', 'Super', 'Racing', 'GT', ':', 'Drag', 'Pro', 'Color', 'Crash', 'Parking', 'Fury', '3D', 'Rally', 'Point', 'Stunt', 'Car', 'Challenge', '3', 'Moving', 'Truck', ':', 'Bounty', 'Infinite', '8', 'Midnight', 'Drive', 'Mad', 'Truck', 'Challenge', 'Special', 'Rally', 'Point', '3', 'Sports', 'Car', 'Challenge', 'Parking', 'Fury', '3D', ':', 'Bounty', 'Hunter', 'Super', 'Star', 'Car', 'Moving', 'Truck', '3D', 'Arena', 'Racing', 'Shift', 'to', 'Drift', 'Just', 'Park', 'It', '11', 'Death', 'Chase', 'Truck', 'Loader', '5', 'Mad', 'Day', 'Blocky', 'Cars', 'Skiddy', 'Taxi', 'Monster', 'Truck', 'Shadow', 'Racer', 'Slot', 'Car', 'Racing', 'Monster', 'Tracks', 'Rally', 'Point', '5', 'Rally', 'Point', '2', 'Truck', 'Loader', '4', 'Blood', 'Drift', 'Zombie', 'Derby', ':', 'Pixel', 'Survival', 'Truck', 'Loader', 'Survival', 'Race', 'Hard', 'Truck', 'Freeway', 'Fury', '3', 'Moving', 'Truck', ':', 'Construction', 'Toy', 'Car', 'Simulator', 'SocCar', '18', 'Wheeler', 'Cargo', 'Simulator', 'Zombie', 'Derby', 'Zombie', 'Derby', ':', 'Blocky', 'Roads', 'Turn', 'Right', 'Desert', 'Worms', 'Car', 'Eats', 'Car', ':', 'Dungeon', 'Adventure', 'Noob', 'Drive', 'Freeway', 'Fury', '2', 'Cartoon', 'Mini', 'Racing', 'Operation', 'Desert', 'Road', 'Real', 'Simulator', 'Monster', 'Truck', 'Gear', 'Madness', 'Mad', 'Car', 'Racing', 'Truck', 'Loader', '3', 'Truck', 'Loader', '2', '2', 'Player', 'City', 'Racing', 'Smash', 'Car', 'Idle', '2', 'Zombie', 'Derby', '2', 'Just', 'Park', 'It', '12', 'Rally', 'Point', '4', 'Electric', 'Highway', 'Monsters', "'", 'Wheels', 'Special', 'Car', 'Eats', 'Car', ':', 'Winter', 'Adventure', 'Jamming', 'Car', 'Escape', 'Cartoon', 'Racers', ':', 'North', 'Pole', '2', 'Player', 'City', 'Racing', '2', 'Car', 'Eats', 'Car', ':', 'Sea', 'Adventure', 'Color', 'Car', '3D', 'Monster', 'Truck', ':', 'Skyroads', 'CATS', '-', 'Crash', 'Arena', 'Turbo', 'Stars', 'Rocking', 'Wheels', 'Parking', 'Block', 'Monster', 'Truck', 'Racing', 'Arena', 'Hole', 'N', "'", 'Fun', 'Dead', 'Paradise', ':', 'Race', 'Shooter', 'Mad', 'Day', '2', 'Crazy', 'Platez', 'Subway', 'Surfers', 'Temple', 'Run', '2', 'Venge.io', 'Stickman', 'Hook', 'Who', 'Is', '? ...
# ---------------------------------
# ['Crazy', 'Cars', 'City', 'Car', 'Driving', 'Stunt', 'Master', 'Rocket', 'Soccer', 'Derby', 'Smash', 'Karts', 'Merge', 'Round', 'Racers', 'City', 'Rider', 'Offroader', 'V5', 'Blumgi', 'Rocket', 'Extreme', 'Car', 'Parking', 'Drive', 'Mad', 'Drifting', 'Games', 'Cyber', 'Cars', 'Punk', 'Racing', 'Top', 'Speed', '3D', '3D', 'Car', 'Simulator', 'Merge', 'Cyber', 'Racers', 'Parking', 'Fury', '3D', 'Beach', 'City', 'Traffic', 'Rush', 'Off-Road', 'Rain', 'Cargo', 'Simulator', 'Burnin', 'Rubber', 'Crash', 'Burn', 'Super', 'Tunnel', 'Rush', 'Cars', 'Thief', 'Real', 'Cars', 'City', 'Car', 'Rush', 'Neon', 'Car', 'Maze', 'Demolition', 'Derby', 'Crash', 'Racing', 'Adventure', 'Drivers', '3D', 'City', 'Racer', 'Grand', 'Prix', 'Hero', 'Mad', 'Cars', 'Racing', 'Crash', 'Rally', 'Champion', 'Flying', 'Car', 'Simulator', 'Extreme', 'Off', 'Road', 'Cars', 'Cargo', 'Burnout', 'Drift', 'Hilltop', 'Merge', 'Gangster', 'Cars', 'Go', 'Kart', 'Go', 'Ultra', 'Cars', 'Thief', 'Tank', 'Edition', 'Dubai', 'Police', 'Parking', 'Burnout', 'Extreme', 'Drift', 'Truck', 'Traffic', 'Brain', 'For', 'Monster', 'Truck', 'Wheeler', 'Cargo', 'Simulator', 'Burnout', 'Drift', 'Seaport', 'Max', 'Freeway', 'Fury', 'Car', 'Simulator', 'Arena', 'BoxRob', 'Monster', 'Truck', 'Forest', 'Delivery', 'Parking', 'Fury', '3D', 'Night', 'Thief', 'Sling', 'Drift', 'Stock', 'Car', 'Hero', 'Fortride', 'Open', 'TinyTownRacing', 'BoxRob', 'Extreme', 'Off', 'Road', 'Cars', 'Neon', 'Flytron', 'Cyberpunk', 'Racer', 'BoxRob', 'Burnin', 'Rubber', 'XS', 'Bumper', 'Cars', 'Soccer', 'School', 'Bus', 'Demolition', 'Derby', 'Super', 'Racing', 'GT', 'Drag', 'Pro', 'Color', 'Crash', 'Parking', 'Fury', '3D', 'Rally', 'Point', 'Stunt', 'Car', 'Challenge', 'Moving', 'Truck', 'Bounty', 'Infinite', 'Midnight', 'Drive', 'Mad', 'Truck', 'Challenge', 'Special', 'Rally', 'Point', 'Sports', 'Car', 'Challenge', 'Parking', 'Fury', '3D', 'Bounty', 'Hunter', 'Super', 'Star', 'Car', 'Moving', 'Truck', '3D', 'Arena', 'Racing', 'Shift', 'Drift', 'Just', 'Park', 'It', 'Death', 'Chase', 'Truck', 'Loader', 'Mad', 'Day', 'Blocky', 'Cars', 'Skiddy', 'Taxi', 'Monster', 'Truck', 'Shadow', 'Racer', 'Slot', 'Car', 'Racing', 'Monster', 'Tracks', 'Rally', 'Point', 'Rally', 'Point', 'Truck', 'Loader', 'Blood', 'Drift', 'Zombie', 'Derby', 'Pixel', 'Survival', 'Truck', 'Loader', 'Survival', 'Race', 'Hard', 'Truck', 'Freeway', 'Fury', 'Moving', 'Truck', 'Construction', 'Toy', 'Car', 'Simulator', 'SocCar', 'Wheeler', 'Cargo', 'Simulator', 'Zombie', 'Derby', 'Zombie', 'Derby', 'Blocky', 'Roads', 'Turn', 'Right', 'Desert', 'Worms', 'Car', 'Eats', 'Car', 'Dungeon', 'Adventure', 'Noob', 'Drive', 'Freeway', 'Fury', 'Cartoon', 'Mini', 'Racing', 'Operation', 'Desert', 'Road', 'Real', 'Simulator', 'Monster', 'Truck', 'Gear', 'Madness', 'Mad', 'Car', 'Racing', 'Truck', 'Loader', 'Truck', 'Loader', 'Player', 'City', 'Racing', 'Smash', 'Car', 'Idle', 'Zombie', 'Derby', 'Just', 'Park', 'It', 'Rally', 'Point', 'Electric', 'Highway', 'Monsters', 'Wheels', 'Special', 'Car', 'Eats', 'Car', 'Winter', 'Adventure', 'Jamming', 'Car', 'Escape', 'Cartoon', 'Racers', 'North', 'Pole', 'Player', 'City', 'Racing', 'Car', 'Eats', 'Car', 'Sea', 'Adventure', 'Color', 'Car', '3D', 'Monster', 'Truck', 'Skyroads', 'CATS', 'Crash', 'Arena', 'Turbo', 'Stars', 'Rocking', 'Wheels', 'Parking', 'Block', 'Monster', 'Truck', 'Racing', 'Arena', 'Hole', 'Fun', 'Dead', 'Paradise', 'Race', 'Shooter', 'Mad', 'Day', 'Crazy', 'Platez', 'Subway', 'Surfers', 'Temple', 'Run', 'Venge.io', 'Stickman', 'Hook', 'Who', 'Narrow.One', 'Repuls.io', 'Brain', 'Test', 'Tricky', 'Stories', 'SchoolBreak.io', 'Friday', 'Night', 'Funkin', 'Idle', 'Ants', 'Moto', 'X3M', 'Stick', 'Merge', 'Parkour', 'Race', 'Mad', 'GunZ', 'Gold', 'Digger', 'FRVR', 'Like', 'King', 'Sushi', 'Party', 'EvoWorld', 'FlyOrDie', 'Crossy', 'Road', 'Where', 'My', 'Cat', 'Combat', 'Online', 'Fury', 'Wars', 'Raft', 'Wars', 'Multiplayer', 'Temple', 'Boom', 'Impossible', 'Quiz', 'Getaway', 'Shootout', 'Bad', 'Ice-Cream', 'S ...
# ['19095', 'تسجيل', 'خروج', 'تسجيل', 'الدخول', 'احجز', 'اونلاين', 'بحث', 'متقدم', 'مقارنة', 'السيارات', 'اللغة', 'عربي', 'English', 'الرئيسية', '(', 'current', ')', 'جديدة', 'مستعملة', 'أضف', 'إعلان', 'فروعنا', 'مراكز', 'الخدمة', 'عن', 'المصرية', 'تواصل', 'معنا', 'المصرية', 'للسيارات', 'slider', 'seaarch', 'الماركة', 'كل', 'الماركات', 'أم', 'جي', 'دى', 'اس', 'جلورى', 'فورثينج', 'بنتلى', 'هيونداى', 'هوندا', 'جاك', 'جاجوار', 'جيب', 'أوبل', 'كيا', 'لادا', 'لاندروفر', 'مازدا', 'مازيراتى', 'متسوبيشى', 'مرسيدس', 'مينى', 'نيسان', 'بورش', 'بيجو', 'تويوتا', 'رينو', 'سانج', 'يونج', 'سكودا', 'سوبارو', 'سوزوكى', 'سيات', 'فولفو', 'فولكس', 'فاجن', 'فيات', 'فورد', 'الفاروميو', 'أودى', 'بي', 'ام', 'دبليو', 'برليناس', 'بى', 'واى', 'دي', 'بروتون', 'شيفروليه', 'شانجان', 'شيرى', 'ستروين', 'جيتور', 'ساو', 'ايست', 'هافال', 'بيستون', 'رينج', 'روفر', 'الموديلات', 'كل', 'الموديلات', 'الحالة', 'جديدة', 'مستعملة', 'سنة', 'أختر', 'السنة', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '-', 'الأسعار', 'استرشادية', 'فقط', 'الأسعار', 'النهائية', 'عند', 'الاستلام', 'مراكز', 'الخدمة', 'و', 'سيارات', 'مستعملة', 'مراكز', 'الخدمة', 'المعتمدة', 'للمصرية', 'للسيارات', 'إحجز', 'صيانتك', 'اضغط', 'للتعرف', 'على', 'أسطول', 'سيارات', 'المصرية', 'المستعملة', 'إضغط', 'لبيع', 'سيارتك', 'brands-slider', 'السيارات', 'الجديدة', 'أخبار', 'عالم', 'السيارات', '``', 'شيري', "''", 'تطرح', 'الإصدار', '``', 'أريزو', '5', 'جي', 'تي', "''", 'رسميًا', 'داخل', 'الصين', 'بقوة', '230', 'حصان', 'الأربعاء', '29', 'مارس', '2023', 'اقرأ', 'المزيد', 'من', 'ميني', 'ڤان', 'إلى', 'SUV', '..', 'إزاحة', 'الستار', 'عن', 'الجيل', 'السادس', 'لـ', '``', 'رينو', 'إسباس', "''", 'بملامح', 'مستوحاة', 'من', '``', 'أوسترال', "''", 'الأربعاء', '29', 'مارس', '2023', 'اقرأ', 'المزيد', 'قبل', 'تدشينها', 'في', 'أبريل', '..', 'الكشف', 'عن', 'صور', 'مقصورة', '``', 'زيكر', 'X', "''", 'التابعة', 'لمجموعة', '``', 'جيلي', "''", 'الأربعاء', '29', 'مارس', '2023', 'اقرأ', 'المزيد', 'الكشف', 'عن', 'الصور', 'الرسمية', 'الأولى', 'لـ', '``', 'هيونداي', 'سوناتا', "''", 'فيس', 'ليفت', '2024', '..', 'ولأول', 'مرة', 'إصدار', '``', 'دفع', 'كلي', "''", 'الأربعاء', '29', 'مارس', '2023', 'اقرأ', 'المزيد', 'تبدأ', 'من', '559', 'ألف', 'جنيه', '..', 'أسعار', 'سيارات', '``', 'ستروين', '``', 'في', 'مصر', 'بعد', 'زيادات', 'مارس', 'الأربعاء', '29', 'مارس', '2023', 'اقرأ', 'المزيد', 'لقطات', 'تجسسية', 'للجيل', 'الثالث', 'من', '``', 'داتشيا', 'داستر', "''", 'موديل', '2024', 'الأربعاء', '29', 'مارس', '2023', 'اقرأ', 'المزيد', '19095', 'الرئيسية', 'جديدة', 'مستعملة', 'عروضنا', 'أخبار', 'عالم', 'السيارات', 'فروعنا', 'مراكز', 'الخدمة', 'الحجز', 'أونلاين', 'تواصل', 'معنا', 'عن', 'المصرية', 'وظائف', 'روابط', 'تهمك', 'أرقام', 'الرافعات', 'قم', 'بتحميل', 'التطبيق', 'الخاص', 'بنا', 'اشترك', 'بالنشرة', 'الإخبارية', 'نرسل', 'أفضل', 'العروض', 'و', 'آخر', 'أخبار', 'السيارات', 'لمستخدمينا', 'المشتركين', 'أسبوعيا', 'تواصل', 'معنا', 'جميع', 'الحقوق', 'محفوظة', '©', 'المصرية', 'للسيارت', '2021', ':', 'Powered', 'By', 'Scripts', 'JS', 'Libraries', 'Scripts', 'Scripts', 'Scripts']
# ---------------------------------
# ['English', 'SUV', 'X', 'Powered', 'By', 'Scripts', 'JS', 'Libraries', 'Scripts', 'Scripts', 'Scripts']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'مشاركة', 'send', 'أسعار', 'السيارات', 'الرسمية', 'محدثة', 'يوميا', 'في', 'مصر', 'لعام', '2022', '-', '2023', 'كل', 'الماركات', 'والموديلات', 'الجديدة', 'ومواصفات', 'وصور', 'السيارات', 'الجديدة', 'في', 'مصر', 'والمعارض', 'المتاحة', 'بها', 'من', 'خلال', 'موقعنا', 'سوق', 'السيارات', 'أفضل', 'خدمة', 'مجانية', 'لبيع', 'وشراء', 'السيارات', '.', 'أنظر', 'أيضا', 'أسعار', 'السيارات', 'المستعملة', 'كل', 'الماركات', 'آخر', 'تحديث', '(', '2023-05-12', ')', 'لا', 'يوجد', 'نتائج', 'شيفروليه', 'كيا', 'بيجو', 'هيونداي', 'سكودا', 'فيات', 'دى', 'اس', 'اوبل', 'بى', 'واى', 'دى\u202c', 'رينو', 'تويوتا', 'هوندا', 'ساوايست', 'مرسيدس', 'هافال', 'سيتروين', 'لكزس', 'جاكوار', 'مازيراتي', 'لاند', 'روفر', 'جيب', 'شيرى', 'لادا', 'جيتور', 'جيلي', 'سوزوكى', 'استون', 'مارتن', 'بروتون', 'بيستون', 'ميتسوبيشي', 'جاك', 'فولفو', 'بايك', 'فورد', 'كاي', 'ي', 'مازدا', 'مينى', 'فولكس', 'فاغن', 'دونج', 'فنج', 'بريليانس', 'سيات', 'كوبرا', 'نيسان', 'ام', 'جى', 'دفسك', 'الفاروميو', 'فورثينج', 'بورش', 'سوبارو', 'شانجى', 'بي', 'ام', 'دبليو', 'سانج', 'يونج', 'اودي', 'شانجان', 'أختر', 'متوسط', 'السعر', 'أقل', 'من', '150,000', '150,000', '-', '175,000', '175,000', '-', '200,000', '20 ...
# ---------------------------------
# ['English', 'CC', 'M50', 'CC', 'CC', 'Comfort', 'CC', 'Comfort', 'Accessories', 'CC', 'CC', 'E1', 'CC', 'F3', 'CC', 'E2', 'CC', 'CC', 'Midline', 'CC', 'F3', 'CC', 'Super', 'Saloon', 'CC', 'L3', 'GLX-i', 'AT', 'CC', 'Luxury', 'CC', 'Luxury', 'Accessories', 'CC', 'L3', 'GS-i', 'AT', 'CC', 'CC', 'E1', 'CC', 'C3', 'Live', 'CC', 'Comfort', 'CC', 'CC', 'L1', 'CC', 'V6', 'Deluxe', 'CC', 'BASIC', 'CC', 'Active', 'CC', 'CC', 'C3', 'Feel', 'CC', 'V6', 'Grand', 'Deluxe', 'CC', 'Luxury', 'CC', 'LX', 'CC', 'High', 'Line', 'CC', 'DX3', 'Highline', 'CC', 'RB', 'TINTED', 'GLASS', 'CC', 'L1', 'CC', 'DX3', 'Highline', 'Two', 'Tone', 'CC', 'C3', 'Feel', 'CC', 'Active', 'CC', 'RB', 'SR', 'TINTED', 'GLASS', 'CC', 'Premium', 'SV', 'CC', 'CC', 'LX-S', 'CC', 'Allure', 'CC', 'RB', 'DAB', 'ABS', 'TINTED', 'GLASS', 'CC', 'Premium', 'SV', 'CC', 'V6', 'Flagship', 'CC', 'AT', 'BASELINE', 'Leather', 'CC', 'I10', 'Spirit', 'CC', 'L2', 'CC', 'RB', 'DAB', 'ABS', 'PLUS', 'TINTED', 'GLASS', 'CC', 'Hatla2ee.com']
# ['السبت', '13', 'مايو', '2023', 'مصراوي', 'لايف', 'الأكثر', 'قراءة', 'الآن', 'أرشيف', 'مصراوى', 'مواقيت', 'الصلاة', '27', 'القاهرة', '-', 'مصر', '27', '17', 'الرطوبة', ':', '32', '%', 'الرياح', ':', 'شمال', 'غرب', 'المزيد', 'أسعار', 'العملات', 'سعر', 'صرف', 'الدولار', 'مقابل', 'الجنيه', 'المصري', 'السبت', '13', 'مايو', '2023', '30.69', 'جنيه', 'المزيد', 'أسعار', 'الذهب', 'سعر', 'جرام', 'الذهب', 'عيار', '21', 'السبت', '13', 'مايو', '2023', '2395', 'جنيه', 'المزيد', 'سوق', 'مصراوي', 'للإعــلان', 'أكثر', 'الكلمات', 'انتشاراً', 'الملك', 'تشارلز', 'امتحانات', 'الثانوية', '2023', 'أحداث', 'السودان', 'سعر', 'الذهب', 'الحوار', 'الوطني', 'الطقس', 'أمازون', 'سعر', 'الدولار', 'سعر', 'الفائدة', 'تم', 'إكتشاف', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", 'عزيزي', 'المستخدم', 'العائد', 'من', 'الإعلانات', 'يمثل', 'مصدر', 'الربح', 'الأساسي', 'للموقع', 'والعاملين', 'به', 'مما', 'يساعدنا', 'على', 'البقاء', 'مستقلين', 'وحياديين', 'حيث', 'أننا', 'غير', 'تابعين', 'لأي', 'جهة', 'حكومية', 'أو', 'حزب', '.', 'لمساعدتنا', 'على', 'الإستمرار', 'في', 'إنتاج', 'محتوى', 'مهني', 'صحفي', 'حيادي', 'غير', 'موجه', 'أو', 'ممول', 'نرجو', 'إلغاء', 'تفعيل', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", '.', 'شكرا', 'لتفهمك', 'أخبار', 'السيارات', 'أخبار', 'السيارات', '``', '4', 'أيام', 'فقط', 'على', 'انتهاء', 'العرض', "''", '..', 'اشتري', 'سوزوكي', 'جيمني', 'موديل', '2023', 'برسوم', 'أخبار', 'السيارات', 'أرخص', 'سيارة', 'أوروبية', '``', 'هاتشباك', "''", 'زيرو', 'فى', 'مصر', '..', 'تعرف', 'على', 'سعرها', 'أخبار', 'السيارات', '4', 'سيارات', 'زيرو', 'تحمل', 'شعار', 'ميتسوبيشي', 'بمصر', '..', 'أرخصهم', 'بـ', '445', 'ألف', 'جنيه', 'أخبار', 'السيارات', '3', 'سيارات', 'سيدان', 'يابانية', 'تبدأ', 'أسعارها', 'من', '170', 'ألف', 'جنيه', 'أخبار', 'السيارات', '``', '6', 'أيام', 'وينتهي', 'العرض', "''", '..', 'اشتري', 'شيري', 'تيجو', '7', 'برو', '2022', 'بـ156', 'ألف', 'جنيه', 'أخبار', 'السيارات', '``', 'اعتمادية', 'يحبها', 'كل', 'من', 'عرفها', "''", '..', 'سيارة', 'أوروبية', '``', 'أتوماتيك', "''", 'بـ200', 'ألف', 'جنيه', 'إعلان', 'إعلان', 'مقالات', 'مصراوي', 'المزيد', 'بعض', 'من', 'طقوس', 'الفصول', '..', 'د', '.', 'هشام', 'عطية', 'عبد', 'المقصود', 'منذ', '11', 'ساعة', 'اهتمامات', 'الشباب', 'العربي', 'د', '.', 'إيمان', 'رجب', '08', 'مايو', ',', '2023', 'الذكاء', 'الاصطناعي', 'في', 'الصحافة', '..', 'أوهام', '``', 'شبيك', 'لبيك', "''", 'علاء', 'الغطريفي', '07', 'مايو', ',', '2023', 'ملفات', 'تفاعلية', 'المزيد', 'رياضة', 'عربية', 'وعالمية', 'فانتازي', '..', '``', 'صلاح', "''", 'من', 'بين', 'الأفضل', 'لاختيارات', 'كابتن', 'الجولة36', 'زووم', '``', 'إيه', 'أهميتك', 'في', 'المجتمع؟', "''", '..', 'أسامة', 'منير', 'يفتح', 'النار', 'على', 'حسن', 'شاكوش', 'لهذا', 'مصراوى', 'TV', 'المزيد', 'أحدث', 'موضوعات', 'السيارات', 'أخبار', 'السيارات', '``', 'سيارة', 'العمر', 'الطويل', "''", '..', 'SUV', 'كورية', '``', 'أتوماتيك', "''", 'أحبها', 'الملايين', 'أخبار', 'السيارات', '3', 'سيارات', 'سيدان', 'يابانية', 'تبدأ', 'أسعارها', 'من', '170', 'ألف', 'جنيه', 'أخبار', 'السيارات', '4', 'سيارات', 'زيرو', 'تحمل', 'شعار', 'ميتسوبيشي', 'بمصر', '..', 'أرخصهم', 'بـ', '445', 'ألف', 'جنيه', 'أخبار', 'السيارات', 'أرخص', 'سيارة', 'أوروبية', '``', 'هاتشباك', "''", 'زيرو', 'فى', 'مصر', '..', 'تعرف', 'على', 'سعرها', 'أخبار', 'السيارات', '``', '4', 'أيام', 'فقط', 'على', 'انتهاء', 'العرض', "''", '..', 'اشتري', 'سوزوكي', 'جيمني', 'موديل', '2023', 'برسوم', 'أخبار', 'السيارات', 'أوبل', 'تطلق', 'سيارتها', 'Mokka', 'Black', 'الجديدة', '..', 'أسعار', 'ومواصفات', 'أخبار', 'السيارات', 'ماسك', 'يعلن', 'قرب', 'استقالته', 'من', 'منصب', 'المدير', 'التنفيذي', 'لتويتر', 'أخبار', 'السيارات', 'تسلا', 'تعدل', 'أسعار', 'سياراتها', 'للمرة', 'الثالثة', 'خلال', 'أقل', 'من', 'شهر', 'أخبار', 'السيارات', 'تسلا', 'تستدعي', '1.1', 'مليون', 'سيارة', 'في', 'الصين', 'بسبب', 'عيب', 'خطير', 'أخبار', 'السيارات', 'كيف', 'تتصرف', 'في', 'حالة', 'وضع', 'الوقود', 'الخاطئ', 'بسياراتك', '..', 'ديزل', 'بدل', 'بنزين', 'والعكس', 'برعاية', 'أخبار', 'الاقتصاد', 'والـ', 'Startups', 'المزيد', 'إعلان', 'نصائح', 'المزيد', 'تنقذك', 'في', 'حالات', 'الطوارئ', '. ...
# ---------------------------------
# ['AD', 'Block', 'AD', 'Block', 'TV', 'SUV', 'Mokka', 'Black', 'Startups', 'SUV', 'SUV', 'Cross', 'Media', 'TV']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'التأمين', 'علي', 'السيارات', 'تقدم', 'شركة', 'كومين', 'لوساطة', 'التأمين', 'تجربة', 'فريدة', 'ومتكاملة', 'عبر', 'الوساطة', 'الرقمية', 'لشراء', 'احتياجات', 'التأمين', 'من', 'خلال', 'شركات', 'تأمين', 'راسخة', '.', 'تم', 'ترخيص', 'كومين', 'من', 'هيئة', 'الرقابة', 'المالية', 'برقم', 'تسجيل', '64', '.', 'تأمين', 'علي', 'سيارة', 'مستعملة', 'تأمين', 'علي', 'سيارة', 'جديدة', 'الماركة', '*', 'إختر', 'ماركة', 'اسبيرانزا', 'استون', 'مارتن', 'اكسييد', 'الفاروميو', 'ام', 'جى', 'امجيراند', 'انفينيتي', 'اوبل', 'اودي', 'ايسوزو', 'بايك', 'بروتون', 'بريليانس', 'بنتلى', 'بوجاتى', 'بورش', 'بونتياك', 'بويك', 'بى', 'واى', 'دى\u202c', 'بي', 'ام', 'دبليو', 'بيجو', 'بيرودوا', 'بيستون', 'تاتا', 'تسلا', 'تويوتا', 'جاك', 'جاكوار', 'جريت', 'وول', 'جون', 'واى', 'جى', 'ام', 'سى', 'جي', 'أي', 'سي', 'جيب', 'جيتور', 'جيلي', 'جينيسيس\u200e', 'داتسون', 'دايهاتسو', 'دايو', 'دفسك', 'دودج', 'دوماى', 'دونج', 'فنج', 'دى', 'اس', 'رولز', 'رويس', 'رينو', 'زد', 'ان', 'اى', 'زوتى', 'ساب', 'سانج', 'يونج', 'ساوايست', 'سايبا', 'سايون', 'سكودا', 'سمارت', 'سوبارو', 'سوزوكى', 'سوكون', 'سيات', 'سيتروين', 'سينوفا', 'شانا', 'شانجان', 'شانجى', 'شيرى', 'شيفروليه', 'غاز', 'فاو', 'فوتون', 'فورثينج', 'فورد', 'فولفو', 'فولكس', 'فاغن', 'فيات', 'ف ...
# ---------------------------------
# ['English', 'Hatla2ee.com']
# ['English', 'أضف', 'إعلان', 'عربيات', 'للبيع', 'عربيات', 'للبيع', 'كل', 'العربيات', 'عربيات', 'جديدة', 'عربيات', 'مستعملة', 'عربيات', 'كهرباء', 'عربيات', 'مستوردة', 'عربيات', 'ينفع', 'تتقسط', 'كتالوج', 'العربيات', 'الجديدة', 'تسعير', 'تقسيط', 'تأمين', 'صيانة', 'التجار', 'والمعارض', 'أخبار', 'أضف', 'إعلان', 'القائمة', 'إغلاق', 'تسجيل', 'دخول', '/', 'تسجيل', 'حساب', 'عربيات', 'للبيع', 'كل', 'العربيات', 'عربيات', 'جديدة', 'عربيات', 'مستعملة', 'عربيات', 'كهرباء', 'عربيات', 'مستوردة', 'عربيات', 'ينفع', 'تتقسط', 'كتالوج', 'العربيات', 'الجديدة', 'سعر', 'عربيتك', 'تقسيط', 'العربية', 'تأمين', 'صيانة', 'عربيتك', 'التجار', 'والمعارض', 'الأخبار', 'أضف', 'إعلان', 'اللغة', 'English', 'سياسة', 'الخصوصية', 'بحث', 'مفصل', 'الاحدث', 'ترتيب', 'حسب', 'إغلاق', 'الاحدث', 'الاقل', 'سعراً', 'الاعلى', 'سعراً', 'السنة', 'الاحدث', 'أولاً', 'السنة', ':', 'الاقدم', 'أولاً', 'الكيلومترات', ':', 'الاقل', 'أولاً', 'الكيلومترات', ':', 'الاكثر', 'أولاً', 'بحث', 'مفصل', 'إعادة', 'الضبط', 'ترتيب', 'حسب', 'الاحدث', 'ترتيب', 'حسب', 'إغلاق', 'الاحدث', 'الاقل', 'سعراً', 'الاعلى', 'سعراً', 'السنة', 'الاحدث', 'أولاً', 'السنة', ':', 'الاقدم', 'أولاً', 'الكيلومترات', ':', 'الاقل', 'أولاً', 'الكيلومترات', ':', 'الاكثر', 'أولاً', 'الحالة', 'الكل', 'جديد', 'عربيات', 'جديدة', 'مستعمل', 'عربيات', 'مستعملة', 'الماركة', 'والموديل', 'أستون', 'مارتن', 'ألفا', 'روميو', 'أوبل', 'أودى', 'إم', 'جي', 'عرض', 'الكل', '89', 'ماركة', 'إختر', 'الماركة', 'إغلاق', 'أستون', 'مارتن', 'ألفا', 'روميو', 'أوبل', 'أودى', 'إم', 'جي', 'اسبيرانزا', 'انفينيتى', 'ايجل', 'ايسوزو', 'بايك', 'بروتون', 'بريليانس', 'بنتلي', 'بورش', 'بونتياك', 'بويك', 'بي', 'ام', 'دبليو', 'بي', 'واى', 'دى', 'بيجو', 'بيرودوا', 'بيستون', 'تسلا', 'تويوتا', 'جاجوار', 'جاك', 'جريت', 'وول', 'جي', 'إم', 'سي', 'جيب', 'جيتور', 'جيلي', 'جين', 'بى', 'داتشيا', 'دايهاتسو', 'دايو', 'دودج', 'دونج', 'فينج', 'دي', 'اس', 'رولز', 'رويس', 'رينج', 'روفر', 'رينو', 'زوتي', 'ساب', 'سامسونج', 'سانج', 'يونج', 'ساوايست', 'سايبا', 'ستروين', 'سكودا', 'سمارت', 'سوبارو', 'سوزوكي', 'سيات', 'سينوفا', 'شانا', 'شانجان', 'شانجي', 'شيري', 'شيفروليه', 'فاو', 'فورثينج', 'فورد', 'فولفو', 'فولكس', 'فاجن', 'فيات', 'فيراري', 'كاديلاك', 'كايي', 'كرايسلر', 'كوبرا', 'كومودو', 'كيا', 'لادا', 'لامبورجيني', 'لاند', 'روفر', 'لانشيا', 'لكزس', 'لنكولن', 'ليفان', 'مابل', 'مازدا', 'مازيراتي', 'ماهيندرا', 'مرسيدس', 'ميتسوبيشي', 'ميركوري', 'ميني', 'نصر', 'نيسان', 'هافال', 'هافي', 'هامر', 'هاوتاي', 'هايما', 'هوندا', 'هيونداى', 'مسح', 'الكل', 'تطبيق', 'مكان', 'تواجد', 'العربية', 'القاهرة', 'الجيزة', 'الفيوم', 'القليوبية', 'الإسكندرية', 'عرض', 'الكل', 'مثال', ':', 'منطقة', 'مصر', 'الجديدة', '|', 'محافظة', 'القاهرة', 'إختر', 'المحافظة', 'إغلاق', 'القاهرة', 'الجيزة', 'الفيوم', 'القليوبية', 'الإسكندرية', 'الإسماعيلية', 'الغربية', 'السويس', 'الشرقية', 'الدقهلية', 'بني', 'سويف', 'المنوفية', 'أسيوط', 'المنيا', 'مرسى', 'مطروح', 'شمال', 'سيناء', 'أسوان', 'الاقصر', 'كفر', 'الشيخ', 'قنا', 'جنوب', 'سيناء', 'حلوان', 'سوهاج', 'دمياط', 'بورسعيد', 'الوادي', 'الجديد', 'البحيرة', 'البحر', 'الاحمر', 'الساحل', 'الشمالى', 'المنصورة', 'الغردقة', 'شرم', 'الشيخ', 'القصير', 'نويبع', 'رأس', 'سدر', 'سفاجا', 'دهب', 'العين', 'السخنة', 'مرسى', 'علم', 'رأس', 'البر', 'الجونة', 'واحة', 'سيوة', 'سانت', 'كاترين', 'طابا', 'الواحات', 'البحرية', 'الطور', 'مسح', 'الكل', 'تطبيق', 'السعر', '(', 'جنيه', ')', 'جنيه', 'جنيه', 'السنة', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992',  ...
# ---------------------------------
# ['English', 'English', 'SUV', 'Please', 'JavaScript']
# ['Google', 'Tag', 'Manager', '(', 'noscript', ')', 'End', 'Google', 'Tag', 'Manager', '(', 'noscript', ')', 'alarm', 'message', 'when', 'added', 'more', 'than', '3', 'cars', 'to', 'compare', 'add', 'class', 'showMsg', 'to', 'body', 'tag', 'متابعة', 'Tab', '1', 'سيارات', 'جديدة', 'Tab', '2', 'سيارات', 'مستعملة', 'Tab', '3', 'موتوسيكلات', 'New', 'Car', 'Content', 'لا', 'توجد', 'سيارات', 'جديدة', 'في', 'قائمة', 'المقارنات', 'قارن', 'Used', 'Car', 'Content', 'لا', 'توجد', 'سيارات', 'مستعملة', 'في', 'قائمة', 'المقارنات', 'قارن', 'Scooter', 'Content', 'لا', 'توجد', 'موتوسيكلات', 'مستعملة', 'في', 'قائمة', 'المقارنات', 'قارن', 'notification', 'خدمة', 'الاشعارات', 'تلقى', 'آخر', 'الأخبار', 'والمستجدات', 'من', 'موقع', 'شيفت', 'اشترك', 'لاحقا', '--', '--', '--', '--', 'Header', '--', '--', '--', '--', 'First', 'Level', 'Menu', 'Item', '1', 'HP', 'الرئيسية', 'Item', '5', 'Experiments', 'تجارب', 'قيادة', 'Item', '2', 'News', 'أخبار', 'Second', 'Level', 'Menu', 'الكل', 'عالمية', 'محلية', 'Item', '3', 'Reports', 'تقارير', 'Second', 'Level', 'Menu', 'سيارات', 'جديدة', 'تغطيات', 'صحفية', 'تكنولوجيا', 'رياضة', 'سيارات', 'Item', '4', 'Events', 'مالتيميديا', 'Second', 'Level', 'Menu', 'صور', 'Item', '7', 'Video', 'فيديو', 'Item', '4', 'Cars', 'Prices', 'أسعار', 'السيارات', 'Item', '4', 'Cars', 'Prices', 'سيارات', 'مستعملة', 'Comparison', 'sell', 'your', 'car', 'بيع', 'عربيتك', 'المقارنة', 'سيارات', 'جديدة', 'سيارات', 'مستعملة', 'موتوسيكلات', 'before', 'login', 'لتتمكن', 'من', 'إضافة', 'إعلان', 'يرجى', 'الدخول', 'على', 'حسابك', 'اذا', 'كنت', 'مشتركاً', 'او', 'تسجيل', 'حساب', 'جديد', 'اذا', 'كنت', 'مستخدم', 'جديد', 'دخول', 'مستخدم', 'جديد', 'login', 'before', 'add', 'photo', 'دخول', 'مستخدم', 'جديد', 'login', 'تسجيل', 'الدخول', 'هنا', 'تسجيل', 'باستخدام', 'الفيسبوك', 'تسجيل', 'باستخدام', 'جوجل', 'Login', 'Form', 'ينبغي', 'إدخال', 'بريد', 'الكتروني', 'صالح', 'يجب', 'أن', 'تحتوي', 'كلمة', 'المرور', 'على', '8', 'أحرف', 'على', 'الأقل', 'وتحتوي', 'على', 'أحرف', 'كبيرة', 'وصغيرة', 'تذكرني', 'نسيت', 'كلمة', 'السر', 'دخول', '--', '--', 'Remember', 'Popup', '--', '--', '-', 'البريد', 'الالكتروني', 'ينبغي', 'إدخال', 'بريد', 'الكتروني', 'صالح', 'متابعة', 'New', 'User', 'مستخدم', 'جديد', 'اضغط', 'هنا', 'new', 'user', 'مستخدم', 'جديد', 'Register', 'Form', 'الأسم', '*', 'هذه', 'المساحة', 'مطلوبة', 'البريد', 'الالكتروني', '*', 'ينبغي', 'إدخال', 'بريد', 'الكتروني', 'صالح', 'كلمة', 'المرور', '*', 'يجب', 'أن', 'تحتوي', 'كلمة', 'المرور', 'على', '8', 'أحرف', 'على', 'الأقل', 'وتحتوي', 'على', 'أحرف', 'كبيرة', 'وصغيرة', 'تأكيد', 'كلمة', 'المرور', '*', 'يجب', 'أن', 'يتطابق', 'تأكيد', 'كلمة', 'المرور', 'مع', 'كلمة', 'المرور', 'التي', 'تم', 'إدخالها', 'رقم', 'المنزل', 'الموبايل', '*', 'يجب', 'عليك', 'إدخال', 'رقم', 'هاتف', 'محمول', 'صالح', 'موافق', 'علي', 'جميع', 'الشروط', 'والاحكام', '*', 'أضف', 'حسابك', 'Loader', 'error', 'Message', 'يجب', 'الموافقة', 'علي', 'الشروط', 'والاحكام', 'أولا', 'مستخدم', 'مسجل؟', 'تسجيل', 'الدخول', 'هنا', 'Social', 'Media', '--', '--', '--', '--', 'Header', '--', '--', '--', '--', '--', '--', '--', '--', 'Header', 'Mob', '--', '--', '--', '--', '--', '--', '--', '--', 'Content', '--', '--', '--', '--', 'Sponsor', 'Start', ':', 'Defining', 'Ads', 'Slots-', 'End', ':', 'Defining', 'Ads', 'Slots-', 'bread', 'crumb', 'الرئيسية', 'سيارات', 'مستعملة', 'للبيع', 'فى', 'مصر', 'Full', 'Width', 'Billboard', 'Start', ':', 'Defining', 'Ads', 'Slots-', 'اعلان', '/96551095/V3_Shift/Desktop/LeaderBoard', 'End', ':', 'Defining', 'Ads', 'Slots-', 'tabs', 'Tab', '1', 'سيارة', 'جديدة', 'Tab', '2', 'سيارة', 'مستعملة', 'search', 'إبحث', 'عن', 'Tab', '1', 'سيارة', 'جديدة', 'Tab', '2', 'سيارة', 'مستعملة', 'Tab', '3', 'New', 'Car', 'Content', 'Used', 'Car', 'Content', 'advanced', 'search', 'Div', 'city', 'area', 'ناقل', 'الحركة', 'أوتوماتيك', 'مانيوال', 'الفئة', '4x4', 'MPV', 'SUV', 'ستيشن', 'سيدان', 'فان', 'كابورليه', 'كوبيه', 'نقل', 'هاتشباك', 'أخرى', 'اللون', 'أبيض', 'أحمر', 'أخضر', 'أزرق', 'أسود', 'أصفر', 'برتقالي', 'بنى', 'بيج', 'ذهبي', 'رمادي', 'فضي', 'كحلى', 'موك ...
# ---------------------------------
# ['Google', 'Manager', 'End', 'Google', 'Manager', 'showMsg', 'Tab', 'Tab', 'Tab', 'Content', 'Used', 'Content', 'Scooter', 'Content', 'Header', 'First', 'Level', 'Menu', 'Item', 'HP', 'Item', 'Experiments', 'Item', 'News', 'Second', 'Level', 'Menu', 'Item', 'Reports', 'Second', 'Level', 'Menu', 'Item', 'Events', 'Second', 'Level', 'Menu', 'Item', 'Video', 'Item', 'Prices', 'Item', 'Prices', 'Comparison', 'Form', 'Remember', 'Popup', 'Register', 'Form', 'Loader', 'Social', 'Media', 'Header', 'Header', 'Mob', 'Content', 'Sponsor', 'Start', 'Defining', 'Ads', 'Slots-', 'End', 'Defining', 'Ads', 'Slots-', 'Full', 'Width', 'Billboard', 'Start', 'Defining', 'Ads', 'Slots-', '/96551095/V3_Shift/Desktop/LeaderBoard', 'End', 'Defining', 'Ads', 'Slots-', 'Tab', 'Tab', 'Tab', 'Tab', 'Tab', 'Content', 'Used', 'Content', 'Div', 'MPV', 'SUV', 'Check', 'Box', 'GPS', 'USB', 'AUX', 'ABS', 'EBD', 'Scooter', 'Content', 'Content', 'Used', 'Content', 'BMW', 'BYD', 'DFM', 'DFSK', 'DS', 'GAC', 'GMC', 'MG', 'ShowCase', 'Start', 'Defining', 'Ads', 'Slots-', '/96551095/V3_Shift/Desktop/MediumRectangle', 'End', 'Defining', 'Ads', 'Slots-', 'Social', 'Media', 'Start', 'Defining', 'Ads', 'Slots-', '/96551095/V3_Shift/Desktop/MediumRectangle2', 'End', 'Defining', 'Ads', 'Slots-', 'Global', 'News', 'V8', 'A110', 'Sports', 'Reports', 'Footer', 'Quick', 'Links', 'Social', 'Media', 'Breaking', 'News', 'Hyperlink1', 'Close', 'Start', 'Defining', 'Ads', 'Slots-', 'End', 'Defining', 'Ads', 'Slots-', 'Lazyload']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'سيارات', 'للبيع', 'سوق', 'السيارات', ':', 'سيارات', 'مستعملة', 'للبيع', 'في', 'مصر', 'سيارات', 'للبيع', '،', 'سوق', 'السيارات', 'المستعملة', 'يحتوي', 'علي', 'أكثر', 'من', '15413', 'سيارة', 'للبيع', 'في', 'مصر', '،', 'تستطيع', 'البحث', 'عن', 'أي', 'ماركة', 'و', 'موديل', 'أو', 'مدينة', 'أو', 'عدد', 'الكيلوميترات', 'أو', 'السعر', 'بسهولة', 'وسرعة', '.', 'إخترماركة', 'الاسعار', 'نوع', 'السيارة', 'slow_motion_video', 'سيارات', 'حالة', 'خاصة', 'السعة', 'اللترية', 'ابحث', 'عن', 'سيارة', 'للبيع', 'هيونداي', '(', '1660', ')', 'شيفروليه', '(', '1212', ')', 'نيسان', '(', '1052', ')', 'فيات', '(', '1037', ')', 'كيا', '(', '969', ')', 'رينو', '(', '726', ')', 'تويوتا', '(', '652', ')', 'ميتسوبيشي', '(', '617', ')', 'مرسيدس', '(', '534', ')', 'بيجو', '(', '461', ')', 'اوبل', '(', '460', ')', 'سكودا', '(', '453', ')', 'موديلات', 'أخرى', '10,000', 'جنيه', '20,000', 'جنيه', '30,000', 'جنيه', '50,000', 'جنيه', '75,000', 'جنيه', '100,000', 'جنيه', '120,000', 'جنيه', '150,000', 'جنيه', '200,000', 'جنيه', '250,000', 'جنيه', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'سيدان', '(', '10403', ')', 'SUV', '(', '2014', ')', 'هاتشباك', '(', '1640', ')', '4x4', '(', '451 ...
# ---------------------------------
# ['English', 'SUV', 'SUV', 'Signature', 'ZS', 'ZS', 'Comfort', 'ACC', 'SR', 'GLS', 'Fully', 'Loaded', 'REDBACK', 'Luxury', 'Line', 'Dynamic', 'F3', 'F3', 'C', 'C', 'A/C', 'ZS', 'ZS', 'Comfort', 'C5', 'C5', 'HCI', 'HCI', 'C31', 'C31', 'X3', 'X3', 'Luxury', 'Tekna', 'IX', 'IX', 'E', 'E', 'Full', 'Option', 'Luxury', 'Dynamic', 'Hatla2ee.com']
# ['عاجل', 'الجزائر', 'تترشح', 'رسميا', 'لعضوية', 'المكتب', 'التنفيذي', 'للاتحاد', 'الأفريقي', 'لكرة', 'القدم', 'السجن', 'وغرامة', '5', 'ملايين', '..', 'عقوبات', 'مشددة', 'تواجه', 'تاجرعملة', 'بالغربية', 'أخبار', 'السيارات|سعر', 'أرخص', 'سيارة', 'تقدمها', 'ميتسوبيشي', '..', 'اشتر', 'شيري', 'تيجو', '8', '2023', 'بـ', '175', 'ألف', '..', '5', 'موديلات', 'أوروبية', '``', 'زيرو', "''", 'بسعر', 'مناسب', 'في', 'مصر', 'بدء', 'التقديم', 'للطلاب', 'المصريين', 'الدارسين', 'بالسودان', 'وروسيا', 'وأوكرانيا', '..', 'من', 'خلال', 'هذا', 'اللينك', 'حبس', 'لص', 'سرق', 'هاتف', 'وشاشة', 'تلفزيون', 'بالقاهرة', 'البحث', 'بحث', 'EN', 'الإشراف', 'العام', 'إلهام', 'أبو', 'الفتح', 'رئيس', 'التحرير', 'أحمــد', 'صبـري', 'الرئيسية', 'اهم', 'الاخبار', 'أخبار', 'البلد', 'حوادث', 'رياضة', 'فن', 'تعليم', 'توك', 'شو', 'مرأة', 'ديني', 'أخبار', 'العالم', 'أصل', 'الحكاية', 'القائمة', 'القائمة', 'الرئيسية', 'اهم', 'الاخبار', 'أخبار', 'البلد', 'حوادث', 'رياضة', 'فن', 'تعليم', 'توك', 'شو', 'مرأة', 'ديني', 'أخبار', 'العالم', 'أصل', 'الحكاية', 'فيديو', 'جراف', 'محافظات', 'اقتصاد', 'منوعات', 'تحقيقات', 'سيارات', 'تكنولوجيا', 'برلمان', 'ملفات', 'مقالات', 'ثقافة', 'بين', 'الناس', 'القائمة', 'الإشراف', 'العام', 'إلهام', 'أبو', 'الفتح', 'رئيس', 'التحرير', 'أحمــد', 'صبـري', 'خصم', '27', '%', '..', 'سعر', 'جوال', 'شاومي', 'Redmi', '9A', 'ثنائي', 'الشريحة', 'في', 'السعودية', '280', 'للكندوز', '..', 'أسعار', 'اللحوم', 'البلدية', 'والمجمدة', 'اليوم', 'السبت', '13', 'مايو', '2023', 'أسرار', 'أسماء', 'الله', 'الحسنى', '..', 'معلومات', 'عن', 'عددها', 'وفوائدها', 'تقلبات', 'حادة', 'وسريعة|', 'الأرصاد', 'تحذر', 'المواطنين', 'من', 'تباين', 'درجات', 'الحرارة', '800', 'جنيه|زلزال', 'يضرب', 'أسعار', 'الذهب', 'بعد', 'تدخل', 'عاجل', 'من', 'الحكومة', 'وعيار21', 'مفاجأة', 'تعليم', 'أسوان', ':', '27', 'ألف', 'و334', 'طالب', 'وطالبة', 'يؤدون', 'إمتحانات', 'الشهادة', 'الإعدادية', 'اليوم', 'ليست', 'ستهم', 'فقط', '..', 'سيدات', 'بالاقصرعملن', 'في', 'مهن', 'الرجال', '..', 'فيديو', 'مكافحة', 'الإدمان', ':', 'أنت', 'أقوى', 'من', 'المخدرات', 'ساهمت', 'في', 'حماية', 'الشباب', 'وزيادة', 'راغبي', 'العلاج', 'بايدن', ':', 'أمريكا', 'مستعدة', 'لإتلاف', 'الأسلحة', 'الكيميائية', 'في', 'الخريف', 'موعد', 'مباراة', 'الأهلي', 'والترجي', 'القادمة', 'في', 'مصر', 'سلة', 'غذاء', 'مصر|قمح', 'الوادي', 'الجديد', 'يُعيد', 'للمحافظة', 'مكانتها', '..', 'مزايا', 'للمستثمرين', 'لزراعة', '3', 'ملايين', 'فدان', 'بالمحصول', 'طريقة', 'عمل', 'الخميرة', 'البلدي', 'في', 'المنزل', 'سيارات', 'أخبار', 'السيارات|سعر', 'أرخص', 'سيارة', 'تقدمها', 'ميتسوبيشي', '..', 'اشتر', 'شيري', 'تيجو', '8', '2023', 'بـ', '175', 'ألف', '..', '5', 'موديلات', 'أوروبية', '``', 'زيرو', "''", 'بسعر', 'مناسب', 'في', 'مصر', '13/05/2023', '07:00', 'ص', 'نشر', 'موقع', 'صدى', 'البلد', 'مجموعة', 'متنوعة', 'من', 'أخبار', 'السيارات', 'خلال', 'الساعات', 'الماضية،', 'بجانب', 'تقارير', 'جديدة', 'عن', 'أسعار', 'ومواصفات', 'السيارات،', 'وأخرى', 'عالمية', 'تحديثات', 'جديدة', 'تقدمها', 'هيونداي', 'لسيارتها', 'i20', 'موديل', '2024', '..', 'صور', '13/05/2023', '05:00', 'ص', 'تواصل', 'عملاقة', 'تصنيع', 'السيارات', 'الكورية', 'الجنوبية', 'هيونداي', 'من', 'تألقها،', 'بعد', 'كشفت', 'عبر', 'الانترنت', 'عن', 'تحديثات', 'جديدة', 'شملت', 'النسخة', 'i20،', 'والتي', 'تنتمي', 'إلى', 'تحديث', 'جديد', 'في', 'أسعار', 'ميتسوبيشي', 'ميراج', '2023', '..', 'لمحبي', 'الهاتشباك', '13/05/2023', '03:00', 'ص', 'شهدت', 'السيارة', 'ميتسوبيشي', 'ميراج', 'موديل', '2023،', 'زيادة', 'سعرية', 'جديدة', 'خلال', 'الساعات', 'القليلة', 'الماضية،', 'حيث', 'ارتفعت', 'اسعار', 'السيارة', 'بقيمة', 'بلغت', '20', 'الف', 'جنيه', 'أرخص', 'فئات', 'سوزوكي', 'ديزاير', 'المقدمة', 'بالسوق', 'المصري', '..', 'اعرف', 'سعرها', '13/05/2023', '01:00', 'ص', 'ارتفعت', 'قائمة', 'اسعار', 'سيارات', 'شركة', 'سوزوكي', 'اليابانية', 'داخل', 'السوق', 'المصري،', 'وذلك', 'خلال', 'الايام', 'القليلة', 'الماضية', 'من', 'شهر', 'مايو', 'الجاري،', 'وشملت', 'الزيادات', 'السعرية', 'النسخة', 'بـ', '175', 'الف', 'جنيه', '..', 'الحق', 'الفرصة', 'واشتري', 'شيري', 'تيجو', '8', 'موديل', '2023', '13/05/2023', '12:01', 'ص', 'يبحث', 'المصريين', 'في', 'ا ...
# ---------------------------------
# ['EN', 'Redmi', '9A', 'GLE', 'G-CLASS', 'SUV', 'DC', 'ZR-V', 'ZR-Vالجديدة', 'HR-Vو', 'CR-V.', 'W12', 'W12', 'BMW', 'GTX', 'GTIمن', 'ID.7سيدان', 'Cyberster', 'Electric', 'Roadster', 'MG', 'Cyberster', 'SUV،', 'All', 'Rights', 'Reserved']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'سيارات', 'للبيع', '/', 'سيارات', 'مستعملة', 'سيارات', 'مستوردة', 'للبيع', 'في', 'مصر', 'تقدم', 'السيارات', 'المستوردة', 'مجموعة', 'متنوعة', 'من', 'الأشكال', 'والأداء', 'والمميزات', 'الغير', 'موجودة', 'في', 'المركبات', 'المحلية', '.', 'من', 'السيارات', 'الأوروبية', 'والأمريكية', 'إلى', 'اليابانية', 'والكورية', '،', 'ستجد', 'هنا', 'سيارة', 'مستوردة', 'مثالية', 'لاحتياجاتك', 'وميزانيتك', '.', 'بيع', 'سيارتك', 'المستوردة', 'الآن', '!', 'filter_list', 'رتب', 'حسب', 'المضاف', 'حديثاً', 'السعر', 'كم', 'سنة', 'notifications_on', 'أحصل', 'على', 'الإشعارات', 'مرسيدس', 'S', '500', '2021', 'مرسيدس', 'S', '500', 'فضي', 'اتوماتيك', '24,000', 'كم', 'مصر', 'الجديدة', 'تقسيط', 'مستوردة', 'date_range', '2023-05-13', '7,314,000', 'جنيه', 'star', 'لاند', 'روفر', 'رنج', 'روفر', 'ايفوك', '2023', 'لاند', 'روفر', 'رنج', 'روفر', 'ايفوك', 'أسود', '0', 'كم', 'مصر', 'الجديدة', 'كسر', 'زيرو', 'تقسيط', 'مستوردة', 'date_range', '2023-05-13', '3,392,000', 'جنيه', 'star', 'مرسيدس', 'GLA', '2023', 'مرسيدس', 'GLA', 'رمادي', '0', 'كم', 'مصر', 'الجديدة', 'كسر', 'زيرو', 'تقسيط', 'مستوردة', 'date_range', '2023-05-13', '3,074,000', 'جنيه', 'star', 'مرسيدس', 'E', '200', '2022', 'مرسيدس', 'E', '200', 'فضي', 'اتوماتيك', '/', 'P ...
# ---------------------------------
# ['English', 'S', 'S', 'GLA', 'GLA', 'E', 'E', 'PREMIUM', 'X4', 'X4', 'xDrive', 'xLine', 'K3', 'K3', 'S', 'S', 'GLC', 'GLC', 'G', 'Class', 'G', 'Class', 'AMG', 'G', 'NIGHT', 'EDITION', 'C', 'C', 'EQS', 'EQS', 'A5', 'A5', 'S-Line', 'GLC', 'GLC', 'E', 'E', 'AMG', 'xDrive', 'G', 'Class', 'G', 'Class', 'Q3', 'Q3', 'Advanced', 'GLC', 'GLC', 'Q3', 'Q3', 'S-Line', 'GLC', 'GLC', 'Hatla2ee.com']

# %%
stop_words = set(nltk.corpus.stopwords.words("arabic"))
from nltk.stem.isri import ISRIStemmer
import re
st = ISRIStemmer()

# w=filtered_sentence
for word in word_tokens:
    if word not  in stop_words:
    #won't take the input correctly, input = output of tokenization# w= 'كلمات'
        print(word+"-->"+st.stem(word))
        u=st.stem(word)

# import nltk

# from nltk.stem.porter import *
# p_stemmer = PorterStemmer()




# for word in  filtered_sentence:
#     print(word+' --> '+p_stemmer.stem(word))

# from nltk.stem.snowball import SnowballStemmer
# s_stemmer = SnowballStemmer(language='english')



# for word in filtered_sentence:
#     print(word+' --> '+s_stemmer.stem(word))
# u=p_stemmer.stem(word)
# Out:
# menu-->menu
# search-->search
# add_circle_outline-->add_circle_outline
# ×-->×
# إبحث-->بحث
# سيارة-->سير
# مستعملة-->عمل
# keyboard_arrow_right-->keyboard_arrow_right
# account_circle-->account_circle
# حسابي-->حسب
# keyboard_arrow_right-->keyboard_arrow_right
# account_circle-->account_circle
# تسجيل-->سجل
# الدخول-->دخل
# time_to_leave-->time_to_leave
# سياراتي-->سير
# (-->(
# إعلاناتي-->اعلاناتي
# )-->)
# احصل-->حصل
# ابلكيشن-->لكش
# هتلاقى-->هتلاقى
# تنزيل-->نزل
# المتجر-->تجر
# احصل-->حصل
# ابلكيشن-->لكش
# هتلاقى-->هتلاقى
# تنزيل-->نزل
# المتجر-->تجر
# مركبات-->ركب
# أخري-->اخر
# keyboard_arrow_right-->keyboard_arrow_right
# more_horiz-->more_horiz
# المزيد-->زيد
# keyboard_arrow_right-->keyboard_arrow_right
# keyboard_backspace-->keyboard_backspace
# اختر-->ختر
# الدولة-->دول
# keyboard_backspace-->keyboard_backspace
# مرحباً-->رحب
# settings-->settings
# إعدادات-->عدد
# account_circle-->account_circle
# سياراتي-->سير
# (-->(
# إعلاناتي-->اعلاناتي
# )-->)
# call_missed_outgoing-->call_missed_outgoing
# تسجيل-->سجل
# خروج-->خرج
# سيارات-->سير
# مستعملة-->عمل
# سيارات-->سير
# جديدة-->جدد
# سيارات-->سير
# مستوردة-->ورد
# تقييم-->قيم
# سعر-->سعر
# عربيتك-->عرب
# أسعار-->سعر
# السيارات-->سير
# المستعملة-->عمل
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# حركة-->حرك
# التغير-->تغر
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# أسعار-->سعر
# صيانات-->صين
# السيارات-->سير
# 2022-->2022
# --->-
# 2023-->2023
# معارض-->عرض
# السيارات-->سير
# المستعمله-->عمل
# معارض-->عرض
# السيارات-->سير
# الجديدة-->جدد
# موزعي-->وزع
# السيارات-->سير
# المعتمدون-->عمد
# مركبات-->ركب
# أخري-->اخر
# حافلات-->حفل
# جديدة-->جدد
# أسعار-->سعر
# سيارات-->سير
# النقل-->نقل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# أتوبيسات-->وبس
# جديدة-->جدد
# أسعار-->سعر
# الأتوبيسات-->وبس
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# موتوسيكلات-->موتوسيكل
# جديدة-->جدد
# أسعار-->سعر
# الموتوسيكلات-->موتوسيكل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# android-->android
# نزل-->نزل
# تطبيق-->طبق
# الهاتف-->هتف
# phone_iphone-->phone_iphone
# نزل-->نزل
# تطبيق-->طبق
# الهاتف-->هتف
# أسعار-->سعر
# السيارات-->سير
# أسعار-->سعر
# السيارات-->سير
# المستعملة-->عمل
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# حركة-->حرك
# التغير-->تغر
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# أسعار-->سعر
# صيانات-->صين
# السيارات-->سير
# 2022-->2022
# --->-
# 2023-->2023
# تقسيط-->قسط
# السيارات-->سير
# تقسيط-->قسط
# سيارات-->سير
# مستعملة-->عمل
# تقسيط-->قسط
# سيارات-->سير
# جديدة-->جدد
# مركبات-->ركب
# أخري-->اخر
# حافلات-->حفل
# جديدة-->جدد
# أسعار-->سعر
# سيارات-->سير
# النقل-->نقل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# أتوبيسات-->وبس
# جديدة-->جدد
# أسعار-->سعر
# الأتوبيسات-->وبس
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# موتوسيكلات-->موتوسيكل
# جديدة-->جدد
# أسعار-->سعر
# الموتوسيكلات-->موتوسيكل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# بيع-->بيع
# سيارتي-->سير
# more_horiz-->more_horiz
# معارض-->عرض
# السيارات-->سير
# معارض-->عرض
# السيارات-->سير
# المستعمله-->عمل
# معارض-->عرض
# السيارات-->سير
# الجديدة-->جدد
# موزعي-->وزع
# السيارات-->سير
# المعتمدون-->عمد
# تأمين-->تأم
# سيارات-->سير
# مراكز-->ركز
# الصيانه-->صين
# اخبار-->خبر
# السيارات-->سير
# تقييم-->قيم
# السيارات-->سير
# سيارات-->سير
# كسر-->كسر
# زيرو-->زيرو
# ونش-->ونش
# إنقاذ-->قاذ
# more_horiz-->more_horiz
# المزيد-->زيد
# تأمين-->تأم
# سيارات-->سير
# سيارات-->سير
# المعاقين-->عاق
# مراكز-->ركز
# الصيانه-->صين
# اخبار-->خبر
# السيارات-->سير
# تقييم-->قيم
# السيارات-->سير
# السيارات-->سير
# الكلاسيكية-->كلاسيكية
# سيارات-->سير
# المعاقين-->عاق
# تقييم-->قيم
# سعر-->سعر
# عربيتك-->عرب
# أخر-->اخر
# زيارة-->زير
# قائمة-->قئم
# السيارات-->سير
# المفضلة-->فضل
# معلومات-->علم
# نصائح-->نصح
# منتدى-->ندى
# السيارات-->سير
# English-->English
# حسابي-->حسب
# إعدادات-->عدد
# سياراتي-->سير
# (-->(
# إعلاناتي-->اعلاناتي
# )-->)
# تسجيل-->سجل
# خروج-->خرج
# account_circle-->account_circle
# دخول-->دخل
# account_circle-->account_circle
# دخول-->دخل
# /-->/
# تسجيل-->سجل
# إنشاء-->شاء
# حساب-->حسب
# جديد-->جدد
# أو،-->او،
# لديك-->لدك
# بالفعل-->فعل
# حساب-->حسب
# !-->!
# رقم-->رقم
# الهاتف-->هتف
# البريد-->برد
# الإلكتروني-->كترو
# كلمة-->كلم
# السر-->لسر
# إعادة-->عدة
# تعيين-->تعي
# كلمة-->كلم
# السر-->لسر
# الخاصة-->خصة
# سيارات-->سير
# للبيع-->بيع
# /-->/
# سيارات-->سير
# مستعملة-->عمل
# سيارات-->سير
# مستوردة-->ورد
# للبيع-->بيع
# مصر-->مصر
# تقدم-->قدم
# السيارات-->سير
# المستوردة-->ورد
# مجموعة-->جمع
# متنوعة-->تنع
# الأشكال-->شكل
# والأداء-->ادء
# والمميزات-->ميز
# الغير-->غير
# موجودة-->وجد
# المركبات-->ركب
# المحلية-->حلة
# .-->.
# السيارات-->سير
# الأوروبية-->ورب
# والأمريكية-->امر
# اليابانية-->ياب
# والكورية-->كور
# ،-->،
# ستجد-->تجد
# سيارة-->سير
# مستوردة-->ورد
# مثالية-->ثلي
# لاحتياجاتك-->لاحتياجاتك
# وميزانيتك-->وميزانيتك
# .-->.
# بيع-->بيع
# سيارتك-->سير
# المستوردة-->ورد
# !-->!
# filter_list-->filter_list
# رتب-->رتب
# المضاف-->ضاف
# حديثاً-->حدث
# السعر-->سعر
# سنة-->سنة
# notifications_on-->notifications_on
# أحصل-->حصل
# الإشعارات-->شعر
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# 2021-->2021
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# فضي-->فضي
# اتوماتيك-->اتوماتيك
# 24,000-->24,000
# مصر-->مصر
# الجديدة-->جدد
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 7,314,000-->7,314,000
# star-->star
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# أسود-->اسد
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 3,392,000-->3,392,000
# star-->star
# مرسيدس-->مرسيدس
# GLA-->GLA
# 2023-->2023
# مرسيدس-->مرسيدس
# GLA-->GLA
# رمادي-->رمد
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 3,074,000-->3,074,000
# star-->star
# مرسيدس-->مرسيدس
# E-->E
# 200-->200
# 2022-->2022
# مرسيدس-->مرسيدس
# E-->E
# 200-->200
# فضي-->فضي
# اتوماتيك-->اتوماتيك
# /-->/
# PREMIUM-->PREMIUM
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 3,975,000-->3,975,000
# star-->star
# ام-->ام
# دبليو-->دبليو
# X4-->X4
# 2023-->2023
# ام-->ام
# دبليو-->دبليو
# X4-->X4
# أسود-->اسد
# اتوماتيك-->اتوماتيك
# /-->/
# xDrive-->xDrive
# 30i-->30i
# xLine-->xLine
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 4,876,000-->4,876,000
# star-->star
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# رمادي-->رمد
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-02-->2023-05-02
# 3,869,000-->3,869,000
# star-->star
# كيا-->كيا
# K3-->K3
# 2022-->2022
# كيا-->كيا
# K3-->K3
# أبيض-->ابض
# 20-->20
# مدينة-->دين
# نصر-->نصر
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-04-26-->2023-04-26
# 950,000-->950,000
# star-->star
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# 2022-->2022
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# أسود-->اسد
# --->-
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-25-->2023-04-25
# 1,000,000-->1,000,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# أسود-->اسد
# 1-->1
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-24-->2023-04-24
# 2,300,000-->2,300,000
# star-->star
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# 2022-->2022
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# أسود-->اسد
# اتوماتيك-->اتوماتيك
# /-->/
# AMG-->AMG
# G-->G
# 63-->63
# /-->/
# NIGHT-->NIGHT
# EDITION-->EDITION
# --->-
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-24-->2023-04-24
# 7,500,000-->7,500,000
# star-->star
# مرسيدس-->مرسيدس
# C-->C
# 200-->200
# 2022-->2022
# مرسيدس-->مرسيدس
# C-->C
# 200-->200
# رمادي-->رمد
# 27,200-->27,200
# 6-->6
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-19-->2023-04-19
# 2,550,000-->2,550,000
# star-->star
# جاكوار-->جاكوار
# اف-->اف
# بيس-->بيس
# 2023-->2023
# جاكوار-->جاكوار
# اف-->اف
# بيس-->بيس
# فضي-->فضي
# 0-->0
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-03-22-->2023-03-22
# 3,750,000-->3,750,000
# star-->star
# لاند-->لند
# روفر-->روفر
# فيلار-->يلر
# 2022-->2022
# لاند-->لند
# روفر-->روفر
# فيلار-->يلر
# أسود-->اسد
# 0-->0
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-03-22-->2023-03-22
# 3,900,000-->3,900,000
# star-->star
# كوبرا-->كوبر
# فورمينتور-->فورمينتور
# 2022-->2022
# كوبرا-->كوبر
# فورمينتور-->فورمينتور
# فيراني-->فير
# اتوماتيك-->اتوماتيك
# 500-->500
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-03-17-->2023-03-17
# 2,650,000-->2,650,000
# star-->star
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# 2023-->2023
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# أبيض-->ابض
# 10-->10
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 1,900,000-->1,900,000
# star-->star
# مرسيدس-->مرسيدس
# EQS-->EQS
# 2023-->2023
# مرسيدس-->مرسيدس
# EQS-->EQS
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 5,500,000-->5,500,000
# star-->star
# اودي-->اود
# A5-->A5
# 2023-->2023
# اودي-->اود
# A5-->A5
# أزرق-->زرق
# اتوماتيك-->اتوماتيك
# /-->/
# S-Line-->S-Line
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 2,350,000-->2,350,000
# star-->star
# بورش-->ورش
# 718-->718
# 2023-->2023
# بورش-->ورش
# 718-->718
# رمادي-->رمد
# --->-
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 4,020,000-->4,020,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# رمادي-->رمد
# 100-->100
# القاهرة-->قهر
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 3,890,000-->3,890,000
# star-->star
# مرسيدس-->مرسيدس
# E-->E
# 300-->300
# 2021-->2021
# مرسيدس-->مرسيدس
# E-->E
# 300-->300
# أسود-->اسد
# اتوماتيك-->اتوماتيك
# /-->/
# AMG-->AMG
# 10,000-->10,000
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 2,200,000-->2,200,000
# star-->star
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# اكس-->اكس
# 2023-->2023
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# اكس-->اكس
# أبيض-->ابض
# اتوماتيك-->اتوماتيك
# /-->/
# xDrive-->xDrive
# 40-->40
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 2,200,000-->2,200,000
# star-->star
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# 2023-->2023
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# فضي-->فضي
# 100-->100
# القاهرة-->قهر
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 1,800,000-->1,800,000
# star-->star
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# 2023-->2023
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# ذهبي-->ذهب
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 10,000,000-->10,000,000
# star-->star
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# 7-->7
# 2023-->2023
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# 7-->7
# فضي-->فضي
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 6,000,000-->6,000,000
# star-->star
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 5,000,000-->5,000,000
# star-->star
# اودي-->اود
# Q3-->Q3
# 2023-->2023
# اودي-->اود
# Q3-->Q3
# أبيض-->ابض
# اتوماتيك-->اتوماتيك
# /-->/
# Advanced-->Advanced
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 1,690,000-->1,690,000
# star-->star
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 5,000,000-->5,000,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 3,300,000-->3,300,000
# star-->star
# اودي-->اود
# Q3-->Q3
# 2023-->2023
# اودي-->اود
# Q3-->Q3
# أبيض-->ابض
# اتوماتيك-->اتوماتيك
# /-->/
# S-Line-->S-Line
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 1,400,000-->1,400,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# أسود-->اسد
# 100-->100
# القاهرة-->قهر
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# هجين-->هجن
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 4,130,000-->4,130,000
# star-->star
# 1-->1
# 2-->2
# 3-->3
# التالى-->تلى
# »-->»
# ×-->×
# تدع-->تدع
# السيارات-->سير
# تبحث-->بحث
# عنها-->عنه
# تفوتك-->تفت
# أحصل-->حصل
# الإشعارات-->شعر
# الخاصة-->خصة
# بالموديلات-->ودل
# تهتم-->هتم
# إحتفظ-->حفظ
# بإعدادات-->إعداد
# بحثك-->بحث
# موديلات-->ودل
# بعينها-->بعن
# تحدث-->حدث
# البائعين-->بئع
# عبر-->عبر
# الواتس-->وتس
# بِع-->بع
# سيارتك-->سير
# مباشرة-->بشر
# هاتفك-->هتف
# المحمول-->حمل
# تطبيق-->طبق
# الهاتف-->هتف
# أسرع-->سرع
# الرئيسيه-->رئس
# اتصل-->تصل
# شروط-->شرط
# الخصوصية-->خصص
# كُن-->كن
# تواصل-->وصل
# معنا-->عنا
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# مصر-->مصر
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# الإمارات-->امر
# سيارات-->سير
# للبيع-->بيع
# الأردن-->ارد
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# السعودية-->سعد
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# عمان-->عمن
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# اليمن-->يمن
# سيارات-->سير
# المستعملة-->عمل
# الكويت-->كوت
# سيارات-->سير
# المستعملة-->عمل
# قطر-->قطر
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# لبنان-->لبن
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# ليبيا-->ليب
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# العراق-->عرق
# ©-->©
# Hatla2ee.com-->Hatla2ee.com
# 2023-->2023
# notification_important-->notification_important
# خدمة-->خدم
# الإشعارات-->شعر
# إشترك-->شرك
# خدمة-->خدم
# أخبار-->خبر
# السيارات‎-->رت‎
# ذكرني-->ذكر
# لاحقا-->لحق
# موافق-->وفق
# ×-->×
# سيارات-->سير
# المقارنة-->قرن
# keyboard_arrow_left-->keyboard_arrow_left
# أضف-->اضف
# سيارة-->سير
# أخري-->اخر
# قارن-->قرن
# keyboard_arrow_right-->keyboard_arrow_right
# close-->close
# هتلاقي-->هتلاق
# أسرع-->سرع
# تطبيق-->طبق
# الهاتف-->هتف
# search-->search
# شراء-->شرء
# add_circle_outline-->add_circle_outline
# بيع-->بيع
# local_offer-->local_offer
# الأسعار-->سعر
# notifications_active-->notifications_active
# تنبيهات-->نبه
# والكثير-->كثر
# ..-->..
# نزل-->نزل
# التطبيق-->طبق
# الأن-->الأ
# close-->close
# هتلاقي-->هتلاق
# أسرع-->سرع
# تطبيق-->طبق
# الهاتف-->هتف
# search-->search
# شراء-->شرء
# add_circle_outline-->add_circle_outline
# بيع-->بيع
# local_offer-->local_offer
# الأسعار-->سعر
# notifications_active-->notifications_active
# تنبيهات-->نبه
# والكثير-->كثر
# ..-->..
# نزل-->نزل
# التطبيق-->طبق
# الأن-->الأ

# %%
# import pandas as pd
# def tf_idf_analysis(keyword):
#     v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
#     x = v.fit_transform(text)

#     f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
#     d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
#     tf=pd.DataFrame((f>0).sum(axis=0))


#     d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

#     d.columns=['word','average_tfidf','max_tfidf','frequency']

#     d['frequency']=round((d['frequency']/len(text))*100)

#     return(d)

# x= tf_idf_analysis(u)
# x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
def tf_idf_analysis(keyword):
    v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=list(stop_words))
    x = v.fit_transform(text)
    f = pd.DataFrame(x.toarray(), columns = v.get_feature_names_out())
    d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    tf=pd.DataFrame((f>0).sum(axis=0))
    d=d.reset_index().merge(tf.reset_index(),on='index',how='left')
    d.columns=['word','average_tfidf','max_tfidf','frequency']
    d['frequency']=round((d['frequency']/len(text))*100)
    d['max_tfidf'] = d['max_tfidf'].round(3)
    d['average_tfidf'] = d['average_tfidf'].round(3)

    d= d[d['word'].str.isalpha()].sort_values('frequency',ascending=False).head(35)
    
    return d

import requests


# Call the tf_idf_analysis function and store the output in a DataFrame variable
output_df = tf_idf_analysis(u)
print (output_df)
# Convert the DataFrame to a dictionary
output_dict = output_df.to_dict('records')

# Connect to the database
# mysql = mysql.connector.connect(
#     host="localhost",
#     user="root",
#     passwd="",
#     database="seopro"
# )

# # Insert the data into the database
# mycursor = mysql.cursor()
sql = "INSERT INTO keyword_ar (word, average_tfidf, max_tfidf, frequency, niche, uid) VALUES (%s, %s, %s, %s, %s, %s)"
for row in output_dict:
    val = (row['word'], row['average_tfidf'], row['max_tfidf'], row['frequency'], niche, uid)
    mycursor.execute(sql, val)
    # data = {'word': row['word'], 'average_tfidf': row['average_tfidf']}
    # response = requests.post('http://example.com/api/data', data=data)
    # if response.status_code == 200:
    #     print('Data sent successfully')
    # else:
    #     print('Error sending data')

mysql.commit()

# Print a message to confirm that the data has been saved
print("Data has been saved to the database.")
# print(x)
#######################################################################
# import pandas as pd
# # documentA = 'ذهب محمد الي الجامعة ليدرس الفيزياء و الكيمياء'
# # documentB=u
# documentA=u
# bagOfWordsA = documentA.split(' ')
# # bagOfWordsB = documentB.split(' ')
# uniqueWords = set(bagOfWordsA)
# uniqueWords
# numOfWordsA = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsA[word] += 1
# numOfWordsA
# numOfWordsB = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsB[word] += 1

# numOfWordsB    
# def computeTF(wordDict, bagOfWords):
#     tfDict = {}
#     bagOfWordsCount = len(bagOfWords)
#     for word, count in wordDict.items():
#         tfDict[word] = count / float(bagOfWordsCount)
#     return tfDict
# tfB = computeTF(numOfWordsB, bagOfWordsA)
# print(tfB)
# Out:
# c:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['آمين', 'أب', 'أخ', 'أفعل', 'أفعله', 'ؤلاء', 'إل', 'إم', 'ات', 'اتان', 'ارتد', 'ان', 'انفك', 'برح', 'تان', 'تبد', 'تحو', 'تعل', 'حد', 'حم', 'حي', 'خب', 'ذار', 'سيما', 'صه', 'ظل', 'ظن', 'عد', 'قط', 'مر', 'مكان', 'مكانكن', 'نب', 'هات', 'هب', 'واها', 'وراء'] not in stop_words.
#   warnings.warn(
#             word  average_tfidf  max_tfidf  frequency
# 8629      سيارات          0.082      0.259      100.0
# 10644        مصر          0.031      0.158       92.0
# 10507     مرسيدس          0.023      0.098       92.0
# 5091     الجديدة          0.049      0.140       92.0
# 5475    السيارات          0.100      0.324       85.0
# 7578       جديدة          0.035      0.112       85.0
# 3784       أخبار          0.031      0.227       85.0
# 9904         كيا          0.019      0.116       77.0
# 7564        جديد          0.009      0.056       77.0
# 8688       سيارة          0.024      0.093       77.0
# 8613        سيات          0.007      0.018       77.0
# 7469      تويوتا          0.010      0.032       77.0
# 8163        روفر          0.012      0.061       77.0
# 3900       أسعار          0.056      0.201       77.0
# 7441       تواصل          0.009      0.047       77.0
# 6946        بورش          0.007      0.016       77.0
# 9515       فولكس          0.011      0.027       77.0
# 11035  ميتسوبيشي          0.013      0.036       77.0
# 10983      موديل          0.015      0.055       77.0
# 11277      هوندا          0.009      0.018       77.0
# 5429       السعر          0.006      0.013       77.0
# 8477       سكودا          0.008      0.022       77.0
# 6116      المزيد          0.022      0.094       77.0
# 7222       تسجيل          0.018      0.067       77.0
# 10768       معنا          0.009      0.047       77.0
# 10562    مستعملة          0.045      0.161       77.0
# 5242    الخصوصية          0.007      0.025       77.0
# 7945       دبليو          0.010      0.028       69.0
# 9526        فيات          0.009      0.024       69.0
# 10293      مارتن          0.006      0.018       69.0
# 10309      مازدا          0.006      0.017       69.0
# 8426         سعر          0.015      0.046       69.0
# 6981        بيجو          0.008      0.017       69.0
# 9480        فورد          0.006      0.017       69.0
# 7709       جيتور          0.005      0.017       69.0
# Data has been saved to the database.

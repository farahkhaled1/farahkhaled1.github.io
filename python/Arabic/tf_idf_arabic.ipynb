# %%
import urllib
# %pip install requests_html
import requests
# !pip install requests
from requests_html import HTMLSession

def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        return response
    except requests.exceptions.RequestException as e:
        print(e)
# Out:
# Requirement already satisfied: requests_html in c:\users\lenovo\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: fake-useragent in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.1.1)
# Requirement already satisfied: parse in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: bs4 in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: w3lib in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.21.0)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (2.28.1)
# Requirement already satisfied: pyquery in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: certifi>=2021 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2022.9.14)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.64.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.11)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\anaconda3\lib\site-packages (from bs4->requests_html) (4.11.1)
# Requirement already satisfied: importlib-resources>=5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fake-useragent->requests_html) (5.10.1)
# Requirement already satisfied: lxml>=2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pyquery->requests_html) (4.9.1)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\lenovo\anaconda3\lib\site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->requests_html) (3.3)
# Requirement already satisfied: six>=1.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from w3lib->requests_html) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
def scrape_google(query):
    
    # query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.com/search?q=" + query)
    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.')

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
links = scrape_google("فراولة")
for link in links:
  print(link)
# Out:
# https://tastyfoodeg.com/ar/shop/fruits/strawberry/
# http://ar.wikipedia.org/wiki/%D9%86%D8%A8%D8%A7%D8%AA
# https://www.atyabtabkha.com/ingredient/%D9%81%D8%B1%D8%A7%D9%88%D9%84%D8%A9-1457743
# http://ar.wikipedia.org/wiki/%D9%88%D8%B1%D8%AF%D9%8A%D8%A9
# https://www.webteb.com/articles/%D9%81%D9%88%D8%A7%D8%A6%D8%AF-%D8%A7%D9%84%D9%81%D8%B1%D8%A7%D9%88%D9%84%D8%A9-%D9%85%D9%86-%D8%A7%D8%AC%D9%84-%D9%85%D9%86%D8%A7%D8%B9%D8%A9-%D9%82%D9%88%D9%8A%D8%A9_14189
# http://marefa.org/%D9%86%D8%A8%D8%A7%D8%AA
# https://ar.wikipedia.org/wiki/%D9%81%D8%B1%D8%A7%D9%88%D9%84%D8%A9
# https://www.youm7.com/story/2023/1/1/%D9%81%D9%88%D8%A7%D8%A6%D8%AF-%D8%A7%D9%84%D9%81%D8%B1%D8%A7%D9%88%D9%84%D8%A9-%D8%B9%D9%84%D9%89-%D8%B5%D8%AD%D8%AA%D9%83-%D9%85%D9%86-%D8%AE%D9%81%D8%B6-%D8%A7%D9%84%D9%88%D8%B2%D9%86-%D9%84%D8%AA%D8%B9%D8%B2%D9%8A%D8%B2-%D9%85%D9%86%D8%A7%D8%B9%D8%AA%D9%83/6028039
# https://www.elconsolto.com/healthy-cooks/healthy-cooks-news/details/2023/1/4/2350276/%D9%83%D9%85-%D8%AB%D9%85%D8%B1%D8%A9-%D9%81%D8%B1%D8%A7%D9%88%D9%84%D8%A9-%D9%8A%D9%85%D9%83%D9%86-%D8%AA%D9%86%D8%A7%D9%88%D9%84%D9%87%D8%A7-%D9%81%D9%8A-%D8%A7%D9%84%D9%8A%D9%88%D9%85-
# https://www.marefa.org/%D9%81%D8%B1%D8%A7%D9%88%D9%84%D8%A9
# https://www.feedo.net/Nutrition/NutritionForHealthyPeople/FoodComposition-Strawberry.htm
# https://www.skynewsarabia.com/technology/1596299-%D8%AF%D8%B1%D8%A7%D8%B3%D8%A9-%D8%AA%D9%83%D8%B4%D9%81-%D9%81%D8%A7%D9%8A%D9%94%D8%AF%D8%A9-%D8%BA%D9%8A%D8%B1-%D9%85%D8%AA%D9%88%D9%82%D8%B9%D8%A9-%D9%84%D8%AA%D9%86%D8%A7%D9%88%D9%84-%D8%A7%D9%84%D9%81%D8%B1%D8%A7%D9%88%D9%84%D8%A9-%D9%8A%D9%88%D9%85%D9%8A%D8%A7

# %%
from nltk.tokenize import  word_tokenize
import nltk
nltk.download('punkt')
# # EXAMPLE_TEXT = """
# # أبو عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك
# # وجغرافيا مسلم. يكنى باسم الخوارزمي وأبي جعفر. قيل أنه ولد حوالي 164هـ 781م (وهو غير مؤكد) وقيل أنه توفي بعد 232هـ أي (بعد 847م). يعتبر
# # من أوائل علماء الرياضيات المسلمين حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره. اتصل بالخليفة العباسي المأمون وعمل في بيت الحكمة في 
# # بغداد وكسب ثقة الخليفة إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل فيها أكثر من سبعين جغرافيا. قبل وفاته في 850 م/232 هـ
# # كان الخوارزمي قد ترك العديد من المؤلفات في علوم الرياضيات والفلك والجغرافيا ومن أهمها

# # """
# EXAMPLE_TEXT=links
# print(word_tokenize(EXAMPLE_TEXT))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# links=scrape_google('cars')
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup

def get_text(url):
    try:
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req,timeout=5).read()
        soup = BeautifulSoup(webpage, "html.parser")
        texts = soup.findAll(text=True)
        res=u" ".join(t.strip() for t in texts if t.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]'])
        return(res)
    except:
        return False
get_text('https://en.wikipedia.org/wiki/Machine_learning')
text=[]
for i in links:
  t=get_text(i)
  if t:
    text.append(t)

    word_tokens = word_tokenize(t)
# word_tokens = 

    filtered_sentence = [w for w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)

    filtered_sentence = [w for w in word_tokens if not w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)
    filtered_sentence = [w for w in word_tokens if not w.lower() in word_tokens]

    print(word_tokens)
    print('---------------------------------')
    print(filtered_sentence)
# Out:
# ['قائمة', 'خضروات', 'فواكه', 'ورقيات', 'أطعمة', 'صحية', 'المدونة', 'اتصل', 'بنا', 'العربية', 'English', 'حسابي', 'طلباتي', '0', 'لا', 'توجد', 'منتجات', 'في', 'سلة', 'التسوق', '.', 'بحث', 'الرئيسية', '›', 'المتجر', '›', 'فواكه', '›', 'فراولة', 'فاكهة', 'فراولة', 'EGP', '30.00', 'غير', 'متوفر', 'في', 'المخزون', 'الفراولة', 'من', 'الفواكه', 'الصحية', 'التي', 'يستفيد', 'منها', 'الجسم', 'كثيراً', 'حيث', 'أنها', 'تحتوي', 'على', 'العديد', 'من', 'الألياف', 'الغذائية', 'والعناصر', 'الصحية', 'والمركبات', 'الكيميائية', 'والفيتامينات', 'والمعادن،', 'ويساهم', 'في', 'تقوية', 'المناعة', 'والحفاظ', 'على', 'صحة', 'الجسم', 'من', 'الإصابة', 'بالعدوى', 'والأنفلونزا', '.', 'التصنيف', ':', 'فواكه', 'الوصف', 'معلومات', 'إضافية', 'مراجعات', '(', '0', ')', 'الفراولة', 'من', 'الفواكه', 'الطبيعية', 'الشهية', 'المحببة', 'إلى', 'القلوب،', 'كما', 'أنها', 'من', 'الثمار', 'التي', 'تدخل', 'في', 'الكثير', 'من', 'العناصر', 'الأساسية', 'المختلفة', 'للمكونات', 'الرئيسية', 'للعديد', 'من', 'الأطعمة', '.', 'حيث', 'أنها', 'تعد', 'عصيراً', '.', 'تأكل', 'من', 'أجل', 'الرجيم', 'والدايت', '.', 'تأكل', 'منفردة', 'شهية', 'لطعمها', 'اللذيذ', '.', 'تدخل', 'في', 'الآيس', 'كريم', '.', 'الشوكولاتة', '.', 'الميك', 'شوت', '.', 'الفطائر', '.', 'تحتوي', 'الفراولة', 'على', 'كميات', 'كبيرة', 'من', 'العناصر', 'المركبة', 'والفيتامينات', 'الغذائية', 'والمعادن', 'والأحماض،', 'منها', ':', 'الفيتامينات', ':', 'فيتامين', 'إيه', '.', 'فيتامين', 'بي', 'المركب', '.', 'فيتامين', 'إتش', '.', 'فيتامين', 'ك', '.', 'فيتامين', 'جي', '.', 'المعادن', '.', 'الكالسيوم', '.', 'المغنسيوم', '.', 'المنجنيز', '.', 'الفسفور', '.', 'البوتاسيوم', '.', 'النحاس', '.', 'الحديد', '.', 'فوائد', 'الفراولة', '.', 'تقوية', 'صحة', 'الفم،', 'حيث', 'أن', 'الفراولة', 'تعمل', 'على', 'تعزيز', 'صحة', 'اللسان', 'واللثة', 'وتخفيف', 'الإصابة', 'بأعراض', 'الالتهابات', 'اللثوية', '.', 'تساهم', 'في', 'تبييض', 'الأسنان', '.', 'تنشيط', 'الأوعية', 'الدموية', 'والمساهمة', 'في', 'الحفاظ', 'على', 'صحة', 'القلب', '.', 'تساهم', 'في', 'فرز', 'هرمون', 'السعادة', 'في', 'الجسم', 'مما', 'يساعد', 'على', 'التخلص', 'من', 'حد', 'الإكتئاب', 'والشعور', 'بالارتياح', 'وهدوء', 'الأعصاب', 'والاسترخاء', 'النفسي', 'والعصبي', '.', 'تعزز', 'الفراولة', 'من', 'صحة', 'المناعة', 'حيث', 'أنها', 'تساهم', 'في', 'تقوية', 'المناعة', 'والمساعدة', 'في', 'مقاومة', 'البكتيريا', 'والفطريات', 'والانفلونزا', '.', 'تساعد', 'الفراولة', 'في', 'حمل', 'صحي', 'حيث', 'أنها', 'تمتلك', 'عنصر', 'حمض', 'الفوليك', 'المهم', 'لصحة', 'الحامل', 'وجنينها', '.', 'يعد', 'الفراولة', 'من', 'أهم', 'العناصر', 'الغذائية', 'المهمة', 'في', 'نظام', 'الدايت', 'والرجيم', 'حيث', 'أنه', 'يعتمد', 'عليه', 'في', 'إحداث', 'حالة', 'الشبع', 'المتكرر', 'في', 'منظومة', 'الاكل', 'المستمرة', '.', 'معلومات', 'إضافية', 'الوزن', '1000', 'جرام', 'المراجعات', 'لا', 'توجد', 'مراجعات', 'بعد', '.', 'كن', 'أول', 'من', 'يقيم', '“', 'فراولة', '”', 'إلغاء', 'الرد', 'لن', 'يتم', 'نشر', 'عنوان', 'بريدك', 'الإلكتروني', '.', 'الحقول', 'الإلزامية', 'مشار', 'إليها', 'بـ', '*', 'تقييمك', 'قيم…', 'مثالي', 'جيد', 'متوسط', 'ليس', 'سيء', 'سيء', 'مراجعتك', '*', 'الاسم', '*', 'البريد', 'الإلكتروني', '*', 'احفظ', 'اسمي،', 'بريدي', 'الإلكتروني،', 'والموقع', 'الإلكتروني', 'في', 'هذا', 'المتصفح', 'لاستخدامها', 'المرة', 'المقبلة', 'في', 'تعليقي', '.', 'Δ', 'منتجات', 'ذات', 'صلة', 'Quick', 'View', 'قراءة', 'المزيد', 'ليمون', 'اضاليا', 'EGP', '12.00', 'تيستي', 'فوود', 'Quick', 'View', 'قراءة', 'المزيد', 'برقوق', 'احمر', 'EGP', '50.00', 'تيستي', 'فوود', 'Quick', 'View', 'قراءة', 'المزيد', 'شمام', 'EGP', '13.00', 'تيستي', 'فوود', 'Quick', 'View', 'قراءة', 'المزيد', 'موز', 'EGP', '15.00', 'تيستي', 'فوود', 'Quick', 'View', 'قراءة', 'المزيد', 'رامبوتان', 'EGP', '450.00', 'تيستي', 'فوود', 'Quick', 'View', 'قراءة', 'المزيد', 'تفاح', 'أصفر', 'EGP', '25.00', 'تيستي', 'فوود', 'Quick', 'View', 'قراءة', 'المزيد', 'تفاح', 'احمر', 'EGP', '25.00', 'تيستي', 'فوود', 'عنا', 'عنا', 'سياسة', 'الخصوصية', 'الشروط', 'والأحكام', 'اتصل', 'بنا', 'منتجاتنا', 'خضروات', 'فواكه', 'ورقيات', 'أطعمة', 'صحية', 'العلامات', 'التجارية', 'بونا', 'ميل', 'تيستي', 'فوود', 'بونا', 'ميل' ...
# ---------------------------------
# ['English', 'EGP', 'Δ', 'Quick', 'View', 'EGP', 'Quick', 'View', 'EGP', 'Quick', 'View', 'EGP', 'Quick', 'View', 'EGP', 'Quick', 'View', 'EGP', 'Quick', 'View', 'EGP', 'Quick', 'View', 'EGP', 'Tasty', 'Food', 'Egypt', 'All', 'Rights', 'Reserved', 'English']
# ['انتقل', 'إلى', 'المحتوى', 'القائمة', 'الرئيسية', 'القائمة', 'الرئيسية', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'الموسوعة', 'الصفحة', 'الرئيسية', 'الأحداث', 'الجارية', 'أحدث', 'التغييرات', 'أحدث', 'التغييرات', 'الأساسية', 'تصفح', 'المواضيع', 'أبجدي', 'بوابات', 'مقالة', 'عشوائية', 'تصفح', 'من', 'غير', 'إنترنت', 'مشاركة', 'تواصل', 'مع', 'ويكيبيديا', 'مساعدة', 'الميدان', 'تبرع', 'لغات', 'في', 'نسخة', 'ويكيبيديا', 'هذه،', 'وصلات', 'اللغات', 'موجودة', 'في', 'الزاوية', 'العليا', 'اليسرى', 'بجانب', 'العنوان', '.', 'انتقل', 'إلى', 'الأعلى', '.', 'بحث', 'إنشاء', 'حساب', 'دخول', 'أدوات', 'شخصية', 'إنشاء', 'حساب', 'دخول', 'صفحات', 'للمحررين', 'الذين', 'سجَّلوا', 'خروجهم', 'تعلَّم', 'المزيد', 'مساهمات', 'نقاش', 'CentralNotice', 'المحتويات', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'المقدمة', '1', 'التصنيف', 'ثبِّت', 'القسم', 'الفرعي', 'التصنيف', '1.1', 'النباتات', 'الدالة', '1.2', 'تتحمل', 'التلوث', '1.3', 'تدل', 'على', 'التربة', 'الملحية', '1.4', 'تنمو', 'في', 'الرمال', '1.5', 'تدل', 'على', 'تدهور', 'الغابات', 'السنديانية', '1.6', 'تنفر', 'من', 'الكلس', '1.7', 'تدل', 'على', 'الغدق', '1.8', 'تغزو', '2', 'مميزات', 'النباتات', '3', 'نمو', 'النباتات', 'ثبِّت', 'القسم', 'الفرعي', 'نمو', 'النباتات', '3.1', 'العوامل', 'المؤثرة', 'على', 'النمو', '3.2', 'طول', 'دورة', 'الحياة', '4', 'أساليب', 'عيش', 'النبات', 'ثبِّت', 'القسم', 'الفرعي', 'أساليب', 'عيش', 'النبات', '4.1', 'النباتات', 'الحولية', '4.2', 'النباتات', 'المحولة', '5', 'أجزاء', 'النبات', '6', 'الفوائد', '7', 'حساسية', 'النبات', '8', 'مقالات', 'ذات', 'صلة', '9', 'المراجع', 'تبديل', 'عرض', 'جدول', 'المحتويات', 'تبديل', 'عرض', 'جدول', 'المحتويات', 'نبات', '227', 'لغة', 'Аԥсшәа', 'Acèh', 'Afrikaans', 'Alemannisch', 'አማርኛ', 'Aragonés', 'Ænglisc', 'الدارجة', 'مصرى', 'অসমীয়া', 'Asturianu', 'अवधी', 'Aymar', 'aru', 'Azərbaycanca', 'تۆرکجه', 'Башҡортса', 'Basa', 'Bali', 'Boarisch', 'Žemaitėška', 'Bikol', 'Central', 'Беларуская', 'Беларуская', '(', 'тарашкевіца', ')', 'Български', 'भोजपुरी', 'Banjar', 'বাংলা', 'Brezhoneg', 'Bosanski', 'Буряад', 'Català', '閩東語', '/', 'Mìng-dĕ̤ng-ngṳ̄', 'Нохчийн', 'Cebuano', 'ᏣᎳᎩ', 'کوردی', 'Corsu', 'Nēhiyawēwin', '/', 'ᓀᐦᐃᔭᐍᐏᐣ', 'Čeština', 'Чӑвашла', 'Cymraeg', 'Dansk', 'Deutsch', 'Zazaki', 'Dolnoserbski', 'डोटेली', 'ދިވެހިބަސް', 'Ελληνικά', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'Estremeñu', 'فارسی', 'Suomi', 'Võro', 'Na', 'Vosa', 'Vakaviti', 'Føroyskt', 'Français', 'Arpetan', 'Nordfriisk', 'Furlan', 'Frysk', 'Gaeilge', '贛語', 'Kriyòl', 'gwiyannen', 'Gàidhlig', 'Galego', 'Avañe', "'", 'ẽ', 'Gaelg', 'Hausa', '客家語/Hak-kâ-ngî', 'עברית', 'हिन्दी', 'Hrvatski', 'Hornjoserbsce', 'Kreyòl', 'ayisyen', 'Magyar', 'Հայերեն', 'Interlingua', 'Bahasa', 'Indonesia', 'Igbo', 'Ilokano', 'ГӀалгӀай', 'Ido', 'Íslenska', 'Italiano', 'ᐃᓄᒃᑎᑐᑦ', '/', 'inuktitut', '日本語', 'Patois', 'La', '.lojban', '.', 'Jawa', 'ქართული', 'Qaraqalpaqsha', 'Taqbaylit', 'Адыгэбзэ', 'Kabɩyɛ', 'Tyap', 'Gĩkũyũ', 'Қазақша', 'ភាសាខ្មែរ', 'ಕನ್ನಡ', '한국어', 'Перем', 'коми', 'कॉशुर', '/', 'کٲشُر', 'Kurdî', 'Kernowek', 'Кыргызча', 'Latina', 'Ladino', 'Lëtzebuergesch', 'Лакку', 'Лезги', 'Lingua', 'Franca', 'Nova', 'Limburgs', 'Ligure', 'Ladin', 'Lombard', 'Lingála', 'Lietuvių', 'Latgaļu', 'Latviešu', 'मैथिली', 'Basa', 'Banyumasan', 'Malagasy', 'Олык', 'марий', 'Minangkabau', 'Македонски', 'മലയാളം', 'Монгол', 'ꯃꯤꯇꯩ', 'ꯂꯣꯟ', 'ဘာသာ', 'မန်', 'मराठी', 'Кырык', 'мары', 'Bahasa', 'Melayu', 'Mirandés', 'မြန်မာဘာသာ', 'Эрзянь', 'مازِرونی', 'Nāhuatl', 'Napulitano', 'Plattdüütsch', 'Nedersaksies', 'नेपाली', 'नेपाल', 'भाषा', 'Nederlands', 'Norsk', 'nynorsk', 'Norsk', 'bokmål', 'Nouormand', 'Occitan', 'Livvinkarjala', 'ଓଡ଼ିଆ', 'Ирон', 'ਪੰਜਾਬੀ', 'Kapampangan', 'Picard', 'Norfuk', '/', 'Pitkern', 'Polski', 'پنجابی', 'پښتو', 'Português', 'Runa', 'Simi', 'Română', 'Armãneashti', 'Tarandíne', 'Русский', 'Русиньскый', 'Ikinyarwanda', 'संस्कृतम्', 'Саха', 'тыла', 'Sardu', 'Sicilianu', 'Scots', 'سنڌي', 'Srpskohrvatski', '/', 'српскохрватски', 'සිංහල', 'Simple', 'English', 'Slovenčina', 'Slovenščina', 'ChiShona', 'Soomaaliga', 'Shqip',  ...
# ---------------------------------
# ['CentralNotice', 'Аԥсшәа', 'Acèh', 'Afrikaans', 'Alemannisch', 'Aragonés', 'Ænglisc', 'Asturianu', 'Aymar', 'Azərbaycanca', 'Башҡортса', 'Basa', 'Bali', 'Boarisch', 'Žemaitėška', 'Bikol', 'Central', 'Беларуская', 'Беларуская', 'Български', 'Banjar', 'Brezhoneg', 'Bosanski', 'Буряад', 'Català', 'Mìng-dĕ̤ng-ngṳ̄', 'Нохчийн', 'Cebuano', 'ᏣᎳᎩ', 'Corsu', 'Nēhiyawēwin', 'Čeština', 'Чӑвашла', 'Cymraeg', 'Dansk', 'Deutsch', 'Zazaki', 'Dolnoserbski', 'Ελληνικά', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'Estremeñu', 'Suomi', 'Võro', 'Na', 'Vosa', 'Vakaviti', 'Føroyskt', 'Français', 'Arpetan', 'Nordfriisk', 'Furlan', 'Frysk', 'Gaeilge', 'Kriyòl', 'Gàidhlig', 'Galego', 'Avañe', 'Gaelg', 'Hausa', '客家語/Hak-kâ-ngî', 'Hrvatski', 'Hornjoserbsce', 'Kreyòl', 'Magyar', 'Հայերեն', 'Interlingua', 'Bahasa', 'Indonesia', 'Igbo', 'Ilokano', 'ГӀалгӀай', 'Ido', 'Íslenska', 'Italiano', 'Patois', 'La', 'Jawa', 'Qaraqalpaqsha', 'Taqbaylit', 'Адыгэбзэ', 'Kabɩyɛ', 'Tyap', 'Gĩkũyũ', 'Қазақша', 'Перем', 'Kurdî', 'Kernowek', 'Кыргызча', 'Latina', 'Ladino', 'Lëtzebuergesch', 'Лакку', 'Лезги', 'Lingua', 'Franca', 'Nova', 'Limburgs', 'Ligure', 'Ladin', 'Lombard', 'Lingála', 'Lietuvių', 'Latgaļu', 'Latviešu', 'Basa', 'Banyumasan', 'Malagasy', 'Олык', 'Minangkabau', 'Македонски', 'Монгол', 'Кырык', 'Bahasa', 'Melayu', 'Mirandés', 'Эрзянь', 'Nāhuatl', 'Napulitano', 'Plattdüütsch', 'Nedersaksies', 'Nederlands', 'Norsk', 'Norsk', 'Nouormand', 'Occitan', 'Livvinkarjala', 'Ирон', 'Kapampangan', 'Picard', 'Norfuk', 'Pitkern', 'Polski', 'Português', 'Runa', 'Simi', 'Română', 'Armãneashti', 'Tarandíne', 'Русский', 'Русиньскый', 'Ikinyarwanda', 'Саха', 'Sardu', 'Sicilianu', 'Scots', 'Srpskohrvatski', 'Simple', 'English', 'Slovenčina', 'Slovenščina', 'ChiShona', 'Soomaaliga', 'Shqip', 'Српски', 'SiSwati', 'Sesotho', 'Seeltersk', 'Sunda', 'Svenska', 'Kiswahili', 'Ślůnski', 'Sakizaya', 'Тоҷикӣ', 'Türkmençe', 'Tagalog', 'Lea', 'faka-Tonga', 'Tok', 'Pisin', 'Türkçe', 'Татарча', 'ChiTumbuka', 'Удмурт', 'Uyghurche', 'Українська', 'Oʻzbekcha', 'Tshivenda', 'Vèneto', 'Vepsän', 'Tiếng', 'Việt', 'West-Vlams', 'Walon', 'Winaray', 'Wolof', 'IsiXhosa', 'Yorùbá', 'Vahcuengh', 'Zeêuws', 'Bân-lâm-gú', 'IsiZulu', 'PDF', 'Fern', 'Plantae', 'Plantae', 'Vegetabilia', 'Plantae', 'Embryophyta', 'Viridiplantae', 'Chlorobionta', 'Primoplantae', 'Plantae', 'Plastida', 'Archaeplastida', 'Lindenmaver', 'Malus', 'Gingko', 'Koelreuteria', 'Liriodendron', 'Tilia', 'Cotoneaster', 'Juniper', 'Privet', 'Spirea', 'Viburnum', 'Atriplex', 'Tamarix', 'Aizoan', 'Haloxilon', 'Retama', 'Calligonus', 'Poterium', 'Citrus', 'Calycotome', 'Castanea', 'Phragmites', 'Fraxinus', 'Eucalyptus', 'Ailanthus', 'A.altissima', 'Prosopis', 'Prosopis', 'Solanum', 'Penumatophores', 'Lenticels', 'Insectivorous', 'Carnivorous', 'Pitcher', 'Nepenthes', 'Kudzu', 'Jasmonic', 'Cotesia،', 'Michael', 'A.', 'Ruggiero،', '\u200fDennis', 'P.', 'Gordon،', '\u200fThomas', 'M.', 'Orrell،', '\u200fNicolas', 'Bailly', 'Thierry', 'Bourgoin', 'A', 'Higher', 'Level', 'Classification', 'All', 'Living', 'Organisms', '//dx.doi.org/10.1371/JOURNAL.PONE.0119248', '//www.ncbi.nlm.nih.gov/pmc/articles/PMC4418965', 'CC0', 'Egypt،', 'Agriculture', 'IAPT', 'ICN', 'ICNCP', 'Guerilla', 'Parterre', 'Flora', 'Indigenous', 'Urban', 'Vegan', 'Index', 'GBIF', 'ITIS', 'TSN', 'iNaturalist', 'WoRMS', 'EoL', 'AlgaeBase', 'Fossilworks', 'NZOR', 'ID', 'Chrysiogenetes', 'Deferribacteres', 'Deinococcus-Thermus', 'P105', 'P225', 'P405', 'P574', 'P935', 'P846', 'P962', 'P1939', 'P815', 'P3151', 'P850', 'P830', 'P1348', 'P842', 'P838', 'P2752', 'BNF', 'BNFdata', 'GND', 'LCCN', 'NDL', 'NKC', 'NARA', 'SUDOC', 'Toggle']
# ['وصفات', 'مقبلات', 'حساء', 'سلطة', 'أطباق', 'جانبية', 'مشروبات', 'سندويشات', 'فطور', 'اكلات', 'وحلويات', 'عيد', 'ميلاد', 'رز', 'زربيان', 'بالدجاج', 'سمك', 'سلمون', 'فيليه', 'كتب', 'الطبخ', 'أطباق', 'رئيسية', 'يخنة', 'وايدام', 'كشري', 'كباب', 'لازانيا', 'دجاج', 'بالفرن', 'كبسة', 'برياني', 'شاورما', 'بالتوست', 'برياني', 'لحم', 'هندي', 'حلى', 'حلى', 'عربي', 'حلى', 'الكاسات', 'بسكويت', 'وكوكيز', 'دونات', 'كريب', 'وبان', 'كيك', 'حلى', 'قهوه', 'ايس', 'كريم', 'كعك', 'طريقة', 'عمل', 'الكنافة', 'بالجبنة', 'بسبوسة', 'بالحليب', 'المكثف', 'المحلى', 'كيك', 'تشيز', 'كيك', 'كب', 'كيك', 'ومافن', 'براونيز', 'تيراميسو', 'كيك', 'اسفنجي', 'كيكة', 'بكريمة', 'الخفق', 'كيك', 'بالبرتقال', 'والحليب', 'فطور', 'كرواسون', 'كريب', 'وبان', 'كيك', 'وافل', 'دونات', 'اومليت', 'أو', 'عجة', 'شكشوكة', 'بيض', 'مخفوق', 'مناقيش', 'مربى', 'فرنش', 'توست', 'كراميل', 'بيض', 'عيون', 'تركي', 'وصفات', 'بالفيديو', 'خطوة', 'بخطوة', 'نصائح', 'تحضير', 'الطعام', 'حفظ', 'الطعام', 'تزيين', 'تنظيف', 'الغذاء', 'الصحي', 'نصائح', 'أخرى', 'مدونة', 'شاركي', 'وصفتك', 'الرئيسية', '»', 'فراولة', 'فراولة', 'فراولة', 'شاركي', 'المقال', 'صغار', 'وكبار', 'يحبّونها', 'وينتظرون', 'موسمها', '.', 'إنها', 'تلك', 'الثمرة', 'حمراء', 'اللون،', 'حلوة', 'الطعم،', 'وتسمى', 'الفراولة،', 'الفريز', 'أو', 'فاكهة', 'الرشاقة', '.', 'لا', 'تترددي', 'في', 'إدخالها', 'في', 'نظام', 'عائلتك', 'الغذائي،', 'ففوائدها', 'كثيرة', '!', 'شراء', 'وحفظ', 'الفراولة', 'إختاري', 'الحبة', 'لللماعة', 'والممتلة،', 'وتجنبي', 'شراءها', 'إذا', 'كانت', 'طرية', 'أو', 'بدأ', 'العفن', 'يتكوّن', 'عليها', '.', 'لا', 'تغسليها', 'قبل', 'حفظها،', 'وضعيها', 'في', 'الثلاجة', 'لمدة', 'أقصاها', 'ثلاثة', 'أيام،', 'ثم', 'أخرجيها', 'قبل', '20', 'دقيقة', 'من', 'استخدامها', '.', 'كيف', 'تُستخدم', 'الفراولة؟', 'أغسلي', 'الفراولة', 'سريعاً', 'بالماء', 'دون', 'نقعها،', 'ثم', 'إنزعي', 'عنها', 'الأوراق', 'والساق', 'الخضراء', 'وإلا', 'سوف', 'تمتصّ', 'الماء', '.', 'يمكن', 'تناولها', 'لوحدها', 'او', 'مع', 'السكر', 'أو', 'الكريمة', 'المخفوقة،', 'فيما', 'البعض', 'يضيفها', 'إلى', 'السلطات', 'مع', 'الروكا،', 'السبانخ', 'وصلصة', 'بخلّ', 'البلسميك،', 'أو', 'إلى', 'سلطة', 'الفواكه', '.', 'كما', 'أنّ', 'الفراولة', 'مرغوبة', 'جداً', 'في', 'البوظة', 'وفي', 'الحلويات،', 'فنجدها', 'دائماً', 'تزيّن', 'الكيكات', 'و', 'التارت', 'والجيلي', 'و', 'التشيزكيك', '.', 'كذلك،', 'يمكن', 'أن', 'تعصر', 'وتتناول', 'لوحدها', 'كمشروب', 'منعش،', 'أو', 'تضاف', 'إلى', 'عصائر', 'أخرى', 'لتحضير', 'كوكتيلات', 'مختلفة', 'أو', 'مع', 'الحليب', 'لـ', 'ميلك', 'شيك', 'لا', 'يقاوم', '!', 'أما', 'مربى', 'الفراولة', '،', 'فيحضر', 'بطبخ', 'الفراولة', 'مع', 'السكر', 'على', 'نار', 'خفيفة', 'لساعة', 'ونصف', '.', 'فوائد', 'الفراولة', 'تشتهر', 'الفراولة', 'بغناها', 'بالفيتامين', 'ج،', 'بالإضافة', 'إلى', 'الألياف،', 'البوتاسيوم،', 'الحديد،', 'الكالسيوم', 'والماغنيزيوم،', 'وذلك،', 'دون', 'أن', 'ننسى', 'أنّ', '100', 'غرام', 'من', 'الفراولة', 'تحتوي', 'فقط', 'على', '50', 'سعرة', 'حرارية', '!', 'هل', 'تعلمين؟', 'بعض', 'أنواع', 'الفراولة', 'لونها', 'أبيض', 'وأصفر،', 'وبعضها', 'الآخر', 'مذاقها', 'كالأناناس', '!', 'المعلومات', 'الغذائية', 'وحدات', 'حرارية', '32', 'كمية', 'الدهون', 'الإجمالية', '0', 'غ', 'دهون', 'مشبّعة', '0', 'غ', 'كمية', 'السكر', 'الإجمالية', '5', 'غ', 'كولسترول', '0', 'ملغ', 'كربوهيدرات', '8', 'غ', 'الألياف', 'الغذائية', '2', 'غ', 'بروتين', '1', 'غ', 'فيتامين', 'C', '98', '%', 'كالسيوم', '2', '%', 'حديد', '2', '%', 'صوديوم', '1', 'ملغ', 'ترتكز', 'نسبة', 'الاستهلاك', 'اليومي', 'على', 'حمية', 'غذائية', 'ذات', 'وحدة2000', '*', 'حرارية', '.', 'وقد', 'تكون', 'نسبة', 'استهلاكك', 'اليومية', 'أكثر', 'أو', 'أقل', 'من', 'هذه', 'النسبة', 'وذلك', 'بحسب', 'حاجة', 'جسمك', 'للوحدات', 'الحرارية', '.', 'وصفات', 'بالفراولة', 'مشروبات', 'طريقة', 'عمل', 'ميلك', 'شايك', 'الفراولة', 'في', 'ديزني', 'لاند', 'باريس', 'مثالية', 'للأولاد', '!', '15', 'دقيقة', 'حلى', 'بالفيديو،', 'وصفة', 'فطيرة', 'الفواكه', 'باستخدام', 'بقايا', 'العجين', 'ألذ', 'وصفة', 'تارت', '!', '3', 'دقيقة', 'حلى', 'ترايفل', 'الكاسترد', 'والفواكه', 'طعمه', 'لا', 'يقاوم', '!', '15', 'دقيقة', 'مشروبات', 'عصير', 'حليب', 'بالفراولة', 'منعش', 'ولذيذ', 'جد ...
# ---------------------------------
# ['C', 'Webedia', 'Group', 'FZ', 'LLC']
# ['انتقل', 'إلى', 'المحتوى', 'القائمة', 'الرئيسية', 'القائمة', 'الرئيسية', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'الموسوعة', 'الصفحة', 'الرئيسية', 'الأحداث', 'الجارية', 'أحدث', 'التغييرات', 'أحدث', 'التغييرات', 'الأساسية', 'تصفح', 'المواضيع', 'أبجدي', 'بوابات', 'مقالة', 'عشوائية', 'تصفح', 'من', 'غير', 'إنترنت', 'مشاركة', 'تواصل', 'مع', 'ويكيبيديا', 'مساعدة', 'الميدان', 'تبرع', 'لغات', 'في', 'نسخة', 'ويكيبيديا', 'هذه،', 'وصلات', 'اللغات', 'موجودة', 'في', 'الزاوية', 'العليا', 'اليسرى', 'بجانب', 'العنوان', '.', 'انتقل', 'إلى', 'الأعلى', '.', 'بحث', 'إنشاء', 'حساب', 'دخول', 'أدوات', 'شخصية', 'إنشاء', 'حساب', 'دخول', 'صفحات', 'للمحررين', 'الذين', 'سجَّلوا', 'خروجهم', 'تعلَّم', 'المزيد', 'مساهمات', 'نقاش', 'CentralNotice', 'المحتويات', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'المقدمة', '1', 'الوصف', 'النباتي', 'ثبِّت', 'القسم', 'الفرعي', 'الوصف', 'النباتي', '1.1', 'الأوراق', '1.2', 'النورة', '1.3', 'الزهرة', '1.4', 'الصفات', 'المميزة', 'للفصيلة', 'الوردية', '2', 'الأسر', 'ثبِّت', 'القسم', 'الفرعي', 'الأسر', '2.1', 'الورداوات', '2.2', 'المشمشاوات', '2.3', 'اللوزاوات', '2.4', 'السبيرياوات', '3', 'المصادر', 'والمراجع', '4', 'مراجع', 'تبديل', 'عرض', 'جدول', 'المحتويات', 'تبديل', 'عرض', 'جدول', 'المحتويات', 'وردية', '93', 'لغة', 'Afrikaans', 'Aragonés', 'مصرى', 'Asturianu', 'Azərbaycanca', 'Башҡортса', 'Беларуская', 'Беларуская', '(', 'тарашкевіца', ')', 'Български', 'Bosanski', 'Català', 'Cebuano', 'Čeština', 'Чӑвашла', 'Cymraeg', 'Dansk', 'Deutsch', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'فارسی', 'Suomi', 'Français', 'Nordfriisk', 'Gaeilge', 'Galego', 'עברית', 'हिन्दी', 'Hrvatski', 'Hornjoserbsce', 'Magyar', 'Հայերեն', 'Bahasa', 'Indonesia', 'Íslenska', 'Italiano', '日本語', 'Jawa', 'ქართული', 'Taqbaylit', 'Қазақша', '한국어', 'Перем', 'коми', 'Kurdî', 'Коми', 'Кыргызча', 'Latina', 'Lëtzebuergesch', 'Lombard', 'Lietuvių', 'Latviešu', 'Македонски', 'മലയാളം', 'Plattdüütsch', 'Nederlands', 'Norsk', 'nynorsk', 'Norsk', 'bokmål', 'Occitan', 'Ирон', 'ਪੰਜਾਬੀ', 'Polski', 'پنجابی', 'Português', 'Runa', 'Simi', 'Română', 'Русский', 'Scots', 'Davvisámegiella', 'Srpskohrvatski', '/', 'српскохрватски', 'Simple', 'English', 'Slovenčina', 'Slovenščina', 'Српски', '/', 'srpski', 'Svenska', 'తెలుగు', 'ไทย', 'Türkmençe', 'Tagalog', 'Türkçe', 'Татарча', '/', 'tatarça', 'Українська', 'Oʻzbekcha', '/', 'ўзбекча', 'Vepsän', 'kel', '’', 'Tiếng', 'Việt', 'West-Vlams', 'Walon', 'Winaray', '吴语', 'მარგალური', '中文', 'Bân-lâm-gú', '粵語', 'عدل', 'الوصلات', 'مقالة', 'نقاش', 'العربية', 'اقرأ', 'عدّل', 'تاريخ', 'أدوات', 'أدوات', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'أفعال', 'اقرأ', 'عدّل', 'تاريخ', 'عام', 'ماذا', 'يصل', 'هنا', 'تغييرات', 'ذات', 'علاقة', 'رفع', 'ملف', 'الصفحات', 'الخاصة', 'وصلة', 'دائمة', 'معلومات', 'الصفحة', 'استشهد', 'بهذه', 'الصفحة', 'عنصر', 'ويكي', 'بيانات', 'طباعة/تصدير', 'إنشاء', 'كتاب', 'تحميل', 'PDF', 'نسخة', 'للطباعة', 'في', 'مشاريع', 'أخرى', 'ويكيميديا', 'كومنز', 'ويكي', 'الأنواع', 'من', 'ويكيبيديا،', 'الموسوعة', 'الحرة', 'هذه', 'المقالة', 'عن', 'فصيلة', 'نباتية', '.', 'لمعانٍ', 'أخرى،', 'طالع', 'وردية', '(', 'توضيح', ')', '.', 'Rosaceaeالفصيلة', 'الوردية', 'العصر', ':', '110', 'مليون', 'سنة', 'قك', 'ك', 'أ', 'س', 'د', 'ف', 'بر', 'ث', 'ج', 'ط', 'ب', 'ن', '↓', 'عصر', 'طباشيري', '-', 'Recent', 'زهرة', 'نبات', 'من', 'الفصيلة', 'الوردية', 'المرتبة', 'التصنيفية', 'فصيلة', '[', '1', ']', '[', '2', ']', 'التصنيف', 'العلمي', 'المملكة', ':', 'النبات', 'القسم', ':', 'مغطاة', 'البذور', 'الطائفة', ':', 'ثنائيات', 'الفلقة', 'الرتبة', ':', 'ورديات', 'الفصيلة', ':', 'الوردية', 'جوسيو', 'الاسم', 'العلمي', 'Rosaceae', '[', '1', ']', '[', '3', ']', 'أنطوان', 'لوران', 'دو', 'جوسيو', '،', '1789', 'Subfamilies', 'ورداوات', 'Spiraeoideae', 'تفاحاوات', 'لوزاوات', 'or', 'لوزاوات', 'Global', 'distribution', 'of', 'Rosaceae', 'تعديل', 'مصدري', '-', 'تعديل', 'الفصيلة', 'الوَرْدِيَّة', '[', '7', ']', 'هي', 'فصيلة', 'نباتية', 'من', 'ذوات', 'الفلقتين', 'تضم', 'عدة', 'أجناس', 'أشجار', 'وشجيرات', 'وجنبات', 'وأعشاب', '.', 'ومعظمها', 'ينمو', 'في', 'المناطق', 'الباردة', '.',  ...
# ---------------------------------
# ['CentralNotice', 'Afrikaans', 'Aragonés', 'Asturianu', 'Azərbaycanca', 'Башҡортса', 'Беларуская', 'Беларуская', 'Български', 'Bosanski', 'Català', 'Cebuano', 'Čeština', 'Чӑвашла', 'Cymraeg', 'Dansk', 'Deutsch', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'Suomi', 'Français', 'Nordfriisk', 'Gaeilge', 'Galego', 'Hrvatski', 'Hornjoserbsce', 'Magyar', 'Հայերեն', 'Bahasa', 'Indonesia', 'Íslenska', 'Italiano', 'Jawa', 'Taqbaylit', 'Қазақша', 'Перем', 'Kurdî', 'Кыргызча', 'Latina', 'Lëtzebuergesch', 'Lombard', 'Lietuvių', 'Latviešu', 'Македонски', 'Plattdüütsch', 'Nederlands', 'Norsk', 'Norsk', 'Occitan', 'Ирон', 'Polski', 'Português', 'Runa', 'Simi', 'Română', 'Русский', 'Scots', 'Davvisámegiella', 'Srpskohrvatski', 'Simple', 'English', 'Slovenčina', 'Slovenščina', 'Српски', 'Svenska', 'Türkmençe', 'Tagalog', 'Türkçe', 'Татарча', 'Українська', 'Oʻzbekcha', 'Vepsän', 'Tiếng', 'Việt', 'West-Vlams', 'Walon', 'Winaray', 'Bân-lâm-gú', 'PDF', 'Rosaceaeالفصيلة', 'Subfamilies', 'Spiraeoideae', 'Global', 'Poterium', 'Aruncusa،', 'Hirtella،', 'Fragaria', 'Prunus', 'Prunus', 'Prunus', 'Prunus', 'Pyrus', 'Pyrus', 'Cydonia', 'Spiraea', 'An', 'Phylogeny', 'Group', 'APG', 'III', '//dx.doi.org/10.1111/J.1095-8339.2009.00996.X', 'Reveal', 'System', 'Appendix', 'IIB', 'Conserved', 'International', 'Code', 'Nomenclature', 'Shenzhen', 'Code', 'Armen', 'Takhtajan', 'ISBN', '//www.researchgate.net/profile/Im-Danylyk/post/Could-someone-share-an-electronic-copy-of-Takhtajan-2009s-Florwering-Plants/attachment/5a60c0e34cde266d58843e72/AS', '3A584177909002241', '401516290275885/download/Flowering+plant+takhtajan.pdf', 'James', 'L.', 'Reveal', 'Summary', 'Kew', 'Bulletin', '//dx.doi.org/10.1007/S12225-011-9259-Y', '//www.researchgate.net/profile/Im-Danylyk/post/Could-someone-share-an-electronic-copy-of-Takhtajan-2009s-Florwering-Plants/attachment/5a60c0e34cde266d58843e72/AS', '3A584177909002241', '401516290275885/download/Flowering+plant+takhtajan.pdf', 'James', 'L.', 'Reveal', 'An', 'Magnoliopsida', 'Angiospermae', 'Botanical', 'Review', 'AUCOTC', '2.0.CO', '//www.researchgate.net/profile/Im-Danylyk/post/Could-someone-share-an-electronic-copy-of-Takhtajan-2009s-Florwering-Plants/attachment/5a60c0e34cde266d58843e72/AS', '3A584177909002241', '401516290275885/download/Flowering+plant+takhtajan.pdf', 'ISBN', 'OCLC', 'OL', '45257084M', 'Q115858440', 'GBIF', 'WoRMS', 'NBN', 'NBNSYS0000160907', 'ITIS', 'TSN', 'iNaturalist', 'IPNI', 'EoL', 'BDTFX', '220AC9D5-032F-6A99-5995-65A7894C44D0', 'Fossilworks', 'Tropicos', 'NZOR', 'ID', 'APG', 'IV', 'Basal', 'Hydatellaceae', 'Cabombaceae', 'Mesangiospermae', 'Canellaceae', 'Winteraceae', 'Siparunaceae', 'Gomortegaceae', 'Atherospermataceae', 'Degeneriaceae', 'Himantandraceae', 'Eupomatiaceae', 'Scheuchzeriaceae', 'Maundiaceae', 'Cymodoceaceae', 'Dasypogonaceae', 'Boryaceae', 'Asteliaceae', 'Lanariaceae', 'Hypoxidaceae', 'Tecophilaeaceae', 'Xeronemataceae', 'Hanguanaceae', 'Philydraceae', 'Campynemataceae', 'Corsiaceae', 'Petermanniaceae', 'Triuridaceae', 'Velloziaceae', 'Petrosaviales', 'Petrosaviaceae', 'Rapateaceae', 'Eriocaulaceae', 'Mayacaceae', 'Thurniaceae', 'Flagellariaceae', 'Joinvilleaceae', 'Ecdeiocoleaceae', 'Lowiaceae', 'Sabiaceae', 'Eupteleaceae', 'Circaeasteraceae', 'Trochodendrales', 'Trochodendraceae', 'Myrothamnaceae', 'Superrosids', 'Peridiscaceae', 'Altingiaceae', 'Cercidiphyllaceae', 'Iteaceae', 'Aphanopetalaceae', 'Tetracarpaeaceae', 'Penthoraceae', 'Cynomoriaceae', 'Apodanthaceae', 'Anisophylleaceae', 'Corynocarpaceae', 'Tetramelaceae', 'Quillajaceae', 'Ticodendraceae', 'Dirachmaceae', 'Lepidobotryaceae', 'Pandaceae', 'Ctenolophonaceae', 'Lophopyxidaceae', 'Putranjivaceae', 'Centroplacaceae', 'Balanopaceae', 'Trigoniaceae', 'Euphroniaceae', 'Humiriaceae', 'Goupiaceae', 'Lacistemataceae', 'Ixonanthaceae', 'Picrodendraceae', 'Huaceae', 'Akaniaceae', 'Limnanthaceae', 'Setchellanthaceae', 'Koeberliniaceae', 'Bataceae', 'Emblingiaceae', 'Tovariaceae', 'Pentadiplandraceae', 'Geissolomataceae', 'Str ...
# ['معلومة', 'أثق', 'بها', 'دخول', 'تسجيل', 'ويب', 'طب', 'معلومة', 'أثق', 'بها', 'طب', 'وصحة', 'الصحة', 'والجمال', 'الحمل', 'والولادة', 'الأمراض', 'الأدوية', 'رمضان', 'السعرات', 'الحرارية', 'للأطعمة', 'جميع', 'الأقسام', '×', 'طب', 'وصحة', 'أجهزة', 'الجسم', 'صحة', 'الأسنان', 'القلب', 'الطب', 'البديل', 'صحة', 'المرأة', 'السرطان', 'صحة', 'العيون', 'ثقافة', 'جنسية', 'الصحة', 'النفسية', 'مشخص', 'الأعراض', 'السكري', 'التكنولوجيا', 'الطبية', 'أخبار', 'الصحة', 'الحمل', 'والولادة', 'ﺣﺎﺳﺒﺔ', 'اﻟﺤﻤﻞ', 'واﻟﻮﻻدة', 'معاني', 'الاسماء', 'ﺗﺨﻄﻴﻂ', 'اﻟﺤﻤﻞ', 'اﻟﻮﻻدة', 'ﻧﻤﻮ', 'وﺗﻄﻮر', 'اﻟﻄﻔﻞ', 'اﻟﺤﻤﻞ', 'الاطفال', 'الرضع', 'رعاية', 'الاطفال', 'ﻣﺮاﺣﻞ', 'ﻧﻤﻮ', 'اﻟﻄﻔﻞ', 'اﻟﺮﺿﻴﻊ', 'الصحة', 'والجمال', 'الريجيم', 'وتخفيف', 'الوزن', 'التغذية', 'السليمة', 'الرياضة', 'والرشاقة', 'الحياة', 'الزوجية', 'العناية', 'بالشعر', 'العناية', 'بالبشرة', 'والجمال', 'جودة', 'الحياة', 'الجيل', 'الذهبي', 'وصفات', 'صحية', 'القيم', 'الغذائية', 'المنتديات', 'الصفحة', 'الرئيسية', 'المدونات', 'ادوات', 'وميديا', 'فيديو', 'عروض', 'مرئية', 'حاسبات', 'اختبر', 'نفسك', 'صح', 'أم', 'خطأ', 'عام', 'الصفحة', 'الرئيسية', 'امراض', 'علاجات', 'تطعيمات', 'رمضان', 'مصطلحات', 'ادوية', 'فيتامينات', 'اسئلة', 'واجوبة', 'فحوصات', 'مقالات', 'تفاعلات', 'الادوية', 'لانك', 'الأهم', 'احجزي', 'موعدك', 'مع', 'طبيب', 'النسائية', 'في', 'عيادة', 'ويب', 'طب', 'الإلكترونية', 'احجز', 'الآن', 'احجزي', 'الآن', 'احجزي', 'موعد', 'في', 'عيادة', 'ويب', 'طب', 'الإلكترونية', 'Trigger/Open', 'The', 'Modal', 'Modal', 'content', '×', 'الرئيسية', 'التغذية', 'السليمة', 'فوائد', 'الفراولة', ':', 'تعرف', 'عليها', 'فوائد', 'الفراولة', ':', 'تعرف', 'عليها', 'برعاية', 'شارك', 'غرد', 'هل', 'أنت', 'من', 'محبي', 'ثمار', 'الفراولة؟', 'إذا', 'أنت', 'تُكسب', 'جسمك', 'العديد', 'من', 'الفوائد،', 'إذ', 'إن', 'فوائد', 'الفراولة', 'جدًا', 'عديدة', 'ومذهلة،', 'تابع', 'المقال', 'لمعرفة', 'هذه', 'الفوائد', '.', 'فلنتعرف', 'في', 'ما', 'يأتي', 'على', 'فوائد', 'الفراولة', 'وكيفية', 'تناولها', 'إضافةً', 'لمعرفة', 'أضرارها', 'المحتملة', ':', 'فوائد', 'الفراولة', 'تمثلت', 'فوائد', 'الفراولة', 'المحتملة', 'في', 'ما', 'يأتي', ':', '1', '.', 'زيادة', 'قوة', 'الجهاز', 'المناعي', 'تحتوي', 'الفراولة', 'على', 'نسبة', 'جيدة', 'من', 'فيتامين', 'ج', '،', 'وهذا', 'الفيتامين', 'قادر', 'على', 'تعزيز', 'وتقوية', 'صحة', 'الجهاز', 'المناعي،', 'كما', 'أنه', 'يعمل', 'على', 'جعل', 'الجهاز', 'الهضمي', 'يمتص', 'الحديد', 'بشكل', 'أفضل،', 'وهذا', 'يحد', 'من', 'الإصابة', 'بفقر', 'الدم', 'الناتج', 'من', 'نقص', 'الحديد', '.', '2', '.', 'دعم', 'عمل', 'الجهاز', 'الهضمي', 'الفوسفور', 'المتواجد', 'في', 'الفراولة', 'يُساهم', 'في', 'تحسين', 'عملية', 'الهضم،', 'كما', 'أنه', 'يمد', 'الجسم', 'بالطاقة', '.', '3', '.', 'المساهمة', 'في', 'الحد', 'من', 'الإصابة', 'بالسرطان', 'الفراولة', 'غنية', 'بالمواد', 'المضادة', 'للأكسدة', 'التي', 'تُحارب', 'الجذور', 'الحرة،', 'ومن', 'هذا', 'المنطلق', 'قد', 'يكون', 'للفراولة', 'دور', 'في', 'الحد', 'من', 'الإصابة', 'بمرض', 'السرطان', '.', '4', '.', 'تنظيم', 'مستويات', 'السكر', 'في', 'الدم', 'من', 'أبرز', 'فوائد', 'الفراولة', 'أنها', 'قد', 'تُساهم', 'في', 'تنظيم', 'مستويات', 'السكر', 'في', 'الجسم،', 'وذلك', 'يعود', 'بسبب', 'احتوائها', 'على', 'الألياف', 'الغذائية', 'التي', 'تُساهم', 'في', 'الحد', 'من', 'الشعور', 'بالجوع،', 'وبتالي', 'تناول', 'كميات', 'طعام', 'أقل،', 'وهذا', 'ما', 'يُساهم', 'في', 'تنظيم', 'السكر', 'في', 'الدم', '.', '5', '.', 'تعزيز', 'صحة', 'القلب', 'والأوعية', 'الدموية', 'أحد', 'فوائد', 'الفراولة', 'تعزيز', 'وتحسين', 'صحة', 'القلب', 'والشرايين', 'عمومًا،', 'وتعزى', 'هذه', 'الفائدة', 'المحتملة', 'إلى', 'احتواء', 'الفراولة', 'على', 'كل', 'مما', 'يأتي', ':', 'الألياف', 'التي', 'قد', 'تساعد', 'على', 'خفض', 'مستويات', 'الكولسترول', 'السيئ', 'في', 'الجسم', '.', 'البوتاسيوم', '،', 'إذ', 'يُعزز', 'البوتاسيوم', 'صحة', 'الأوعية', 'الدموية،', 'ويمنع', 'ارتفاع', 'ضغط', 'الدم،', 'وهذا', 'يؤدي', 'إلى', 'تعزيز', 'صحة', 'القلب.\ufeff', 'نسب', 'معتدلة', 'من', 'حمض', 'الفوليك', '(', 'Folic', 'acid', ')', 'الذي', 'يُساعد', 'على', 'تحسين', 'صحة', 'القلب', '.', 'مضادات', 'الأكسدة', '،', 'مثل', ':', 'الأنثوسيانين', '(', 'Anthocyanin', ')', '،', 'ومضادات', 'ا ...
# ---------------------------------
# ['Trigger/Open', 'The', 'Modal', 'Modal', 'Folic', 'Anthocyanin', 'IgE', 'Webteb', 'Google', 'Tag', 'Manager', 'End', 'Google', 'Tag', 'Manager']
# ['إنشاء', 'حساب', 'دخول', 'تصفح', 'الصفحة', 'الرئيسية', 'أحدث', 'التغييرات', 'الصفحات', 'الخاصّة', 'رفع', 'ملف', 'تصفح', 'المواضيع', 'أبجدي', 'دليل', 'الأسلوب', 'صفحة', 'عشوائية', 'مشاريع', 'شقيقة', 'معرفة_المصادر', 'معرفة_الأخبار', 'المشاركة', 'والمساعدة', 'بوابة', 'المجتمع', 'مساعدة', 'الميدان', 'بحث', 'وبينار', 'مصادر', 'صور', 'الأخبار', 'فيديو', 'close', 'projects', 'هل', 'تعلم', 'أن', 'قلب', 'طائر', 'الطنان', 'يدق', '1.000', 'مرة', 'في', 'الدقيقة', '.', 'أن', 'يمكن', 'للبومة', 'تدوير', 'رأسها', 'وعنقها', '270°،', 'مع', '17', 'فقرة', 'عنقية', 'مقارنة', 'بسبع', 'فقرات', 'لدى', 'البشر', '.', 'أن', 'أول', 'عملة', 'ورقية', 'طُورت', 'في', 'الصين', 'بالقرن', '7،', 'إلا', 'أن', 'العملات', 'الورقية', 'لم', 'تظهر', 'حتى', 'القرن', '11', '.', 'أن', 'الدنا', 'البشري', 'إذا', 'تمدد', 'سيصل', 'إلى', 'القمر', '6.000', 'مرة', '.', 'أن', 'سويسرا', 'تستهلك', 'أكبر', 'كمية', 'من', 'الشوكولاتة', 'في', 'العالم،', 'بمعدل', '10', 'كج', 'للفرد', 'سنوياً', '.', 'أن', 'الهيكل', 'العظمي', 'للفيل', 'الأفريقي', 'يشكل', '15', '%', 'تقريباً', 'من', 'وزنه', '.', 'أن', 'البرق', 'يضرب', 'الأرض', '6.000', 'مرة', 'في', 'الدقيقة', '.', 'أن', 'فيلم', 'سنو', 'وايت', 'والأقزام', 'السبعة', 'هو', 'أول', 'فيلم', 'رسوم', 'متحركة', 'طويل', 'كامل،', 'وأنتجته', 'والت', 'ديزني', 'عام', '1937', '.', 'للمزيد', 'لغات', 'أخرى', 'Afrikaans', 'Alemannisch', 'Aragonés', 'Asturianu', 'Aymar', 'aru', 'Azərbaycanca', 'Žemaitėška', 'Български', 'বাংলা', 'Brezhoneg', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'Deutsch', 'Ελληνικά', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'فارسی', 'Suomi', 'Français', 'Arpetan', 'Furlan', 'Gaeilge', '贛語', 'Galego', 'Avañe', "'", 'ẽ', 'Gaelg', 'עברית', 'हिन्दी', 'Hrvatski', 'Hornjoserbsce', 'Kreyòl', 'ayisyen', 'Magyar', 'Հայերեն', 'Interlingua', 'Bahasa', 'Indonesia', 'Ido', 'Íslenska', 'Italiano', 'ᐃᓄᒃᑎᑐᑦ/inuktitut', '日本語', 'Ქართული', '한국어', 'Kernowek', 'Latina', 'Lëtzebuergesch', 'Ligure', 'Lingála', 'Lietuvių', 'Latviešu', 'Македонски', 'മലയാളം', 'मराठी', 'Bahasa', 'Melayu', 'Nāhuatl', 'Plattdüütsch', 'Nedersaksies', 'Nederlands', 'Norsk', 'nynorsk', 'Norsk', 'Nouormand', 'Occitan', 'Ирон', 'Polski', 'Português', 'Runa', 'Simi', 'Română', 'Tarandíne', 'Русский', 'Саха', 'тыла', 'Sicilianu', 'Srpskohrvatski', '/', 'српскохрватски', 'Simple', 'English', 'Slovenčina', 'Slovenščina', 'Shqip', 'Српски', '/', 'srpski', 'Seeltersk', 'Svenska', 'Kiswahili', 'தமிழ்', 'తెలుగు', 'ไทย', 'Tagalog', 'Lea', 'faka-Tonga', 'Türkçe', 'ChiTumbuka', 'Українська', 'اردو', 'Tiếng', 'Việt', 'West-Vlams', 'Walon', 'Wolof', 'ייִדיש', 'Zeêuws', '中文', '文言', 'Bân-lâm-gú', '粵語', 'أضف', 'وصلات', 'مستخدم', 'مميز', 'Marefa', 'Sidebar', '160x600', 'مقالة', 'ناقش', 'هذه', 'الصفحة', 'اقرأ', 'عرض', 'المصدر', 'تاريخ', 'المزيد', 'أدوات', 'ماذا', 'يرتبط', 'هنا؟', 'تغييرات', 'ذات', 'علاقة', 'الصفحات', 'الخاصّة', 'نسخة', 'للطباعة', 'وصلة', 'دائمة', 'معلومات', 'عن', 'هذه', 'الصفحة', 'Marefa', 'Top', 'Leaderboard', 'نبات', 'start', 'content', 'نبات', 'Temporal', 'range', ':', 'كمبري', 'مبكر', 'إلى', 'الحاضر،', 'ولكن', 'انظر', 'المقال', '،', '520–0', 'Ma', 'PreЄ', 'Є', 'O', 'S', 'D', 'C', 'P', 'T', 'J', 'K', 'Pg', 'N', 'التصنيف', 'العلمي', 'Domain', ':', 'حقيقيات', 'النوى', '(', 'unranked', ')', ':', 'Archaeplastida', 'مملكة', ':', 'النبات', 'هيكل', ',', '1866', '[', '1', ']', 'الأقسام', 'طحالب', 'خضراء', 'الطحالب', 'الخضراء', 'Chlorophyta', 'طحالب', 'فحمية', 'Charophyta', 'نباتات', 'الأرض', '(', 'أو', 'إمبريات', 'embryophytes', ')', 'نباتات', 'لاوعائية', '(', 'أو', 'بريويات', 'bryophytes', ')', 'الماركنتيات', 'Marchantiophyta', '—', 'حشيشة', 'الكبد', 'liverworts', 'الأنثوسروتيات', 'Anthocerotophyta', '—', 'حشيشة', 'قرنية', 'hornworts', 'البرويات', 'Bryophyta', '—', 'حزازيات', 'mosses', '†', 'Horneophytopsida', 'نباتات', 'وعائية', '(', 'tracheophytes', ')', '†', 'Rhyniophyta', '—rhyniophytes', '†', 'Zosterophyllophyta', '—zosterophylls', 'ذئبيات', 'الأرجل', 'Lycopodiophyta', '—', 'clubmosses', '†', 'Trimerophytophyta', '—trimerophytes', 'سرخس', '(', 'أو', 'مجنحة', ...
# ---------------------------------
# ['Afrikaans', 'Alemannisch', 'Aragonés', 'Asturianu', 'Aymar', 'Azərbaycanca', 'Žemaitėška', 'Български', 'Brezhoneg', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'Deutsch', 'Ελληνικά', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'Suomi', 'Français', 'Arpetan', 'Furlan', 'Gaeilge', 'Galego', 'Avañe', 'Gaelg', 'Hrvatski', 'Hornjoserbsce', 'Kreyòl', 'Magyar', 'Հայերեն', 'Interlingua', 'Bahasa', 'Indonesia', 'Ido', 'Íslenska', 'Italiano', 'Ქართული', 'Kernowek', 'Latina', 'Lëtzebuergesch', 'Ligure', 'Lingála', 'Lietuvių', 'Latviešu', 'Македонски', 'Bahasa', 'Melayu', 'Nāhuatl', 'Plattdüütsch', 'Nedersaksies', 'Nederlands', 'Norsk', 'Norsk', 'Nouormand', 'Occitan', 'Ирон', 'Polski', 'Português', 'Runa', 'Simi', 'Română', 'Tarandíne', 'Русский', 'Саха', 'Sicilianu', 'Srpskohrvatski', 'Simple', 'English', 'Slovenčina', 'Slovenščina', 'Shqip', 'Српски', 'Seeltersk', 'Svenska', 'Kiswahili', 'Tagalog', 'Lea', 'faka-Tonga', 'Türkçe', 'ChiTumbuka', 'Українська', 'Tiếng', 'Việt', 'West-Vlams', 'Walon', 'Wolof', 'Zeêuws', 'Bân-lâm-gú', 'Marefa', 'Sidebar', 'Marefa', 'Top', 'Leaderboard', 'Temporal', 'Ma', 'PreЄ', 'Є', 'O', 'D', 'C', 'P', 'T', 'J', 'K', 'Pg', 'N', 'Domain', 'Archaeplastida', 'Chlorophyta', 'Charophyta', 'Marchantiophyta', 'Anthocerotophyta', 'Bryophyta', 'Horneophytopsida', 'Rhyniophyta', 'Zosterophyllophyta', 'Lycopodiophyta', 'Trimerophytophyta', 'Pteridophyta', 'Progymnospermophyta', 'Pteridospermatophyta', 'Pinophyta', 'Cycadophyta', 'Ginkgophyta', 'Gnetophyta', 'Magnoliophyta', 'Angiospermae', 'Nematophytes', 'Kunstformen', 'Natur', 'Marefa', 'Dicksonia', 'Yew', 'Venus', 'Darwin', 'Origin', 'Cossypium', 'L', 'Family', 'Malvaceae', 'Malvales', 'Dicotyledonae', 'Sub', 'Angiospermae', 'Anthophyta', 'Kingdom', 'Marefa', 'Eichler', 'Bold', 'Cycadophyta', 'Procaryota', 'RNA', 'DNA', 'Mycococcms', 'Bergey', 'Manual', 'Protophyta', 'Prasinophyceae', 'Streptobionta', 'Stomatophytes', 'Polysporangiates', 'Eutracheophytes', 'Euphyllophytina', 'Lignophytia', 'Progymnospermophyta', 'Pteridophyta', 'Pteridopsida', 'Marattiopsida', 'Equisetopsida', 'Psilotopsida', 'Cladoxylopsida', 'Lycophytina', 'Lycopodiophyta', 'Zosterophyllophyta', 'Rhyniophyta', 'Aglaophyton', 'Horneophytopsida', 'Bryophyta', 'Anthocerotophyta', 'Marchantiophyta', 'Charophyta', 'Chlorophyta', 'Trebouxiophyceae', 'Pleurastrophyceae', 'Chlorophyceae', 'Ulvophyceae', 'Dicksonia', 'Marefa', 'Paleobotany', 'Forest', 'National', 'Park', 'Biological', 'Germination', 'Haeckel', 'G', 'Generale', 'Morphologie', 'Organismen', 'Berlin', 'Verlag', 'Georg', 'Reimer', 'I–II', 'I–VIII', 'Van', 'Hoek', 'C.', 'D.', 'G.', 'Mann', 'H.', 'M.', 'Jahns', 'Algae', 'An', 'Introduction', 'Phycology', 'Cambridge', 'Cambridge', 'University', 'Press', 'ISBN', 'Guiry', 'M.D', 'Guiry', 'G.M', 'AlgaeBase', 'Chlorophyta', 'World-wide', 'National', 'University', 'Ireland', 'Galway', 'gettaxon=Chlorophyta', 'Guiry', 'M.D', 'Guiry', 'G.M', 'AlgaeBase', 'Charophyta', 'World-wide', 'National', 'University', 'Ireland', 'Galway', 'gettaxon=Charophyta', 'Van', 'Hoek', 'C.', 'D.', 'G.', 'Mann', 'H.', 'M.', 'Jahns', 'Algae', 'An', 'Introduction', 'Phycology', 'Cambridge', 'Cambridge', 'University', 'Press', 'ISBN', 'Crandall-Stotler', 'Barbara', 'Stotler', 'Raymond', 'E.', 'Morphology', 'Marchantiophyta', 'A.', 'Jonathan', 'Shaw', 'Bernard', 'Goffinet', 'Eds', 'Bryophyte', 'Biology', 'Cambridge', 'Cambridge', 'University', 'Press', 'ISBN', 'Schuster', 'Rudolf', 'M.', 'Hepaticae', 'Anthocerotae', 'North', 'America', 'VI', 'Chicago', 'Field', 'Museum', 'Natural', 'ISBN', 'Goffinet', 'Bernard', 'Systematics', 'Bryophyta', 'Monographs', 'Systematic', 'Botany', 'Missouri', 'Botanical', 'Garden', 'Press', 'Unknown', 'Raven', 'Peter', 'H.', 'Ray', 'F.', 'Evert', 'Susan', 'E.', 'Eichhorn', 'Biology', 'New', 'York', 'W.', 'H.', 'Freeman', 'Company', 'ISBN', 'Gifford', 'Ernest', 'M.', 'Adriance', 'S.', 'Foster', 'Morphology', 'Evolution', 'Vascular', 'New', 'York', 'W.', 'H.', 'Freeman', 'Compan ...
# ['انتقل', 'إلى', 'المحتوى', 'القائمة', 'الرئيسية', 'القائمة', 'الرئيسية', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'الموسوعة', 'الصفحة', 'الرئيسية', 'الأحداث', 'الجارية', 'أحدث', 'التغييرات', 'أحدث', 'التغييرات', 'الأساسية', 'تصفح', 'المواضيع', 'أبجدي', 'بوابات', 'مقالة', 'عشوائية', 'تصفح', 'من', 'غير', 'إنترنت', 'مشاركة', 'تواصل', 'مع', 'ويكيبيديا', 'مساعدة', 'الميدان', 'تبرع', 'لغات', 'في', 'نسخة', 'ويكيبيديا', 'هذه،', 'وصلات', 'اللغات', 'موجودة', 'في', 'الزاوية', 'العليا', 'اليسرى', 'بجانب', 'العنوان', '.', 'انتقل', 'إلى', 'الأعلى', '.', 'بحث', 'إنشاء', 'حساب', 'دخول', 'أدوات', 'شخصية', 'إنشاء', 'حساب', 'دخول', 'صفحات', 'للمحررين', 'الذين', 'سجَّلوا', 'خروجهم', 'تعلَّم', 'المزيد', 'مساهمات', 'نقاش', 'CentralNotice', 'المحتويات', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'المقدمة', '1', 'الوصف', 'النباتي', '2', 'ألوان', 'الفراولة', '3', 'القيمة', 'والأثر', 'الطبي', '4', 'القيمة', 'الغذائية', '5', 'زراعة', 'الفراولة', 'في', 'الحقول', 'المفتوحة', '6', 'إنتاج', 'الفراولة', 'ثبِّت', 'القسم', 'الفرعي', 'إنتاج', 'الفراولة', '6.1', 'الزراعة', 'بالشتلات', 'المبردة', '6.2', 'الزراعة', 'بالشتلات', 'الطازجة', '7', 'مكافحة', 'الآفات', '8', 'جمع', 'المحصول', '9', 'أصول', 'التعبئة', '10', 'معرض', 'الصور', '11', 'انظر', 'أيضاً', '12', 'المراجع', 'تبديل', 'عرض', 'جدول', 'المحتويات', 'تبديل', 'عرض', 'جدول', 'المحتويات', 'فراولة', '113', 'لغة', 'Аԥсшәа', 'Aragonés', 'مصرى', 'অসমীয়া', 'Asturianu', 'Atikamekw', 'Azərbaycanca', 'Башҡортса', 'Žemaitėška', 'Bikol', 'Central', 'Беларуская', 'Български', 'বাংলা', 'བོད་ཡིག', 'Brezhoneg', 'Bosanski', 'Català', '閩東語', '/', 'Mìng-dĕ̤ng-ngṳ̄', 'Cebuano', 'ᏣᎳᎩ', 'کوردی', 'Corsu', 'Čeština', 'Kaszëbsczi', 'Dansk', 'Deutsch', 'Dolnoserbski', 'Ελληνικά', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'فارسی', 'Suomi', 'Føroyskt', 'Français', 'Nordfriisk', 'Galego', 'Avañe', "'", 'ẽ', 'ગુજરાતી', '客家語/Hak-kâ-ngî', 'עברית', 'हिन्दी', 'Hrvatski', 'Hornjoserbsce', 'Magyar', 'Հայերեն', 'Bahasa', 'Indonesia', 'Iñupiatun', 'Ido', 'Italiano', '日本語', 'Jawa', 'ಕನ್ನಡ', '한국어', 'Latina', 'Limburgs', 'Lombard', 'ລາວ', 'Lietuvių', 'Latviešu', 'Malagasy', 'Minangkabau', 'Македонски', 'മലയാളം', 'Монгол', 'मराठी', 'Кырык', 'мары', 'Bahasa', 'Melayu', 'မြန်မာဘာသာ', 'مازِرونی', 'नेपाली', 'नेपाल', 'भाषा', 'Nederlands', 'Norsk', 'nynorsk', 'Norsk', 'bokmål', 'Diné', 'bizaad', 'ਪੰਜਾਬੀ', 'Polski', 'Piemontèis', 'پنجابی', 'Português', 'Русский', 'संस्कृतम्', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Scots', 'سنڌي', 'Simple', 'English', 'Shqip', 'Српски', '/', 'srpski', 'Svenska', 'Kiswahili', 'Sakizaya', 'தமிழ்', 'Тоҷикӣ', 'ไทย', 'Türkmençe', 'Türkçe', 'Татарча', '/', 'tatarça', 'ئۇيغۇرچە', '/', 'Uyghurche', 'Українська', 'Vèneto', 'Tiếng', 'Việt', 'West-Vlams', 'Winaray', '吴语', 'მარგალური', 'Vahcuengh', '中文', 'Bân-lâm-gú', '粵語', 'IsiZulu', 'عدل', 'الوصلات', 'مقالة', 'نقاش', 'العربية', 'اقرأ', 'عدّل', 'تاريخ', 'أدوات', 'أدوات', 'انقل', 'للشريط', 'الجانبي', 'أخف', 'أفعال', 'اقرأ', 'عدّل', 'تاريخ', 'عام', 'ماذا', 'يصل', 'هنا', 'تغييرات', 'ذات', 'علاقة', 'رفع', 'ملف', 'الصفحات', 'الخاصة', 'وصلة', 'دائمة', 'معلومات', 'الصفحة', 'استشهد', 'بهذه', 'الصفحة', 'عنصر', 'ويكي', 'بيانات', 'طباعة/تصدير', 'إنشاء', 'كتاب', 'تحميل', 'PDF', 'نسخة', 'للطباعة', 'في', 'مشاريع', 'أخرى', 'ويكيميديا', 'كومنز', 'ويكي', 'الأنواع', 'من', 'ويكيبيديا،', 'الموسوعة', 'الحرة', 'فراولة', 'المرتبة', 'التصنيفية', 'نوع', 'التصنيف', 'العلمي', 'النطاق', ':', 'حقيقيات', 'النوى', 'المملكة', ':', 'النباتات', 'الفرقة', 'العليا', ':', 'النباتات', 'الأرضية', 'القسم', ':', 'نباتات', 'وعائية', 'الشعبة', ':', 'شعبة', 'البذريات', 'الشعيبة', ':', 'مستورات', 'البذور', 'العمارة', ':', 'شليكية', 'الطويئفة', ':', 'الورديات', 'الرتبة', 'العليا', ':', 'الورديات', 'الرتبة', ':', 'ورديات', 'الفصيلة', ':', 'وردية', 'الأسرة', ':', 'الوردية', 'القبيلة', ':', 'Potentilleae', 'العميرة', ':', 'شليكية', 'الجنس', ':', 'شليك', 'الاسم', 'العلمي', 'Fragaria', 'x', 'ananassa', '(', 'Weston', ')', 'Duchesne،', '1788', 'معرض', 'صور', 'فراولة', '-', 'ويكيميديا', 'كومنز', 'تعديل', 'مصدري', '-', 'تعديل', 'الفراولة', '(', 'عن', 'اليونانية ...
# ---------------------------------
# ['CentralNotice', 'Аԥсшәа', 'Aragonés', 'Asturianu', 'Atikamekw', 'Azərbaycanca', 'Башҡортса', 'Žemaitėška', 'Bikol', 'Central', 'Беларуская', 'Български', 'Brezhoneg', 'Bosanski', 'Català', 'Mìng-dĕ̤ng-ngṳ̄', 'Cebuano', 'ᏣᎳᎩ', 'Corsu', 'Čeština', 'Kaszëbsczi', 'Dansk', 'Deutsch', 'Dolnoserbski', 'Ελληνικά', 'English', 'Esperanto', 'Español', 'Eesti', 'Euskara', 'Suomi', 'Føroyskt', 'Français', 'Nordfriisk', 'Galego', 'Avañe', '客家語/Hak-kâ-ngî', 'Hrvatski', 'Hornjoserbsce', 'Magyar', 'Հայերեն', 'Bahasa', 'Indonesia', 'Iñupiatun', 'Ido', 'Italiano', 'Jawa', 'Latina', 'Limburgs', 'Lombard', 'Lietuvių', 'Latviešu', 'Malagasy', 'Minangkabau', 'Македонски', 'Монгол', 'Кырык', 'Bahasa', 'Melayu', 'Nederlands', 'Norsk', 'Norsk', 'Diné', 'Polski', 'Piemontèis', 'Português', 'Русский', 'Scots', 'Simple', 'English', 'Shqip', 'Српски', 'Svenska', 'Kiswahili', 'Sakizaya', 'Тоҷикӣ', 'Türkmençe', 'Türkçe', 'Татарча', 'Uyghurche', 'Українська', 'Vèneto', 'Tiếng', 'Việt', 'West-Vlams', 'Winaray', 'Vahcuengh', 'Bân-lâm-gú', 'IsiZulu', 'PDF', 'Potentilleae', 'Fragaria', 'Weston', 'Duchesne،', 'Fragaria', 'A،', 'B،', 'C.', 'PH', 'Parker', 'Earle', 'FAO', 'ITIS', 'TSN', 'GBIF', 'iNaturalist', 'BDTFX', 'IPNI', 'FRAN', 'EoL', 'Fragaria', 'NBN', 'NHMSYS0000458878', 'PlantList', 'Tropicos', 'NZOR', 'ID', 'NZOR', 'ID', 'UNII', 'BRO5T4GIXN', 'P105', 'P935', 'P815', 'P846', 'P3151', 'P3105', 'P961', 'P1772', 'P1745', 'P830', 'P1421', 'P1939', 'P4301', 'P3240', 'P1747', 'P838', 'P3420', 'P1070', 'P960', 'P2752', 'P3405', 'P652', 'GND', 'Toggle']
# ['ADiPOLO', 'DFP', 'DFP', '<', 'script', '>', 'googletag.cmd.push', '(', 'function', '(', ')', '{', 'googletag.defineSlot', '(', "'/21823462148/Youm7-Leaderboard-Inner", "'", ',', '[', '[', '970', ',', '250', ']', ',', '[', '970', ',', '90', ']', ',', '[', '728', ',', '90', ']', ']', ',', "'div-gpt-ad-1562083652224-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/21823462148/Youm7-Widget-Inner", "'", ',', '[', '[', '468', ',', '60', ']', ',', '[', '468', ',', '110', ']', ']', ',', "'div-gpt-ad-1559564022999-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/21823462148/Youm7-TakeOver-Inner-R", "'", ',', '[', '[', '130', ',', '600', ']', ',', '[', '160', ',', '600', ']', ']', ',', "'div-gpt-ad-1559565327743-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/21823462148/Youm7-TakeOver-Inner-L", "'", ',', '[', '[', '130', ',', '600', ']', ',', '[', '160', ',', '600', ']', ']', ',', "'div-gpt-ad-1559565105568-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/21823462148/Youm7-SuperWidget", "'", ',', '[', '550', ',', '60', ']', ',', "'div-gpt-ad-1559437718274-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/21823462148/Youm7-MPU-Inner-1", "'", ',', '[', '[', '300', ',', '600', ']', ',', '[', '300', ',', '250', ']', ',', "'fluid", "'", ',', '[', '336', ',', '280', ']', ',', '[', '200', ',', '200', ']', ']', ',', "'div-gpt-ad-1559435367505-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/233509614/Adcrew-EGY/Youm7_OutStream_Smart_SB", "'", ',', '[', '1', ',', '1', ']', ',', "'div-gpt-ad-1567539609163-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/21823462148/Youm7-SuperWidget", "'", ',', '[', '336', ',', '280', ']', ',', "'div-gpt-ad-1571134486646-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/4525877/Desktop-MPU", "'", ',', '[', '300', ',', '250', ']', ',', "'div-gpt-ad-1573404451965-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/108861785/youm7_rectangle/youm7_rectangle_sticky", "'", ',', '[', '300', ',', '250', ']', ',', "'div-gpt-ad-1566472685057-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.defineSlot', '(', "'/4525877/Desktop-MPU-2", "'", ',', '[', '300', ',', '250', ']', ',', "'div-gpt-ad-1574767853673-0", "'", ')', '.setTargeting', '(', "'Y7-Section", "'", ',', '[', "'HEALTH", "'", ']', ')', '.addService', '(', 'googletag.pubads', '(', ')', ')', ';', 'googletag.pubads', '(', ')', '.collapseEmptyDivs', '(', ')', ';', 'googletag.enableServices', '(', ')', ';', '}', ')', ';', '<', '/script', '>', 'Comments', 'Adrecovery', 'Google', 'Analytis', 'March', '2020', 'Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'Analytics', 'Google', 'Analytics4', 'Test', 'Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google ...
# ---------------------------------
# ...
# ---------------------------------
# ['MedicineNet', 'BMI', 'BMR']
# ['إنشاء', 'حساب', 'دخول', 'تصفح', 'الصفحة', 'الرئيسية', 'أحدث', 'التغييرات', 'الصفحات', 'الخاصّة', 'رفع', 'ملف', 'تصفح', 'المواضيع', 'أبجدي', 'دليل', 'الأسلوب', 'صفحة', 'عشوائية', 'مشاريع', 'شقيقة', 'معرفة_المصادر', 'معرفة_الأخبار', 'المشاركة', 'والمساعدة', 'بوابة', 'المجتمع', 'مساعدة', 'الميدان', 'بحث', 'وبينار', 'مصادر', 'صور', 'الأخبار', 'فيديو', 'close', 'projects', 'هل', 'تعلم', 'أن', 'قلب', 'طائر', 'الطنان', 'يدق', '1.000', 'مرة', 'في', 'الدقيقة', '.', 'أن', 'يمكن', 'للبومة', 'تدوير', 'رأسها', 'وعنقها', '270°،', 'مع', '17', 'فقرة', 'عنقية', 'مقارنة', 'بسبع', 'فقرات', 'لدى', 'البشر', '.', 'أن', 'أول', 'عملة', 'ورقية', 'طُورت', 'في', 'الصين', 'بالقرن', '7،', 'إلا', 'أن', 'العملات', 'الورقية', 'لم', 'تظهر', 'حتى', 'القرن', '11', '.', 'أن', 'الدنا', 'البشري', 'إذا', 'تمدد', 'سيصل', 'إلى', 'القمر', '6.000', 'مرة', '.', 'أن', 'سويسرا', 'تستهلك', 'أكبر', 'كمية', 'من', 'الشوكولاتة', 'في', 'العالم،', 'بمعدل', '10', 'كج', 'للفرد', 'سنوياً', '.', 'أن', 'الهيكل', 'العظمي', 'للفيل', 'الأفريقي', 'يشكل', '15', '%', 'تقريباً', 'من', 'وزنه', '.', 'أن', 'البرق', 'يضرب', 'الأرض', '6.000', 'مرة', 'في', 'الدقيقة', '.', 'أن', 'فيلم', 'سنو', 'وايت', 'والأقزام', 'السبعة', 'هو', 'أول', 'فيلم', 'رسوم', 'متحركة', 'طويل', 'كامل،', 'وأنتجته', 'والت', 'ديزني', 'عام', '1937', '.', 'للمزيد', 'لغات', 'أخرى', 'Български', 'Català', 'Dansk', 'Deutsch', 'English', 'Esperanto', 'Español', 'Suomi', 'Français', 'Frysk', 'Galego', 'Magyar', 'Ido', 'Italiano', '日本語', '한국어', 'Lietuvių', 'Nederlands', 'Polski', 'Português', 'Simple', 'English', 'Svenska', 'Türkçe', 'Українська', '中文', 'أضف', 'وصلات', 'مستخدم', 'مميز', 'Marefa', 'Sidebar', '160x600', 'مقالة', 'ناقش', 'هذه', 'الصفحة', 'اقرأ', 'عرض', 'المصدر', 'تاريخ', 'المزيد', 'أدوات', 'ماذا', 'يرتبط', 'هنا؟', 'تغييرات', 'ذات', 'علاقة', 'الصفحات', 'الخاصّة', 'نسخة', 'للطباعة', 'وصلة', 'دائمة', 'معلومات', 'عن', 'هذه', 'الصفحة', 'Marefa', 'Top', 'Leaderboard', 'فراولة', 'start', 'content', 'الفراولة', 'Strawberry', 'التصنيف', 'العلمي', 'مملكة', ':', 'نباتية', '(', 'unranked', ')', ':', 'نباتات', 'مزهرة', '(', 'unranked', ')', ':', 'مغطاة', 'البذور', 'Order', ':', 'Rosales', 'Family', ':', 'الوردية', 'Subfamily', ':', 'Rosoideae', 'Tribe', ':', 'Potentilleae', 'Subtribe', ':', 'Fragariinae', '[', '1', ']', 'Genus', ':', 'Fragaria', 'L.', 'Species', '20+', 'species', ';', 'see', 'text', 'الفراولة،', 'الفريز،', 'توت', 'الأرض', 'الفراولة', 'أو', 'الفريز', '،', 'نبات', 'عشبي', 'مستديم', 'الخضرة', 'ومعمر', 'من', 'الفصيلة', 'الوردية', 'Rosaceae', 'من', 'محاصيل', 'الفاكهة', 'ذات', 'العائد', 'الكبير', 'للمزارع،', 'ويمكن', 'استهلاك', 'ثماره', 'وتصديرها', 'إما', 'طازجة', 'أو', 'مجمدة', 'أو', 'مصنعة', '.', 'فهرست', '1', 'التسمية', '2', 'الوصف', '2.1', 'اللون', '2.2', 'المجموعة', 'الجذرية', '2.3', 'المجموعة', 'الخضرية', '2.4', 'الثمار', '3', 'التصنيف', '4', 'الأهمية', 'الغذائية', '5', 'المتطلبات', 'البيئية', '5.1', 'التربة', '5.2', 'الحرارة', '5.3', 'الضوء', '6', 'التكاثر', '7', 'زراعة', 'الفريز', '7.1', 'الزراعة', 'بالشتلات', 'المثلجة', '7.2', 'الزراعة', 'بالشتلات', 'الطازجة', ':', '7.3', 'عمليات', 'الخدمة', 'بعد', 'الزراعة', '7.4', 'الري', '7.5', 'التقليم', 'وخف', 'الأزهار', '7.6', 'التسميد', '7.7', 'تجديد', 'الزراعة', '7.8', 'النضج', 'والجني', 'والتخزين', '7.9', 'أهم', 'الآفات', '7.10', 'جمع', 'المحصول', '7.11', 'أصول', 'التعبئة', '8', 'انظر', 'أيضا', '9', 'المصادر', '9.1', 'الهوامش', '10', 'وصلات', 'خارجية', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.' ...
# ---------------------------------
# ['Български', 'Català', 'Dansk', 'Deutsch', 'English', 'Esperanto', 'Español', 'Suomi', 'Français', 'Frysk', 'Galego', 'Magyar', 'Ido', 'Italiano', 'Lietuvių', 'Nederlands', 'Polski', 'Português', 'Simple', 'English', 'Svenska', 'Türkçe', 'Українська', 'Marefa', 'Sidebar', 'Marefa', 'Top', 'Leaderboard', 'Order', 'Rosales', 'Family', 'Subfamily', 'Rosoideae', 'Tribe', 'Potentilleae', 'Subtribe', 'Fragariinae', 'Fragaria', 'L.', 'Rosaceae', 'Marefa', 'Fraise،', 'Fragaria', 'Redeva', 'Gold', 'Woodland', 'Fragaria', 'Garden', 'Fragaria', 'Fragaria', 'SENGA', 'PRECOSANA', 'GORELLA', 'SENGA', 'GIGANA', 'SENGA', 'SENGANA', 'TAGO', 'SEQUOIA', 'ALISO', 'Marefa', 'B', 'C.', 'pH', 'PH', 'Marefa', 'P2O5', 'Mock', 'Barren', 'Fragaria', 'Potentilla', 'Tree', 'Fragaria', 'Germplasm', 'Resources', 'Information', 'Network', 'United', 'States', 'Department', 'Agriculture', 'Retrieved', 'Retrieved', 'Retrieved', 'Flavonoids', 'Salk', 'Scientists', 'Say', 'Apple', 'Salk', 'Institute', 'Retrieved', 'Balconmicrobio.com', 'How', 'Spanish', 'GRIN', 'Fragaria', 'Taxonomy', 'Database', 'Listing', 'Fragaria', 'USDA', 'NewPP', 'Cached', 'Reduced', 'CPU', 'Real', 'Preprocessor', 'Highest', 'Expensive', 'Unstrip', 'Unstrip', 'Lua', 'Lua', 'Number', 'Wikibase', 'Transclusion', 'Taxobox', 'Taxobox/core', 'Reflist', 'Cite_web', 'Taxonomy', 'Taxonomy/nobreak', 'Taxobox_colour', 'If_empty', 'Taxonbar/candidate', 'Saved', 'Berries', 'Taxoboxes', 'Taxoboxes', 'Taxobox', 'AddThis', 'Global', 'Google', 'Analytics', 'Google', 'Analytics', 'Google', 'Analytics']
# ['#', 'BeginTemplate', '``', '..', '/NutritionTemplate.dwt', "''", 'Header', 'NutritionBannerTopResp.', ',', '728x90', ',', 'created', '08/02/18', 'تابعنا', 'من', 'خلال', 'فيدو', 'على', 'الفيسبوك', 'فيدو', 'على', 'التويتر', 'Navigation', 'Bar', 'Articles', '#', 'BeginEditable', '``', 'content01', "''", 'فوائد', 'الفراولة', 'الصحية', '*', 'الفراولة', ':', 'الفراولة', 'هي', 'مصدر', 'غنى', 'بمضادات', 'الأكسدة', 'وإضافتها', 'إلى', 'نظام', 'غذائي', 'متوازن', 'يمكن', 'أن', 'يقدم', 'مجموعة', 'واسعة', 'من', 'الفوائد،', 'بعض', 'مضادات', 'الأكسدة', 'الموجودة', 'في', 'الفراولة', 'تشمل', 'فيتامين', '``', 'ج', "''", 'و', 'الليوتين', 'و', 'الكاروتين', '.', 'بالإضافة', 'إلى', 'ذلك،', 'تعتبر', 'الفراولة', 'مصدرًا', 'جيدًا', 'للفيتامينات', 'و', 'المعادن', 'الأخرى', '.', 'وتحتوي', 'أيضًا', 'على', 'كميات', 'مناسبة', 'من', 'حمض', 'الفوليك', '(', 'فيتامين', 'ب9', ')', 'و', 'البوتاسيوم', 'و', 'المنجنيز', '.', 'كما', 'تُعد', 'مصدر', 'غنى', 'بالألياف', 'الغذائية', 'المهمة', 'لتغذية', 'البكتيريا', 'النافعة', 'في', 'الأمعاء', 'وتحسين', 'صحة', 'الجهاز', 'الهضمي', '،', 'لذا', 'فهى', 'تساعد', 'في', 'الوقاية', 'من', 'العديد', 'من', 'الأمراض', '.', 'المزيد', 'عن', 'الألياف', '..', 'تتكون', 'الكربوهيدرات', 'في', 'الفراولة', 'بشكل', 'أساسي', 'من', 'الألياف', 'والسكريات', 'البسيطة', '.', 'وبها', 'مؤشر', 'جلايسيمي', '(', 'تأثير', 'الكربوهيدرات', 'على', 'ارتفاع', 'أو', 'انخفاض', 'سكر', 'الدم', ')', 'منخفض', 'نسبيًا', 'لا', 'يسبب', 'ارتفاعًا', 'كبيرًا', 'في', 'مستويات', 'السكر', 'في', 'الدم', '.', 'وعادة', 'ما', 'يتم', 'استهلاك', 'الفراولة', 'نيئة', 'وطازجة،', 'ويمكن', 'استخدامها', 'أيضًا', 'في', 'مجموعة', 'متنوعة', 'من', 'المربات', 'والجيلى', '(', 'الهلام', ')', 'والحلويات', '.', 'المزيد', 'عن', 'الكربوهيدرات', '..', 'الفراولة', '.', 'الفوائد', 'الصحية', 'للفراولة', '.', 'كيفية', 'اختيار', 'ثمار', 'الفراولة', '.', 'التخزين', 'الصحيح', 'لثمار', 'الفراولة', '.', 'القيم', 'الغذائية', 'فى', 'الفراولة', '.', 'الكم', 'الموصى', 'بتناوله', '.', '*', 'الفوائد', 'الصحية', 'للفراولة', ':', '-', 'الفراولة', 'تحمى', 'من', 'الإصابة', 'بمرض', 'السرطان', ':', 'تعتبر', 'الفراولة', 'من', 'المصادر', 'الجيدة', 'بشكل', 'استثنائي', 'لفيتامين', '``', 'ج', "''", 'والألياف،', 'وكلاهما', 'وُجد', 'أنه', 'يحمي', 'من', 'سرطان', 'المريء', 'و', 'القولون', '.', 'يمكن', 'أن', 'تُعزى', 'خصائص', 'الفراولة', 'المضادة', 'للسرطان', '،', 'وفقًا', 'للمعهد', 'الأمريكي', 'لأبحاث', 'السرطان،', 'إلى', 'وجود', 'حمض', 'الإيلاجيك/', 'Ellagic', '-', 'وهو', 'مادة', 'كيميائية', 'نباتية', 'يمكن', 'أن', 'تمنع', 'سرطانات', 'الجلد', 'و', 'الرئة', 'و', 'المثانة', 'والثدي', '.', 'يعمل', 'حمض', 'الإيلاجيك', 'كعامل', 'مضاد', 'للسرطان', 'بعدة', 'طرق', '-', 'فهو', 'يعمل', 'كمضاد', 'للأكسدة،', 'ويبطئ', 'إنتاج', 'الخلايا', 'السرطانية،', 'ويساعد', 'الجسم', 'على', 'تدمير', 'أنواع', 'معينة', 'من', 'المواد', 'المسرطنة', '.', '-', 'الفراولة', 'تحمى', 'القلب', ':', 'إن', 'وفرة', 'مضادات', 'الأكسدة', 'في', 'الفراولة', 'يجعلها', 'الغذاء', 'المثالي', 'لحماية', 'القلب', 'من', 'الأمراض', '.', 'تحتوي', 'الفراولة', 'على', 'مادة', 'الأنثوسيانين', '-', 'Anthocyanin', '(', 'مضادات', 'الأكسدة', 'المسئولة', 'عن', 'لونها', 'الأحمر', ')', '،', 'والتي', 'تحمي', 'بطانة', 'الدورة', 'الدموية،', 'وبالتالي', 'تحمي', 'الشرايين', 'من', 'تراكم', 'الترسبات', 'وتنظم', 'ضغط', 'الدم', '.', 'كما', 'تشير', 'نتائج', 'الدراسات', 'إلى', 'أن', 'النساء', 'اللائي', 'تناولن', 'ثلاث', 'حصص', 'أو', 'أكثر', 'من', 'الفراولة', '(', 'الحصة', 'الواحدة', 'من', 'الفراولة', 'تتكون', 'من', 'ثمان', 'ثمرات', 'كبيرة', 'الحجم', 'تحتوى', 'على', 'خمسين', 'سعر', 'حراري', ')', 'أسبوعيًا', 'قللن', 'من', 'خطر', 'الإصابة', 'بنوبة', 'قلبية', 'بمقدار', 'الثلث', '.', 'المزيد', 'عن', 'الأزمات', 'القلبية', '..', '-', 'الفراولة', 'تعزز', 'مناعة', 'الجسم', ':', 'تعتبر', 'الفراولة', 'من', 'المصادر', 'الممتازة', 'لفيتامين', '``', 'ج', "''", '.', 'تحتوي', 'الحصة', 'الواحدة', 'من', 'الفراولة', 'على', 'فيتامين', '``', 'ج', "''", 'أكثر', 'من', 'البرتقال', '.', 'وقد', 'تم', 'التوصل', 'إلى', 'أن', 'فيتامين', '``', 'ج', "''", 'يحفز', 'الأجسام', 'المضادة', 'المعززة', 'للمناعة،', 'والتي', 'تعزز', 'في',  ...
# ---------------------------------
# ['BeginTemplate', '/NutritionTemplate.dwt', 'Header', 'NutritionBannerTopResp.', 'Navigation', 'Bar', 'Articles', 'BeginEditable', 'Ellagic', 'Anthocyanin', 'Low', 'Density', 'Lipoprotein', 'LDL', 'LDL', 'الماليك/Malic', 'هيدروكسي/Alpha', 'الساليسيليك/Salicylic', 'Strawberries', 'How', 'Grow', 'Strawberries', 'A', 'Look', 'Nutritional', 'Value', 'Benefits', 'Strawberries', 'Strawberries', 'A', 'EndEditable', 'NutritionLeftResponsive', 'NutriationSquareNew24/10/2020', 'Banner', 'Footer', 'NutritionBottomResponsive', 'Footer', 'Copyright', 'Design', 'Designed', 'Developed', 'EBM', 'Co.', 'EndTemplate']
# ['المزيد', '°C', '°C', '{', '{', 'weatherDataItem.maxTemperature', '|', 'decimalNumber', ':', 'null', ':', "'floor", "'", '}', '}', '°C', 'تسجيل', 'الدخول', 'راديو', 'مباشر', 'دخول', '°C', 'مباشر', 'راديو', 'عاجل', 'الإشعارات', 'الرئيسية', 'أخبار', 'آخر', 'الأخبار', 'الأكثر', 'قراءة', 'تقارير', 'مصورة', 'اخترنا', 'لكم', 'تقارير', 'خاصة', 'شرق', 'أوسط', 'آخر', 'الأخبار', 'من', 'مصر', 'نافذة', 'مغاربية', 'بيئة', 'ومناخ', 'كوب', '28', 'صحة', 'غذاء', 'أوبئة', 'عالم', 'آخر', 'الأخبار', 'الولايات', 'المتحدة', 'رياضة', 'علوم', 'آخر', 'الأخبار', 'تكنولوجيا', 'الذكاء', 'الاصطناعي', 'منوعات', 'فيديو', 'أحدث', 'الفيديوهات', 'نجوم', 'على', 'سكاي', 'الأكثر', 'تفاعلا', 'سوشيال', 'فيديو', 'برامجنا', 'حديث', 'الصور', 'إنفوغرافيك', 'مقالات', 'رأي', 'ملفات', 'مزيد', 'رياضة', 'علوم', 'منوعات', 'فيديو', 'برامجنا', 'حديث', 'الصور', 'إنفوغرافيك', 'مقالات', 'رأي', 'ملفات', 'عاجل', 'مباشر', 'راديو', '[', 'if', 'lte', 'IE', '10', ']', '>', '<', 'div', 'style=', "''", 'position', ':', 'fixed', ';', 'top', ':', '0', ';', 'left', ':', '0', ';', 'width', ':', '100', '%', ';', 'height', ':', '100', '%', ';', 'background', ':', '#', 'f5f5f5', ';', 'z-index', ':', '100000', ';', 'overflow', ':', 'auto', ';', "''", '>', '<', 'div', 'style=', "''", 'width', ':', '100', '%', ';', "''", '>', '<', 'img', 'style=', "''", 'width', ':', '100', '%', ';', 'max-height', ':', '100px', "''", 'src=', "''", 'https', ':', '//www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/notsupported-header.jpg', "''", 'alt=', "''", "''", 'role=', "''", 'presentation', "''", '>', '<', '/div', '>', '<', 'div', 'style=', "''", 'text-align', ':', 'center', ';', 'width', ':', '100', '%', ';', "''", '>', '<', 'img', 'style=', "''", 'width:100', '%', ';', 'max-width', ':', '640px', ';', "''", 'src=', "''", 'https', ':', '//www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/not-supported.jpg', "''", 'alt=', "''", "''", 'role=', "''", 'presentation', "''", '>', '<', '/div', '>', '<', 'div', 'style=', "''", 'width', ':', '100', '%', ';', 'position', ':', 'fixed', ';', 'bottom', ':', '0', ';', 'background-color', ':', '#', '4d535d', "''", '>', '<', 'img', 'src=', "''", 'https', ':', '//www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/notsupported-footer.jpg', "''", 'alt=', "''", "''", 'role=', "''", 'presentation', "''", '>', '<', '/div', '>', '<', '/div', '>', '<', '!', '[', 'endif', ']', 'الرئيسية', 'الأخبار', 'العاجلة', 'أخبار', 'شرق', 'أوسط', 'صحة', 'عالم', 'رياضة', 'علوم', 'منوعات', 'فيديو', 'برامجنا', 'حديث', 'الصور', 'البث', 'المباشر', 'راديو', 'إنفوغرافيك', 'مقالات', 'رأي', 'ملفات', 'آخر', 'الأخبار', 'تكنولوجيا', 'الذكاء', 'الاصطناعي', '{', '{', 'promoBar.promoMessage', '}', '}', '{', '{', 'promoBar.description', '}', '}', '{', '{', 'btnText', '}', '}', 'X', 'لم', 'تفعّل', 'خدمة', 'إشعارات', 'الأخبار', 'العاجلة', 'اضغط', 'للمزيد', 'إشترك', 'شكرًا', 'للاشتراك', 'بخدمة', 'الأخبار', 'العاجلة', 'www.skynewsarabia.com', 'دراسة', 'تكشف', 'فائدة', '``', 'غير', 'متوقعة', "''", 'لتناول', 'الفراولة', 'يوميا', 'l', '11', 'فبراير', '2023', '-', '11:59', 'بتوقيت', 'أبوظبي', 'وكالات', '-', 'أبوظبي', 'تناول', 'الفراولة', 'مفيد', 'لصحة', 'القلب', 'كشفت', 'دراسة', 'صادرة', 'عن', 'مؤشر', 'Global', 'Burden', 'of', 'Disease،', 'عن', 'فوائد', 'تناول', 'الفراولة', 'على', 'صحة', 'القلب', '.', 'ووفق', 'الدراسة،', 'فإن', 'تناول', 'كوب', 'صغير', 'من', 'الفراولة', 'يوميا،', 'يمكن', 'أن', 'يحسّن', 'من', 'صحة', 'القلب', '.', 'وقال', 'البروفيسور', 'في', 'معهد', 'ليلينوي', 'للتكنولوجيا،', 'بريت', 'بيرتون', 'فريمان،', 'في', 'بيان', ':', '``', 'أظهرت', 'الدراسة', 'أن', 'اتباع', 'نظام', 'غذائي', 'لا', 'يتضمن', 'تناول', 'الفاكهة', '،', 'من', 'بين', 'عوامل', 'الخطر', 'للإصابة', 'بأمراض', 'القلب', 'والأوعية', 'الدموية', 'والسكري', '``', '.', 'وأضاف', 'فريمان', ':', '``', 'من', 'الضروري', 'أن', 'تتضمن', 'الأنظمة', 'الغذائية', 'كميات', 'كافية', 'من', 'الفاكهة،', 'ومراعاة', 'التنوع', 'فيها', "''", '،', 'وفقما', 'نقلت', 'شبكة', '``', 'يو', 'بي', 'آي', "''", 'للأنباء', '.',  ...
# ---------------------------------
# ['°C', '°C', 'weatherDataItem.maxTemperature', 'decimalNumber', '°C', '°C', 'IE', 'promoBar.promoMessage', 'promoBar.description', 'btnText', 'X', 'Global', 'Burden', 'Disease،', ':article.mediaAsset.caption', 'article.match.roundName', 'sidebarWidgetTitle', 'sidebarWidgetTitle', 'breakingNewsWidgetTitle', 'radioWidgetTitle', 'pollWidgetTitle', 'breakingNewsWidgetTitle', 'pollWidgetTitle', 'radioWidgetTitle', 'sidebarWidgetTitle', 'sidebarWidgetTitle', 'SKY', 'Sky', 'International', 'AG']

# %%
stop_words = set(nltk.corpus.stopwords.words("arabic"))
from nltk.stem.isri import ISRIStemmer
import re
st = ISRIStemmer()

# w=filtered_sentence
for word in word_tokens:
    if word not  in stop_words:
    #won't take the input correctly, input = output of tokenization# w= 'كلمات'
        print(word+"-->"+st.stem(word))
        u=st.stem(word)

# import nltk

# from nltk.stem.porter import *
# p_stemmer = PorterStemmer()




# for word in  filtered_sentence:
#     print(word+' --> '+p_stemmer.stem(word))

# from nltk.stem.snowball import SnowballStemmer
# s_stemmer = SnowballStemmer(language='english')



# for word in filtered_sentence:
#     print(word+' --> '+s_stemmer.stem(word))
# u=p_stemmer.stem(word)
# Out:
# المزيد-->زيد
# °C-->°C
# °C-->°C
# {-->{
# {-->{
# weatherDataItem.maxTemperature-->weatherDataItem.maxTemperature
# |-->|
# decimalNumber-->decimalNumber
# :-->:
# null-->null
# :-->:
# 'floor-->'floor
# '-->'
# }-->}
# }-->}
# °C-->°C
# تسجيل-->سجل
# الدخول-->دخل
# راديو-->راديو
# مباشر-->بشر
# دخول-->دخل
# °C-->°C
# مباشر-->بشر
# راديو-->راديو
# عاجل-->عجل
# الإشعارات-->شعر
# الرئيسية-->رئس
# أخبار-->خبر
# آخر-->اخر
# الأخبار-->خبر
# الأكثر-->كثر
# قراءة-->قرء
# تقارير-->قرر
# مصورة-->صور
# اخترنا-->ختر
# تقارير-->قرر
# شرق-->شرق
# أوسط-->وسط
# آخر-->اخر
# الأخبار-->خبر
# مصر-->مصر
# نافذة-->نفذ
# مغاربية-->غرب
# بيئة-->بيئ
# ومناخ-->ناخ
# كوب-->كوب
# 28-->28
# صحة-->صحة
# غذاء-->غذء
# أوبئة-->وبئ
# عالم-->علم
# آخر-->اخر
# الأخبار-->خبر
# الولايات-->ولي
# المتحدة-->تحد
# رياضة-->ريض
# علوم-->علم
# آخر-->اخر
# الأخبار-->خبر
# تكنولوجيا-->كنولوج
# الذكاء-->ذكء
# الاصطناعي-->صطناع
# منوعات-->نوع
# فيديو-->يدو
# أحدث-->حدث
# الفيديوهات-->يدو
# نجوم-->نجم
# سكاي-->سكي
# الأكثر-->كثر
# تفاعلا-->فعل
# سوشيال-->شيل
# فيديو-->يدو
# برامجنا-->رمج
# حديث-->حدث
# الصور-->صور
# إنفوغرافيك-->انفوغرافيك
# مقالات-->قال
# رأي-->رأي
# ملفات-->ملف
# مزيد-->زيد
# رياضة-->ريض
# علوم-->علم
# منوعات-->نوع
# فيديو-->يدو
# برامجنا-->رمج
# حديث-->حدث
# الصور-->صور
# إنفوغرافيك-->انفوغرافيك
# مقالات-->قال
# رأي-->رأي
# ملفات-->ملف
# عاجل-->عجل
# مباشر-->بشر
# راديو-->راديو
# [-->[
# if-->if
# lte-->lte
# IE-->IE
# 10-->10
# ]-->]
# >-->>
# <--><
# div-->div
# style=-->style=
# ''-->''
# position-->position
# :-->:
# fixed-->fixed
# ;-->;
# top-->top
# :-->:
# 0-->0
# ;-->;
# left-->left
# :-->:
# 0-->0
# ;-->;
# width-->width
# :-->:
# 100-->100
# %-->%
# ;-->;
# height-->height
# :-->:
# 100-->100
# %-->%
# ;-->;
# background-->background
# :-->:
# #-->#
# f5f5f5-->f5f5f5
# ;-->;
# z-index-->z-index
# :-->:
# 100000-->100000
# ;-->;
# overflow-->overflow
# :-->:
# auto-->auto
# ;-->;
# ''-->''
# >-->>
# <--><
# div-->div
# style=-->style=
# ''-->''
# width-->width
# :-->:
# 100-->100
# %-->%
# ;-->;
# ''-->''
# >-->>
# <--><
# img-->img
# style=-->style=
# ''-->''
# width-->width
# :-->:
# 100-->100
# %-->%
# ;-->;
# max-height-->max-height
# :-->:
# 100px-->100px
# ''-->''
# src=-->src=
# ''-->''
# https-->https
# :-->:
# //www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/notsupported-header.jpg-->//www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/notsupported-header.jpg
# ''-->''
# alt=-->alt=
# ''-->''
# ''-->''
# role=-->role=
# ''-->''
# presentation-->presentation
# ''-->''
# >-->>
# <--><
# /div-->/div
# >-->>
# <--><
# div-->div
# style=-->style=
# ''-->''
# text-align-->text-align
# :-->:
# center-->center
# ;-->;
# width-->width
# :-->:
# 100-->100
# %-->%
# ;-->;
# ''-->''
# >-->>
# <--><
# img-->img
# style=-->style=
# ''-->''
# width:100-->width:100
# %-->%
# ;-->;
# max-width-->max-width
# :-->:
# 640px-->640px
# ;-->;
# ''-->''
# src=-->src=
# ''-->''
# https-->https
# :-->:
# //www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/not-supported.jpg-->//www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/not-supported.jpg
# ''-->''
# alt=-->alt=
# ''-->''
# ''-->''
# role=-->role=
# ''-->''
# presentation-->presentation
# ''-->''
# >-->>
# <--><
# /div-->/div
# >-->>
# <--><
# div-->div
# style=-->style=
# ''-->''
# width-->width
# :-->:
# 100-->100
# %-->%
# ;-->;
# position-->position
# :-->:
# fixed-->fixed
# ;-->;
# bottom-->bottom
# :-->:
# 0-->0
# ;-->;
# background-color-->background-color
# :-->:
# #-->#
# 4d535d-->4d535d
# ''-->''
# >-->>
# <--><
# img-->img
# src=-->src=
# ''-->''
# https-->https
# :-->:
# //www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/notsupported-footer.jpg-->//www.skynewsarabia.com/asset/1643193804/16.3/assets/img/not-supported/notsupported-footer.jpg
# ''-->''
# alt=-->alt=
# ''-->''
# ''-->''
# role=-->role=
# ''-->''
# presentation-->presentation
# ''-->''
# >-->>
# <--><
# /div-->/div
# >-->>
# <--><
# /div-->/div
# >-->>
# <--><
# !-->!
# [-->[
# endif-->endif
# ]-->]
# الرئيسية-->رئس
# الأخبار-->خبر
# العاجلة-->عجل
# أخبار-->خبر
# شرق-->شرق
# أوسط-->وسط
# صحة-->صحة
# عالم-->علم
# رياضة-->ريض
# علوم-->علم
# منوعات-->نوع
# فيديو-->يدو
# برامجنا-->رمج
# حديث-->حدث
# الصور-->صور
# البث-->لبث
# المباشر-->بشر
# راديو-->راديو
# إنفوغرافيك-->انفوغرافيك
# مقالات-->قال
# رأي-->رأي
# ملفات-->ملف
# آخر-->اخر
# الأخبار-->خبر
# تكنولوجيا-->كنولوج
# الذكاء-->ذكء
# الاصطناعي-->صطناع
# {-->{
# {-->{
# promoBar.promoMessage-->promoBar.promoMessage
# }-->}
# }-->}
# {-->{
# {-->{
# promoBar.description-->promoBar.description
# }-->}
# }-->}
# {-->{
# {-->{
# btnText-->btnText
# }-->}
# }-->}
# X-->X
# تفعّل-->فعل
# خدمة-->خدم
# إشعارات-->شعر
# الأخبار-->خبر
# العاجلة-->عجل
# اضغط-->ضغط
# للمزيد-->زيد
# إشترك-->شرك
# شكرًا-->شكر
# للاشتراك-->شرك
# بخدمة-->خدم
# الأخبار-->خبر
# العاجلة-->عجل
# www.skynewsarabia.com-->www.skynewsarabia.com
# دراسة-->درس
# تكشف-->كشف
# فائدة-->فئد
# ``-->``
# متوقعة-->توقع
# ''-->''
# لتناول-->نول
# الفراولة-->رول
# يوميا-->يوم
# l-->l
# 11-->11
# 2023-->2023
# --->-
# 11:59-->11:59
# بتوقيت-->بتق
# أبوظبي-->وظب
# وكالات-->وكل
# --->-
# أبوظبي-->وظب
# تناول-->نول
# الفراولة-->رول
# مفيد-->فيد
# لصحة-->لصح
# القلب-->قلب
# كشفت-->كشف
# دراسة-->درس
# صادرة-->صدر
# مؤشر-->ؤشر
# Global-->Global
# Burden-->Burden
# of-->of
# Disease،-->Disease،
# فوائد-->فئد
# تناول-->نول
# الفراولة-->رول
# صحة-->صحة
# القلب-->قلب
# .-->.
# ووفق-->وفق
# الدراسة،-->دراسة،
# تناول-->نول
# كوب-->كوب
# صغير-->صغر
# الفراولة-->رول
# يوميا،-->يا،
# يمكن-->يمكن
# يحسّن-->يحس
# صحة-->صحة
# القلب-->قلب
# .-->.
# وقال-->وقل
# البروفيسور-->بروفيسور
# معهد-->عهد
# ليلينوي-->ينو
# للتكنولوجيا،-->تكنولوجيا،
# بريت-->برت
# بيرتون-->بير
# فريمان،-->ريمان،
# بيان-->بين
# :-->:
# ``-->``
# أظهرت-->ظهر
# الدراسة-->درس
# اتباع-->تبع
# نظام-->نظم
# غذائي-->غذي
# يتضمن-->تضم
# تناول-->نول
# الفاكهة-->فكه
# ،-->،
# عوامل-->عمل
# الخطر-->خطر
# للإصابة-->صبة
# بأمراض-->أمراض
# القلب-->قلب
# والأوعية-->وعي
# الدموية-->دمي
# والسكري-->سكر
# ``-->``
# .-->.
# وأضاف-->أضف
# فريمان-->فرم
# :-->:
# ``-->``
# الضروري-->ضرر
# تتضمن-->تضم
# الأنظمة-->نظم
# الغذائية-->غذي
# كميات-->كمي
# كافية-->كفي
# الفاكهة،-->كهة،
# ومراعاة-->راع
# التنوع-->تنع
# ''-->''
# ،-->،
# وفقما-->وفق
# نقلت-->نقل
# شبكة-->شبك
# ``-->``
# يو-->يو
# ''-->''
# للأنباء-->باء
# .-->.
# وتابع-->تبع
# قائلا-->قئل
# :-->:
# ``-->``
# تناول-->نول
# كوب-->كوب
# الفراولة-->رول
# يوميا-->يوم
# يظهر-->ظهر
# آثارا-->ثرا
# مفيدة-->فيد
# صحة-->صحة
# القلب-->قلب
# والأوعية-->وعي
# الدموية-->دمي
# ''-->''
# .-->.
# فوائد-->فئد
# عظيمة-->عظم
# تشير-->تشر
# الدراسة-->درس
# فوائد-->فئد
# تناول-->نول
# الفراولة-->رول
# تشمل،-->شمل،
# تخفيض-->خفض
# الكوليسترول-->كوليسترول
# السيء،-->يء،
# وزيادة-->زيد
# قوة-->قوة
# الأوعية-->وعي
# الدموية-->دمي
# ومرونتها،-->ومرونتها،
# وخفض-->خفض
# السكر-->سكر
# الدم-->لدم
# ومقاومة-->قام
# الأنسولين-->سول
# ،-->،
# بالإضافة-->ضفة
# تقليل-->قلل
# الالتهابات-->لهب
# .-->.
# قالت-->قلت
# الأستاذة-->اذة
# المساعدة-->سعد
# جامعة-->جمع
# نيفادا-->يفد
# لاس-->لاس
# فيغاس،-->غس،
# الدكتورة-->دكتور
# أربيتا-->ارب
# باسو،-->بس،
# دراسة-->درس
# أجريت-->اجر
# 33-->33
# بالغا،-->غا،
# يعانون-->يعن
# السمنة،-->نة،
# أظهرت-->ظهر
# تناول-->نول
# كوبين-->كوب
# ونصف-->نصف
# الفراولة-->رول
# يوميا،-->يا،
# أدى-->ادى
# تحسن-->تحس
# كبير-->كبر
# مقاومة-->قام
# الأنسولين-->سول
# .-->.
# أوضحت-->وضح
# باسو-->بسو
# ``-->``
# دراستنا-->درس
# تدعم-->دعم
# الفرضية-->فرض
# القائلة-->قئل
# بأن-->بأن
# استهلاك-->هلا
# الفراولة-->رول
# يمكن-->يمكن
# يحسن-->يحس
# مخاطر-->خطر
# استقلاب-->قلب
# القلب-->قلب
# ''-->''
# .-->.
# أكدت-->اكد
# باسو-->بسو
# أنه-->انه
# المهم-->مهم
# اعتماد-->عمد
# الفراولة-->رول
# كـ-->كـ
# ''-->''
# دواء-->دوء
# ''-->''
# للوقاية-->وقي
# مرض-->مرض
# السكري-->سكر
# النوع-->نوع
# الثاني،-->ثاني،
# وأمراض-->أمراض
# القلب-->قلب
# والأوعية-->وعي
# الدموية-->دمي
# البالغين-->بلغ
# .-->.
# دراسات-->درس
# أخرى-->خرى
# كانت-->كانت
# وجدت-->وجد
# أدلة-->ادل
# الفراولة-->رول
# تساعد-->سعد
# الحماية-->حمي
# أنواع-->واع
# السرطان،-->رطن،
# ويمكن-->ويم
# تكون-->تكون
# مفيدة-->فيد
# للأشخاص-->شخص
# يعانون-->يعن
# ارتفاع-->رفع
# ضغط-->ضغط
# الدم-->لدم
# .-->.
# الفراولة-->رول
# أمراض-->مرض
# القلب-->قلب
# صحة-->صحة
# القلب-->قلب
# عاجل-->عجل
# l-->l
# ظبي-->ظبي
# --->-
# سكاي-->سكي
# نيوز-->نيز
# عربية-->عرب
# {-->{
# {-->{
# :-->:
# :article.mediaAsset.caption-->:article.mediaAsset.caption
# }-->}
# }-->}
# {-->{
# {-->{
# article.match.competition-->article.match.competition
# }-->}
# }-->}
# --->-
# {-->{
# {-->{
# article.match.roundName-->article.match.roundName
# }-->}
# }-->}
# *-->*
# --->-
# *-->*
# ألغيت-->الغ
# تأجلت-->أجل
# توقفت-->وقف
# مباشر-->بشر
# ووفق-->وفق
# الدراسة،-->دراسة،
# تناول-->نول
# كوب-->كوب
# صغير-->صغر
# الفراولة-->رول
# يوميا،-->يا،
# يمكن-->يمكن
# يحسّن-->يحس
# صحة-->صحة
# القلب-->قلب
# .-->.
# وقال-->وقل
# البروفيسور-->بروفيسور
# معهد-->عهد
# ليلينوي-->ينو
# للتكنولوجيا،-->تكنولوجيا،
# بريت-->برت
# بيرتون-->بير
# فريمان،-->ريمان،
# بيان-->بين
# :-->:
# ``-->``
# أظهرت-->ظهر
# الدراسة-->درس
# اتباع-->تبع
# نظام-->نظم
# غذائي-->غذي
# يتضمن-->تضم
# تناول-->نول
# الفاكهة-->فكه
# ،-->،
# عوامل-->عمل
# الخطر-->خطر
# للإصابة-->صبة
# بأمراض-->أمراض
# القلب-->قلب
# والأوعية-->وعي
# الدموية-->دمي
# والسكري-->سكر
# ``-->``
# .-->.
# وأضاف-->أضف
# فريمان-->فرم
# :-->:
# ``-->``
# الضروري-->ضرر
# تتضمن-->تضم
# الأنظمة-->نظم
# الغذائية-->غذي
# كميات-->كمي
# كافية-->كفي
# الفاكهة،-->كهة،
# ومراعاة-->راع
# التنوع-->تنع
# ''-->''
# ،-->،
# وفقما-->وفق
# نقلت-->نقل
# شبكة-->شبك
# ``-->``
# يو-->يو
# ''-->''
# للأنباء-->باء
# .-->.
# وتابع-->تبع
# قائلا-->قئل
# :-->:
# ``-->``
# تناول-->نول
# كوب-->كوب
# الفراولة-->رول
# يوميا-->يوم
# يظهر-->ظهر
# آثارا-->ثرا
# مفيدة-->فيد
# صحة-->صحة
# القلب-->قلب
# والأوعية-->وعي
# الدموية-->دمي
# ''-->''
# .-->.
# فوائد-->فئد
# عظيمة-->عظم
# تشير-->تشر
# الدراسة-->درس
# فوائد-->فئد
# تناول-->نول
# الفراولة-->رول
# تشمل،-->شمل،
# تخفيض-->خفض
# الكوليسترول-->كوليسترول
# السيء،-->يء،
# وزيادة-->زيد
# قوة-->قوة
# الأوعية-->وعي
# الدموية-->دمي
# ومرونتها،-->ومرونتها،
# وخفض-->خفض
# السكر-->سكر
# الدم-->لدم
# ومقاومة-->قام
# الأنسولين-->سول
# ،-->،
# بالإضافة-->ضفة
# تقليل-->قلل
# الالتهابات-->لهب
# .-->.
# قالت-->قلت
# الأستاذة-->اذة
# المساعدة-->سعد
# جامعة-->جمع
# نيفادا-->يفد
# لاس-->لاس
# فيغاس،-->غس،
# الدكتورة-->دكتور
# أربيتا-->ارب
# باسو،-->بس،
# دراسة-->درس
# أجريت-->اجر
# 33-->33
# بالغا،-->غا،
# يعانون-->يعن
# السمنة،-->نة،
# أظهرت-->ظهر
# تناول-->نول
# كوبين-->كوب
# ونصف-->نصف
# الفراولة-->رول
# يوميا،-->يا،
# أدى-->ادى
# تحسن-->تحس
# كبير-->كبر
# مقاومة-->قام
# الأنسولين-->سول
# .-->.
# أوضحت-->وضح
# باسو-->بسو
# ``-->``
# دراستنا-->درس
# تدعم-->دعم
# الفرضية-->فرض
# القائلة-->قئل
# بأن-->بأن
# استهلاك-->هلا
# الفراولة-->رول
# يمكن-->يمكن
# يحسن-->يحس
# مخاطر-->خطر
# استقلاب-->قلب
# القلب-->قلب
# ''-->''
# .-->.
# أكدت-->اكد
# باسو-->بسو
# أنه-->انه
# المهم-->مهم
# اعتماد-->عمد
# الفراولة-->رول
# كـ-->كـ
# ''-->''
# دواء-->دوء
# ''-->''
# للوقاية-->وقي
# مرض-->مرض
# السكري-->سكر
# النوع-->نوع
# الثاني،-->ثاني،
# وأمراض-->أمراض
# القلب-->قلب
# والأوعية-->وعي
# الدموية-->دمي
# البالغين-->بلغ
# .-->.
# دراسات-->درس
# أخرى-->خرى
# كانت-->كانت
# وجدت-->وجد
# أدلة-->ادل
# الفراولة-->رول
# تساعد-->سعد
# الحماية-->حمي
# أنواع-->واع
# السرطان،-->رطن،
# ويمكن-->ويم
# تكون-->تكون
# مفيدة-->فيد
# للأشخاص-->شخص
# يعانون-->يعن
# ارتفاع-->رفع
# ضغط-->ضغط
# الدم-->لدم
# .-->.
# الأكثر-->كثر
# قراءة-->قرء
# {-->{
# {-->{
# sidebarWidgetTitle-->sidebarWidgetTitle
# }-->}
# }-->}
# {-->{
# {-->{
# sidebarWidgetTitle-->sidebarWidgetTitle
# }-->}
# }-->}
# {-->{
# {-->{
# breakingNewsWidgetTitle-->breakingNewsWidgetTitle
# }-->}
# }-->}
# l-->l
# عاجل-->عجل
# المزيد-->زيد
# {-->{
# {-->{
# radioWidgetTitle-->radioWidgetTitle
# }-->}
# }-->}
# l-->l
# {-->{
# {-->{
# pollWidgetTitle-->pollWidgetTitle
# }-->}
# }-->}
# اخترنا-->ختر
# الأكثر-->كثر
# مشاهدة-->شهد
# {-->{
# {-->{
# breakingNewsWidgetTitle-->breakingNewsWidgetTitle
# }-->}
# }-->}
# l-->l
# عاجل-->عجل
# المزيد-->زيد
# {-->{
# {-->{
# pollWidgetTitle-->pollWidgetTitle
# }-->}
# }-->}
# {-->{
# {-->{
# radioWidgetTitle-->radioWidgetTitle
# }-->}
# }-->}
# l-->l
# {-->{
# {-->{
# sidebarWidgetTitle-->sidebarWidgetTitle
# }-->}
# }-->}
# {-->{
# {-->{
# sidebarWidgetTitle-->sidebarWidgetTitle
# }-->}
# }-->}
# العودة-->عود
# للأعلى-->على
# تحميل-->حمل
# تطبيق-->طبق
# الهاتف-->هتف
# سكاي-->سكي
# نيوز-->نيز
# عربية-->عرب
# اتصل-->تصل
# حول-->حول
# سكاي-->سكي
# نيوز-->نيز
# عربية-->عرب
# برنامج-->رنمج
# التدريب-->درب
# الشروط-->شرط
# والأحكام-->ٔحكام
# سياسة-->سيس
# الخصوصية-->خصص
# وظائف-->وظف
# شاغرة-->شغر
# أعلن-->اعل
# معنا-->عنا
# شاركنا-->شرك
# برأيك-->برأ
# تابعونا-->بعو
# تطبيقاتنا-->طبق
# راديو-->راديو
# مباشر-->بشر
# ترددات-->ردد
# القناة-->قنة
# البث-->لبث
# المباشر-->بشر
# دليل-->دلل
# البث-->لبث
# الأقسام-->قسم
# شرق-->شرق
# أوسط-->وسط
# نافذة-->نفذ
# مغاربية-->غرب
# مستجدات-->سجد
# كورونا-->كورو
# عالم-->علم
# رياضة-->ريض
# علوم-->علم
# اقتصاد-->قصد
# منوعات-->نوع
# برامجنا-->رمج
# غرفة-->غرف
# الأخبار-->خبر
# منصات-->منص
# القصة-->قصة
# اقتصادكم-->قصد
# وثائقيات-->وثق
# مواجهة-->وجه
# نيران-->نير
# صديقة-->صدق
# اشترك-->شرك
# بالنشرة-->نشر
# الإخبارية-->خبر
# نشرة-->نشر
# إخبارية-->خبر
# ترسل-->رسل
# مباشرة-->بشر
# لبريدك-->برد
# الإلكتروني-->كترو
# يوميا-->يوم
# إشترك-->شرك
# كافة-->كفة
# العلامات-->علم
# التجارية-->جرة
# الخاصة-->خصة
# بـ-->بـ
# SKY-->SKY
# وكل-->وكل
# تتضمنه-->تضم
# حقوق-->حقق
# الملكية-->لكة
# الفكرية-->فكر
# ملك-->ملك
# لمجموعة-->جمع
# Sky-->Sky
# International-->International
# AG-->AG
# تستخدم-->خدم
# بتصريح-->صرح
# مسبق-->سبق
# اشترك-->شرك
# خدمة-->خدم
# الإشعارات-->شعر
# لمتابعة-->تبع
# آخر-->اخر
# الأخبار-->خبر
# المحلية-->حلة
# والعالمية-->علم
# فور-->فور
# وقوعها-->وقع
# اشترك-->شرك
# تفعّل-->فعل
# خدمة-->خدم
# إشعارات-->شعر
# الأخبار-->خبر
# العاجلة-->عجل
# اضغط-->ضغط
# للمزيد-->زيد
# للحصول-->حصل
# علي-->علي
# الاشعارات-->شعر
# تهمك-->تهم
# قم-->قم
# بتخصيص-->خصص
# خدمة-->خدم
# الاشعارات-->شعر
# طريق-->طرق
# صفحة-->صفح
# إلاعدادات-->عدد

# %%
import pandas as pd
def tf_idf_analysis(keyword):
    v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
    x = v.fit_transform(text)

    f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
    d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
    tf=pd.DataFrame((f>0).sum(axis=0))


    d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

    d.columns=['word','average_tfidf','max_tfidf','frequency']

    d['frequency']=round((d['frequency']/len(text))*100)

    return(d)

x= tf_idf_analysis(u)
x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
# print(x)
#######################################################################
# import pandas as pd
# # documentA = 'ذهب محمد الي الجامعة ليدرس الفيزياء و الكيمياء'
# # documentB=u
# documentA=u
# bagOfWordsA = documentA.split(' ')
# # bagOfWordsB = documentB.split(' ')
# uniqueWords = set(bagOfWordsA)
# uniqueWords
# numOfWordsA = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsA[word] += 1
# numOfWordsA
# numOfWordsB = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsB[word] += 1

# numOfWordsB    
# def computeTF(wordDict, bagOfWords):
#     tfDict = {}
#     bagOfWordsCount = len(bagOfWords)
#     for word, count in wordDict.items():
#         tfDict[word] = count / float(bagOfWordsCount)
#     return tfDict
# tfB = computeTF(numOfWordsB, bagOfWordsA)
# print(tfB)
# Out:
# c:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['آمين', 'أب', 'أخ', 'أفعل', 'أفعله', 'ؤلاء', 'إل', 'إم', 'ات', 'اتان', 'ارتد', 'ان', 'انفك', 'برح', 'تان', 'تبد', 'تحو', 'تعل', 'حد', 'حم', 'حي', 'خب', 'ذار', 'سيما', 'صه', 'ظل', 'ظن', 'عد', 'قط', 'مر', 'مكان', 'مكانكن', 'نب', 'هات', 'هب', 'واها', 'وراء'] not in stop_words.
#   warnings.warn(
# c:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#              word  average_tfidf  max_tfidf  frequency
# 7725   الإنجليزية       0.071202   0.794482       33.0
# 11429    الفراولة       0.130110   0.514938       83.0
# 13471    النباتات       0.091254   0.511822       50.0
# 17323       حاسبة       0.026375   0.316504        8.0
# 17592         حلى       0.026009   0.312105        8.0
# 2765    googletag       0.022749   0.272992        8.0
# 19196       صفحات       0.045344   0.260895       25.0
# 19868      علاقات       0.021100   0.253203        8.0
# 10029     الزراعة       0.033184   0.241057       33.0
# 13351      النبات       0.049547   0.236067       42.0
# 11625      الفريز       0.023295   0.234994       25.0
# 17733       خاصية       0.038451   0.229588       25.0
# 23717      نباتات       0.040373   0.225803       42.0
# 21333         كيك       0.018206   0.218473        8.0
# 20590        فوود       0.018166   0.217992        8.0
# 16923       تيستي       0.018166   0.217992        8.0
# 2327          egp       0.018166   0.217992        8.0
# 16032      تستخدم       0.037343   0.212341       42.0
# 5277         view       0.015895   0.190743        8.0
# 4364        quick       0.015895   0.190743        8.0
# 19346          طب       0.016955   0.179829       17.0
# 26459         ويب       0.013960   0.167514        8.0
# 18059       دقيقة       0.017479   0.165742       25.0
# 19664         عدل       0.030279   0.156537       25.0
# 6400          أيض       0.017055   0.153408       42.0
# 2780          gpt       0.012740   0.152875        8.0
# 21873      للرجال       0.012308   0.147702        8.0
# 6694        احجزي       0.012215   0.146575        8.0
# 20764       قراءة       0.015689   0.144705       25.0
# 8784       الثمار       0.026102   0.143448       50.0
# 3082        inner       0.011830   0.141956        8.0
# 27210        يمكن       0.022618   0.136518       75.0
# 7007      الأخبار       0.014924   0.136058       33.0
# 4605      section       0.010920   0.131036        8.0
# 4343       pubads       0.010920   0.131036        8.0

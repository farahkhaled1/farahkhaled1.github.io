# %%
import urllib
# %pip install requests_html
import requests
# !pip install requests
from requests_html import HTMLSession
import mysql.connector

# Connect to the database
mysql = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="seopro"
)

# Create a cursor object
mycursor = mysql.cursor()

# Execute an SQL query to select the last row from the table
mycursor.execute("SELECT uid, niche FROM given_niche_ar ORDER BY id DESC LIMIT 1")

# Fetch the last row from the table
niche_arr = mycursor.fetchone()

# # Convert niche[0] to a string
# niche= str(niche_arr[0])

# # Print the last row as a string
# print(niche)

# Extract the id and niche values from the row
uid = niche_arr[0]
niche = niche_arr[1]

# Print the niche and id values
print(niche)
print(uid)
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        return response
    except requests.exceptions.RequestException as e:
        print(e)
# Out:
# Requirement already satisfied: requests_html in c:\users\lenovo\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: w3lib in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.21.0)
# Requirement already satisfied: pyquery in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (2.28.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: fake-useragent in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.1.1)
# Requirement already satisfied: bs4 in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: parse in c:\users\lenovo\anaconda3\lib\site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.64.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: certifi>=2021 in c:\users\lenovo\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2022.9.14)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\anaconda3\lib\site-packages (from bs4->requests_html) (4.11.1)
# Requirement already satisfied: importlib-resources>=5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fake-useragent->requests_html) (5.10.1)
# Requirement already satisfied: lxml>=2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pyquery->requests_html) (4.9.1)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\lenovo\anaconda3\lib\site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->requests_html) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: six>=1.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from w3lib->requests_html) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# سيارات
# 5

# %%
def scrape_google(query):
    
    # query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.com/search?q=" + query)
    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.')

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
links = scrape_google(niche)
for link in links:
  print(link)
# Out:
# https://policies.google.com/terms?hl=ar&fg=1
# https://eg.hatla2ee.com/ar/car/price/toyota
# https://eg.hatla2ee.com/ar/car/price/chevrolet
# https://support.google.com/websearch/?p=ws_results_help&hl=ar&fg=1
# https://eg.hatla2ee.com/ar/car/disabled
# https://maps.google.com/maps?q=%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA&um=1&ie=UTF-8&sa=X&ved=2ahUKEwiUy7GWvPH-AhUFTaQEHTjNCrsQ_AUoAnoECAEQBA
# https://eg.hatla2ee.com/ar/car/price/kia
# https://www.olx.com.eg/vehicles/cars-for-sale/
# https://egypt.yallamotor.com/ar/new-cars
# https://poki.com/ar/%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA
# https://elmasria-auto.com/
# https://policies.google.com/privacy?hl=ar&fg=1
# https://eg.hatla2ee.com/ar/car/all-prices
# https://www.masrawy.com/channel/autos
# https://eg.hatla2ee.com/ar/car/insurance
# https://www.contactcars.com/ar/usedcars
# https://support.google.com/websearch/answer/181196?hl=ar
# https://www.shift-eg.com/ar/used-car/search
# https://eg.hatla2ee.com/ar/car/price/hyundai
# https://eg.hatla2ee.com/ar/car
# https://www.elbalad.news/category/17
# https://eg.hatla2ee.com/ar/imported-car

# %%
from nltk.tokenize import  word_tokenize
import nltk
nltk.download('punkt')
# # EXAMPLE_TEXT = """
# # أبو عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك
# # وجغرافيا مسلم. يكنى باسم الخوارزمي وأبي جعفر. قيل أنه ولد حوالي 164هـ 781م (وهو غير مؤكد) وقيل أنه توفي بعد 232هـ أي (بعد 847م). يعتبر
# # من أوائل علماء الرياضيات المسلمين حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره. اتصل بالخليفة العباسي المأمون وعمل في بيت الحكمة في 
# # بغداد وكسب ثقة الخليفة إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل فيها أكثر من سبعين جغرافيا. قبل وفاته في 850 م/232 هـ
# # كان الخوارزمي قد ترك العديد من المؤلفات في علوم الرياضيات والفلك والجغرافيا ومن أهمها

# # """
# EXAMPLE_TEXT=links
# print(word_tokenize(EXAMPLE_TEXT))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# links=scrape_google('cars')
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup

def get_text(url):
    try:
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req,timeout=5).read()
        soup = BeautifulSoup(webpage, "html.parser")
        texts = soup.findAll(text=True)
        res=u" ".join(t.strip() for t in texts if t.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]'])
        return(res)
    except:
        return False
get_text('https://en.wikipedia.org/wiki/Machine_learning')
text=[]
for i in links:
  t=get_text(i)
  if t:
    text.append(t)

    word_tokens = word_tokenize(t)
# word_tokens = 

    filtered_sentence = [w for w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)

    filtered_sentence = [w for w in word_tokens if not w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)
    filtered_sentence = [w for w in word_tokens if not w.lower() in word_tokens]

    print(word_tokens)
    print('---------------------------------')
    print(filtered_sentence)
# Out:
# ['الخصوصية', 'والبنود', 'تسجيل', 'الدخول', 'نظرة', 'عامة', 'سياسة', 'الخصوصية', 'بنود', 'الخدمة', 'التقنيات', 'الأسئلة', 'الشائعة', 'الخصوصية', 'والبنود', 'نظرة', 'عامة', 'سياسة', 'الخصوصية', 'بنود', 'الخدمة', 'تحديثات', 'التعريفات', 'قائمة', 'الخدمات', 'والبنود', 'الإضافية', 'الخاصة', 'بكل', 'خدمة', 'كيفية', 'تعامل', 'Google', 'مع', 'طلبات', 'الحكومة', 'للحصول', 'على', 'معلومات', 'المستخدم', 'التقنيات', 'الأسئلة', 'الشائعة', 'الخصوصية', 'والبنود', 'الخصوصية', 'والبنود', 'نظرة', 'عامة', 'سياسة', 'الخصوصية', 'بنود', 'الخدمة', 'التقنيات', 'الأسئلة', 'الشائعة', 'حساب', 'Google', 'البنود', 'مقدمة', 'علاقتك', 'مع', 'Google', 'استخدام', 'خدمات', 'Google', 'المحتوى', 'في', 'خدمات', 'Google', 'البرامج', 'في', 'خدمات', 'Google', 'في', 'حال', 'وجود', 'مشاكل', 'أو', 'خلافات', 'لمحة', 'عن', 'هذه', 'البنود', 'تحديثات', 'التعريفات', 'قائمة', 'الخدمات', 'والبنود', 'الإضافية', 'الخاصة', 'بكل', 'خدمة', 'كيفية', 'تعامل', 'Google', 'مع', 'طلبات', 'الحكومة', 'للحصول', 'على', 'معلومات', 'المستخدم', 'بنود', 'خدمة', 'Google', 'يسري', 'بتاريخ', '5', 'يناير', '2022', '|', 'النُسخ', 'المؤرشفة', '|', 'تنزيل', 'ملف', 'PDF', 'النسخة', 'المطابقة', 'للبلد', ':', 'مصر', 'ما', 'تتضمنّه', 'هذه', 'البنود', 'ندرك', 'أنك', 'قد', 'تميل', 'إلى', 'تخطّي', 'بنود', 'الخدمة', 'هذه،', 'ولكنه', 'من', 'المهم', 'التأكيد', 'على', 'ما', 'يمكن', 'أن', 'تتوقعه', 'منّا', 'عند', 'استخدامك', 'خدمات', 'Google،', 'وما', 'نتوقعه', 'نحن', 'منك', '.', 'تبيِّن', 'بنود', 'الخدمة', 'هذه', 'طريقة', 'Google', 'في', 'ممارسة', 'أعمالها', 'والقوانين', 'التي', 'تنطبق', 'عليها', 'و', 'بعض', 'المبادئ', 'التي', 'نعتقد', 'دائمًا', 'أنها', 'صحيحة', '.', 'ونتيجةً', 'لذلك،', 'تساعد', 'بنود', 'الخدمة', 'هذه', 'على', 'تحديد', 'علاقتك', 'مع', 'Google', 'أثناء', 'تفاعلك', 'مع', 'خدماتنا', '.', 'وتتضمّن', 'هذه', 'البنود،', 'على', 'سبيل', 'المثال،', 'المواضيع', 'الرئيسية', 'التالية', ':', 'ما', 'يمكن', 'أن', 'تتوقعه', 'منّا', ':', 'يوضّح', 'هذا', 'القسم', 'كيف', 'نقدّم', 'خدماتنا', 'ونطوّرها', 'ما', 'نتوقعه', 'منك', ':', 'يضع', 'هذا', 'القسم', 'قواعد', 'معيّنة', 'لاستخدام', 'خدماتنا', 'المحتوى', 'في', 'خدمات', 'Google', ':', 'يصف', 'هذا', 'القسم', 'حقوق', 'الملكية', 'الفكرية', 'للمحتوى', 'الذي', 'تجده', 'في', 'خدماتنا،', 'سواء', 'كان', 'المحتوى', 'يخصك', 'أو', 'يخص', 'Google', 'أو', 'يخص', 'مستخدمين', 'آخرين', 'في', 'حال', 'وجود', 'مشاكل', 'أو', 'خلافات', ':', 'يوضّح', 'هذا', 'القسم', 'الحقوق', 'القانونية', 'الأخرى', 'التي', 'تمتلكها', 'وما', 'يجب', 'توقعه', 'في', 'حال', 'انتهاك', 'هذه', 'البنود', 'من', 'المهم', 'فهم', 'هذه', 'البنود', 'لأنّ', 'استخدامك', 'لخدماتنا', 'يعني', 'قبولك', 'الالتزام', 'بهذه', 'البنود', '.', 'بالإضافة', 'إلى', 'هذه', 'البنود،', 'ننشر', 'أيضًا', 'سياسة', 'الخصوصية', '.', 'وعلى', 'الرغم', 'من', 'أنها', 'ليست', 'جزءًا', 'من', 'هذه', 'البنود،', 'ننصحك', 'بالاطّلاع', 'عليها', 'للتعرّف', 'بشكل', 'أفضل', 'على', 'كيفية', 'تعديل', 'معلوماتك', 'وإدارتها', 'وتصديرها', 'وحذفها', '.', 'البنود', 'مقدِّم', 'الخدمة', 'تكون', 'الجهة', 'المسؤولة', 'عن', 'توفير', 'خدمات', 'Google', 'والتي', 'تتعاقد', 'أنت', 'معها', 'هي', ':', 'Google', 'LLC', 'تم', 'تأسيسها', 'بموجب', 'قوانين', 'ولاية', 'ديلاوير', 'في', 'الولايات', 'المتحدة', 'الأمريكية،', 'وهي', 'قائمة', 'بموجب', 'قوانين', 'الولايات', 'المتحدة', 'الأمريكية', '1600', 'Amphitheatre', 'Parkway', 'Mountain', 'View', ',', 'California', '94043', 'USA', 'السن', 'المسموح', 'به', 'إذا', 'كنت', 'تحت', 'السن', 'المسموح', 'به', 'لإدارة', 'حسابك', 'على', 'Google', 'بنفسك', '،', 'عليك', 'الحصول', 'على', 'إذن', 'من', 'أحد', 'والدَيك', 'أو', 'الوصي', 'القانوني', 'لاستخدام', 'حساب', 'Google', '.', 'يُرجى', 'أن', 'تطلب', 'من', 'أحد', 'والدَيك', 'أو', 'الوصي', 'القانوني', 'الاطّلاع', 'على', 'هذه', 'البنود', 'معك', '.', 'في', 'حال', 'كنت', 'أحد', 'الوالدَين', 'أو', 'الوصي', 'القانوني', 'وتسمح', 'لطفلك', 'باستخدام', 'الخدمات', '،', 'ستنطبق', 'هذه', 'البنود', 'عليك', 'وستكون', 'مسؤولاً', 'عن', 'الأنشطة', 'التي', 'يجريها', 'طفلك', 'ضمن', 'هذه', 'الخدمات', '.', 'تتضمّن', 'بعض', 'خدمات', 'Google', 'متطلبات', 'إضافية', 'للسن', 'المسموح', 'به', 'كما', 'هو', 'موضّح', 'في', ' ...
# ---------------------------------
# ['Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'PDF', 'Google،', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'LLC', 'Amphitheatre', 'Parkway', 'Mountain', 'View', 'California', 'USA', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'LLC', 'Google', 'Google', 'Google', 'Shopping', 'Google', 'Google', 'Nest', 'Google', 'Google', 'Google', 'Google', 'Google', 'Takeout', 'Google', 'Google', 'Google', 'Google،', 'Play', 'Google', 'Play', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Gmail،', 'Google', 'Google،', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google،', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google،', 'Google،', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google،', 'وGoogle', 'Google', 'Google', 'Google،', 'Google', 'LLC', 'Google', 'Ireland', 'Limited', 'وGoogle', 'Commerce', 'Limited', 'وGoogle', 'Dialer', 'Inc.\u200e', 'Google', 'Google', 'Google', 'Google', 'Shopping', 'Google', 'Google', 'Nest', 'Google', 'Google', 'Google', 'Google', 'Blogger', 'Google', 'Drive', 'Gmail', 'Google', 'Google', 'Google', 'Google،', 'Google', 'Google', 'Afrikaans', 'Bahasa', 'Indonesia', 'Bahasa', 'Melayu', 'Català', 'Čeština', 'Dansk', 'Deutsch', 'Eesti', 'English', 'English', 'United', 'Kingdom', 'Español', 'Español', 'Latinoamérica', 'Euskara', 'Filipino', 'Français', 'Français', 'Canada', 'Galego', 'Hrvatski', 'Isizulu', 'Íslenska', 'Italiano', 'Kiswahili', 'Latviešu', 'Lietuvių', 'Magyar', 'Nederlands', 'Norsk', 'Polski', 'Português', 'Brasil', 'Português', 'Portugal', 'Română', 'Slovenčina', 'Slovenščina', 'Srpski', 'Suomi', 'Svenska', 'Tiếng', 'Việt', 'Türkçe', 'Ελληνικά', 'Български', 'Русский', 'Српски', 'Українська', 'Google', 'Google', 'Google']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'أسعار', 'تويوتا', '2022', '-', '2023', 'في', 'مصر', 'تويوتا', 'مصر', 'تويوتا', 'مستعمل', 'للبيع', 'أسعار', 'تويوتا', 'المستعملة', 'آخر', 'تغير', 'في', 'أسعار', 'تويوتا', 'الجديدة', 'بيع', 'سيارتي', 'الأن', 'تويوتا', 'بيلتا', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'Active', '2022', '1500', 'CC', '360,000', 'جنيه', 'اتوماتيك', '/', 'Smart', '2022', '1500', 'CC', '405,000', 'جنيه', 'اتوماتيك', '/', 'Active', '2023', '1500', 'CC', '540,000', 'جنيه', 'اتوماتيك', '/', 'Smart', '2023', '1500', 'CC', '595,000', 'جنيه', 'تويوتا', 'روميون', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'GL', '2022', '1500', 'CC', '390,000', 'جنيه', 'اتوماتيك', '/', 'GLX', '2022', '1500', 'CC', '420,000', 'جنيه', 'اتوماتيك', '/', 'Active', '2023', '1500', 'CC', '575,000', 'جنيه', 'اتوماتيك', '/', 'GLX', '2023', '1500', 'CC', '575,000', 'جنيه', 'تويوتا', 'رش', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'F/O', '2022', '1500', 'CC', '440,000', 'جنيه', 'اتوماتيك', '/', 'Highline', '2022', '1500', 'CC', '470,000', 'جنيه', 'اتوماتيك', '/', 'F/O', '2023', '1500', 'CC', '520,000', ' ...
# ---------------------------------
# ['English', 'Active', 'CC', 'Smart', 'CC', 'Active', 'CC', 'Smart', 'CC', 'GL', 'CC', 'GLX', 'CC', 'Active', 'CC', 'GLX', 'CC', 'F/O', 'CC', 'Highline', 'CC', 'F/O', 'CC', 'Highline', 'CC', 'Active', 'CC', 'Active', 'CC', 'Comfort', 'CC', 'CC', 'CC', 'GR', 'CC', 'Elgance', 'CC', 'Active', 'CC', 'Active', 'CC', 'Comfort', 'CC', 'CC', 'CC', 'CC', 'GR', 'CC', 'Elgance', 'CC', 'CC', 'Comfort', 'CC', 'Smart', 'CC', 'C-HR', 'CC', 'CC', 'SMART', 'CC', 'ELEGANCE', 'CC', 'SMART', 'CC', 'ELEGANCE', 'CC', 'Sport', 'CC', 'CC', 'VX', 'CC', 'CC', 'Full', 'Option', 'CC', 'Active', 'Active', 'ELEGANCE', 'ELEGANCE', 'GR', 'GR', 'Elgance', 'Comfort', 'Active', 'Active', 'GLX', 'Active', 'Smart', 'Active', 'Full', 'Option', 'Sport', 'ELEGANCE', 'SMART', 'Full', 'Option', 'Fulloption', 'Fulloption', 'Highline', 'Comfort', 'SUV', 'CVT', 'DSG', 'MG', 'Toyota', 'Hiace', 'Cars', 'Yassmin_1470570459', 'Hatla2ee.com']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'أسعار', 'شيفروليه', '2022', '-', '2023', 'في', 'مصر', 'شيفروليه', 'مصر', 'شيفروليه', 'مستعمل', 'للبيع', 'أسعار', 'شيفروليه', 'المستعملة', 'آخر', 'تغير', 'في', 'أسعار', 'شيفروليه', 'الجديدة', 'بيع', 'سيارتي', 'الأن', 'شيفروليه', 'أوبترا', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'Comfort', '2022', '1500', 'CC', '208,500', 'جنيه', 'اتوماتيك', '/', 'Comfort', 'w', 'Accessories', '2022', '1500', 'CC', '215,500', 'جنيه', 'اتوماتيك', '/', 'Luxury', '2022', '1500', 'CC', '270,500', 'جنيه', 'اتوماتيك', '/', 'Luxury', 'w', 'Accessories', '2022', '1500', 'CC', '277,000', 'جنيه', 'اتوماتيك', '/', 'Luxury', 'w', 'Accessories', '2023', '1500', 'CC', '501,000', 'جنيه', '59,000', 'جنيه', 'إلى', '80,000', 'جنيه', 'شيفروليه', 'ماليبو', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'LS', '2022', '1500', 'CC', 'تربو', '426,500', 'جنيه', 'اتوماتيك', '/', 'LT', '2022', '1500', 'CC', 'تربو', '489,900', 'جنيه', 'شيفروليه', 'كابتيفا', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'LS', '2022', '1500', 'CC', 'تربو', '979,990', 'جنيه', 'اتوماتيك', '/', 'LT', '2022', '1500', 'CC ...
# ---------------------------------
# ['English', 'Comfort', 'CC', 'Comfort', 'Accessories', 'CC', 'Luxury', 'CC', 'Luxury', 'Accessories', 'CC', 'Luxury', 'Accessories', 'CC', 'LS', 'CC', 'LT', 'CC', 'LS', 'CC', 'LT', 'CC', 'Premier', 'CC', 'Premier', 'CC', 'N300', 'Full', 'Highline', 'Premier', 'Premier', 'LT', 'LS', 'Luxury', 'Accessories', 'Premier', 'Premier', 'LT', 'LS', 'Luxury', 'Accessories', 'Luxury', 'Accessories', 'Premier', 'Premier', 'LT', 'LS', 'Premier', 'Premier', 'LT', 'LS', 'Comfort', 'Accessories', 'Highline', 'Premier', 'SUV', 'CVT', 'DSG', 'MG', 'Toyota', 'Hiace', 'Cars', 'Yassmin_1470570459', 'Hatla2ee.com']
# ['التخطّي', 'إلى', 'المحتوى', 'الرئيسي', 'مساعدة', 'بحث', 'Google', 'تسجيل', 'الدخول', 'مساعدة', 'Google', 'مركز', 'المساعدة', 'بحث', 'Google', 'سياسة', 'الخصوصية', 'بنود', 'الخدمة', 'إرسال', 'التعليقات', 'إرسال', 'تعليقات', 'بشأن', '...', 'محتوى', 'المساعدة', 'والمعلومات', 'هذه', 'تجربة', 'مركز', 'المساعدة', 'العامة', 'التالي', 'مركز', 'المساعدة', 'الإشعارات', 'بحث', 'Google', 'كيف', 'يمكننا', 'مساعدتك؟', 'تصفّح', 'مواضيع', 'المساعدة', 'المقالات', 'الأكثر', 'شيوعًا', 'إدارة', 'سجلّ', 'البحث', 'وحذفه', 'فهم', 'وإدارة', 'موقعك', 'الجغرافي', 'عند', 'البحث', 'على', 'Google', 'إدارة', 'عبارات', 'البحث', 'المقترحة', 'من', 'خلال', 'ميزة', '``', 'الإكمال', 'التلقائي', "''", 'من', 'Google', 'البحث', 'عن', '``', 'النشاط', 'على', 'الويب', 'وفي', 'التطبيقات', "''", 'والتحكُّم', 'فيه', 'تخصيص', 'البطاقات', 'التي', 'تظهر', 'لك', 'في', 'ميزة', '``', 'اقتراحات', "''", 'الحصول', 'على', 'معلومات', 'عن', 'صورك', 'وكل', 'ما', 'يحيط', 'بك', 'استخدام', '``', 'Ok', 'Google', "''", 'لعمليات', 'البحث', 'الصوتي', 'والإجراءات', 'الصوتية', 'تحرِّي', 'المشكلات', 'وإصلاحها', 'وطلبات', 'الإزالة', 'إزالة', 'المعلومات', 'من', 'Google', 'مشكلات', 'تتعلق', 'ببحث', 'Google', 'ميزات', 'البحث', 'كيفية', 'البحث', 'على', 'Google', 'ما', 'يمكنك', 'البحث', 'عنه', 'حصر', 'نتائج', 'البحث', 'باستخدام', 'الفلاتر', 'أدوات', 'تمكين', 'الوصول', 'في', '``', 'بحث', 'Google', "''", 'الحصول', 'على', 'نتائج', 'بحث', 'مرتبطة', 'بالسفر', 'من', 'Gmail', 'عرض', 'النُسخ', 'المخبّأة', 'لصفحات', 'الويب', 'في', 'نتائج', '``', 'بحث', 'Google', "''", 'العثور', 'على', 'مقالات', 'التحقق', 'من', 'صحة', 'الأخبار', 'في', 'نتائج', 'البحث', 'معرفة', 'معلومات', 'عن', 'ناشر', 'أخبار', 'استخدام', '``', 'كتب', 'Google', "''", 'البحث', 'والتصفّح', 'بخصوصية', 'تامة', 'تحميل', 'الصفحات', 'على', 'الجهاز', 'الجوّال', 'بشكل', 'أسرع', 'باستخدام', 'تقنية', 'Web', 'Light', 'الاطّلاع', 'على', 'نصائح', 'بشأن', 'البحث', 'والتعرّف', 'على', 'كيفية', 'ارتباط', 'النتائج', 'ببحثك', 'على', 'Google', 'الاطّلاع', 'على', 'مزيد', 'من', 'المعلومات', 'عن', 'صفحات', 'الويب', 'البحث', 'عن', 'فيديوهات', 'في', '``', 'بحث', 'Google', "''", 'تقييم', 'المعلومات', 'التي', 'تعثر', 'عليها', 'باستخدام', 'محرّك', 'بحث', 'Google', 'الجوّال', 'نصائح', 'بحث', 'الجوّال', 'استخدام', 'تطبيق', 'Google', 'على', 'Android', 'استخدام', 'تطبيق', 'Google', 'على', 'أجهزة', 'iPhone', 'وiPad', 'استخدام', 'تطبيق', 'Google', 'Go', 'إعداد', 'Gboard', 'إرسال', 'مكان', 'من', 'نتائج', '``', 'بحث', 'Google', "''", 'إلى', 'هاتفك', 'استخدام', 'ميزة', '``', 'الكتابة', 'اليدوية', "''", 'لإجراء', 'بحث', 'الاستماع', 'إلى', 'ملفات', 'بودكاست', 'باستخدام', '``', 'Google', 'بودكاست', "''", 'تطبيق', 'بحث', 'Google', 'لنظام', 'التشغيل', 'Windows', 'إدارة', 'ملفّات', 'البودكاست', 'في', '``', 'Google', 'بودكاست', "''", 'تجربة', 'الوضع', 'الثلاثي', 'الأبعاد', 'والواقع', 'المعزّز', 'في', '``', 'بحث', 'Google', "''", 'بحث', 'الصور', 'إزالة', 'صورة', 'من', 'Google', 'البحث', 'عن', 'الصور', 'على', 'Google', 'إجراء', 'بحث', 'على', 'Google', 'باستخدام', 'صورة', 'تحديد', 'المشاكل', 'في', '``', 'صور', 'بحث', 'Google', "''", 'وحلّها', 'البحث', 'عن', 'الصور', 'التي', 'يمكنك', 'استخدامها', 'ومشاركتها', 'إضافة', 'صورة', 'إلى', 'Google', 'الحصول', 'على', 'معلومات', 'حول', 'صورة', 'العثور', 'على', 'تفاصيل', '``', 'صور', 'Google', "''", 'البحث', 'عن', 'ملفات', 'بودكاست', 'على', '``', 'Google', 'بودكاست', "''", 'وتشغيلها', 'وإدارتها', 'الاستماع', 'إلى', 'ملفات', 'بودكاست', 'باستخدام', '``', 'Google', 'بودكاست', "''", 'إدارة', 'ملفّات', 'البودكاست', 'في', '``', 'Google', 'بودكاست', "''", 'إدارة', 'إعدادات', '``', 'Google', 'بودكاست', "''", 'الاستماع', 'إلى', 'ملفات', 'بودكاست', 'باستخدام', 'CarPlay', 'الاستماع', 'إلى', 'ملفات', 'بودكاست', 'باستخدام', 'Android', 'Auto', 'الحصول', 'على', 'اقتراحات', 'مناسبة', 'أكثر', 'لك', 'في', '``', 'Google', 'بودكاست', "''", 'حلّ', 'المشاكل', 'المتعلّقة', 'بـ', '``', 'Google', 'بودكاست', "''", 'البحث', 'عن', 'إشعارات', 'البرامج', 'الخارجية', 'في', 'Google', 'لنظام', 'التشغيل', 'Android', 'التحكم', 'في', 'خصوصيتك', 'فلترة', 'النتائج', 'التي', 'تتضمّن', ' ...
# ---------------------------------
# ['Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Ok', 'Google', 'Google', 'Google', 'Google', 'Google', 'Gmail', 'Google', 'Google', 'Web', 'Light', 'Google', 'Google', 'Google', 'Google', 'Android', 'Google', 'iPhone', 'وiPad', 'Google', 'Go', 'Gboard', 'Google', 'Google', 'Google', 'Windows', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'CarPlay', 'Android', 'Auto', 'Google', 'Google', 'Google', 'Android', 'Gmail', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Finance', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Google', 'Deutsch\u200e', 'English\u200e', 'Latinoamérica', 'Filipino\u200e', 'Indonesia\u200e', 'Melayu\u200e', 'Nederlands\u200e', 'Brasil', 'Tiếng', 'Việt\u200e', 'Türkçe\u200e', 'Ελληνικά\u200e', 'Google']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'سيارات', 'للبيع', '/', 'سيارات', 'مستعملة', 'سيارات', 'المعاقين', 'للبيع', 'في', 'مصر', 'سيارات', 'المعاقين،', 'هي', 'سيارات', 'معدة', 'ومجهزة', 'للمعاقين', 'تراعي', 'حالتهم', 'وتسهل', 'إنتقالهم', '.', 'ابحث', 'عن', 'سيارة', 'للبيع', 'إختر', 'ماركة', 'اسبيرانزا', 'استون', 'مارتن', 'اكسييد', 'الفاروميو', 'ام', 'جى', 'امجيراند', 'انفينيتي', 'اوبل', 'اودي', 'ايسوزو', 'بايك', 'بروتون', 'بريليانس', 'بنتلى', 'بوجاتى', 'بورش', 'بونتياك', 'بويك', 'بى', 'واى', 'دى\u202c', 'بي', 'ام', 'دبليو', 'بيجو', 'بيرودوا', 'بيستون', 'تاتا', 'تسلا', 'تويوتا', 'جاك', 'جاكوار', 'جريت', 'وول', 'جون', 'واى', 'جى', 'ام', 'سى', 'جي', 'أي', 'سي', 'جيب', 'جيتور', 'جيلي', 'جينيسيس\u200e', 'داتسون', 'دايهاتسو', 'دايو', 'دفسك', 'دودج', 'دوماى', 'دونج', 'فنج', 'دى', 'اس', 'رولز', 'رويس', 'رينو', 'زد', 'ان', 'اى', 'زوتى', 'ساب', 'سانج', 'يونج', 'ساوايست', 'سايبا', 'سايون', 'سكودا', 'سمارت', 'سوبارو', 'سوزوكى', 'سوكون', 'سيات', 'سيتروين', 'سينوفا', 'شانا', 'شانجان', 'شانجى', 'شيرى', 'شيفروليه', 'غاز', 'فاو', 'فوتون', 'فورثينج', 'فورد', 'فولفو', 'فولكس', 'فاغن', 'فيات', 'فيرارى', 'كاديلاك', 'كارى', 'كاي', 'ي', 'كرايسلر', 'كوبرا', 'كيا', 'كيتون', 'كينبو', 'لادا', 'لاند', 'روفر', 'لاندويند', 'لانشيا', 'لكزس', 'لمبرجيني', 'ل ...
# ---------------------------------
# ['English', 'SUV', 'C', 'C', 'K3', 'K3', 'GDI', 'GDI', 'E', 'E', 'C', 'C', 'K3', 'K3', 'E', 'E', 'C', 'AMG', 'C', 'AMG', 'C', 'C', 'E', 'E', 'Hatla2ee.com']
# ['When', 'you', 'have', 'eliminated', 'the', 'JavaScript', ',', 'whatever', 'remains', 'must', 'be', 'an', 'empty', 'page', '.', 'تفعيل', 'JavaScript', 'لمشاهدة', 'خرائط', 'Google', '.']
# ---------------------------------
# ['When', 'JavaScript', 'JavaScript', 'Google']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'أسعار', 'كيا', '2022', '-', '2023', 'في', 'مصر', 'كيا', 'مصر', 'كيا', 'مستعمل', 'للبيع', 'أسعار', 'كيا', 'المستعملة', 'آخر', 'تغير', 'في', 'أسعار', 'كيا', 'الجديدة', 'بيع', 'سيارتي', 'الأن', 'كيا', 'جراند', 'سيراتو', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'LX', 'FO', '2022', '1600', 'CC', '539,900', 'جنيه', 'اتوماتيك', '/', 'EX', 'Cam', '2022', '1600', 'CC', '589,900', 'جنيه', 'اتوماتيك', '/', 'Highline', '2022', '1600', 'CC', '619,900', 'جنيه', 'اتوماتيك', '/', 'Topline', '2022', '1600', 'CC', '669,900', 'جنيه', 'كيا', 'سبورتاج', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'LX', 'CAM', '2022', '1600', 'CC', '554,900', 'جنيه', 'اتوماتيك', '/', 'LX', 'FO', 'Plus', '2022', '1600', 'CC', '609,900', 'جنيه', 'اتوماتيك', '/', 'Highline', 'Plus', '2022', '1600', 'CC', '654,900', 'جنيه', 'اتوماتيك', '/', 'Topline', 'Plus', '2022', '1600', 'CC', '704,900', 'جنيه', 'اتوماتيك', '/', 'Topline', 'Plus', '+', 'Black', 'Edition', '2022', '1600', 'CC', '719,900', 'جنيه', 'كيا', 'سبورتاج', 'الجيل', 'الجديد', 'الخصائص', 'سعة', 'الماتور', 'السعر', 'أوڤر', 'برايس', 'اتوماتيك', '/', 'LX', '2022 ...
# ---------------------------------
# ['English', 'LX', 'FO', 'CC', 'EX', 'Cam', 'CC', 'Highline', 'CC', 'Topline', 'CC', 'LX', 'CAM', 'CC', 'LX', 'FO', 'Plus', 'CC', 'Highline', 'Plus', 'CC', 'Topline', 'Plus', 'CC', 'Topline', 'Plus', 'Black', 'Edition', 'CC', 'LX', 'CC', 'EX', 'CC', 'Highline', 'CC', 'Top', 'Line', 'CC', 'GT-Line', 'CC', 'LX', 'CC', 'EX', 'CC', 'A/T', 'Highline', 'CC', 'Top', 'Line', 'CC', 'GT-Line', 'CC', 'Highline', 'CC', 'Top', 'Line', 'CC', 'High', 'Line', 'CC', 'Top', 'Line', 'CC', 'High', 'Line', 'CC', 'Top', 'Line', 'CC', 'EX', 'Cam', 'EX', 'A/T', 'Highline', 'Top', 'Line', 'GT-Line', 'Top', 'Line', 'Highline', 'GT-Line', 'Top', 'Line', 'A/T', 'Highline', 'EX', 'LX', 'GT-Line', 'Top', 'Line', 'A/T', 'Highline', 'EX', 'LX', 'GT-Line', 'Top', 'Line', 'Highline', 'EX', 'LX', 'Top', 'Line', 'Highline', 'Topline', 'LX', 'CAM', 'SUV', 'CVT', 'DSG', 'MG', 'Toyota', 'Hiace', 'Cars', 'Yassmin_1470570459', 'Hatla2ee.com']
# ['فقط', 'في', 'سيارات', 'للبيع', 'تسجيل', 'الدخول', 'بيع', 'عربيات', 'وقطع', 'غيار', 'سيارات', 'للبيع', 'سيارات', 'للإيجار', 'كاوتش،', 'بطاريات،', 'زيوت،', 'و', 'كماليات', 'قطع', 'غيار', 'سيارات', 'موتوسيكلات', 'و', 'إكسسواراتها', 'مركبات', 'بحرية', 'أتوبيسات،', 'شاحنات', 'نقل', 'ثقيل،', 'و', 'وسائل', 'نقل', 'أخرى', 'عقارات', 'شقق', 'و', 'دوبلكس', 'للبيع', 'شقق', 'و', 'دوبلكس', 'للإيجار', 'فلل', 'للبيع', 'فلل', 'للإيجار', 'عقارات', 'مصايف', 'للبيع', 'عقارات', 'مصايف', 'للإيجار', 'عقار', 'تجارى', 'للبيع', 'عقار', 'تجارى', 'للإيجار', 'مبانى', 'و', 'أراضى', 'موبايلات', 'و', 'تابلت', 'موبايلات', 'تابلت', 'إكسسوارات', 'موبايل', 'و', 'تابلت', 'خطوط', 'موبايل', 'وظائف', 'محاسبة', 'و', 'بنوك', 'هندسة', 'مصممين', 'خدمة', 'عملاء', 'عمال', 'و', 'فنيين', 'إدارة', 'و', 'أعمال', 'إستشارية', 'سائقين', '-', 'توصيل', 'تعليم', 'موارد', 'بشرية', 'سياحة', 'و', 'سفر', 'تكنولوجيا', 'و', 'معلومات', 'تسويق', 'و', 'علاقات', 'عامة', 'طب', '-', 'صحة', '-', 'تمريض', 'مبيعات', 'سكرتارية', 'حراسات', 'و', 'أمن', 'محامين', '-', 'شئون', 'قانونية', 'وظيفة', 'أخرى', 'المزيد', 'من', 'الفئات', 'الكترونيات', 'وأجهزة', 'منزلية', 'تلفزيونات', 'وصوتيات', ',', 'كمبيوتر', 'و', 'إكسسوارات', ',', 'أجهزة', 'وألعاب', 'فيديو', 'أثاث', 'منزل', '-', 'ديكور', 'الحمام', ',', 'غرفة', 'نوم', ',', 'غرفة', 'سفرة', 'الموضة', 'والجمال', 'ملابس', 'حريمي', ',', 'ملابس', 'رجالي', ',', 'إكسسوارات', '-', 'مستحضرات', 'تجميل-', 'عناية', 'شخصية', 'حريمي', 'حيوانات', 'أليفة', 'و', 'إكسسواراتها', 'طيور', '-', 'حمام', ',', 'قطط', ',', 'كلاب', 'مستلزمات', 'أطفال', 'عناية', '-', 'صحة', 'الطفل', 'و', 'الأم', ',', 'ملابس', 'أطفال', ',', 'أدوات', 'تغذية', 'للطفل', 'هوايات،', 'رياضة', 'و', 'كتب', 'تحف', '-', 'مقتنيات', ',', 'دراجات', ',', 'كتب', 'تجارة', '-', 'صناعة', '-', 'زراعة', 'زراعة', ',', 'أعمال', 'بناء', ',', 'معدات', 'صناعية', 'خدمات', 'خدمات', 'شركات', ',', 'سيارات', ',', 'حفلات', '-', 'مناسبات', 'كل', 'ما', 'في', 'الكترونيات', 'وأجهزة', 'منزلية', 'تلفزيونات', 'وصوتيات', 'تليفزيونات', 'دي', 'في', 'دي', 'ومسارح', 'منزلية', 'صوتيات', 'منزلية', 'مشغلات', 'MP3', 'وصوتيات', 'ريسيفرات', 'كمبيوتر', 'و', 'إكسسوارات', 'كمبيوتر', 'لاب', 'توب', 'اكسسوارات', 'و', 'قطع', 'غيار', 'كمبيوتر', 'أجهزة', 'وألعاب', 'فيديو', 'أجهزة', 'ألعاب', 'فيديو', 'ألعاب', 'فيديو', 'و', 'إكسسواراتها', 'كاميرات', 'وتصوير', 'كاميرات', 'كاميرات', 'مراقبة', 'اكسسوارات', 'الكاميرا', 'مناظير/تلسكوبات', 'أجهزة', 'منزلية', 'ثلاجات', 'وديب', 'فريزر', 'بوتاجازات', 'وأفران', 'ومايكروويف', 'غسالات', 'أطباق', 'معدات', 'وأدوات', 'طبخ', 'غسالات', 'ومجففات', 'مبردات', 'مياه', 'و', 'غلايات', 'تكييفات', 'ومراوح', 'أجهزة', 'نظافة', 'أجهزة', 'منزلية', 'أخرى', 'سخانات', 'كل', 'ما', 'في', 'أثاث', 'منزل', '-', 'ديكور', 'الحمام', 'غرفة', 'نوم', 'غرفة', 'سفرة', 'أقمشة', '-', 'ستائر', '-', 'سجاد', 'حديقة', 'و', 'أماكن', 'خارجية', 'ديكورات', 'منزل', 'مطبخ', '-', 'أدوات', 'مطبخ', 'إضاءة', 'غرفة', 'معيشة', 'أثاث', 'متعدد/أخر', 'كل', 'ما', 'في', 'الموضة', 'والجمال', 'ملابس', 'حريمي', 'ملابس', 'رجالي', 'إكسسوارات', '-', 'مستحضرات', 'تجميل-', 'عناية', 'شخصية', 'حريمي', 'إكسسوارات', '-', 'عناية', 'شخصية', 'رجالي', 'كل', 'ما', 'في', 'حيوانات', 'أليفة', 'و', 'إكسسواراتها', 'طيور', '-', 'حمام', 'قطط', 'كلاب', 'حيوانات', 'أليفة', 'أخرى', 'إكسسوارات', '-', 'منتجات', 'عناية', 'بالحيوان', 'كل', 'ما', 'في', 'مستلزمات', 'أطفال', 'عناية', '-', 'صحة', 'الطفل', 'و', 'الأم', 'ملابس', 'أطفال', 'أدوات', 'تغذية', 'للطفل', 'سراير', '-', 'عربات', '-', 'أدوات', 'تنقل', 'بالطفل', 'ألعاب', 'أطفال', 'مستلزمات', 'أطفال', 'أخرى', 'كل', 'ما', 'في', 'هوايات،', 'رياضة', 'و', 'كتب', 'تحف', '-', 'مقتنيات', 'دراجات', 'كتب', 'ألعاب', 'لوحية', '-', 'ورقية', 'أفلام', '-', 'موسيقى', 'آلات', 'موسيقية', 'أدوات', 'رياضية', 'أدوات', 'دراسة', 'تذاكر', '-', 'قسائم', 'شنط', 'سفر', 'منتجات', 'أخرى', 'كل', 'ما', 'في', 'تجارة', '-', 'صناعة', '-', 'زراعة', 'زراعة', 'أعمال', 'بناء', 'معدات', 'صناعية', 'مستلزمات', 'طبية', 'أثاث', 'و', 'مستلزمات', 'المكتب', 'معدات', 'مطاعم', 'مشروع', 'كامل', 'للبيع', 'تجارة،', 'صناعة', 'وزراعة', 'أخرى', 'كل', 'ما', 'في', 'خدمات', 'خدمات', 'شركات', 'سيارات', 'حفلات', '-' ...
# ---------------------------------
# ['MP3', 'SUV', '4X4', 'ABS', 'EBD', 'Zeed', 'Legend', 'Autopark', 'Allam', 'Mercedes', 'Benz', 'A35', 'Audi', 'Q8', 'S-line', 'Plus', 'B', 'M', 'W', 'X7', 'All', 'M50i', 'Mercedes', 'C200', 'Mercedes', 'GLC', 'Coupe', 'C200', 'Night', 'Passat', 'Comfortline', 'Factory', 'Paint', 'Full', 'Protection', '3M', 'Km', 'XV', 'SPORT', 'Mitsubishi', 'Atrage', 'GLE450', 'Zeroo', 'Mercedes', 'GLC200', 'SUV', 'Mg5', 'VW', 'ID4', 'PRO', 'MERCEDES', 'GLC', 'SUV', 'ZERO', 'KM', 'Nissan', '2022-Toyota', 'Belta', 'RANGE', 'ROVER', 'Sport', 'P400', 'HSE', 'Sierra', 'GMC', 'AT4', 'MG', 'Mercedes', 'E180', 'BMW', 'Z4', 'M40i', 'Range', 'Rover', 'Velar', 'Mg', 'Zs', 'Mercedes', 'Benz', 'C180', 'C180', 'Mercedes', 'Benz', 'C180', 'C180', 'Dubizzle', 'Group']
# ['Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'AdWords', ':', '830020857', 'مصر', 'الإمارات', 'السعودية', 'قطر', 'عُمان', 'الكويت', 'البحرين', 'EN', 'جديد', 'مستعمل', 'تجارب', 'القيادة', 'أخبار', 'السيارات', 'فيديوهات', 'السيارات', 'خدمات', 'استيراد', 'السيارات', 'المزيد', 'أعلن', 'معنا', 'شركات', 'السيارات', 'بيع', 'سيارتك', 'دخول', '|', 'تسجيل', 'sidebar', 'دخول', '|', 'تسجيل', 'بيع', 'سيارتك', 'مجاني', 'دليل', 'شراء', 'السيارات', 'سيارات', 'مستعملة', 'استيراد', 'السيارات', 'جديد', 'أخبار', 'السيارات', 'فيديوهات', 'السيارات', 'المزيد', 'مصر', 'EN', 'single', 'items', 'sideoverlay', 'سيارات', 'مستعملة', 'ابحث', 'عن', 'سيارات', 'مستعملة', 'تصفح', 'السيارات', 'المستعملة', 'سيارات', 'مستعملة', 'للتصدير', 'دليل', 'شراء', 'السيارات', 'تصفح', 'دليل', 'السيارات', 'الجديدة', 'ابحث', 'عن', 'سيارات', 'جديدة', 'قارن', 'بين', 'السيارات', 'الجديدة', 'أسعار', 'السيارات', 'قاموس', 'السيارات', 'أخبار', 'السيارات', 'آخر', 'المشاركات', 'أخبار', 'السيارات', 'القيادات', 'الاولى', 'إطلاقات', 'السيارات', 'الجديدة', 'تجارب', 'القيادة', 'المزيد', 'أعلن', 'معنا', 'شركات', 'السيارات', 'اختر', 'الدولة', 'الإمارات', 'السعودية', 'قطر', 'عُمان', 'الكويت', 'البحرين', 'ابحث', 'عن', 'سيارات', 'مستعملة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'تصفح', 'السيارات', 'المستعملة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'سيارات', 'مستعملة', 'للاستيراد', 'جديد', 'حمل', 'الأن', 'تطبيق', 'يلاموتور', 'الجديد', '!', 'وتواصل', 'بسهولة', 'مع', 'البائعين', 'عبر', 'الهاتف', 'أو', 'الرسائل', 'النصية', 'أو', 'الواتساب', 'هل', 'تريد', 'بيع', 'سيارتك؟', 'تصفح', 'دليل', 'السيارات', 'الجديدة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'ابحث', 'عن', 'سيارات', 'جديدة', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'شكل', 'السيارة', 'سيدان', 'هاتشباك', 'كشف', 'كروس', 'أوفر', 'ميني', 'فان', 'دفع', 'رباعي', 'كوبيه', 'بيك', 'أب', 'ستايشن', 'فان', 'اعرض', 'جميع', 'أشكال', 'السيارات', 'قم', 'بالبحث', 'عن', 'السيارات', 'حسب', 'الماركة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'عرض', 'جميع', 'الماركات', 'قارن', 'بين', 'السيارات', 'الجديدة', 'مقارنة', 'بين', 'أكثر', 'السيارات', 'شهرة', 'VS', 'ميتسوبيشي', 'باجيرو', '2020', 'من', '1,650,000', 'ج.م', 'تويوتا', 'فورتشنر', '2020', 'من', '739,900', 'ج.م', 'قارن', 'VS', 'تويوتا', 'لاند', 'كروزر', '2020', 'TBD', 'نيسان', 'باترول', '2020', 'من', '3,500,000', 'ج.م', 'قارن', 'VS', 'رينو', 'داستر', '2018', 'من', '210,000', 'ج.م', 'دايهتسو', 'تيريوس', '2018', 'TBD', 'قارن', 'VS', 'ميتسوبيشي', 'باجيرو', '2018', 'من', '1,000,000', 'ج.م', 'تويوتا', 'فورتشنر', '2018', 'من', '1,000,000', 'ج.م', 'قارن', 'اعرض', 'جميع', 'مقارنات', 'السيارات', 'الجديدة', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'الجديدة', 'هيونداي', 'شفروليه', 'تويوتا', 'كيا', 'ميتسوبيشي', 'نيسان', 'مرسيدس', 'بنز', 'بي', 'إم', 'دبليو', 'إم', 'جي', 'رينو', 'اعرض', 'جميع', 'أسعار', 'السيارات', 'جديد', 'حمل', 'الأن', 'تطبيق', 'يل ...
# ---------------------------------
# ['Global', 'Google', 'AdWords', 'EN', 'EN', 'VS', 'VS', 'TBD', 'VS', 'TBD', 'VS', 'AUX', 'ABS', 'READ', 'MORE', 'Tab', 'Container', 'Browse', 'Make', 'Paid', 'Full', 'Banner', 'Sell', 'FREE', 'Spotlight', 'TBD', 'TBD', 'TBD', 'TBD', 'TBD', 'modelsCards', 'H2', 'Z100', 'S-Presso', 'modelsCards', 'Z560', 'modelsCards', 'HR-V', 'C5', 'Aircross', 'modelsCards', 'Crossback', 'VS', 'VS', 'TBD', 'VS', 'TBD', 'VS', 'VS', 'TBD', 'VS', 'VS', 'VS', 'VS', 'VS', 'VS', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'EGP', 'Venue', 'Z', 'ZS', 'GT', 'Crossland', 'X', 'Grandland', 'X', 'Crossland', 'S-Presso', 'Video', 'Section', 'Popular', 'Subscribe', 'Now', 'Toyota', 'LandCruiser', 'Opel', 'Mokka', 'SUV', 'Hyundai', 'Veloster', 'N', 'Lotus', 'Exige', 'Ford', 'Mustang', 'Mach', 'Changan', 'CS75', 'Plus', 'McLaren', 'GT', 'News', 'Latest', 'News', 'UAE', 'JETOUR', 'Anas', 'Assaf', 'Anas', 'Assaf', 'Anas', 'Assaf', 'HONGQI', 'H9', 'Anas', 'Assaf', 'Make', 'Modal', 'Popover', 'Footer', 'Footer', 'Footer', 'DEKSTOP', 'YALLAMOTOR.COM', 'EN', 'YallaMotor.com', 'Facebook', 'Pixel', 'Code', 'End', 'Facebook', 'Pixel', 'Code']
# ['ماذا', 'ستلعب', 'اليوم؟', 'ألعاب', 'سيارات', 'Crazy', 'Cars', 'City', 'Car', 'Driving', ':', 'Stunt', 'Master', 'Rocket', 'Soccer', 'Derby', 'Smash', 'Karts', 'Merge', 'Round', 'Racers', 'City', 'Rider', 'Offroader', 'V5', 'Blumgi', 'Rocket', 'Extreme', 'Car', 'Parking', '!', 'Drive', 'Mad', 'ألعاب', 'سباق', 'سيارات', 'ألعاب', 'شاحنات', 'Drifting', 'Games', 'ألعاب', 'درايفر', 'Cyber', 'Cars', 'Punk', 'Racing', 'Top', 'Speed', '3D', '3D', 'Car', 'Simulator', 'Merge', 'Cyber', 'Racers', 'Parking', 'Fury', '3D', ':', 'Beach', 'City', 'Traffic', 'Rush', '!', 'Off-Road', 'Rain', 'Cargo', 'Simulator', 'Burnin', "'", 'Rubber', 'Crash', 'n', "'", 'Burn', 'Super', 'Tunnel', 'Rush', 'Cars', 'Thief', 'Real', 'Cars', 'in', 'City', 'Car', 'Rush', 'Neon', 'Car', 'Maze', 'Demolition', 'Derby', 'Crash', 'Racing', 'Adventure', 'Drivers', '3D', 'City', 'Racer', 'Grand', 'Prix', 'Hero', 'Mad', 'Cars', 'Racing', 'and', 'Crash', 'Rally', 'Champion', 'Flying', 'Car', 'Simulator', 'Extreme', 'Off', 'Road', 'Cars', '3', ':', 'Cargo', 'Burnout', 'Drift', ':', 'Hilltop', 'Merge', 'Gangster', 'Cars', 'Go', 'Kart', 'Go', '!', 'Ultra', '!', 'Cars', 'Thief', ':', 'Tank', 'Edition', 'Dubai', 'Police', 'Parking', '2', 'Burnout', 'Extreme', 'Drift', '2', 'Truck', 'Traffic', 'Brain', 'For', 'Monster', 'Truck', '18', 'Wheeler', 'Cargo', 'Simulator', '2', 'Burnout', 'Drift', ':', 'Seaport', 'Max', 'Freeway', 'Fury', 'Car', 'Simulator', 'Arena', 'BoxRob', '3', 'Monster', 'Truck', ':', 'Forest', 'Delivery', 'Parking', 'Fury', '3D', ':', 'Night', 'Thief', 'Sling', 'Drift', 'Stock', 'Car', 'Hero', 'Fortride', ':', 'Open', 'World', 'TinyTownRacing', 'BoxRob', 'Extreme', 'Off', 'Road', 'Cars', 'Neon', 'Flytron', ':', 'Cyberpunk', 'Racer', 'BoxRob', '2', 'Burnin', "'", 'Rubber', '5', 'XS', 'Bumper', 'Cars', 'Soccer', 'School', 'Bus', 'Demolition', 'Derby', 'Super', 'Racing', 'GT', ':', 'Drag', 'Pro', 'Color', 'Crash', 'Parking', 'Fury', '3D', 'Rally', 'Point', 'Stunt', 'Car', 'Challenge', '3', 'Moving', 'Truck', ':', 'Bounty', 'Infinite', '8', 'Midnight', 'Drive', 'Mad', 'Truck', 'Challenge', 'Special', 'Rally', 'Point', '3', 'Sports', 'Car', 'Challenge', 'Parking', 'Fury', '3D', ':', 'Bounty', 'Hunter', 'Super', 'Star', 'Car', 'Moving', 'Truck', '3D', 'Arena', 'Racing', 'Shift', 'to', 'Drift', 'Just', 'Park', 'It', '11', 'Death', 'Chase', 'Truck', 'Loader', '5', 'Mad', 'Day', 'Blocky', 'Cars', 'Skiddy', 'Taxi', 'Monster', 'Truck', 'Shadow', 'Racer', 'Slot', 'Car', 'Racing', 'Monster', 'Tracks', 'Rally', 'Point', '5', 'Rally', 'Point', '2', 'Truck', 'Loader', '4', 'Blood', 'Drift', 'Zombie', 'Derby', ':', 'Pixel', 'Survival', 'Truck', 'Loader', 'Survival', 'Race', 'Hard', 'Truck', 'Freeway', 'Fury', '3', 'Moving', 'Truck', ':', 'Construction', 'Toy', 'Car', 'Simulator', 'SocCar', '18', 'Wheeler', 'Cargo', 'Simulator', 'Zombie', 'Derby', 'Zombie', 'Derby', ':', 'Blocky', 'Roads', 'Turn', 'Right', 'Desert', 'Worms', 'Car', 'Eats', 'Car', ':', 'Dungeon', 'Adventure', 'Noob', 'Drive', 'Freeway', 'Fury', '2', 'Cartoon', 'Mini', 'Racing', 'Operation', 'Desert', 'Road', 'Real', 'Simulator', 'Monster', 'Truck', 'Gear', 'Madness', 'Mad', 'Car', 'Racing', 'Truck', 'Loader', '3', 'Truck', 'Loader', '2', '2', 'Player', 'City', 'Racing', 'Smash', 'Car', 'Idle', '2', 'Zombie', 'Derby', '2', 'Just', 'Park', 'It', '12', 'Rally', 'Point', '4', 'Electric', 'Highway', 'Monsters', "'", 'Wheels', 'Special', 'Car', 'Eats', 'Car', ':', 'Winter', 'Adventure', 'Jamming', 'Car', 'Escape', 'Cartoon', 'Racers', ':', 'North', 'Pole', '2', 'Player', 'City', 'Racing', '2', 'Car', 'Eats', 'Car', ':', 'Sea', 'Adventure', 'Color', 'Car', '3D', 'Monster', 'Truck', ':', 'Skyroads', 'CATS', '-', 'Crash', 'Arena', 'Turbo', 'Stars', 'Rocking', 'Wheels', 'Parking', 'Block', 'Monster', 'Truck', 'Racing', 'Arena', 'Hole', 'N', "'", 'Fun', 'Dead', 'Paradise', ':', 'Race', 'Shooter', 'Mad', 'Day', '2', 'Crazy', 'Platez', 'Subway', 'Surfers', 'Temple', 'Run', '2', 'Venge.io', 'Stickman', 'Hook', 'Who', 'Is', '? ...
# ---------------------------------
# ['Crazy', 'Cars', 'City', 'Car', 'Driving', 'Stunt', 'Master', 'Rocket', 'Soccer', 'Derby', 'Smash', 'Karts', 'Merge', 'Round', 'Racers', 'City', 'Rider', 'Offroader', 'V5', 'Blumgi', 'Rocket', 'Extreme', 'Car', 'Parking', 'Drive', 'Mad', 'Drifting', 'Games', 'Cyber', 'Cars', 'Punk', 'Racing', 'Top', 'Speed', '3D', '3D', 'Car', 'Simulator', 'Merge', 'Cyber', 'Racers', 'Parking', 'Fury', '3D', 'Beach', 'City', 'Traffic', 'Rush', 'Off-Road', 'Rain', 'Cargo', 'Simulator', 'Burnin', 'Rubber', 'Crash', 'Burn', 'Super', 'Tunnel', 'Rush', 'Cars', 'Thief', 'Real', 'Cars', 'City', 'Car', 'Rush', 'Neon', 'Car', 'Maze', 'Demolition', 'Derby', 'Crash', 'Racing', 'Adventure', 'Drivers', '3D', 'City', 'Racer', 'Grand', 'Prix', 'Hero', 'Mad', 'Cars', 'Racing', 'Crash', 'Rally', 'Champion', 'Flying', 'Car', 'Simulator', 'Extreme', 'Off', 'Road', 'Cars', 'Cargo', 'Burnout', 'Drift', 'Hilltop', 'Merge', 'Gangster', 'Cars', 'Go', 'Kart', 'Go', 'Ultra', 'Cars', 'Thief', 'Tank', 'Edition', 'Dubai', 'Police', 'Parking', 'Burnout', 'Extreme', 'Drift', 'Truck', 'Traffic', 'Brain', 'For', 'Monster', 'Truck', 'Wheeler', 'Cargo', 'Simulator', 'Burnout', 'Drift', 'Seaport', 'Max', 'Freeway', 'Fury', 'Car', 'Simulator', 'Arena', 'BoxRob', 'Monster', 'Truck', 'Forest', 'Delivery', 'Parking', 'Fury', '3D', 'Night', 'Thief', 'Sling', 'Drift', 'Stock', 'Car', 'Hero', 'Fortride', 'Open', 'TinyTownRacing', 'BoxRob', 'Extreme', 'Off', 'Road', 'Cars', 'Neon', 'Flytron', 'Cyberpunk', 'Racer', 'BoxRob', 'Burnin', 'Rubber', 'XS', 'Bumper', 'Cars', 'Soccer', 'School', 'Bus', 'Demolition', 'Derby', 'Super', 'Racing', 'GT', 'Drag', 'Pro', 'Color', 'Crash', 'Parking', 'Fury', '3D', 'Rally', 'Point', 'Stunt', 'Car', 'Challenge', 'Moving', 'Truck', 'Bounty', 'Infinite', 'Midnight', 'Drive', 'Mad', 'Truck', 'Challenge', 'Special', 'Rally', 'Point', 'Sports', 'Car', 'Challenge', 'Parking', 'Fury', '3D', 'Bounty', 'Hunter', 'Super', 'Star', 'Car', 'Moving', 'Truck', '3D', 'Arena', 'Racing', 'Shift', 'Drift', 'Just', 'Park', 'It', 'Death', 'Chase', 'Truck', 'Loader', 'Mad', 'Day', 'Blocky', 'Cars', 'Skiddy', 'Taxi', 'Monster', 'Truck', 'Shadow', 'Racer', 'Slot', 'Car', 'Racing', 'Monster', 'Tracks', 'Rally', 'Point', 'Rally', 'Point', 'Truck', 'Loader', 'Blood', 'Drift', 'Zombie', 'Derby', 'Pixel', 'Survival', 'Truck', 'Loader', 'Survival', 'Race', 'Hard', 'Truck', 'Freeway', 'Fury', 'Moving', 'Truck', 'Construction', 'Toy', 'Car', 'Simulator', 'SocCar', 'Wheeler', 'Cargo', 'Simulator', 'Zombie', 'Derby', 'Zombie', 'Derby', 'Blocky', 'Roads', 'Turn', 'Right', 'Desert', 'Worms', 'Car', 'Eats', 'Car', 'Dungeon', 'Adventure', 'Noob', 'Drive', 'Freeway', 'Fury', 'Cartoon', 'Mini', 'Racing', 'Operation', 'Desert', 'Road', 'Real', 'Simulator', 'Monster', 'Truck', 'Gear', 'Madness', 'Mad', 'Car', 'Racing', 'Truck', 'Loader', 'Truck', 'Loader', 'Player', 'City', 'Racing', 'Smash', 'Car', 'Idle', 'Zombie', 'Derby', 'Just', 'Park', 'It', 'Rally', 'Point', 'Electric', 'Highway', 'Monsters', 'Wheels', 'Special', 'Car', 'Eats', 'Car', 'Winter', 'Adventure', 'Jamming', 'Car', 'Escape', 'Cartoon', 'Racers', 'North', 'Pole', 'Player', 'City', 'Racing', 'Car', 'Eats', 'Car', 'Sea', 'Adventure', 'Color', 'Car', '3D', 'Monster', 'Truck', 'Skyroads', 'CATS', 'Crash', 'Arena', 'Turbo', 'Stars', 'Rocking', 'Wheels', 'Parking', 'Block', 'Monster', 'Truck', 'Racing', 'Arena', 'Hole', 'Fun', 'Dead', 'Paradise', 'Race', 'Shooter', 'Mad', 'Day', 'Crazy', 'Platez', 'Subway', 'Surfers', 'Temple', 'Run', 'Venge.io', 'Stickman', 'Hook', 'Who', 'Narrow.One', 'Repuls.io', 'Brain', 'Test', 'Tricky', 'Stories', 'SchoolBreak.io', 'Friday', 'Night', 'Funkin', 'Idle', 'Ants', 'Moto', 'X3M', 'Stick', 'Merge', 'Parkour', 'Race', 'Mad', 'GunZ', 'Gold', 'Digger', 'FRVR', 'Like', 'King', 'Sushi', 'Party', 'EvoWorld', 'FlyOrDie', 'Crossy', 'Road', 'Where', 'My', 'Cat', 'Combat', 'Online', 'Fury', 'Wars', 'Raft', 'Wars', 'Multiplayer', 'Temple', 'Boom', 'Impossible', 'Quiz', 'Getaway', 'Shootout', 'Bad', 'Ice-Cream', 'S ...
# ...
# ---------------------------------
# ['English', 'RB', 'TINTED', 'CC', 'SR', 'TINTED', 'CC', 'DAB', 'ABS', 'TINTED', 'CC', 'DAB', 'ABS', 'PLUS', 'TINTED', 'CC', 'Highline', 'TINTED', 'CC', 'TINTED', 'CC', 'SR', 'TINTED', 'CC', 'DAB', 'ABS', 'TINTED', 'CC', 'DAB', 'ABS', 'PLUS', 'TINTED', 'CC', 'Highline', 'TINTED', 'CC', 'I10', 'Spirit', 'CC', 'Elite', 'CC', 'GL', 'TINTED', 'CC', 'GL', 'SR', 'TINTED', 'CC', 'GL', 'DAB', 'ABS', 'Tinted', 'CC', 'GL', 'TINTED', 'CC', 'GL', 'SR', 'TINTED', 'CC', 'GL', 'DAB', 'ABS', 'Tinted', 'CC', 'HIGHLINE', 'TINTED', 'CC', 'SMART', 'CC', 'SMART', 'SAFETY', 'CC', 'SMART', 'FUN', 'CC', 'SMART', 'PLUS', 'CC', 'MODERN', 'CC', 'SMART', 'V2', 'CC', 'ADVANCED', 'CC', 'ADVANCED', 'WHITE', 'PACK', 'CC', 'PREMIUM', 'CC', 'PREMIUM', 'WHITE', 'PACK', 'CC', 'SMART', 'CC', 'SMART', '/Two', 'Tone', 'CC', 'SMART', 'PLUS', 'CC', 'SMART', 'PLUS', 'Two', 'Tone', 'CC', 'MODERN', 'CC', 'MODERN', 'Two', 'Tone', 'CC', 'ADVANCED', 'CC', 'ADVANCED', 'Two', 'Tone', 'CC', 'HCI', 'Smart', 'Safety', 'CC', 'SMART', 'FUN', 'CC', 'Smart', 'Plus', 'CC', 'I20', 'SPIRIT', 'CC', 'Dynamic', 'CC', 'Elite', 'CC', 'Ultimate', 'CC', 'Spirit', 'CC', 'Dynamic', 'CC', 'Elite', 'CC', 'Ultimate', 'CC', 'Shadow', 'CC', 'Blaze', 'CC', 'Redine', 'CC', 'NIGHT', 'CC', 'MID-NIGHT', 'CC', 'BLACK', 'DIAMOND', 'CC', 'COLLECTOR', 'CC', 'GL', 'TINTED', 'Dynamic', 'GL', 'SR', 'TINTED', 'HIGHLINE', 'TINTED', 'MID-NIGHT', 'RB', 'Highline', 'TINTED', 'COLLECTOR', 'BLACK', 'DIAMOND', 'MID-NIGHT', 'NIGHT', 'Redine', 'Blaze', 'Shadow', 'HIGHLINE', 'TINTED', 'GL', 'DAB', 'ABS', 'Tinted', 'GL', 'SR', 'TINTED', 'GL', 'TINTED', 'RB', 'Highline', 'TINTED', 'RB', 'DAB', 'ABS', 'PLUS', 'TINTED', 'RB', 'DAB', 'ABS', 'TINTED', 'RB', 'SR', 'TINTED', 'RB', 'TINTED', 'Shadow', 'I20', 'Ultimate', 'I20', 'Elite', 'I20', 'Dynamic', 'SR', 'GLS', 'Fully', 'Loaded', 'REDBACK', 'Premium', 'GDI', 'GDI', 'TURBO', 'GdI', '7DCT', 'LIMITED', 'GDI', 'GDI', 'GL', 'IX35', 'SUV', 'IX35', 'SUV', 'CVT', 'DSG', 'MG', 'Toyota', 'Hiace', 'Cars', 'Yassmin_1470570459', 'Hatla2ee.com']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'سيارات', 'للبيع', 'سوق', 'السيارات', ':', 'سيارات', 'مستعملة', 'للبيع', 'في', 'مصر', 'سيارات', 'للبيع', '،', 'سوق', 'السيارات', 'المستعملة', 'يحتوي', 'علي', 'أكثر', 'من', '15411', 'سيارة', 'للبيع', 'في', 'مصر', '،', 'تستطيع', 'البحث', 'عن', 'أي', 'ماركة', 'و', 'موديل', 'أو', 'مدينة', 'أو', 'عدد', 'الكيلوميترات', 'أو', 'السعر', 'بسهولة', 'وسرعة', '.', 'إخترماركة', 'الاسعار', 'نوع', 'السيارة', 'slow_motion_video', 'سيارات', 'حالة', 'خاصة', 'السعة', 'اللترية', 'ابحث', 'عن', 'سيارة', 'للبيع', 'هيونداي', '(', '1660', ')', 'شيفروليه', '(', '1212', ')', 'نيسان', '(', '1052', ')', 'فيات', '(', '1037', ')', 'كيا', '(', '969', ')', 'رينو', '(', '726', ')', 'تويوتا', '(', '652', ')', 'ميتسوبيشي', '(', '617', ')', 'مرسيدس', '(', '534', ')', 'بيجو', '(', '461', ')', 'اوبل', '(', '460', ')', 'سكودا', '(', '453', ')', 'موديلات', 'أخرى', '10,000', 'جنيه', '20,000', 'جنيه', '30,000', 'جنيه', '50,000', 'جنيه', '75,000', 'جنيه', '100,000', 'جنيه', '120,000', 'جنيه', '150,000', 'جنيه', '200,000', 'جنيه', '250,000', 'جنيه', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'سيدان', '(', '10403', ')', 'SUV', '(', '2014', ')', 'هاتشباك', '(', '1640', ')', '4x4', '(', '451 ...
# ---------------------------------
# ['English', 'SUV', 'SUV', 'Signature', 'ZS', 'ZS', 'Comfort', 'ACC', 'SR', 'GLS', 'Fully', 'Loaded', 'REDBACK', 'Luxury', 'Line', 'Dynamic', 'F3', 'F3', 'C', 'C', 'A/C', 'ZS', 'ZS', 'Comfort', 'C5', 'C5', 'HCI', 'HCI', 'C31', 'C31', 'X3', 'X3', 'Luxury', 'Tekna', 'IX', 'IX', 'E', 'E', 'Full', 'Option', 'Luxury', 'Dynamic', 'Hatla2ee.com']
# ['عاجل', 'داليا', 'مصطفي', 'تخطف', 'الأنظار', 'في', 'أحدث', 'ظهور', 'عمره', '31', 'عامًا', '..', 'سر', 'حياة', 'أكبر', 'كلب', 'في', 'العالم', 'خليك', 'واعي', '..', 'جامعة', 'الفيوم', 'والمنتدى', 'الاستراتيجى', 'للتنمية', 'يناقشان', 'قوة', 'التعليم', 'في', 'المجتمع', 'الأحد', 'الجزائر', 'تترشح', 'رسميا', 'لعضوية', 'المكتب', 'التنفيذي', 'للاتحاد', 'الأفريقي', 'لكرة', 'القدم', 'السجن', 'وغرامة', '5', 'ملايين', '..', 'عقوبات', 'مشددة', 'تواجه', 'تاجرعملة', 'بالغربية', 'البحث', 'بحث', 'EN', 'الإشراف', 'العام', 'إلهام', 'أبو', 'الفتح', 'رئيس', 'التحرير', 'أحمــد', 'صبـري', 'الرئيسية', 'اهم', 'الاخبار', 'أخبار', 'البلد', 'حوادث', 'رياضة', 'فن', 'تعليم', 'توك', 'شو', 'مرأة', 'ديني', 'أخبار', 'العالم', 'أصل', 'الحكاية', 'القائمة', 'القائمة', 'الرئيسية', 'اهم', 'الاخبار', 'أخبار', 'البلد', 'حوادث', 'رياضة', 'فن', 'تعليم', 'توك', 'شو', 'مرأة', 'ديني', 'أخبار', 'العالم', 'أصل', 'الحكاية', 'فيديو', 'جراف', 'محافظات', 'اقتصاد', 'منوعات', 'تحقيقات', 'سيارات', 'تكنولوجيا', 'برلمان', 'ملفات', 'مقالات', 'ثقافة', 'بين', 'الناس', 'القائمة', 'الإشراف', 'العام', 'إلهام', 'أبو', 'الفتح', 'رئيس', 'التحرير', 'أحمــد', 'صبـري', 'كل', 'شهرين', '..', 'رد', 'ناري', 'من', 'كبير', 'الأثريين', 'على', 'شائعة', 'إغلاق', 'هرم', 'خوفو', 'صحف', 'الكويت|إسرائيل', 'تواصل', 'ضرب', 'غزة', 'وتستهدف', 'قياديًا', 'في', 'الجهاد', '..', 'الصين', 'تحذر', 'من', 'نتائج', 'كارثية', 'لأي', 'حرب', 'جديدة', 'أكبر', 'سوق', 'لبيع', 'الكلاب', '..', 'حكايات', 'المربين', 'بالمحلة', ':', 'أعلى', 'درجات', 'الوفاء', 'والأمان', 'في', 'الحراسة|فيديو', 'الحكومة', 'تجهز', 'مفاجأة', 'لـ', '22', 'مليون', 'مواطن', 'خلال', 'ساعات|', 'ماذا', 'يحدث؟', 'خصم', '27', '%', '..', 'سعر', 'جوال', 'شاومي', 'Redmi', '9A', 'ثنائي', 'الشريحة', 'في', 'السعودية', '280', 'للكندوز', '..', 'أسعار', 'اللحوم', 'البلدية', 'والمجمدة', 'اليوم', 'السبت', '13', 'مايو', '2023', 'أسرار', 'أسماء', 'الله', 'الحسنى', '..', 'معلومات', 'عن', 'عددها', 'وفوائدها', 'تقلبات', 'حادة', 'وسريعة|', 'الأرصاد', 'تحذر', 'المواطنين', 'من', 'تباين', 'درجات', 'الحرارة', '800', 'جنيه|زلزال', 'يضرب', 'أسعار', 'الذهب', 'بعد', 'تدخل', 'عاجل', 'من', 'الحكومة', 'وعيار21', 'مفاجأة', 'تعليم', 'أسوان', ':', '27', 'ألف', 'و334', 'طالب', 'وطالبة', 'يؤدون', 'إمتحانات', 'الشهادة', 'الإعدادية', 'اليوم', 'ليست', 'ستهم', 'فقط', '..', 'سيدات', 'بالاقصرعملن', 'في', 'مهن', 'الرجال', '..', 'فيديو', 'مكافحة', 'الإدمان', ':', 'أنت', 'أقوى', 'من', 'المخدرات', 'ساهمت', 'في', 'حماية', 'الشباب', 'وزيادة', 'راغبي', 'العلاج', 'سيارات', 'أخبار', 'السيارات|سعر', 'أرخص', 'سيارة', 'تقدمها', 'ميتسوبيشي', '..', 'اشتر', 'شيري', 'تيجو', '8', '2023', 'بـ', '175', 'ألف', '..', '5', 'موديلات', 'أوروبية', '``', 'زيرو', "''", 'بسعر', 'مناسب', 'في', 'مصر', '13/05/2023', '07:00', 'ص', 'نشر', 'موقع', 'صدى', 'البلد', 'مجموعة', 'متنوعة', 'من', 'أخبار', 'السيارات', 'خلال', 'الساعات', 'الماضية،', 'بجانب', 'تقارير', 'جديدة', 'عن', 'أسعار', 'ومواصفات', 'السيارات،', 'وأخرى', 'عالمية', 'تحديثات', 'جديدة', 'تقدمها', 'هيونداي', 'لسيارتها', 'i20', 'موديل', '2024', '..', 'صور', '13/05/2023', '05:00', 'ص', 'تواصل', 'عملاقة', 'تصنيع', 'السيارات', 'الكورية', 'الجنوبية', 'هيونداي', 'من', 'تألقها،', 'بعد', 'كشفت', 'عبر', 'الانترنت', 'عن', 'تحديثات', 'جديدة', 'شملت', 'النسخة', 'i20،', 'والتي', 'تنتمي', 'إلى', 'تحديث', 'جديد', 'في', 'أسعار', 'ميتسوبيشي', 'ميراج', '2023', '..', 'لمحبي', 'الهاتشباك', '13/05/2023', '03:00', 'ص', 'شهدت', 'السيارة', 'ميتسوبيشي', 'ميراج', 'موديل', '2023،', 'زيادة', 'سعرية', 'جديدة', 'خلال', 'الساعات', 'القليلة', 'الماضية،', 'حيث', 'ارتفعت', 'اسعار', 'السيارة', 'بقيمة', 'بلغت', '20', 'الف', 'جنيه', 'أرخص', 'فئات', 'سوزوكي', 'ديزاير', 'المقدمة', 'بالسوق', 'المصري', '..', 'اعرف', 'سعرها', '13/05/2023', '01:00', 'ص', 'ارتفعت', 'قائمة', 'اسعار', 'سيارات', 'شركة', 'سوزوكي', 'اليابانية', 'داخل', 'السوق', 'المصري،', 'وذلك', 'خلال', 'الايام', 'القليلة', 'الماضية', 'من', 'شهر', 'مايو', 'الجاري،', 'وشملت', 'الزيادات', 'السعرية', 'النسخة', 'بـ', '175', 'الف', 'جنيه', '..', 'الحق', 'الفرصة', 'واشتري', 'شيري', 'تيجو', '8', 'موديل', '2023', '13/05/2023', '12:01', 'ص', 'يبحث', 'المصريين',  ...
# ---------------------------------
# ['EN', 'Redmi', '9A', 'GLE', 'G-CLASS', 'SUV', 'DC', 'ZR-V', 'ZR-Vالجديدة', 'HR-Vو', 'CR-V.', 'W12', 'W12', 'BMW', 'GTX', 'GTIمن', 'ID.7سيدان', 'Cyberster', 'Electric', 'Roadster', 'MG', 'Cyberster', 'SUV،', 'All', 'Rights', 'Reserved']
# ['menu', 'search', 'add_circle_outline', '×', 'إبحث', 'عن', 'سيارة', 'مستعملة', 'keyboard_arrow_right', 'account_circle', 'حسابي', 'keyboard_arrow_right', 'account_circle', 'تسجيل', 'الدخول', 'time_to_leave', 'سياراتي', '(', 'إعلاناتي', ')', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'احصل', 'على', 'ابلكيشن', 'هتلاقى', 'تنزيل', 'من', 'المتجر', 'مركبات', 'أخري', 'keyboard_arrow_right', 'more_horiz', 'المزيد', 'keyboard_arrow_right', 'keyboard_backspace', 'اختر', 'الدولة', 'keyboard_backspace', 'مرحباً', 'settings', 'إعدادات', 'account_circle', 'سياراتي', '(', 'إعلاناتي', ')', 'call_missed_outgoing', 'تسجيل', 'خروج', 'سيارات', 'مستعملة', 'سيارات', 'جديدة', 'سيارات', 'مستوردة', 'تقييم', 'سعر', 'عربيتك', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'android', 'نزل', 'تطبيق', 'الهاتف', 'phone_iphone', 'نزل', 'تطبيق', 'الهاتف', 'أسعار', 'السيارات', 'أسعار', 'السيارات', 'المستعملة', 'أسعار', 'السيارات', 'الجديدة', '2022', '-', '2023', 'حركة', 'التغير', 'في', 'أسعار', 'السيارات', 'الجديدة', 'أسعار', 'صيانات', 'السيارات', '2022', '-', '2023', 'تقسيط', 'السيارات', 'تقسيط', 'سيارات', 'مستعملة', 'تقسيط', 'سيارات', 'جديدة', 'مركبات', 'أخري', 'حافلات', 'جديدة', 'أسعار', 'سيارات', 'النقل', 'الجديدة', '2022', '-', '2023', 'أتوبيسات', 'جديدة', 'أسعار', 'الأتوبيسات', 'الجديدة', '2022', '-', '2023', 'موتوسيكلات', 'جديدة', 'أسعار', 'الموتوسيكلات', 'الجديدة', '2022', '-', '2023', 'بيع', 'سيارتي', 'more_horiz', 'معارض', 'السيارات', 'معارض', 'السيارات', 'المستعمله', 'معارض', 'السيارات', 'الجديدة', 'موزعي', 'السيارات', 'المعتمدون', 'تأمين', 'سيارات', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'سيارات', 'كسر', 'زيرو', 'ونش', 'إنقاذ', 'more_horiz', 'المزيد', 'تأمين', 'سيارات', 'سيارات', 'المعاقين', 'مراكز', 'الصيانه', 'اخبار', 'السيارات', 'تقييم', 'السيارات', 'السيارات', 'الكلاسيكية', 'سيارات', 'المعاقين', 'تقييم', 'سعر', 'عربيتك', 'أخر', 'زيارة', 'قائمة', 'السيارات', 'المفضلة', 'معلومات', 'و', 'نصائح', 'منتدى', 'السيارات', 'English', 'حسابي', 'إعدادات', 'سياراتي', '(', 'إعلاناتي', ')', 'تسجيل', 'خروج', 'account_circle', 'دخول', 'account_circle', 'دخول', '/', 'تسجيل', 'إنشاء', 'حساب', 'جديد', 'أو،', 'لديك', 'بالفعل', 'حساب', '!', 'رقم', 'الهاتف', 'أو', 'البريد', 'الإلكتروني', 'كلمة', 'السر', 'إعادة', 'تعيين', 'كلمة', 'السر', 'الخاصة', 'بك', 'سيارات', 'للبيع', '/', 'سيارات', 'مستعملة', 'سيارات', 'مستوردة', 'للبيع', 'في', 'مصر', 'تقدم', 'السيارات', 'المستوردة', 'مجموعة', 'متنوعة', 'من', 'الأشكال', 'والأداء', 'والمميزات', 'الغير', 'موجودة', 'في', 'المركبات', 'المحلية', '.', 'من', 'السيارات', 'الأوروبية', 'والأمريكية', 'إلى', 'اليابانية', 'والكورية', '،', 'ستجد', 'هنا', 'سيارة', 'مستوردة', 'مثالية', 'لاحتياجاتك', 'وميزانيتك', '.', 'بيع', 'سيارتك', 'المستوردة', 'الآن', '!', 'filter_list', 'رتب', 'حسب', 'المضاف', 'حديثاً', 'السعر', 'كم', 'سنة', 'notifications_on', 'أحصل', 'على', 'الإشعارات', 'مرسيدس', 'S', '500', '2021', 'مرسيدس', 'S', '500', 'فضي', 'اتوماتيك', '24,000', 'كم', 'مصر', 'الجديدة', 'تقسيط', 'مستوردة', 'date_range', '2023-05-13', '7,314,000', 'جنيه', 'star', 'لاند', 'روفر', 'رنج', 'روفر', 'ايفوك', '2023', 'لاند', 'روفر', 'رنج', 'روفر', 'ايفوك', 'أسود', '0', 'كم', 'مصر', 'الجديدة', 'كسر', 'زيرو', 'تقسيط', 'مستوردة', 'date_range', '2023-05-13', '3,392,000', 'جنيه', 'star', 'مرسيدس', 'GLA', '2023', 'مرسيدس', 'GLA', 'رمادي', '0', 'كم', 'مصر', 'الجديدة', 'كسر', 'زيرو', 'تقسيط', 'مستوردة', 'date_range', '2023-05-13', '3,074,000', 'جنيه', 'star', 'مرسيدس', 'E', '200', '2022', 'مرسيدس', 'E', '200', 'فضي', 'اتوماتيك', '/', 'P ...
# ---------------------------------
# ['English', 'S', 'S', 'GLA', 'GLA', 'E', 'E', 'PREMIUM', 'X4', 'X4', 'xDrive', 'xLine', 'K3', 'K3', 'S', 'S', 'GLC', 'GLC', 'G', 'Class', 'G', 'Class', 'AMG', 'G', 'NIGHT', 'EDITION', 'C', 'C', 'EQS', 'EQS', 'A5', 'A5', 'S-Line', 'GLC', 'GLC', 'E', 'E', 'AMG', 'xDrive', 'G', 'Class', 'G', 'Class', 'Q3', 'Q3', 'Advanced', 'GLC', 'GLC', 'Q3', 'Q3', 'S-Line', 'GLC', 'GLC', 'Hatla2ee.com']

# %%
stop_words = set(nltk.corpus.stopwords.words("arabic"))
from nltk.stem.isri import ISRIStemmer
import re
st = ISRIStemmer()

# w=filtered_sentence
for word in word_tokens:
    if word not  in stop_words:
    #won't take the input correctly, input = output of tokenization# w= 'كلمات'
        print(word+"-->"+st.stem(word))
        u=st.stem(word)

# import nltk

# from nltk.stem.porter import *
# p_stemmer = PorterStemmer()




# for word in  filtered_sentence:
#     print(word+' --> '+p_stemmer.stem(word))

# from nltk.stem.snowball import SnowballStemmer
# s_stemmer = SnowballStemmer(language='english')



# for word in filtered_sentence:
#     print(word+' --> '+s_stemmer.stem(word))
# u=p_stemmer.stem(word)
# Out:
# menu-->menu
# search-->search
# add_circle_outline-->add_circle_outline
# ×-->×
# إبحث-->بحث
# سيارة-->سير
# مستعملة-->عمل
# keyboard_arrow_right-->keyboard_arrow_right
# account_circle-->account_circle
# حسابي-->حسب
# keyboard_arrow_right-->keyboard_arrow_right
# account_circle-->account_circle
# تسجيل-->سجل
# الدخول-->دخل
# time_to_leave-->time_to_leave
# سياراتي-->سير
# (-->(
# إعلاناتي-->اعلاناتي
# )-->)
# احصل-->حصل
# ابلكيشن-->لكش
# هتلاقى-->هتلاقى
# تنزيل-->نزل
# المتجر-->تجر
# احصل-->حصل
# ابلكيشن-->لكش
# هتلاقى-->هتلاقى
# تنزيل-->نزل
# المتجر-->تجر
# مركبات-->ركب
# أخري-->اخر
# keyboard_arrow_right-->keyboard_arrow_right
# more_horiz-->more_horiz
# المزيد-->زيد
# keyboard_arrow_right-->keyboard_arrow_right
# keyboard_backspace-->keyboard_backspace
# اختر-->ختر
# الدولة-->دول
# keyboard_backspace-->keyboard_backspace
# مرحباً-->رحب
# settings-->settings
# إعدادات-->عدد
# account_circle-->account_circle
# سياراتي-->سير
# (-->(
# إعلاناتي-->اعلاناتي
# )-->)
# call_missed_outgoing-->call_missed_outgoing
# تسجيل-->سجل
# خروج-->خرج
# سيارات-->سير
# مستعملة-->عمل
# سيارات-->سير
# جديدة-->جدد
# سيارات-->سير
# مستوردة-->ورد
# تقييم-->قيم
# سعر-->سعر
# عربيتك-->عرب
# أسعار-->سعر
# السيارات-->سير
# المستعملة-->عمل
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# حركة-->حرك
# التغير-->تغر
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# أسعار-->سعر
# صيانات-->صين
# السيارات-->سير
# 2022-->2022
# --->-
# 2023-->2023
# معارض-->عرض
# السيارات-->سير
# المستعمله-->عمل
# معارض-->عرض
# السيارات-->سير
# الجديدة-->جدد
# موزعي-->وزع
# السيارات-->سير
# المعتمدون-->عمد
# مركبات-->ركب
# أخري-->اخر
# حافلات-->حفل
# جديدة-->جدد
# أسعار-->سعر
# سيارات-->سير
# النقل-->نقل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# أتوبيسات-->وبس
# جديدة-->جدد
# أسعار-->سعر
# الأتوبيسات-->وبس
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# موتوسيكلات-->موتوسيكل
# جديدة-->جدد
# أسعار-->سعر
# الموتوسيكلات-->موتوسيكل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# android-->android
# نزل-->نزل
# تطبيق-->طبق
# الهاتف-->هتف
# phone_iphone-->phone_iphone
# نزل-->نزل
# تطبيق-->طبق
# الهاتف-->هتف
# أسعار-->سعر
# السيارات-->سير
# أسعار-->سعر
# السيارات-->سير
# المستعملة-->عمل
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# حركة-->حرك
# التغير-->تغر
# أسعار-->سعر
# السيارات-->سير
# الجديدة-->جدد
# أسعار-->سعر
# صيانات-->صين
# السيارات-->سير
# 2022-->2022
# --->-
# 2023-->2023
# تقسيط-->قسط
# السيارات-->سير
# تقسيط-->قسط
# سيارات-->سير
# مستعملة-->عمل
# تقسيط-->قسط
# سيارات-->سير
# جديدة-->جدد
# مركبات-->ركب
# أخري-->اخر
# حافلات-->حفل
# جديدة-->جدد
# أسعار-->سعر
# سيارات-->سير
# النقل-->نقل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# أتوبيسات-->وبس
# جديدة-->جدد
# أسعار-->سعر
# الأتوبيسات-->وبس
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# موتوسيكلات-->موتوسيكل
# جديدة-->جدد
# أسعار-->سعر
# الموتوسيكلات-->موتوسيكل
# الجديدة-->جدد
# 2022-->2022
# --->-
# 2023-->2023
# بيع-->بيع
# سيارتي-->سير
# more_horiz-->more_horiz
# معارض-->عرض
# السيارات-->سير
# معارض-->عرض
# السيارات-->سير
# المستعمله-->عمل
# معارض-->عرض
# السيارات-->سير
# الجديدة-->جدد
# موزعي-->وزع
# السيارات-->سير
# المعتمدون-->عمد
# تأمين-->تأم
# سيارات-->سير
# مراكز-->ركز
# الصيانه-->صين
# اخبار-->خبر
# السيارات-->سير
# تقييم-->قيم
# السيارات-->سير
# سيارات-->سير
# كسر-->كسر
# زيرو-->زيرو
# ونش-->ونش
# إنقاذ-->قاذ
# more_horiz-->more_horiz
# المزيد-->زيد
# تأمين-->تأم
# سيارات-->سير
# سيارات-->سير
# المعاقين-->عاق
# مراكز-->ركز
# الصيانه-->صين
# اخبار-->خبر
# السيارات-->سير
# تقييم-->قيم
# السيارات-->سير
# السيارات-->سير
# الكلاسيكية-->كلاسيكية
# سيارات-->سير
# المعاقين-->عاق
# تقييم-->قيم
# سعر-->سعر
# عربيتك-->عرب
# أخر-->اخر
# زيارة-->زير
# قائمة-->قئم
# السيارات-->سير
# المفضلة-->فضل
# معلومات-->علم
# نصائح-->نصح
# منتدى-->ندى
# السيارات-->سير
# English-->English
# حسابي-->حسب
# إعدادات-->عدد
# سياراتي-->سير
# (-->(
# إعلاناتي-->اعلاناتي
# )-->)
# تسجيل-->سجل
# خروج-->خرج
# account_circle-->account_circle
# دخول-->دخل
# account_circle-->account_circle
# دخول-->دخل
# /-->/
# تسجيل-->سجل
# إنشاء-->شاء
# حساب-->حسب
# جديد-->جدد
# أو،-->او،
# لديك-->لدك
# بالفعل-->فعل
# حساب-->حسب
# !-->!
# رقم-->رقم
# الهاتف-->هتف
# البريد-->برد
# الإلكتروني-->كترو
# كلمة-->كلم
# السر-->لسر
# إعادة-->عدة
# تعيين-->تعي
# كلمة-->كلم
# السر-->لسر
# الخاصة-->خصة
# سيارات-->سير
# للبيع-->بيع
# /-->/
# سيارات-->سير
# مستعملة-->عمل
# سيارات-->سير
# مستوردة-->ورد
# للبيع-->بيع
# مصر-->مصر
# تقدم-->قدم
# السيارات-->سير
# المستوردة-->ورد
# مجموعة-->جمع
# متنوعة-->تنع
# الأشكال-->شكل
# والأداء-->ادء
# والمميزات-->ميز
# الغير-->غير
# موجودة-->وجد
# المركبات-->ركب
# المحلية-->حلة
# .-->.
# السيارات-->سير
# الأوروبية-->ورب
# والأمريكية-->امر
# اليابانية-->ياب
# والكورية-->كور
# ،-->،
# ستجد-->تجد
# سيارة-->سير
# مستوردة-->ورد
# مثالية-->ثلي
# لاحتياجاتك-->لاحتياجاتك
# وميزانيتك-->وميزانيتك
# .-->.
# بيع-->بيع
# سيارتك-->سير
# المستوردة-->ورد
# !-->!
# filter_list-->filter_list
# رتب-->رتب
# المضاف-->ضاف
# حديثاً-->حدث
# السعر-->سعر
# سنة-->سنة
# notifications_on-->notifications_on
# أحصل-->حصل
# الإشعارات-->شعر
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# 2021-->2021
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# فضي-->فضي
# اتوماتيك-->اتوماتيك
# 24,000-->24,000
# مصر-->مصر
# الجديدة-->جدد
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 7,314,000-->7,314,000
# star-->star
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# أسود-->اسد
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 3,392,000-->3,392,000
# star-->star
# مرسيدس-->مرسيدس
# GLA-->GLA
# 2023-->2023
# مرسيدس-->مرسيدس
# GLA-->GLA
# رمادي-->رمد
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 3,074,000-->3,074,000
# star-->star
# مرسيدس-->مرسيدس
# E-->E
# 200-->200
# 2022-->2022
# مرسيدس-->مرسيدس
# E-->E
# 200-->200
# فضي-->فضي
# اتوماتيك-->اتوماتيك
# /-->/
# PREMIUM-->PREMIUM
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 3,975,000-->3,975,000
# star-->star
# ام-->ام
# دبليو-->دبليو
# X4-->X4
# 2023-->2023
# ام-->ام
# دبليو-->دبليو
# X4-->X4
# أسود-->اسد
# اتوماتيك-->اتوماتيك
# /-->/
# xDrive-->xDrive
# 30i-->30i
# xLine-->xLine
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-13-->2023-05-13
# 4,876,000-->4,876,000
# star-->star
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# رنج-->رنج
# روفر-->روفر
# ايفوك-->يفو
# رمادي-->رمد
# 0-->0
# مصر-->مصر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-05-02-->2023-05-02
# 3,869,000-->3,869,000
# star-->star
# كيا-->كيا
# K3-->K3
# 2022-->2022
# كيا-->كيا
# K3-->K3
# أبيض-->ابض
# 20-->20
# مدينة-->دين
# نصر-->نصر
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-04-26-->2023-04-26
# 950,000-->950,000
# star-->star
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# 2022-->2022
# مرسيدس-->مرسيدس
# S-->S
# 500-->500
# أسود-->اسد
# --->-
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-25-->2023-04-25
# 1,000,000-->1,000,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# أسود-->اسد
# 1-->1
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-24-->2023-04-24
# 2,300,000-->2,300,000
# star-->star
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# 2022-->2022
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# أسود-->اسد
# اتوماتيك-->اتوماتيك
# /-->/
# AMG-->AMG
# G-->G
# 63-->63
# /-->/
# NIGHT-->NIGHT
# EDITION-->EDITION
# --->-
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# تقسيط-->قسط
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-24-->2023-04-24
# 7,500,000-->7,500,000
# star-->star
# مرسيدس-->مرسيدس
# C-->C
# 200-->200
# 2022-->2022
# مرسيدس-->مرسيدس
# C-->C
# 200-->200
# رمادي-->رمد
# 27,200-->27,200
# 6-->6
# مستوردة-->ورد
# date_range-->date_range
# 2023-04-19-->2023-04-19
# 2,550,000-->2,550,000
# star-->star
# جاكوار-->جاكوار
# اف-->اف
# بيس-->بيس
# 2023-->2023
# جاكوار-->جاكوار
# اف-->اف
# بيس-->بيس
# فضي-->فضي
# 0-->0
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-03-22-->2023-03-22
# 3,750,000-->3,750,000
# star-->star
# لاند-->لند
# روفر-->روفر
# فيلار-->يلر
# 2022-->2022
# لاند-->لند
# روفر-->روفر
# فيلار-->يلر
# أسود-->اسد
# 0-->0
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-03-22-->2023-03-22
# 3,900,000-->3,900,000
# star-->star
# كوبرا-->كوبر
# فورمينتور-->فورمينتور
# 2022-->2022
# كوبرا-->كوبر
# فورمينتور-->فورمينتور
# فيراني-->فير
# اتوماتيك-->اتوماتيك
# 500-->500
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# مستوردة-->ورد
# date_range-->date_range
# 2023-03-17-->2023-03-17
# 2,650,000-->2,650,000
# star-->star
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# 2023-->2023
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# أبيض-->ابض
# 10-->10
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 1,900,000-->1,900,000
# star-->star
# مرسيدس-->مرسيدس
# EQS-->EQS
# 2023-->2023
# مرسيدس-->مرسيدس
# EQS-->EQS
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 5,500,000-->5,500,000
# star-->star
# اودي-->اود
# A5-->A5
# 2023-->2023
# اودي-->اود
# A5-->A5
# أزرق-->زرق
# اتوماتيك-->اتوماتيك
# /-->/
# S-Line-->S-Line
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 2,350,000-->2,350,000
# star-->star
# بورش-->ورش
# 718-->718
# 2023-->2023
# بورش-->ورش
# 718-->718
# رمادي-->رمد
# --->-
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 4,020,000-->4,020,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# رمادي-->رمد
# 100-->100
# القاهرة-->قهر
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 3,890,000-->3,890,000
# star-->star
# مرسيدس-->مرسيدس
# E-->E
# 300-->300
# 2021-->2021
# مرسيدس-->مرسيدس
# E-->E
# 300-->300
# أسود-->اسد
# اتوماتيك-->اتوماتيك
# /-->/
# AMG-->AMG
# 10,000-->10,000
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 2,200,000-->2,200,000
# star-->star
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# اكس-->اكس
# 2023-->2023
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# اكس-->اكس
# أبيض-->ابض
# اتوماتيك-->اتوماتيك
# /-->/
# xDrive-->xDrive
# 40-->40
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 2,200,000-->2,200,000
# star-->star
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# 2023-->2023
# تسلا-->تسل
# موديل-->ودل
# 3-->3
# فضي-->فضي
# 100-->100
# القاهرة-->قهر
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-15-->2023-03-15
# 1,800,000-->1,800,000
# star-->star
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# 2023-->2023
# مرسيدس-->مرسيدس
# G-->G
# Class-->Class
# ذهبي-->ذهب
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 10,000,000-->10,000,000
# star-->star
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# 7-->7
# 2023-->2023
# ام-->ام
# دبليو-->دبليو
# اى-->اى
# 7-->7
# فضي-->فضي
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# كهربائية-->كهربائية
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 6,000,000-->6,000,000
# star-->star
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 5,000,000-->5,000,000
# star-->star
# اودي-->اود
# Q3-->Q3
# 2023-->2023
# اودي-->اود
# Q3-->Q3
# أبيض-->ابض
# اتوماتيك-->اتوماتيك
# /-->/
# Advanced-->Advanced
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 1,690,000-->1,690,000
# star-->star
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# 2023-->2023
# لاند-->لند
# روفر-->روفر
# ديفندر-->ديفندر
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 5,000,000-->5,000,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 200-->200
# أسود-->اسد
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 3,300,000-->3,300,000
# star-->star
# اودي-->اود
# Q3-->Q3
# 2023-->2023
# اودي-->اود
# Q3-->Q3
# أبيض-->ابض
# اتوماتيك-->اتوماتيك
# /-->/
# S-Line-->S-Line
# 100-->100
# التجمع-->جمع
# --->-
# القاهرة-->قهر
# الجديدة-->جدد
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 1,400,000-->1,400,000
# star-->star
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# 2023-->2023
# مرسيدس-->مرسيدس
# GLC-->GLC
# 300-->300
# أسود-->اسد
# 100-->100
# القاهرة-->قهر
# كسر-->كسر
# زيرو-->زيرو
# يمكن-->يمكن
# إستيرادها-->يرد
# هجين-->هجن
# date_range-->date_range
# 2023-03-14-->2023-03-14
# 4,130,000-->4,130,000
# star-->star
# 1-->1
# 2-->2
# 3-->3
# التالى-->تلى
# »-->»
# ×-->×
# تدع-->تدع
# السيارات-->سير
# تبحث-->بحث
# عنها-->عنه
# تفوتك-->تفت
# أحصل-->حصل
# الإشعارات-->شعر
# الخاصة-->خصة
# بالموديلات-->ودل
# تهتم-->هتم
# إحتفظ-->حفظ
# بإعدادات-->إعداد
# بحثك-->بحث
# موديلات-->ودل
# بعينها-->بعن
# تحدث-->حدث
# البائعين-->بئع
# عبر-->عبر
# الواتس-->وتس
# بِع-->بع
# سيارتك-->سير
# مباشرة-->بشر
# هاتفك-->هتف
# المحمول-->حمل
# تطبيق-->طبق
# الهاتف-->هتف
# أسرع-->سرع
# الرئيسيه-->رئس
# اتصل-->تصل
# شروط-->شرط
# الخصوصية-->خصص
# كُن-->كن
# تواصل-->وصل
# معنا-->عنا
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# مصر-->مصر
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# الإمارات-->امر
# سيارات-->سير
# للبيع-->بيع
# الأردن-->ارد
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# السعودية-->سعد
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# عمان-->عمن
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# اليمن-->يمن
# سيارات-->سير
# المستعملة-->عمل
# الكويت-->كوت
# سيارات-->سير
# المستعملة-->عمل
# قطر-->قطر
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# لبنان-->لبن
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# ليبيا-->ليب
# سيارات-->سير
# مستعملة-->عمل
# للبيع-->بيع
# العراق-->عرق
# ©-->©
# Hatla2ee.com-->Hatla2ee.com
# 2023-->2023
# notification_important-->notification_important
# خدمة-->خدم
# الإشعارات-->شعر
# إشترك-->شرك
# خدمة-->خدم
# أخبار-->خبر
# السيارات‎-->رت‎
# ذكرني-->ذكر
# لاحقا-->لحق
# موافق-->وفق
# ×-->×
# سيارات-->سير
# المقارنة-->قرن
# keyboard_arrow_left-->keyboard_arrow_left
# أضف-->اضف
# سيارة-->سير
# أخري-->اخر
# قارن-->قرن
# keyboard_arrow_right-->keyboard_arrow_right
# close-->close
# هتلاقي-->هتلاق
# أسرع-->سرع
# تطبيق-->طبق
# الهاتف-->هتف
# search-->search
# شراء-->شرء
# add_circle_outline-->add_circle_outline
# بيع-->بيع
# local_offer-->local_offer
# الأسعار-->سعر
# notifications_active-->notifications_active
# تنبيهات-->نبه
# والكثير-->كثر
# ..-->..
# نزل-->نزل
# التطبيق-->طبق
# الأن-->الأ
# close-->close
# هتلاقي-->هتلاق
# أسرع-->سرع
# تطبيق-->طبق
# الهاتف-->هتف
# search-->search
# شراء-->شرء
# add_circle_outline-->add_circle_outline
# بيع-->بيع
# local_offer-->local_offer
# الأسعار-->سعر
# notifications_active-->notifications_active
# تنبيهات-->نبه
# والكثير-->كثر
# ..-->..
# نزل-->نزل
# التطبيق-->طبق
# الأن-->الأ

# %%
# import pandas as pd
# def tf_idf_analysis(keyword):
#     v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
#     x = v.fit_transform(text)

#     f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
#     d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
#     tf=pd.DataFrame((f>0).sum(axis=0))


#     d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

#     d.columns=['word','average_tfidf','max_tfidf','frequency']

#     d['frequency']=round((d['frequency']/len(text))*100)

#     return(d)

# x= tf_idf_analysis(u)
# x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
def tf_idf_analysis(keyword):
    v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=list(stop_words))
    x = v.fit_transform(text)
    f = pd.DataFrame(x.toarray(), columns = v.get_feature_names_out())
    d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    tf=pd.DataFrame((f>0).sum(axis=0))
    d=d.reset_index().merge(tf.reset_index(),on='index',how='left')
    d.columns=['word','average_tfidf','max_tfidf','frequency']
    d['frequency']=round((d['frequency']/len(text))*100)
    d['max_tfidf'] = d['max_tfidf'].round(3)
    d['average_tfidf'] = d['average_tfidf'].round(3)

    d= d[d['word'].str.isalpha()].sort_values('frequency',ascending=False).head(35)
    
    return d

import requests


# Call the tf_idf_analysis function and store the output in a DataFrame variable
output_df = tf_idf_analysis(u)
print (output_df)
# Convert the DataFrame to a dictionary
output_dict = output_df.to_dict('records')

# Connect to the database
# mysql = mysql.connector.connect(
#     host="localhost",
#     user="root",
#     passwd="",
#     database="seopro"
# )

# # Insert the data into the database
# mycursor = mysql.cursor()
sql = "INSERT INTO keyword_ar (word, average_tfidf, max_tfidf, frequency, niche, uid) VALUES (%s, %s, %s, %s, %s, %s)"
for row in output_dict:
    val = (row['word'], row['average_tfidf'], row['max_tfidf'], row['frequency'], niche, uid)
    mycursor.execute(sql, val)
    # data = {'word': row['word'], 'average_tfidf': row['average_tfidf']}
    # response = requests.post('http://example.com/api/data', data=data)
    # if response.status_code == 200:
    #     print('Data sent successfully')
    # else:
    #     print('Error sending data')

mysql.commit()

# Print a message to confirm that the data has been saved
print("Data has been saved to the database.")
# print(x)
#######################################################################
# import pandas as pd
# # documentA = 'ذهب محمد الي الجامعة ليدرس الفيزياء و الكيمياء'
# # documentB=u
# documentA=u
# bagOfWordsA = documentA.split(' ')
# # bagOfWordsB = documentB.split(' ')
# uniqueWords = set(bagOfWordsA)
# uniqueWords
# numOfWordsA = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsA[word] += 1
# numOfWordsA
# numOfWordsB = dict.fromkeys(uniqueWords, 0)

# for word in bagOfWordsA:
#     numOfWordsB[word] += 1

# numOfWordsB    
# def computeTF(wordDict, bagOfWords):
#     tfDict = {}
#     bagOfWordsCount = len(bagOfWords)
#     for word, count in wordDict.items():
#         tfDict[word] = count / float(bagOfWordsCount)
#     return tfDict
# tfB = computeTF(numOfWordsB, bagOfWordsA)
# print(tfB)
# Out:
# c:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['آمين', 'أب', 'أخ', 'أفعل', 'أفعله', 'ؤلاء', 'إل', 'إم', 'ات', 'اتان', 'ارتد', 'ان', 'انفك', 'برح', 'تان', 'تبد', 'تحو', 'تعل', 'حد', 'حم', 'حي', 'خب', 'ذار', 'سيما', 'صه', 'ظل', 'ظن', 'عد', 'قط', 'مر', 'مكان', 'مكانكن', 'نب', 'هات', 'هب', 'واها', 'وراء'] not in stop_words.
#   warnings.warn(
#             word  average_tfidf  max_tfidf  frequency
# 16358     سيارات          0.072      0.282       82.0
# 5376       أخبار          0.019      0.208       82.0
# 8960    الخصوصية          0.009      0.053       82.0
# 14366      جديدة          0.027      0.106       82.0
# 13421      تسجيل          0.013      0.059       82.0
# 8519     الجديدة          0.042      0.152       77.0
# 20294        مصر          0.025      0.157       77.0
# 9032      الدخول          0.006      0.022       73.0
# 20004     مرسيدس          0.017      0.112       73.0
# 10716     المزيد          0.014      0.085       73.0
# 2950     english          0.005      0.015       73.0
# 5567       أسعار          0.048      0.202       68.0
# 20483    معلومات          0.008      0.075       68.0
# 14349       جديد          0.007      0.053       68.0
# 20567       معنا          0.006      0.044       68.0
# 9372    السيارات          0.083      0.350       68.0
# 17895      فولكس          0.007      0.028       64.0
# 20132    مستعملة          0.036      0.169       64.0
# 16137      سكودا          0.007      0.025       64.0
# 9291       السعر          0.012      0.057       64.0
# 15098       خدمة          0.009      0.055       64.0
# 16724       شروط          0.004      0.017       64.0
# 13571      تطبيق          0.013      0.028       64.0
# 12700       بورش          0.005      0.016       64.0
# 21080  ميتسوبيشي          0.009      0.033       64.0
# 15667       روفر          0.009      0.066       64.0
# 16424      سيارة          0.017      0.095       64.0
# 16339       سيات          0.006      0.019       64.0
# 21731      هوندا          0.006      0.019       64.0
# 18488        كيا          0.023      0.218       64.0
# 14123      تواصل          0.006      0.046       64.0
# 14205     تويوتا          0.017      0.211       64.0
# 16612     شانجان          0.006      0.022       59.0
# 21419      نصائح          0.005      0.031       59.0
# 18686       لاند          0.007      0.049       59.0
# Data has been saved to the database.

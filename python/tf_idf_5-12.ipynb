# %%
pip install fake-useragent
# Out:
# Requirement already satisfied: fake-useragent in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (1.1.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install requests-html
# Out:
# Requirement already satisfied: requests-html in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (0.10.0)
# Requirement already satisfied: fake-useragent in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests-html) (1.1.1)
# Requirement already satisfied: requests in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests-html) (2.28.2)
# Requirement already satisfied: pyquery in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests-html) (2.0.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests-html) (1.0.2)
# Requirement already satisfied: bs4 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests-html) (0.0.1)
# Requirement already satisfied: w3lib in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests-html) (2.1.1)
# Requirement already satisfied: parse in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests-html) (1.19.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (1.26.14)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (4.64.1)
# Requirement already satisfied: certifi>=2021 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (2022.12.7)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (6.0.0)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (10.4)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (8.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from bs4->requests-html) (4.11.2)
# Requirement already satisfied: lxml>=2.1 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyquery->requests-html) (4.9.2)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from pyquery->requests-html) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests->requests-html) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from requests->requests-html) (3.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.15.0)
# Requirement already satisfied: colorama in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hashim\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4->requests-html) (2.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import urllib
import pandas as pd
from requests_html import HTML
from requests_html import HTMLSession
from flask import Flask 
app = Flask(__name__)

# %%
# new_stopwords = ["all", "due", "to", "on", "daily","per","article","com","http"]

# stop_words = nltk.corpus.stopwords.words('english')
# stop_words.extend(new_stopwords)
# print(stop_words)

# %%
# import nltk
# nltk.download('stopwords')
# # # stpwrd = nltk.corpus.stopwords.words('english')
# # # new_stopwords = ["http","com"]
# # # stpwrd.extend(new_stopwords)
# # # print(stpwrd)

# # stopwords = list(set(stopwords.words('english')))

# # stop_words = list(set(stpwrd))
# # print(stop_words)

# from nltk.corpus import stopwords
# stopWords = list(set(stopwords.words('english')))
# new_stopwords = ["http","com","per","www","min","max","edu","https","blog","start","end","google","ar","en","said","type","div","see","seen","say","said"]
# stopWords.extend(new_stopwords)
# print(stopWords)

# %%
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup

def get_text(url):
    try:
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req,timeout=5).read()
        soup = BeautifulSoup(webpage, "html.parser")
        texts = soup.findAll(text=True)
        res=u" ".join(t.strip() for t in texts if t.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]'])
        return(res)
    except:
        return False

# %%
# get_text('https://en.wikipedia.org/wiki/Machine_learning')

# %%
# get_text('https://en.wikipedia.org/wiki/Machine_learning')[0:6000]
# get_text('https://en.wikipedia.org/wiki/Machine_learning')

#I will return the first 500 characters\

import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words

import nltk
nltk.download('punkt')
# example_sent = "This is a sample sentence, And This showing off the stop words filtration."
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(get_text('https://en.wikipedia.org/wiki/Machine_learning'))
word_tokens

filtered_sentence = [w for w in word_tokens]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)

filtered_sentence = [w for w in word_tokens if not w in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Hashim\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hashim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 179
# ['Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'page', 'Contents', 'Current', 'events', 'Random', 'article', 'About', 'Wikipedia', 'Contact', 'us', 'Donate', 'Contribute', 'Help', 'Learn', 'to', 'edit', 'Community', 'portal', 'Recent', 'changes', 'Upload', 'file', 'Languages', 'Language', 'links', 'are', 'at', 'the', 'top', 'of', 'the', 'page', 'across', 'from', 'the', 'title', '.', 'Search', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'Contributions', 'Talk', 'CentralNotice', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Overview', '2', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'Toggle', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'subsection', '2.1', 'Artificial', 'intelligence', '2.2', 'Data', 'mining', '2.3', 'Generalization', '2.4', 'Statistics', '2.5', 'Physics', '3', 'Theory', '4', 'Approaches', 'Toggle', 'Approaches', 'subsection', '4.1', 'Supervised', 'learning', '4.2', 'Unsupervised', 'learning', '4.3', 'Semi-supervised', 'learning', '4.4', 'Reinforcement', 'learning', '4.5', 'Dimensionality', 'reduction', '4.6', 'Other', 'types', '4.6.1', 'Self-learning', '4.6.2', 'Feature', 'learning', '4.6.3', 'Sparse', 'dictionary', 'learning', '4.6.4', 'Anomaly', 'detection', '4.6.5', 'Robot', 'learning', '4.6.6', 'Association', 'rules', '4.7', 'Models', '4.7.1', 'Artificial', 'neural', 'networks', '4.7.2', 'Decision', 'trees', '4.7.3', 'Support-vector', 'machines', '4.7.4', 'Regression', 'analysis', '4.7.5', 'Bayesian', 'networks', '4.7.6', 'Gaussian', 'processes', '4.7.7', 'Genetic', 'algorithms', '4.8', 'Training', 'models', '4.8.1', 'Federated', 'learning', '5', 'Applications', '6', 'Limitations', 'Toggle', 'Limitations', 'subsection', '6.1', 'Bias', '6.2', 'Explainability', '6.3', 'Overfitting', '6.4', 'Other', 'limitations', 'and', 'vulnerabilities', '7', 'Model', 'assessments', '8', 'Ethics', '9', 'Hardware', 'Toggle', 'Hardware', 'subsection', '9.1', 'Neuromorphic/Physical', 'Neural', 'Networks', '9.2', 'Embedded', 'Machine', 'Learning', '10', 'Software', 'Toggle', 'Software', 'subsection', '10.1', 'Free', 'and', 'open-source', 'software', '10.2', 'Proprietary', 'software', 'with', 'free', 'and', 'open-source', 'editions', '10.3', 'Proprietary', 'software', '11', 'Journals', '12', 'Conferences', '13', 'See', 'also', '14', 'References', '15', 'Sources', '16', 'Further', 'reading', '17', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', 'Toggle', 'the', 'table', 'of', 'contents', 'Machine', 'learning', '73', 'languages', 'العربية', 'অসমীয়া', 'Azərbaycanca', 'বাংলা', 'Bân-lâm-gú', 'Беларуская', 'भोजपुरी', 'Български', 'བོད་ཡིག', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'الدارجة', 'Deutsch', 'Eesti', 'Ελληνικά', 'Español', 'Euskara', 'فارسی', 'Français', 'Galego', '한국어', 'Հայերեն', 'हिन्दी', 'Bahasa', 'Indonesia', 'IsiZulu', 'Íslenska', 'Italiano', 'עברית', 'ಕನ್ನಡ', 'Latviešu', 'Lietuvių', 'Magyar', 'Македонски', 'മലയാളം', 'मराठी', 'Bahasa', 'Melayu', 'Монгол', 'Nederlands', '日本語', 'Norsk', 'bokmål', 'Norsk', 'nynorsk', 'Occitan', 'ଓଡ଼ିଆ', 'پنجابی', 'Polski', 'Português', 'Română', 'Runa', 'Simi', 'Русский', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Shqip', 'Simple', 'English', 'Slovenščina', 'کوردی', 'Српски', '/', 'srpski', 'Srpskohrvatski', '/', 'српскохрватски', 'Suomi', 'Svenska', 'Tagalog', 'తెలుగు', 'ไทย', 'Türkçe', 'Українська', 'اردو', 'ئۇيغۇرچە', '/', 'Uyghurche', 'Tiếng', 'Việt', 'Võro', '吴语', '粵語', '中文', 'Edit', 'links', 'Article', 'Talk', 'English', 'Read', 'Edit', 'View', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'Read', 'Edit', 'View', 'history', 'General', 'What', 'links', 'here', 'Related', 'changes', 'Upload', 'file', 'Special', 'pages', 'Permanent', 'link', 'Page', 'information', 'Cite', 'this', 'page', 'Wikidata', 'item', 'Print/export', 'Download', 'as ...
# ---------------------------------
# ['Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'page', 'Contents', 'Current', 'events', 'Random', 'article', 'About', 'Wikipedia', 'Contact', 'us', 'Donate', 'Contribute', 'Help', 'Learn', 'to', 'edit', 'Community', 'portal', 'Recent', 'changes', 'Upload', 'file', 'Languages', 'Language', 'links', 'are', 'at', 'the', 'top', 'of', 'the', 'page', 'across', 'from', 'the', 'title', '.', 'Search', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'Contributions', 'Talk', 'CentralNotice', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Overview', '2', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'Toggle', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'subsection', '2.1', 'Artificial', 'intelligence', '2.2', 'Data', 'mining', '2.3', 'Generalization', '2.4', 'Statistics', '2.5', 'Physics', '3', 'Theory', '4', 'Approaches', 'Toggle', 'Approaches', 'subsection', '4.1', 'Supervised', 'learning', '4.2', 'Unsupervised', 'learning', '4.3', 'Semi-supervised', 'learning', '4.4', 'Reinforcement', 'learning', '4.5', 'Dimensionality', 'reduction', '4.6', 'Other', 'types', '4.6.1', 'Self-learning', '4.6.2', 'Feature', 'learning', '4.6.3', 'Sparse', 'dictionary', 'learning', '4.6.4', 'Anomaly', 'detection', '4.6.5', 'Robot', 'learning', '4.6.6', 'Association', 'rules', '4.7', 'Models', '4.7.1', 'Artificial', 'neural', 'networks', '4.7.2', 'Decision', 'trees', '4.7.3', 'Support-vector', 'machines', '4.7.4', 'Regression', 'analysis', '4.7.5', 'Bayesian', 'networks', '4.7.6', 'Gaussian', 'processes', '4.7.7', 'Genetic', 'algorithms', '4.8', 'Training', 'models', '4.8.1', 'Federated', 'learning', '5', 'Applications', '6', 'Limitations', 'Toggle', 'Limitations', 'subsection', '6.1', 'Bias', '6.2', 'Explainability', '6.3', 'Overfitting', '6.4', 'Other', 'limitations', 'and', 'vulnerabilities', '7', 'Model', 'assessments', '8', 'Ethics', '9', 'Hardware', 'Toggle', 'Hardware', 'subsection', '9.1', 'Neuromorphic/Physical', 'Neural', 'Networks', '9.2', 'Embedded', 'Machine', 'Learning', '10', 'Software', 'Toggle', 'Software', 'subsection', '10.1', 'Free', 'and', 'open-source', 'software', '10.2', 'Proprietary', 'software', 'with', 'free', 'and', 'open-source', 'editions', '10.3', 'Proprietary', 'software', '11', 'Journals', '12', 'Conferences', '13', 'See', 'also', '14', 'References', '15', 'Sources', '16', 'Further', 'reading', '17', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', 'Toggle', 'the', 'table', 'of', 'contents', 'Machine', 'learning', '73', 'languages', 'العربية', 'অসমীয়া', 'Azərbaycanca', 'বাংলা', 'Bân-lâm-gú', 'Беларуская', 'भोजपुरी', 'Български', 'བོད་ཡིག', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'الدارجة', 'Deutsch', 'Eesti', 'Ελληνικά', 'Español', 'Euskara', 'فارسی', 'Français', 'Galego', '한국어', 'Հայերեն', 'हिन्दी', 'Bahasa', 'Indonesia', 'IsiZulu', 'Íslenska', 'Italiano', 'עברית', 'ಕನ್ನಡ', 'Latviešu', 'Lietuvių', 'Magyar', 'Македонски', 'മലയാളം', 'मराठी', 'Bahasa', 'Melayu', 'Монгол', 'Nederlands', '日本語', 'Norsk', 'bokmål', 'Norsk', 'nynorsk', 'Occitan', 'ଓଡ଼ିଆ', 'پنجابی', 'Polski', 'Português', 'Română', 'Runa', 'Simi', 'Русский', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Shqip', 'Simple', 'English', 'Slovenščina', 'کوردی', 'Српски', '/', 'srpski', 'Srpskohrvatski', '/', 'српскохрватски', 'Suomi', 'Svenska', 'Tagalog', 'తెలుగు', 'ไทย', 'Türkçe', 'Українська', 'اردو', 'ئۇيغۇرچە', '/', 'Uyghurche', 'Tiếng', 'Việt', 'Võro', '吴语', '粵語', '中文', 'Edit', 'links', 'Article', 'Talk', 'English', 'Read', 'Edit', 'View', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'Read', 'Edit', 'View', 'history', 'General', 'What', 'links', 'here', 'Related', 'changes', 'Upload', 'file', 'Special', 'pages', 'Permanent', 'link', 'Page', 'information', 'Cite', 'this', 'page', 'Wikidata', 'item', 'Print/export', 'Download', 'as ...
# ['Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'page', 'Contents', 'Current', 'events', 'Random', 'article', 'About', 'Wikipedia', 'Contact', 'us', 'Donate', 'Contribute', 'Help', 'Learn', 'to', 'edit', 'Community', 'portal', 'Recent', 'changes', 'Upload', 'file', 'Languages', 'Language', 'links', 'are', 'at', 'the', 'top', 'of', 'the', 'page', 'across', 'from', 'the', 'title', '.', 'Search', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'Contributions', 'Talk', 'CentralNotice', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Overview', '2', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'Toggle', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'subsection', '2.1', 'Artificial', 'intelligence', '2.2', 'Data', 'mining', '2.3', 'Generalization', '2.4', 'Statistics', '2.5', 'Physics', '3', 'Theory', '4', 'Approaches', 'Toggle', 'Approaches', 'subsection', '4.1', 'Supervised', 'learning', '4.2', 'Unsupervised', 'learning', '4.3', 'Semi-supervised', 'learning', '4.4', 'Reinforcement', 'learning', '4.5', 'Dimensionality', 'reduction', '4.6', 'Other', 'types', '4.6.1', 'Self-learning', '4.6.2', 'Feature', 'learning', '4.6.3', 'Sparse', 'dictionary', 'learning', '4.6.4', 'Anomaly', 'detection', '4.6.5', 'Robot', 'learning', '4.6.6', 'Association', 'rules', '4.7', 'Models', '4.7.1', 'Artificial', 'neural', 'networks', '4.7.2', 'Decision', 'trees', '4.7.3', 'Support-vector', 'machines', '4.7.4', 'Regression', 'analysis', '4.7.5', 'Bayesian', 'networks', '4.7.6', 'Gaussian', 'processes', '4.7.7', 'Genetic', 'algorithms', '4.8', 'Training', 'models', '4.8.1', 'Federated', 'learning', '5', 'Applications', '6', 'Limitations', 'Toggle', 'Limitations', 'subsection', '6.1', 'Bias', '6.2', 'Explainability', '6.3', 'Overfitting', '6.4', 'Other', 'limitations', 'and', 'vulnerabilities', '7', 'Model', 'assessments', '8', 'Ethics', '9', 'Hardware', 'Toggle', 'Hardware', 'subsection', '9.1', 'Neuromorphic/Physical', 'Neural', 'Networks', '9.2', 'Embedded', 'Machine', 'Learning', '10', 'Software', 'Toggle', 'Software', 'subsection', '10.1', 'Free', 'and', 'open-source', 'software', '10.2', 'Proprietary', 'software', 'with', 'free', 'and', 'open-source', 'editions', '10.3', 'Proprietary', 'software', '11', 'Journals', '12', 'Conferences', '13', 'See', 'also', '14', 'References', '15', 'Sources', '16', 'Further', 'reading', '17', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', 'Toggle', 'the', 'table', 'of', 'contents', 'Machine', 'learning', '73', 'languages', 'العربية', 'অসমীয়া', 'Azərbaycanca', 'বাংলা', 'Bân-lâm-gú', 'Беларуская', 'भोजपुरी', 'Български', 'བོད་ཡིག', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'الدارجة', 'Deutsch', 'Eesti', 'Ελληνικά', 'Español', 'Euskara', 'فارسی', 'Français', 'Galego', '한국어', 'Հայերեն', 'हिन्दी', 'Bahasa', 'Indonesia', 'IsiZulu', 'Íslenska', 'Italiano', 'עברית', 'ಕನ್ನಡ', 'Latviešu', 'Lietuvių', 'Magyar', 'Македонски', 'മലയാളം', 'मराठी', 'Bahasa', 'Melayu', 'Монгол', 'Nederlands', '日本語', 'Norsk', 'bokmål', 'Norsk', 'nynorsk', 'Occitan', 'ଓଡ଼ିଆ', 'پنجابی', 'Polski', 'Português', 'Română', 'Runa', 'Simi', 'Русский', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Shqip', 'Simple', 'English', 'Slovenščina', 'کوردی', 'Српски', '/', 'srpski', 'Srpskohrvatski', '/', 'српскохрватски', 'Suomi', 'Svenska', 'Tagalog', 'తెలుగు', 'ไทย', 'Türkçe', 'Українська', 'اردو', 'ئۇيغۇرچە', '/', 'Uyghurche', 'Tiếng', 'Việt', 'Võro', '吴语', '粵語', '中文', 'Edit', 'links', 'Article', 'Talk', 'English', 'Read', 'Edit', 'View', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'Read', 'Edit', 'View', 'history', 'General', 'What', 'links', 'here', 'Related', 'changes', 'Upload', 'file', 'Special', 'pages', 'Permanent', 'link', 'Page', 'information', 'Cite', 'this', 'page', 'Wikidata', 'item', 'Print/export', 'Download', 'as ...
# ---------------------------------
# ['Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'page', 'Contents', 'Current', 'events', 'Random', 'article', 'About', 'Wikipedia', 'Contact', 'us', 'Donate', 'Contribute', 'Help', 'Learn', 'edit', 'Community', 'portal', 'Recent', 'changes', 'Upload', 'file', 'Languages', 'Language', 'links', 'top', 'page', 'across', 'title', '.', 'Search', 'Create', 'account', 'Log', 'Personal', 'tools', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'Contributions', 'Talk', 'CentralNotice', 'Contents', 'move', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Overview', '2', 'History', 'relationships', 'fields', 'Toggle', 'History', 'relationships', 'fields', 'subsection', '2.1', 'Artificial', 'intelligence', '2.2', 'Data', 'mining', '2.3', 'Generalization', '2.4', 'Statistics', '2.5', 'Physics', '3', 'Theory', '4', 'Approaches', 'Toggle', 'Approaches', 'subsection', '4.1', 'Supervised', 'learning', '4.2', 'Unsupervised', 'learning', '4.3', 'Semi-supervised', 'learning', '4.4', 'Reinforcement', 'learning', '4.5', 'Dimensionality', 'reduction', '4.6', 'Other', 'types', '4.6.1', 'Self-learning', '4.6.2', 'Feature', 'learning', '4.6.3', 'Sparse', 'dictionary', 'learning', '4.6.4', 'Anomaly', 'detection', '4.6.5', 'Robot', 'learning', '4.6.6', 'Association', 'rules', '4.7', 'Models', '4.7.1', 'Artificial', 'neural', 'networks', '4.7.2', 'Decision', 'trees', '4.7.3', 'Support-vector', 'machines', '4.7.4', 'Regression', 'analysis', '4.7.5', 'Bayesian', 'networks', '4.7.6', 'Gaussian', 'processes', '4.7.7', 'Genetic', 'algorithms', '4.8', 'Training', 'models', '4.8.1', 'Federated', 'learning', '5', 'Applications', '6', 'Limitations', 'Toggle', 'Limitations', 'subsection', '6.1', 'Bias', '6.2', 'Explainability', '6.3', 'Overfitting', '6.4', 'Other', 'limitations', 'vulnerabilities', '7', 'Model', 'assessments', '8', 'Ethics', '9', 'Hardware', 'Toggle', 'Hardware', 'subsection', '9.1', 'Neuromorphic/Physical', 'Neural', 'Networks', '9.2', 'Embedded', 'Machine', 'Learning', '10', 'Software', 'Toggle', 'Software', 'subsection', '10.1', 'Free', 'open-source', 'software', '10.2', 'Proprietary', 'software', 'free', 'open-source', 'editions', '10.3', 'Proprietary', 'software', '11', 'Journals', '12', 'Conferences', '13', 'See', 'also', '14', 'References', '15', 'Sources', '16', 'Further', 'reading', '17', 'External', 'links', 'Toggle', 'table', 'contents', 'Toggle', 'table', 'contents', 'Machine', 'learning', '73', 'languages', 'العربية', 'অসমীয়া', 'Azərbaycanca', 'বাংলা', 'Bân-lâm-gú', 'Беларуская', 'भोजपुरी', 'Български', 'བོད་ཡིག', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'الدارجة', 'Deutsch', 'Eesti', 'Ελληνικά', 'Español', 'Euskara', 'فارسی', 'Français', 'Galego', '한국어', 'Հայերեն', 'हिन्दी', 'Bahasa', 'Indonesia', 'IsiZulu', 'Íslenska', 'Italiano', 'עברית', 'ಕನ್ನಡ', 'Latviešu', 'Lietuvių', 'Magyar', 'Македонски', 'മലയാളം', 'मराठी', 'Bahasa', 'Melayu', 'Монгол', 'Nederlands', '日本語', 'Norsk', 'bokmål', 'Norsk', 'nynorsk', 'Occitan', 'ଓଡ଼ିଆ', 'پنجابی', 'Polski', 'Português', 'Română', 'Runa', 'Simi', 'Русский', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Shqip', 'Simple', 'English', 'Slovenščina', 'کوردی', 'Српски', '/', 'srpski', 'Srpskohrvatski', '/', 'српскохрватски', 'Suomi', 'Svenska', 'Tagalog', 'తెలుగు', 'ไทย', 'Türkçe', 'Українська', 'اردو', 'ئۇيغۇرچە', '/', 'Uyghurche', 'Tiếng', 'Việt', 'Võro', '吴语', '粵語', '中文', 'Edit', 'links', 'Article', 'Talk', 'English', 'Read', 'Edit', 'View', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'Read', 'Edit', 'View', 'history', 'General', 'What', 'links', 'Related', 'changes', 'Upload', 'file', 'Special', 'pages', 'Permanent', 'link', 'Page', 'information', 'Cite', 'page', 'Wikidata', 'item', 'Print/export', 'Download', 'PDF', 'Printable', 'version', 'In', 'projects', 'Wikimedia', 'Commons', 'Wikiquote', 'Wikiversity', 'From', 'Wikipedia', ',', 'free', 'encyclopedia', 'Study', 'algorithms', 'improve', 'automatically', 'experience', 'For', 'journa ...
# ['Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'page', 'Contents', 'Current', 'events', 'Random', 'article', 'About', 'Wikipedia', 'Contact', 'us', 'Donate', 'Contribute', 'Help', 'Learn', 'to', 'edit', 'Community', 'portal', 'Recent', 'changes', 'Upload', 'file', 'Languages', 'Language', 'links', 'are', 'at', 'the', 'top', 'of', 'the', 'page', 'across', 'from', 'the', 'title', '.', 'Search', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'Contributions', 'Talk', 'CentralNotice', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Overview', '2', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'Toggle', 'History', 'and', 'relationships', 'to', 'other', 'fields', 'subsection', '2.1', 'Artificial', 'intelligence', '2.2', 'Data', 'mining', '2.3', 'Generalization', '2.4', 'Statistics', '2.5', 'Physics', '3', 'Theory', '4', 'Approaches', 'Toggle', 'Approaches', 'subsection', '4.1', 'Supervised', 'learning', '4.2', 'Unsupervised', 'learning', '4.3', 'Semi-supervised', 'learning', '4.4', 'Reinforcement', 'learning', '4.5', 'Dimensionality', 'reduction', '4.6', 'Other', 'types', '4.6.1', 'Self-learning', '4.6.2', 'Feature', 'learning', '4.6.3', 'Sparse', 'dictionary', 'learning', '4.6.4', 'Anomaly', 'detection', '4.6.5', 'Robot', 'learning', '4.6.6', 'Association', 'rules', '4.7', 'Models', '4.7.1', 'Artificial', 'neural', 'networks', '4.7.2', 'Decision', 'trees', '4.7.3', 'Support-vector', 'machines', '4.7.4', 'Regression', 'analysis', '4.7.5', 'Bayesian', 'networks', '4.7.6', 'Gaussian', 'processes', '4.7.7', 'Genetic', 'algorithms', '4.8', 'Training', 'models', '4.8.1', 'Federated', 'learning', '5', 'Applications', '6', 'Limitations', 'Toggle', 'Limitations', 'subsection', '6.1', 'Bias', '6.2', 'Explainability', '6.3', 'Overfitting', '6.4', 'Other', 'limitations', 'and', 'vulnerabilities', '7', 'Model', 'assessments', '8', 'Ethics', '9', 'Hardware', 'Toggle', 'Hardware', 'subsection', '9.1', 'Neuromorphic/Physical', 'Neural', 'Networks', '9.2', 'Embedded', 'Machine', 'Learning', '10', 'Software', 'Toggle', 'Software', 'subsection', '10.1', 'Free', 'and', 'open-source', 'software', '10.2', 'Proprietary', 'software', 'with', 'free', 'and', 'open-source', 'editions', '10.3', 'Proprietary', 'software', '11', 'Journals', '12', 'Conferences', '13', 'See', 'also', '14', 'References', '15', 'Sources', '16', 'Further', 'reading', '17', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', 'Toggle', 'the', 'table', 'of', 'contents', 'Machine', 'learning', '73', 'languages', 'العربية', 'অসমীয়া', 'Azərbaycanca', 'বাংলা', 'Bân-lâm-gú', 'Беларуская', 'भोजपुरी', 'Български', 'བོད་ཡིག', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'الدارجة', 'Deutsch', 'Eesti', 'Ελληνικά', 'Español', 'Euskara', 'فارسی', 'Français', 'Galego', '한국어', 'Հայերեն', 'हिन्दी', 'Bahasa', 'Indonesia', 'IsiZulu', 'Íslenska', 'Italiano', 'עברית', 'ಕನ್ನಡ', 'Latviešu', 'Lietuvių', 'Magyar', 'Македонски', 'മലയാളം', 'मराठी', 'Bahasa', 'Melayu', 'Монгол', 'Nederlands', '日本語', 'Norsk', 'bokmål', 'Norsk', 'nynorsk', 'Occitan', 'ଓଡ଼ିଆ', 'پنجابی', 'Polski', 'Português', 'Română', 'Runa', 'Simi', 'Русский', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Shqip', 'Simple', 'English', 'Slovenščina', 'کوردی', 'Српски', '/', 'srpski', 'Srpskohrvatski', '/', 'српскохрватски', 'Suomi', 'Svenska', 'Tagalog', 'తెలుగు', 'ไทย', 'Türkçe', 'Українська', 'اردو', 'ئۇيغۇرچە', '/', 'Uyghurche', 'Tiếng', 'Việt', 'Võro', '吴语', '粵語', '中文', 'Edit', 'links', 'Article', 'Talk', 'English', 'Read', 'Edit', 'View', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'Read', 'Edit', 'View', 'history', 'General', 'What', 'links', 'here', 'Related', 'changes', 'Upload', 'file', 'Special', 'pages', 'Permanent', 'link', 'Page', 'information', 'Cite', 'this', 'page', 'Wikidata', 'item', 'Print/export', 'Download', 'as ...
# ---------------------------------
# ['Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'page', 'Contents', 'Current', 'events', 'Random', 'article', 'Wikipedia', 'Contact', 'us', 'Donate', 'Contribute', 'Help', 'Learn', 'edit', 'Community', 'portal', 'Recent', 'changes', 'Upload', 'file', 'Languages', 'Language', 'links', 'top', 'page', 'across', 'title', '.', 'Search', 'Create', 'account', 'Log', 'Personal', 'tools', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'Contributions', 'Talk', 'CentralNotice', 'Contents', 'move', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Overview', '2', 'History', 'relationships', 'fields', 'Toggle', 'History', 'relationships', 'fields', 'subsection', '2.1', 'Artificial', 'intelligence', '2.2', 'Data', 'mining', '2.3', 'Generalization', '2.4', 'Statistics', '2.5', 'Physics', '3', 'Theory', '4', 'Approaches', 'Toggle', 'Approaches', 'subsection', '4.1', 'Supervised', 'learning', '4.2', 'Unsupervised', 'learning', '4.3', 'Semi-supervised', 'learning', '4.4', 'Reinforcement', 'learning', '4.5', 'Dimensionality', 'reduction', '4.6', 'types', '4.6.1', 'Self-learning', '4.6.2', 'Feature', 'learning', '4.6.3', 'Sparse', 'dictionary', 'learning', '4.6.4', 'Anomaly', 'detection', '4.6.5', 'Robot', 'learning', '4.6.6', 'Association', 'rules', '4.7', 'Models', '4.7.1', 'Artificial', 'neural', 'networks', '4.7.2', 'Decision', 'trees', '4.7.3', 'Support-vector', 'machines', '4.7.4', 'Regression', 'analysis', '4.7.5', 'Bayesian', 'networks', '4.7.6', 'Gaussian', 'processes', '4.7.7', 'Genetic', 'algorithms', '4.8', 'Training', 'models', '4.8.1', 'Federated', 'learning', '5', 'Applications', '6', 'Limitations', 'Toggle', 'Limitations', 'subsection', '6.1', 'Bias', '6.2', 'Explainability', '6.3', 'Overfitting', '6.4', 'limitations', 'vulnerabilities', '7', 'Model', 'assessments', '8', 'Ethics', '9', 'Hardware', 'Toggle', 'Hardware', 'subsection', '9.1', 'Neuromorphic/Physical', 'Neural', 'Networks', '9.2', 'Embedded', 'Machine', 'Learning', '10', 'Software', 'Toggle', 'Software', 'subsection', '10.1', 'Free', 'open-source', 'software', '10.2', 'Proprietary', 'software', 'free', 'open-source', 'editions', '10.3', 'Proprietary', 'software', '11', 'Journals', '12', 'Conferences', '13', 'See', 'also', '14', 'References', '15', 'Sources', '16', 'reading', '17', 'External', 'links', 'Toggle', 'table', 'contents', 'Toggle', 'table', 'contents', 'Machine', 'learning', '73', 'languages', 'العربية', 'অসমীয়া', 'Azərbaycanca', 'বাংলা', 'Bân-lâm-gú', 'Беларуская', 'भोजपुरी', 'Български', 'བོད་ཡིག', 'Bosanski', 'Català', 'Čeština', 'Cymraeg', 'Dansk', 'الدارجة', 'Deutsch', 'Eesti', 'Ελληνικά', 'Español', 'Euskara', 'فارسی', 'Français', 'Galego', '한국어', 'Հայերեն', 'हिन्दी', 'Bahasa', 'Indonesia', 'IsiZulu', 'Íslenska', 'Italiano', 'עברית', 'ಕನ್ನಡ', 'Latviešu', 'Lietuvių', 'Magyar', 'Македонски', 'മലയാളം', 'मराठी', 'Bahasa', 'Melayu', 'Монгол', 'Nederlands', '日本語', 'Norsk', 'bokmål', 'Norsk', 'nynorsk', 'Occitan', 'ଓଡ଼ିଆ', 'پنجابی', 'Polski', 'Português', 'Română', 'Runa', 'Simi', 'Русский', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Shqip', 'Simple', 'English', 'Slovenščina', 'کوردی', 'Српски', '/', 'srpski', 'Srpskohrvatski', '/', 'српскохрватски', 'Suomi', 'Svenska', 'Tagalog', 'తెలుగు', 'ไทย', 'Türkçe', 'Українська', 'اردو', 'ئۇيغۇرچە', '/', 'Uyghurche', 'Tiếng', 'Việt', 'Võro', '吴语', '粵語', '中文', 'Edit', 'links', 'Article', 'Talk', 'English', 'Read', 'Edit', 'View', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'Read', 'Edit', 'View', 'history', 'General', 'links', 'Related', 'changes', 'Upload', 'file', 'Special', 'pages', 'Permanent', 'link', 'Page', 'information', 'Cite', 'page', 'Wikidata', 'item', 'Print/export', 'Download', 'PDF', 'Printable', 'version', 'projects', 'Wikimedia', 'Commons', 'Wikiquote', 'Wikiversity', 'Wikipedia', ',', 'free', 'encyclopedia', 'Study', 'algorithms', 'improve', 'automatically', 'experience', 'journal', ',', 'see', 'Machine', 'Learning', '(', 'journal', ')', '.', '` ...
# C:\Users\Hashim\AppData\Local\Temp\ipykernel_6740\920451373.py:16: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)

# %%
# from nltk.data import url2pathname
# import nltk
# nltk.download('stopwords')

# from nltk.corpus import stopwords
# from nltk.tokenize import word_tokenize

# stop_words = set(stopwords.words('english'))
# print(len(stop_words))
# stop_words

# import nltk
# nltk.download('punkt')
# # example_sent = get_text('https://en.wikipedia.org/wiki/Machine_learning')
# stop_words = set(stopwords.words('english'))

# links=scrape_google('tote bags')

# text=[]
# for i in links:
#   t=get_text(i)
#   if t:
#     text.append(t)

#     word_tokens = word_tokenize(t)
# # word_tokens = 

#     # filtered_sentence = [w for w in word_tokens]

#     # print(word_tokens)
#     # print('---------------------------------')
#     # print(filtered_sentence)

#     # filtered_sentence = [w for w in word_tokens if not w in stop_words]

#     # print(word_tokens)
#  # print('---------------------------------')
#     # print(filtered_sentence)
#     filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

#     print(word_tokens)
#     print('---------------------------------')
#     print(filtered_sentence)

# %%
# import nltk

# from nltk.stem.porter import *
# p_stemmer = PorterStemmer()

# words = ['run','runner','running','ran','runs','easily','fairly']

# for word in words:
#     print(word+' --> '+p_stemmer.stem(word))

# from nltk.stem.snowball import SnowballStemmer
# s_stemmer = SnowballStemmer(language='english')

# words = ['run','runner','running','ran','runs','easily','fairly']

# for word in words:
#     print(word+' --> '+s_stemmer.stem(word))

# %% [markdown]
# stemming

# %%
# import these modules
# from nltk.stem import PorterStemmer
# from nltk.tokenize import word_tokenize
  
# ps = PorterStemmer()
  
# # choose some words to be stemmed
# #words = ["program", "programs", "programmer", "programming", "programmers"]
# words = get_text('https://google.com')

# for w in words:
#     print(words,':', ps.stem(words))

##############################################

# %% [markdown]
# Step 2: Get the URLs from competitors

# %%
# def google_results(keyword, n_results):
#     query = keyword
#     query = urllib.parse.quote_plus(query) # Format into URL encoding
#     number_result = n_results
#     ua = UserAgent()
#     google_url = "https://www.google.com/search?q=" + query + "&num=" + str(number_result)
#     response = requests.get(google_url, {"User-Agent": ua.random})
#     soup = BeautifulSoup(response.text, "html.parser")
#     result_div = soup.find_all('div', attrs = {'class': 'ZINbbc'})
#     results=[re.search('\/url\?q\=(.*)\&sa',str(i.find('a', href = True)['href'])) for i in result_div if "url" in str(i)]
#     links=[i.group(1) for i in results if i != None]
#     return (soup)

# %%
# google_results('machine learning',10)

# %%
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        #  response = requests.get(url)
        # content = response.content
        # soup = BeautifulSoup(content, "html.parser")
       
        return response
    except requests.exceptions.RequestException as e:
        print(e)
def scrape_google(query):

    query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.co.uk/search?q=" + query)
    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.')

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
scrape_google("cars")
# Out:
# ['https://www.cars.com/',
#  'https://www.cars.com/research/compare/',
#  'https://www.cars.com/research/',
#  'https://www.imdb.com/title/tt0317219/fullcredits',
#  'https://eg.hatla2ee.com/en/car',
#  'https://www.masrawy.com/news/news_cases/details/2023/5/12/2412142/-%D8%A7%D9%84%D9%86%D8%B4%D8%B1%D8%A9-%D8%A7%D9%84%D9%85%D8%B1%D9%88%D8%B1%D9%8A%D8%A9-%D8%A7%D9%86%D8%AA%D8%B8%D8%A7%D9%85-%D8%AD%D8%B1%D9%83%D8%A9-%D8%A7%D9%84%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA-%D8%A8%D9%85%D8%AD%D8%A7%D9%88%D8%B1-%D9%88%D9%85%D9%8A%D8%A7%D8%AF%D9%8A%D9%86-%D8%A7%D9%84%D9%82%D8%A7%D9%87%D8%B1%D8%A9-%D9%88%D8%A7%D9%84%D8%AC%D9%8A%D8%B2%D8%A9',
#  'https://translate.google.com/translate?hl=ar&sl=en&u=https://eg.hatla2ee.com/en/car&prev=search&pto=aue',
#  'https://www.imdb.com/video/vi365149977/',
#  'https://cars.disney.com/',
#  'https://translate.google.com/translate?hl=ar&sl=en&u=https://www.contactcars.com/en/newcars&prev=search&pto=aue',
#  'https://www.youm7.com/story/2023/5/12/%D9%85%D8%AA%D9%87%D9%85%D8%A7%D9%86-%D8%A8%D8%B3%D8%B1%D9%82%D8%A9-%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA-%D9%81%D9%89-%D8%A7%D9%84%D9%82%D8%A7%D9%87%D8%B1%D8%A9-%D9%8A%D8%B9%D8%AA%D8%B1%D9%81%D8%A7%D9%86-%D8%A8%D8%AA%D9%82%D8%B7%D9%8A%D8%B9%D9%87%D8%A7-%D9%88%D8%A8%D9%8A%D8%B9%D9%87%D8%A7-%D9%84%D8%AA%D8%AC%D8%A7%D8%B1-%D8%A7%D9%84%D8%AE%D8%B1%D8%AF%D8%A9/6177831',
#  'https://www.olx.com.eg/en/vehicles/cars-for-sale/',
#  'https://www.youtube.com/watch?v=SbXIj2T-_uk',
#  'https://egypt.yallamotor.com/',
#  'https://translate.google.com/translate?hl=ar&sl=en&u=https://egypt.yallamotor.com/&prev=search&pto=aue',
#  'https://translate.google.com/translate?hl=ar&sl=en&u=https://www.imdb.com/title/tt0317219/&prev=search&pto=aue',
#  'https://www.contactcars.com/en/newcars',
#  'https://www.imdb.com/title/tt0317219/',
#  'https://www.youm7.com/story/2023/5/12/%D8%A7%D9%84%D9%86%D8%B4%D8%B1%D8%A9-%D8%A7%D9%84%D9%85%D8%B1%D9%88%D8%B1%D9%8A%D8%A9-%D8%B3%D9%8A%D9%88%D9%84%D8%A9-%D8%A8%D8%AD%D8%B1%D9%83%D8%A9-%D8%A7%D9%84%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA-%D9%81%D9%89-%D8%B4%D9%88%D8%A7%D8%B1%D8%B9-%D9%88%D9%85%D9%8A%D8%A7%D8%AF%D9%8A%D9%86-%D8%A7%D9%84%D9%82%D8%A7%D9%87%D8%B1%D8%A9-%D9%88%D8%A7%D9%84%D8%AC%D9%8A%D8%B2%D8%A9/6177627',
#  'https://www.imdb.com/title/tt1216475/',
#  'https://translate.google.com/translate?hl=ar&sl=en&u=https://www.cars.com/&prev=search&pto=aue',
#  'https://www.youtube.com/watch?v=vFcIPBvKsWI',
#  'https://www.youtube.com/watch?v=fdGWRq1dVBA',
#  'https://m.imdb.com/title/tt0317219/fullcredits/cast',
#  'https://www.cars.com/shopping/',
#  'https://www.cars.com/sell/']

# %% [markdown]
# Step 3: Analyse the text and get the most important words.

# %%
# def tf_idf_analysis(keyword):
#     # links=google_results(keyword,12)
#     links=scrape_google(keyword)

#     text=[]
#     for i in links:
#         t=get_text(i)
#         if t:
#             text.append(t)
            
#     v = TfidfVectorizer(min_df=2,analyzer='word',ngram_range=(1,2),stop_words=stopWords)
#     x = v.fit_transform(text)

#     f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
#     d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
#     tf=pd.DataFrame((f>0).sum(axis=0))


#     d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

#     d.columns=['word','average_tfidf','max_tfidf','frequency']


# #you can comment the following part if you want the number of URLs that the word occurs. The percentage makes sense
# #when we have a lot of URLs to check

#     d['frequency']=round((d['frequency']/len(text))*100)

#     return(d)


# x= tf_idf_analysis('tote bags')
# x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)

# %%
from nltk.data import url2pathname
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup


stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words

import nltk
nltk.download('punkt')
# example_sent = get_text('https://en.wikipedia.org/wiki/Machine_learning')
stop_words = set(stopwords.words('english'))

links=scrape_google('cars')

text=[]
for i in links:
  t=get_text(i)
  if t:
    text.append(t)

    word_tokens = word_tokenize(t)
# word_tokens = 

    filtered_sentence = [w for w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)

    filtered_sentence = [w for w in word_tokens if not w in stop_words]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

    print(word_tokens)
    print('---------------------------------')
    print(filtered_sentence)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Hashim\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hashim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 179
# C:\Users\Hashim\AppData\Local\Temp\ipykernel_6740\920451373.py:16: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# ['[', 'if', 'IE', ']', '>', '<', 'link', 'rel=', "''", 'stylesheet', "''", 'type=', "''", 'text/css', "''", 'href=', "''", 'https', ':', '//m.media-amazon.com/images/S/sash/pXHSPBTKPo0GIjW.css', "''", '/', '>', '<', '!', '[', 'endif', ']', 'begin', 'SRA', 'begin', 'ads', 'header', 'Include', 'the', 'CREM', 'library', 'for', 'MRC', 'logic', 'end', 'ads', 'header', 'begin', 'sis', 'pixel', 'slot', 'Begin', 'SIS', 'code', 'End', 'SIS', 'code', 'begin', 'comscore', 'beacon', 'end', 'comscore', 'beacon', 'end', 'sis', 'pixel', 'slot', 'Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Lantern', 'slotname', 'top_ad', 'Lantern', 'placement', 'id', ':', 'begin', 'TOP_AD', 'End', 'TOP_AD', 'no', 'content', 'received', 'for', 'slot', ':', 'navstrip', 'begin', 'INJECTED_NAVSTRIP', 'End', 'INJECTED_NAVSTRIP', 'begin', 'INJECTED_BILLBOARD', 'End', 'INJECTED_BILLBOARD', 'Edit', 'Cars', '(', '2006', ')', 'Full', 'Cast', '&', 'Crew', 'See', 'agents', 'for', 'this', 'cast', '&', 'crew', 'on', 'IMDbPro', 'Directed', 'by', 'John', 'Lasseter', 'Joe', 'Ranft', '...', '(', 'co-director', ')', 'Writing', 'Credits', 'John', 'Lasseter', '...', '(', 'original', 'story', 'by', ')', '&', 'Joe', 'Ranft', '...', '(', 'original', 'story', 'by', ')', '&', 'Jorgen', 'Klubien', '...', '(', 'original', 'story', 'by', ')', 'Dan', 'Fogelman', '...', '(', 'screenplay', 'by', ')', 'and', 'John', 'Lasseter', '...', '(', 'screenplay', 'by', ')', 'and', 'Joe', 'Ranft', '...', '(', 'screenplay', 'by', ')', 'and', 'Kiel', 'Murray', '...', '(', 'screenplay', 'by', ')', '&', 'Phil', 'Lorin', '...', '(', 'screenplay', 'by', ')', 'and', 'Jorgen', 'Klubien', '...', '(', 'screenplay', 'by', ')', 'Cast', '(', 'in', 'credits', 'order', ')', 'verified', 'as', 'complete', 'Owen', 'Wilson', '...', 'Lightning', 'McQueen', '(', 'voice', ')', 'Paul', 'Newman', '...', 'Doc', 'Hudson', '(', 'voice', ')', 'Bonnie', 'Hunt', '...', 'Sally', 'Carrera', '(', 'voice', ')', 'Larry', 'the', 'Cable', 'Guy', '...', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', '...', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', '...', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', '...', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', '...', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', '...', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', '...', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', '...', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', '...', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', '...', 'Mack', '/', 'Hamm', 'Truck', '/', 'Abominable', 'Snow', 'Plow', '/', 'P.T', '.', 'Flea', 'Car', '(', 'voice', ')', 'Joe', 'Ranft', '...', 'Red', '/', 'Jerry', 'Recycled', 'Ba ...
# ---------------------------------
# ['[', 'IE', ']', '>', '<', 'link', 'rel=', "''", 'stylesheet', "''", 'type=', "''", 'text/css', "''", 'href=', "''", 'https', ':', '//m.media-amazon.com/images/S/sash/pXHSPBTKPo0GIjW.css', "''", '/', '>', '<', '!', '[', 'endif', ']', 'begin', 'SRA', 'begin', 'ads', 'header', 'Include', 'CREM', 'library', 'MRC', 'logic', 'end', 'ads', 'header', 'begin', 'sis', 'pixel', 'slot', 'Begin', 'SIS', 'code', 'End', 'SIS', 'code', 'begin', 'comscore', 'beacon', 'end', 'comscore', 'beacon', 'end', 'sis', 'pixel', 'slot', 'Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Lantern', 'slotname', 'top_ad', 'Lantern', 'placement', 'id', ':', 'begin', 'TOP_AD', 'End', 'TOP_AD', 'content', 'received', 'slot', ':', 'navstrip', 'begin', 'INJECTED_NAVSTRIP', 'End', 'INJECTED_NAVSTRIP', 'begin', 'INJECTED_BILLBOARD', 'End', 'INJECTED_BILLBOARD', 'Edit', 'Cars', '(', '2006', ')', 'Full', 'Cast', '&', 'Crew', 'See', 'agents', 'cast', '&', 'crew', 'IMDbPro', 'Directed', 'John', 'Lasseter', 'Joe', 'Ranft', '...', '(', 'co-director', ')', 'Writing', 'Credits', 'John', 'Lasseter', '...', '(', 'original', 'story', ')', '&', 'Joe', 'Ranft', '...', '(', 'original', 'story', ')', '&', 'Jorgen', 'Klubien', '...', '(', 'original', 'story', ')', 'Dan', 'Fogelman', '...', '(', 'screenplay', ')', 'John', 'Lasseter', '...', '(', 'screenplay', ')', 'Joe', 'Ranft', '...', '(', 'screenplay', ')', 'Kiel', 'Murray', '...', '(', 'screenplay', ')', '&', 'Phil', 'Lorin', '...', '(', 'screenplay', ')', 'Jorgen', 'Klubien', '...', '(', 'screenplay', ')', 'Cast', '(', 'credits', 'order', ')', 'verified', 'complete', 'Owen', 'Wilson', '...', 'Lightning', 'McQueen', '(', 'voice', ')', 'Paul', 'Newman', '...', 'Doc', 'Hudson', '(', 'voice', ')', 'Bonnie', 'Hunt', '...', 'Sally', 'Carrera', '(', 'voice', ')', 'Larry', 'Cable', 'Guy', '...', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', '...', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', '...', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', '...', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', '...', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', '...', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', '...', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', '...', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', '...', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', '...', 'Mack', '/', 'Hamm', 'Truck', '/', 'Abominable', 'Snow', 'Plow', '/', 'P.T', '.', 'Flea', 'Car', '(', 'voice', ')', 'Joe', 'Ranft', '...', 'Red', '/', 'Jerry', 'Recycled', 'Batteries', '/', 'Peterbilt', '(', 'voice', ')', 'Michael', 'Keaton', '...', 'Chick', 'Hicks', '(', 'voice', ')', 'Richard', 'Petty', '...', 'King', '(', 'voice', ')', 'Jeremy', 'Piven', '...', 'Harv', '(', 'voice', ')', 'Bob', 'Costas', '...', 'Bob', 'Cutlass', '(', ' ...
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'My', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Other', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'More', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'My', 'Cars', '(', 'My', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Out', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'My', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'More', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Your', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'My', 'Account', 'Settings', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Log', 'Out', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'up', 'Create', 'a', 'New', 'Account', 'Or', ',', 'you', 'already', 'have', 'an', 'account', '!', 'Mobile', 'number', ',', 'Email', 'or', 'Username', 'Password', 'Reset', 'Your', 'Password', 'Cars', 'for', 'sale', 'Find', 'used', 'car', 'for', 'sale', 'in', 'Egypt', 'Choose', 'a', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'For', 'Sale', 'Hyundai', '(', '1653', ')', 'Chevrolet', '(', '1211', ')', 'Nissan', '(', '1058', ')', 'Fiat', '(', '1038', ')', 'Kia', '(', '953', ')', 'Renault', '(', '716', ')', 'Toyota', '(', '639', ')', 'Mitsubishi', '(', '613', ')', 'Mercedes', '(', '530', ')', 'Opel', '(', '461', ')', 'Peugeot', '(', '453', ')', 'Skoda', '(', '441', ')', 'Other', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '10365', ')', 'SUV', '(', '2005', ')', 'Hatchback', '(', '1632', ')', '4x4', '(', '446', ')', 'MiniVans', '(', '320', ')', 'Coupe', '(', '77', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', ' ...
# ---------------------------------
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'Cars', '(', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'Cars', '(', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'Account', 'Settings', 'Cars', '(', 'Ads', ')', 'Log', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'Create', 'New', 'Account', ',', 'already', 'account', '!', 'Mobile', 'number', ',', 'Email', 'Username', 'Password', 'Reset', 'Password', 'Cars', 'sale', 'Find', 'used', 'car', 'sale', 'Egypt', 'Choose', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'Sale', 'Hyundai', '(', '1653', ')', 'Chevrolet', '(', '1211', ')', 'Nissan', '(', '1058', ')', 'Fiat', '(', '1038', ')', 'Kia', '(', '953', ')', 'Renault', '(', '716', ')', 'Toyota', '(', '639', ')', 'Mitsubishi', '(', '613', ')', 'Mercedes', '(', '530', ')', 'Opel', '(', '461', ')', 'Peugeot', '(', '453', ')', 'Skoda', '(', '441', ')', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '10365', ')', 'SUV', '(', '2005', ')', 'Hatchback', '(', '1632', ')', '4x4', '(', '446', ')', 'MiniVans', '(', '320', ')', 'Coupe', '(', '77', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', '3000', 'CC', '72', '4000', 'CC', '83', '5000', 'CC', '5', '6000', 'CC', '13', 'Select', 'make', 'Alfa', 'Romeo', 'Aston', 'Martin', 'Audi', 'Baic', 'Bentley', 'Bestune', 'BMW', 'Brilliance', 'Bugatti', 'Buick', 'Byd', 'Cadil ...
# ['الجمعة', '12', 'مايو', '2023', 'مصراوي', 'لايف', 'الأكثر', 'قراءة', 'الآن', 'أرشيف', 'مصراوى', 'مواقيت', 'الصلاة', '27', 'القاهرة', '-', 'مصر', '27', '17', 'الرطوبة', ':', '32', '%', 'الرياح', ':', 'شمال', 'غرب', 'المزيد', 'أسعار', 'العملات', 'سعر', 'صرف', 'الدولار', 'مقابل', 'الجنيه', 'المصري', 'الجمعة', '12', 'مايو', '2023', '30.89', 'جنيه', 'المزيد', 'أسعار', 'الذهب', 'سعر', 'جرام', 'الذهب', 'عيار', '21', 'الجمعة', '12', 'مايو', '2023', '2455', 'جنيه', 'المزيد', 'سوق', 'مصراوي', 'للإعــلان', 'أكثر', 'الكلمات', 'انتشاراً', 'الملك', 'تشارلز', 'امتحانات', 'الثانوية', '2023', 'أحداث', 'السودان', 'سعر', 'الذهب', 'الحوار', 'الوطني', 'الطقس', 'أمازون', 'سعر', 'الدولار', 'سعر', 'الفائدة', 'تم', 'إكتشاف', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", 'عزيزي', 'المستخدم', 'العائد', 'من', 'الإعلانات', 'يمثل', 'مصدر', 'الربح', 'الأساسي', 'للموقع', 'والعاملين', 'به', 'مما', 'يساعدنا', 'على', 'البقاء', 'مستقلين', 'وحياديين', 'حيث', 'أننا', 'غير', 'تابعين', 'لأي', 'جهة', 'حكومية', 'أو', 'حزب', '.', 'لمساعدتنا', 'على', 'الإستمرار', 'في', 'إنتاج', 'محتوى', 'مهني', 'صحفي', 'حيادي', 'غير', 'موجه', 'أو', 'ممول', 'نرجو', 'إلغاء', 'تفعيل', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", '.', 'شكرا', 'لتفهمك', 'إعلان', 'الرئيسية', 'أخبار', 'حوادث', 'وقضايا', 'النشرة', 'المرورية', '..', 'انتظام', 'حركة', 'السيارات', 'بمحاور', 'وميادين', 'القاهرة', 'والجيزة', '09:17', 'ص', 'الجمعة', '12', 'مايو', '2023', 'سيولة', 'مرورية-أرشيفية', 'تابع', 'صفحتنا', 'على', 'أخبار', 'جوجل', 'تابع', 'صفحتنا', 'على', 'فيسبوك', 'تابع', 'صفحتنا', 'على', 'يوتيوب', 'كتب-', 'علاء', 'عمران', ':', 'تشهد', 'الطرق', 'الرئيسية', 'في', 'محافظتي', 'القاهرة', 'والجيزة،', 'خلال', 'الذروة', 'الأولى،', 'من', 'صباح', 'اليوم', 'الجمعة،', 'سيولة', 'مرورية', 'بحركة', 'السير', 'وسط', 'تواجد', 'أمني', 'في', 'الشوارع', 'والميادين', 'لملاحظة', 'حركة', 'السيارات', '.', 'وظهر', 'انسياب', 'في', 'حركة', 'السير', 'بميدان', 'التحرير', 'ومنطقة', 'وسط', 'القاهرة،', 'مع', 'انتظام', 'حركة', 'سير', 'السيارات', 'بجميع', 'المداخل', 'المؤدية', 'للميدان،', 'كما', 'ظهرت', 'سيولة', 'مرورية', 'أعلى', 'مناطق', 'كورنيش', 'النيل،', 'وكذلك', 'للمتجه', 'إلى', 'مناطق', 'حلوان', 'والملك', 'الصالح', '.', 'وانتظمت', 'حركة', 'السيارات', 'أعلى', 'الطريق', 'الدائري', 'ومحور', '26', 'يوليو،', 'كما', 'يشهد', 'كوبري', 'أكتوبر', 'وميدان', 'روكسي', 'ورمسيس', 'وعبد', 'المنعم', 'رياض', 'ومناطق', 'وسط', 'البلد', 'انتظامًا', 'بحركة', 'السيارات', '.', 'وشهدت', 'حركة', 'السيارات،', 'أعلى', 'محاور', 'الجيزة،', 'انتظامًا', 'بشوارع', 'الجيزة', 'والنيل', 'السياحي،', 'والهرم', 'والبحر', 'الأعظم،', 'ونزلة', 'الدائري', 'اتجاه', 'الصعيد،', 'والوراق', 'والمريوطية،', 'وسط', 'انتشار', 'الخدمات', 'بكل', 'الطرق', '.', 'وانتظمت', 'حركة', 'السيارات', 'بالطريق', 'الزراعي', 'أمام', 'القادم', 'من', 'مدينة', 'بنها', 'وفي', 'طريقه', 'إلى', 'ميدان', 'المؤسسة', 'ومنطقة', 'المظلات،', 'وكذلك', 'بطول', 'كورنيش', 'النيل', 'من', 'منطقة', 'المظلات', 'وحتى', 'ميدان', 'عبد', 'المنعم', 'رياض،', 'وسط', 'تواجد', 'رجال', 'المرور', 'لمتابعة', 'الحركة', 'المرورية', '.', 'وتتابع', 'غرفة', 'عمليات', 'الإدارة', 'العامة', 'لمرور', 'حركة', 'السيارات', 'أعلى', 'المحاور', 'والميادين،', 'بواسطة', 'الخدمات', 'المرورية', 'المنتشرة', 'على', 'الطرق،', 'كما', 'يتم', 'مراقبة', 'حركة', 'السيارات', 'بواسطة', 'كاميرات', 'المراقبة،', 'لرصد', 'أي', 'كثافات', 'مرورية', 'بالمحاور', 'مع', 'نشر', 'الأوناش', 'المرورية', 'بالطرق', 'لرفع', 'أي', 'معوقات', 'مرورية', 'سواء', 'الحوادث', 'أو', 'الأعطال', '.', 'كما', 'تم', 'التنسيق', 'مع', 'إدارات', 'المرور', 'على', 'مستوى', 'الجمهورية', 'للدفع', 'بالخدمات', 'المرورية', 'وسيارات', 'الإغاثة', 'المرورية', 'والدراجات', 'البخارية', 'والتنسيق', 'مع', 'غرفة', 'عمليات', 'الإدارة', 'العامة', 'للمرور', 'للإخطار', 'أول', 'بأول', 'عن', 'حالة', 'الطرق', '.', 'سوق', 'مصراوى', 'بقسط', 'يبدأ', '171', 'جنيها', 'شهرياً', '..', 'أفضل', 'لاب', 'توب', 'للعمل', 'والدراسة', 'تفاصيل', 'أفضل', 'مشروبات', 'لحرق', 'الدهون', 'الزائدة', 'بدون', 'رجيم', 'تبدأ', 'من', '27', 'جنيها', 'تفاصيل', 'أفضل', 'شنطة', 'وقبعة', 'للشاطئ', 'لصيف', '2023', '..', 'تبدأ', 'من', '99', 'جنيه ...
# ---------------------------------
# ['الجمعة', '12', 'مايو', '2023', 'مصراوي', 'لايف', 'الأكثر', 'قراءة', 'الآن', 'أرشيف', 'مصراوى', 'مواقيت', 'الصلاة', '27', 'القاهرة', '-', 'مصر', '27', '17', 'الرطوبة', ':', '32', '%', 'الرياح', ':', 'شمال', 'غرب', 'المزيد', 'أسعار', 'العملات', 'سعر', 'صرف', 'الدولار', 'مقابل', 'الجنيه', 'المصري', 'الجمعة', '12', 'مايو', '2023', '30.89', 'جنيه', 'المزيد', 'أسعار', 'الذهب', 'سعر', 'جرام', 'الذهب', 'عيار', '21', 'الجمعة', '12', 'مايو', '2023', '2455', 'جنيه', 'المزيد', 'سوق', 'مصراوي', 'للإعــلان', 'أكثر', 'الكلمات', 'انتشاراً', 'الملك', 'تشارلز', 'امتحانات', 'الثانوية', '2023', 'أحداث', 'السودان', 'سعر', 'الذهب', 'الحوار', 'الوطني', 'الطقس', 'أمازون', 'سعر', 'الدولار', 'سعر', 'الفائدة', 'تم', 'إكتشاف', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", 'عزيزي', 'المستخدم', 'العائد', 'من', 'الإعلانات', 'يمثل', 'مصدر', 'الربح', 'الأساسي', 'للموقع', 'والعاملين', 'به', 'مما', 'يساعدنا', 'على', 'البقاء', 'مستقلين', 'وحياديين', 'حيث', 'أننا', 'غير', 'تابعين', 'لأي', 'جهة', 'حكومية', 'أو', 'حزب', '.', 'لمساعدتنا', 'على', 'الإستمرار', 'في', 'إنتاج', 'محتوى', 'مهني', 'صحفي', 'حيادي', 'غير', 'موجه', 'أو', 'ممول', 'نرجو', 'إلغاء', 'تفعيل', 'مانع', 'الإعلانات', '``', 'AD', 'Block', "''", '.', 'شكرا', 'لتفهمك', 'إعلان', 'الرئيسية', 'أخبار', 'حوادث', 'وقضايا', 'النشرة', 'المرورية', '..', 'انتظام', 'حركة', 'السيارات', 'بمحاور', 'وميادين', 'القاهرة', 'والجيزة', '09:17', 'ص', 'الجمعة', '12', 'مايو', '2023', 'سيولة', 'مرورية-أرشيفية', 'تابع', 'صفحتنا', 'على', 'أخبار', 'جوجل', 'تابع', 'صفحتنا', 'على', 'فيسبوك', 'تابع', 'صفحتنا', 'على', 'يوتيوب', 'كتب-', 'علاء', 'عمران', ':', 'تشهد', 'الطرق', 'الرئيسية', 'في', 'محافظتي', 'القاهرة', 'والجيزة،', 'خلال', 'الذروة', 'الأولى،', 'من', 'صباح', 'اليوم', 'الجمعة،', 'سيولة', 'مرورية', 'بحركة', 'السير', 'وسط', 'تواجد', 'أمني', 'في', 'الشوارع', 'والميادين', 'لملاحظة', 'حركة', 'السيارات', '.', 'وظهر', 'انسياب', 'في', 'حركة', 'السير', 'بميدان', 'التحرير', 'ومنطقة', 'وسط', 'القاهرة،', 'مع', 'انتظام', 'حركة', 'سير', 'السيارات', 'بجميع', 'المداخل', 'المؤدية', 'للميدان،', 'كما', 'ظهرت', 'سيولة', 'مرورية', 'أعلى', 'مناطق', 'كورنيش', 'النيل،', 'وكذلك', 'للمتجه', 'إلى', 'مناطق', 'حلوان', 'والملك', 'الصالح', '.', 'وانتظمت', 'حركة', 'السيارات', 'أعلى', 'الطريق', 'الدائري', 'ومحور', '26', 'يوليو،', 'كما', 'يشهد', 'كوبري', 'أكتوبر', 'وميدان', 'روكسي', 'ورمسيس', 'وعبد', 'المنعم', 'رياض', 'ومناطق', 'وسط', 'البلد', 'انتظامًا', 'بحركة', 'السيارات', '.', 'وشهدت', 'حركة', 'السيارات،', 'أعلى', 'محاور', 'الجيزة،', 'انتظامًا', 'بشوارع', 'الجيزة', 'والنيل', 'السياحي،', 'والهرم', 'والبحر', 'الأعظم،', 'ونزلة', 'الدائري', 'اتجاه', 'الصعيد،', 'والوراق', 'والمريوطية،', 'وسط', 'انتشار', 'الخدمات', 'بكل', 'الطرق', '.', 'وانتظمت', 'حركة', 'السيارات', 'بالطريق', 'الزراعي', 'أمام', 'القادم', 'من', 'مدينة', 'بنها', 'وفي', 'طريقه', 'إلى', 'ميدان', 'المؤسسة', 'ومنطقة', 'المظلات،', 'وكذلك', 'بطول', 'كورنيش', 'النيل', 'من', 'منطقة', 'المظلات', 'وحتى', 'ميدان', 'عبد', 'المنعم', 'رياض،', 'وسط', 'تواجد', 'رجال', 'المرور', 'لمتابعة', 'الحركة', 'المرورية', '.', 'وتتابع', 'غرفة', 'عمليات', 'الإدارة', 'العامة', 'لمرور', 'حركة', 'السيارات', 'أعلى', 'المحاور', 'والميادين،', 'بواسطة', 'الخدمات', 'المرورية', 'المنتشرة', 'على', 'الطرق،', 'كما', 'يتم', 'مراقبة', 'حركة', 'السيارات', 'بواسطة', 'كاميرات', 'المراقبة،', 'لرصد', 'أي', 'كثافات', 'مرورية', 'بالمحاور', 'مع', 'نشر', 'الأوناش', 'المرورية', 'بالطرق', 'لرفع', 'أي', 'معوقات', 'مرورية', 'سواء', 'الحوادث', 'أو', 'الأعطال', '.', 'كما', 'تم', 'التنسيق', 'مع', 'إدارات', 'المرور', 'على', 'مستوى', 'الجمهورية', 'للدفع', 'بالخدمات', 'المرورية', 'وسيارات', 'الإغاثة', 'المرورية', 'والدراجات', 'البخارية', 'والتنسيق', 'مع', 'غرفة', 'عمليات', 'الإدارة', 'العامة', 'للمرور', 'للإخطار', 'أول', 'بأول', 'عن', 'حالة', 'الطرق', '.', 'سوق', 'مصراوى', 'بقسط', 'يبدأ', '171', 'جنيها', 'شهرياً', '..', 'أفضل', 'لاب', 'توب', 'للعمل', 'والدراسة', 'تفاصيل', 'أفضل', 'مشروبات', 'لحرق', 'الدهون', 'الزائدة', 'بدون', 'رجيم', 'تبدأ', 'من', '27', 'جنيها', 'تفاصيل', 'أفضل', 'شنطة', 'وقبعة', 'للشاطئ', 'لصيف', '2023', '..', 'تبدأ', 'من', '99', 'جنيه ...
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'My', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Other', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'More', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'My', 'Cars', '(', 'My', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Out', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'My', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'More', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Your', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'My', 'Account', 'Settings', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Log', 'Out', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'up', 'Create', 'a', 'New', 'Account', 'Or', ',', 'you', 'already', 'have', 'an', 'account', '!', 'Mobile', 'number', ',', 'Email', 'or', 'Username', 'Password', 'Reset', 'Your', 'Password', 'Cars', 'for', 'sale', 'Find', 'used', 'car', 'for', 'sale', 'in', 'Egypt', 'Choose', 'a', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'For', 'Sale', 'Hyundai', '(', '1653', ')', 'Chevrolet', '(', '1211', ')', 'Nissan', '(', '1058', ')', 'Fiat', '(', '1038', ')', 'Kia', '(', '953', ')', 'Renault', '(', '716', ')', 'Toyota', '(', '639', ')', 'Mitsubishi', '(', '613', ')', 'Mercedes', '(', '530', ')', 'Opel', '(', '461', ')', 'Peugeot', '(', '453', ')', 'Skoda', '(', '441', ')', 'Other', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '10365', ')', 'SUV', '(', '2005', ')', 'Hatchback', '(', '1632', ')', '4x4', '(', '446', ')', 'MiniVans', '(', '320', ')', 'Coupe', '(', '77', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', ' ...
# ---------------------------------
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'Cars', '(', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'Cars', '(', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'Account', 'Settings', 'Cars', '(', 'Ads', ')', 'Log', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'Create', 'New', 'Account', ',', 'already', 'account', '!', 'Mobile', 'number', ',', 'Email', 'Username', 'Password', 'Reset', 'Password', 'Cars', 'sale', 'Find', 'used', 'car', 'sale', 'Egypt', 'Choose', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'Sale', 'Hyundai', '(', '1653', ')', 'Chevrolet', '(', '1211', ')', 'Nissan', '(', '1058', ')', 'Fiat', '(', '1038', ')', 'Kia', '(', '953', ')', 'Renault', '(', '716', ')', 'Toyota', '(', '639', ')', 'Mitsubishi', '(', '613', ')', 'Mercedes', '(', '530', ')', 'Opel', '(', '461', ')', 'Peugeot', '(', '453', ')', 'Skoda', '(', '441', ')', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '10365', ')', 'SUV', '(', '2005', ')', 'Hatchback', '(', '1632', ')', '4x4', '(', '446', ')', 'MiniVans', '(', '320', ')', 'Coupe', '(', '77', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', '3000', 'CC', '72', '4000', 'CC', '83', '5000', 'CC', '5', '6000', 'CC', '13', 'Select', 'make', 'Alfa', 'Romeo', 'Aston', 'Martin', 'Audi', 'Baic', 'Bentley', 'Bestune', 'BMW', 'Brilliance', 'Bugatti', 'Buick', 'Byd', 'Cadil ...
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'Sign', 'In', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Close', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', '(', '2019', ')', 'Short', ',', 'News', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', 'On', 'this', 'IMDbrief', ',', 'sponsored', 'by', 'Coca-Cola', ',', 'we', "'re", 'putting', 'the', 'pedal', 'to', 'the', 'metal', 'on', 'the', 'best', 'racing', 'films', 'of', 'all', 'time', '.', 'Get', 'the', 'IMDb', 'App', 'Sign', 'in', 'for', 'more', 'access', 'Sign', 'in', 'for', 'more', 'access', 'Get', 'the', 'IMDb', 'App', 'Help', 'Site', 'Index', 'IMDbPro', 'Box', 'Office', 'Mojo', 'IMDb', 'Developer', 'Press', 'Room', 'Advertising', 'Jobs', 'Conditions', 'of', 'Use', 'Privacy', 'Policy', 'Your', 'Ads', 'Privacy', 'Choices', '©', '1990-', '2023', 'by', 'IMDb.com', ',', 'Inc', '.']
# ---------------------------------
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'Sign', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Close', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', '(', '2019', ')', 'Short', ',', 'News', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', 'IMDbrief', ',', 'sponsored', 'Coca-Cola', ',', "'re", 'putting', 'pedal', 'metal', 'best', 'racing', 'films', 'time', '.', 'Get', 'IMDb', 'App', 'Sign', 'access', 'Sign', 'access', 'Get', 'IMDb', 'App', 'Help', 'Site', 'Index', 'IMDbPro', 'Box', 'Office', 'Mojo', 'IMDb', 'Developer', 'Press', 'Room', 'Advertising', 'Jobs', 'Conditions', 'Use', 'Privacy', 'Policy', 'Ads', 'Privacy', 'Choices', '©', '1990-', '2023', 'IMDb.com', ',', 'Inc', '.']
# ['Sign', 'In', 'My', 'Account', 'Account', 'Settings', 'Sign', 'Out', 'Disney.com', 'Disney+', 'Home', 'On', 'Disney+', 'The', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Home', 'Walt', 'Disney', 'World', 'Walt', 'Disney', 'World', 'Disneyland', 'Disney', 'Cruise', 'Line', 'Aulani', 'All', 'Parks', '&', 'Travel', 'Movies', 'Home', 'Movies', 'Anywhere', 'All', 'Movies', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'All', 'Disney', 'News', 'D23', 'Live', 'Shows', 'Home', 'Disney', 'on', 'Broadway', 'Disney', 'on', 'Ice', 'Disney', 'Live', '!', 'Skip', 'Navigation', 'Disney.com', 'Disney+', 'On', 'Disney+', 'The', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Walt', 'Disney', 'World', 'Resort', 'Disneyland', 'Resort', 'Disney', 'Cruise', 'Line', 'Aulani', '-', 'A', 'Disney', 'Resort', 'and', 'Spa', 'Adventures', 'by', 'Disney', 'Disney', 'Vacation', 'Club', 'Movies', 'Movies', 'Anywhere', 'All', 'Movies', 'Disney', 'Movie', 'Club', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'All', 'More', 'Disney', 'News', 'D23', ':', 'The', 'Official', 'Disney', 'Fan', 'Club', 'Live', 'Shows', 'Sign', 'In', 'My', 'Account', 'Account', 'Settings', 'Sign', 'Out', 'Search', 'Video', 'Galleries', 'Movies', 'RSN', 'Shop', 'Parks', 'Cancel', 'Skip', 'Navigation', 'Movies', 'Video', 'Galleries', 'RSN', 'Parks', 'More', 'Explore', 'More', 'STREAM', 'CARS', 'NOW', 'ON', 'DISNEY+', 'End', 'of', 'video_wrapper', 'End', '#', 'video_watch_container', 'Up', 'Next', 'End', 'of', 'bound', 'Shop', 'See', 'All', 'Cars', 'on', 'the', 'Road', 'Swim', 'Trunks', 'for', 'Kids', '$', '24.99', '$', '20.00', 'Cars', 'on', 'the', 'Road', 'Swim', 'Bag', '$', '19.99', '$', '16.00', 'Cars', 'on', 'the', 'Road', 'Sunglasses', 'for', 'Kids', '$', '16.99', '$', '12.00', 'Cars', 'on', 'the', 'Road', 'Sweatshirt', 'for', 'Kids', '$', '34.99', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'for', 'Kids', '–', 'Customizable', '$', '16.95', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'for', 'Men', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Mousepad', '–', 'Customizable', '$', '12.95', 'Cars', '3', 'Piston', 'Cup', 'Pattern', 'iPhone', '6/6S', 'Case', '–', 'Customizable', '$', '39.95', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Mug', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Rust-eze', 'Tee', 'for', 'Girls', '–', 'Customizable', '$', '18.95', 'Cars', 'on', 'the', 'Road', 'Bodysuit', 'for', 'Baby', '$', '19.99', 'Cars', 'Disney', 'Gift', 'Card', '$', '500.00', 'Cars', 'on', 'the', 'Road', 'Rash', 'Guard', 'for', 'Kids', '$', '24.99', '$', '20.00', 'Cars', 'on', 'the', 'Road', 'Stainless', 'Steel', 'Water', 'Bottle', 'with', 'Built-In', 'Straw', '$', '19.99', 'Cars', 'on', 'the', 'Road', 'Beach', 'Towel', '–', 'Personalized', '$', '19.99', '$', '16.00', 'Cars', 'on', 'the', 'Road', 'Rolling', 'Luggage', '–', 'Small', '$', '49.99', 'Cars', 'Racing', 'Insignia', 'T-Shirt', 'for', 'Adults', '–', 'Customized', '$', '24.99', 'Cars', 'Time', 'Teacher', 'Watch', 'for', 'Kids', '$', '31.99', 'Radiator', 'Springs', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Rust-eze', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Cruz', 'Ramirez', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Lightning', 'McQueen', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Smokey', "'s", 'Garage', 'Morphing', 'Mug', '–', 'Cars', '3', '–', 'Customizable', '$', '19.95', 'Ivy', 'Die', 'Cast', 'Set', '–', 'Cars', 'on', 'the', 'Road', '$', '16.99', 'Mater', 'Die', 'Cast', 'Set', '–', 'Cars', 'on', 'the', 'Road', '$', '16.99', 'Lightning', 'McQueen', 'Time', 'Teacher', 'Watch', 'for', 'Kids', '–', 'Cars', '$', '31.99', 'Jackson', 'Storm', 'Tee', 'for', 'Kids', '–', 'Cars', '3', '–', 'Customizable', '$', '16.95', 'Rust-eze', 'Tee', 'for', 'Kids', '–', 'Cars', '3', '–', 'Customizable', '$', '16.95', 'Smoke ...
# ---------------------------------
# ['Sign', 'Account', 'Account', 'Settings', 'Sign', 'Disney.com', 'Disney+', 'Home', 'Disney+', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Home', 'Walt', 'Disney', 'World', 'Walt', 'Disney', 'World', 'Disneyland', 'Disney', 'Cruise', 'Line', 'Aulani', 'Parks', '&', 'Travel', 'Movies', 'Home', 'Movies', 'Anywhere', 'Movies', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'Disney', 'News', 'D23', 'Live', 'Shows', 'Home', 'Disney', 'Broadway', 'Disney', 'Ice', 'Disney', 'Live', '!', 'Skip', 'Navigation', 'Disney.com', 'Disney+', 'Disney+', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Walt', 'Disney', 'World', 'Resort', 'Disneyland', 'Resort', 'Disney', 'Cruise', 'Line', 'Aulani', '-', 'Disney', 'Resort', 'Spa', 'Adventures', 'Disney', 'Disney', 'Vacation', 'Club', 'Movies', 'Movies', 'Anywhere', 'Movies', 'Disney', 'Movie', 'Club', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'Disney', 'News', 'D23', ':', 'Official', 'Disney', 'Fan', 'Club', 'Live', 'Shows', 'Sign', 'Account', 'Account', 'Settings', 'Sign', 'Search', 'Video', 'Galleries', 'Movies', 'RSN', 'Shop', 'Parks', 'Cancel', 'Skip', 'Navigation', 'Movies', 'Video', 'Galleries', 'RSN', 'Parks', 'Explore', 'STREAM', 'CARS', 'DISNEY+', 'End', 'video_wrapper', 'End', '#', 'video_watch_container', 'Next', 'End', 'bound', 'Shop', 'See', 'Cars', 'Road', 'Swim', 'Trunks', 'Kids', '$', '24.99', '$', '20.00', 'Cars', 'Road', 'Swim', 'Bag', '$', '19.99', '$', '16.00', 'Cars', 'Road', 'Sunglasses', 'Kids', '$', '16.99', '$', '12.00', 'Cars', 'Road', 'Sweatshirt', 'Kids', '$', '34.99', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'Kids', '–', 'Customizable', '$', '16.95', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'Men', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Mousepad', '–', 'Customizable', '$', '12.95', 'Cars', '3', 'Piston', 'Cup', 'Pattern', 'iPhone', '6/6S', 'Case', '–', 'Customizable', '$', '39.95', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Mug', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Rust-eze', 'Tee', 'Girls', '–', 'Customizable', '$', '18.95', 'Cars', 'Road', 'Bodysuit', 'Baby', '$', '19.99', 'Cars', 'Disney', 'Gift', 'Card', '$', '500.00', 'Cars', 'Road', 'Rash', 'Guard', 'Kids', '$', '24.99', '$', '20.00', 'Cars', 'Road', 'Stainless', 'Steel', 'Water', 'Bottle', 'Built-In', 'Straw', '$', '19.99', 'Cars', 'Road', 'Beach', 'Towel', '–', 'Personalized', '$', '19.99', '$', '16.00', 'Cars', 'Road', 'Rolling', 'Luggage', '–', 'Small', '$', '49.99', 'Cars', 'Racing', 'Insignia', 'T-Shirt', 'Adults', '–', 'Customized', '$', '24.99', 'Cars', 'Time', 'Teacher', 'Watch', 'Kids', '$', '31.99', 'Radiator', 'Springs', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Rust-eze', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Cruz', 'Ramirez', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Lightning', 'McQueen', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Smokey', "'s", 'Garage', 'Morphing', 'Mug', '–', 'Cars', '3', '–', 'Customizable', '$', '19.95', 'Ivy', 'Die', 'Cast', 'Set', '–', 'Cars', 'Road', '$', '16.99', 'Mater', 'Die', 'Cast', 'Set', '–', 'Cars', 'Road', '$', '16.99', 'Lightning', 'McQueen', 'Time', 'Teacher', 'Watch', 'Kids', '–', 'Cars', '$', '31.99', 'Jackson', 'Storm', 'Tee', 'Kids', '–', 'Cars', '3', '–', 'Customizable', '$', '16.95', 'Rust-eze', 'Tee', 'Kids', '–', 'Cars', '3', '–', 'Customizable', '$', '16.95', 'Smokey', "'s", 'Garage', 'Tee', 'Kids', '–', 'Cars', '3', '–', 'Customizable', '$', '16.95', 'Rust-eze', 'Tee', 'Men', '–', 'Cars', '3', '–', 'Customizable', '$', '19.95', 'River', 'Scott', 'Tee', 'Women', '–', 'Cars', '3', '–', 'Customizable', '$', '24.95', 'River', 'Scott', 'Tee', 'Kids', '–', 'Cars', '3', '–', 'Customizable', '$', '16.95', 'Hudson', 'Hornet', 'Tee', 'Men', '–', 'Cars', '3', '–', 'Customizable', '$', '19.95', 'Lightning',  ...
# ...
# ---------------------------------
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'Sign', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'topics', 'Cars', '2', '2011', 'G', '1h', '46m', 'IMDb', 'RATING', '6.2', '/', '10', '200K', 'RATING', 'Rate', 'POPULARITY', '2,123', '28', 'Play', 'trailer', '0', ':', '44', '50', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'pal', 'Mater', 'head', 'overseas', 'compete', 'World', 'Grand', 'Prix', 'race', '.', 'road', 'championship', 'becomes', 'rocky', 'Mater', 'gets', 'caught', 'intrigui', '...', 'Read', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'pal', 'Mater', 'head', 'overseas', 'compete', 'World', 'Grand', 'Prix', 'race', '.', 'road', 'championship', 'becomes', 'rocky', 'Mater', 'gets', 'caught', 'intriguing', 'adventure', ':', 'international', 'espionage', '.', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'pal', 'Mater', 'head', 'overseas', 'compete', 'World', 'Grand', 'Prix', 'race', '.', 'road', 'championship', 'becomes', 'rocky', 'Mater', 'gets', 'caught', 'intriguing', 'adventure', ':', 'international', 'espionage', '.', 'Directors', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Writers', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Dan', 'Fogelman', 'Stars', 'Owen', 'Wilson', 'Larry', 'Cable', 'Guy', 'Michael', 'Caine', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '6.2', '/', '10', '200K', 'RATING', 'Rate', 'POPULARITY', '2,123', '28', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Writers', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Dan', 'Fogelman', 'Stars', 'Owen', 'Wilson', 'Larry', 'Cable', 'Guy', 'Michael', 'Caine', '438', 'User', 'reviews', '315', 'Critic', 'reviews', '57', 'Metascore', 'See', 'IMDbPro', 'Awards', '1', 'win', '&', '19', 'nominations', 'Videos', '50', 'Trailer', '0:44', 'Watch', 'Â', '“', 'Tokyo', 'PartyÂ', '”', 'Trailer', '2:31', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '3', 'Trailer', '2:10', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '2', 'Trailer', '2:15', 'Watch', 'Cars', '2', ':', 'International', 'Trailer', 'Trailer', '1:27', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '1', 'Trailer', '0:35', 'Watch', 'Cars', '2', ':', 'Logo', 'Reveal', 'Clip', '0:41', 'Watch', 'Â', '“', 'Lewis', 'Hamilton/Jeff', 'Gorvette', 'CameosÂ', '”', 'Clip', '1:21', 'Watch', '``', 'Carmac', "''", 'Clip', '0:31', 'Watch', 'Â', '“', 'Meet', 'FinnÂ', '”', 'Clip', '0:57', 'Watch', 'Cars', '2', '--', 'WonderCon', 'Footage', 'Clip', '0:31', 'Watch', 'Cars', '2', ':', 'Meet', 'Finn', 'Clip', '0:25', 'Watch', 'Cars', '2', ':', 'Showroom', 'Turntable', 'Brent', 'Mustangburger', 'Photos', '188', 'Top', 'cast', 'Edit', 'Owen' ...
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ---------------------------------
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ---------------------------------
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ['end', 'mobile', 'ads', 'header', 'begin', 'sis', 'pixel', 'slot', 'Begin', 'SIS', 'code', 'End', 'SIS', 'code', 'begin', 'comscore', 'beacon', 'end', 'comscore', 'beacon', 'end', 'sis', 'pixel', 'slot', 'Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'inline', 'wrapper', 'style', 'based', 'on', 'orientation', 'for', '1p', 'ads', 'begin', 'INLINE20', 'SPONSORED', 'End', 'INLINE20', 'Full', 'Cast', '&', 'Crew', ':', 'Cars', '(', '2006', ')', 'Cast', '(', '86', ')', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Larry', 'the', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '/', 'Hamm', 'Truck', '/', 'Abominable', 'Snow', 'Plow', '/', 'P.T', '.', 'Flea', 'Car', '(', 'voice', ')', 'Joe', 'Ranft', 'Red', '/', 'Jerry', 'Recycled', 'Batteries', '/', 'Peterbilt', '(', 'voice', ')', 'Michael', 'Keaton', 'Chick', 'Hicks', '(', 'voice', ')', 'Richard', 'Petty', 'The', 'King', '(', 'voice', ')', 'Jeremy', 'Piven', 'Harv', '(', 'voice', ')', 'Bob', 'Costas', 'Bob', 'Cutlass', '(', 'voice', ')', 'Darrell', 'Waltrip', 'Darrell', 'Cartrip', '(', 'voice', ')', 'Richard', 'Kind', 'Van', '(', 'voice', ')', 'Edie', 'McClurg', 'Minny', '(', 'voice', ')', 'Humpy', 'Wheeler', 'Tex', '(', 'voice', ')', 'Tom', 'Magliozzi', 'Rusty', 'Rust-eze', '(', 'voice', ')', 'Ray', 'Magliozzi', 'Dusty', 'Rust-eze', '(', 'voice', ')', 'Lynda', 'Petty', 'Mrs', '.', 'The', 'King', '(', 'voice', ')', 'Andrew', 'Stanton', 'Fred', '(', 'voice', ')', 'Dale', 'Earnhardt', 'Jr', '.', 'Junior', '(', 'voice', ')', 'Michael', 'Schumacher', 'Michael', 'Schumacher', 'Ferrari', '(', 'voice', ')', 'Jay', 'Leno', 'Jay', 'Limo', '(', 'voice', ')', 'Mario', 'Andretti', 'Mario', 'Andretti', '(', 'voice', ')', 'Sarah', 'Clark', 'Kori', 'Turbowitz', '(', 'voice', ')', 'Mike', 'Nelson', 'Not', 'Chuck', '(', 'voice', ')', '(', 'as', 'Mike', "'No", 'Name', "'", 'Nelson', ')', 'Jonas', 'Rivera', 'Boost', '(', 'voice', ')', 'Lou', 'Romano', 'Snotrod', '(', 'voice', ')', 'Adrian', 'Ochoa', 'Wingo', '(', 'voice', ')', 'E.J', '.', 'Holowicki', 'DJ', '(', 'voice', ')', 'Elissa', 'Knight', 'Tia', '(', 'voice', ')', 'Lindsey', 'Collins', 'Mia', ' ...
# ---------------------------------
# ['end', 'mobile', 'ads', 'header', 'begin', 'sis', 'pixel', 'slot', 'Begin', 'SIS', 'code', 'End', 'SIS', 'code', 'begin', 'comscore', 'beacon', 'end', 'comscore', 'beacon', 'end', 'sis', 'pixel', 'slot', 'Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'inline', 'wrapper', 'style', 'based', 'orientation', '1p', 'ads', 'begin', 'INLINE20', 'SPONSORED', 'End', 'INLINE20', 'Full', 'Cast', '&', 'Crew', ':', 'Cars', '(', '2006', ')', 'Cast', '(', '86', ')', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Larry', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '/', 'Hamm', 'Truck', '/', 'Abominable', 'Snow', 'Plow', '/', 'P.T', '.', 'Flea', 'Car', '(', 'voice', ')', 'Joe', 'Ranft', 'Red', '/', 'Jerry', 'Recycled', 'Batteries', '/', 'Peterbilt', '(', 'voice', ')', 'Michael', 'Keaton', 'Chick', 'Hicks', '(', 'voice', ')', 'Richard', 'Petty', 'King', '(', 'voice', ')', 'Jeremy', 'Piven', 'Harv', '(', 'voice', ')', 'Bob', 'Costas', 'Bob', 'Cutlass', '(', 'voice', ')', 'Darrell', 'Waltrip', 'Darrell', 'Cartrip', '(', 'voice', ')', 'Richard', 'Kind', 'Van', '(', 'voice', ')', 'Edie', 'McClurg', 'Minny', '(', 'voice', ')', 'Humpy', 'Wheeler', 'Tex', '(', 'voice', ')', 'Tom', 'Magliozzi', 'Rusty', 'Rust-eze', '(', 'voice', ')', 'Ray', 'Magliozzi', 'Dusty', 'Rust-eze', '(', 'voice', ')', 'Lynda', 'Petty', 'Mrs', '.', 'King', '(', 'voice', ')', 'Andrew', 'Stanton', 'Fred', '(', 'voice', ')', 'Dale', 'Earnhardt', 'Jr', '.', 'Junior', '(', 'voice', ')', 'Michael', 'Schumacher', 'Michael', 'Schumacher', 'Ferrari', '(', 'voice', ')', 'Jay', 'Leno', 'Jay', 'Limo', '(', 'voice', ')', 'Mario', 'Andretti', 'Mario', 'Andretti', '(', 'voice', ')', 'Sarah', 'Clark', 'Kori', 'Turbowitz', '(', 'voice', ')', 'Mike', 'Nelson', 'Chuck', '(', 'voice', ')', '(', 'Mike', "'No", 'Name', "'", 'Nelson', ')', 'Jonas', 'Rivera', 'Boost', '(', 'voice', ')', 'Lou', 'Romano', 'Snotrod', '(', 'voice', ')', 'Adrian', 'Ochoa', 'Wingo', '(', 'voice', ')', 'E.J', '.', 'Holowicki', 'DJ', '(', 'voice', ')', 'Elissa', 'Knight', 'Tia', '(', 'voice', ')', 'Lindsey', 'Collins', 'Mia', '(', 'voice', ')', 'Larry', 'Benton', 'Motorhome', 'Race', 'Fan', '#', '1', '(', 'voice', ')', 'Douglas', 'Keever', 'Motorhome', 'Race', 'Fan', '#', '2',  ...

# %%
import nltk

from nltk.stem.porter import *
p_stemmer = PorterStemmer()




for word in  filtered_sentence:
    print(word+' --> '+p_stemmer.stem(word))

from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')



for word in filtered_sentence:
    print(word+' --> '+s_stemmer.stem(word))
u=p_stemmer.stem(word)
# Out:
# end --> end
# mobile --> mobil
# ads --> ad
# header --> header
# begin --> begin
# sis --> si
# pixel --> pixel
# slot --> slot
# Begin --> begin
# SIS --> si
# code --> code
# End --> end
# SIS --> si
# code --> code
# begin --> begin
# comscore --> comscor
# beacon --> beacon
# end --> end
# comscore --> comscor
# beacon --> beacon
# end --> end
# sis --> si
# pixel --> pixel
# slot --> slot
# Menu --> menu
# Movies --> movi
# Release --> releas
# Calendar --> calendar
# Top --> top
# 250 --> 250
# Movies --> movi
# Popular --> popular
# Movies --> movi
# Browse --> brows
# Movies --> movi
# Genre --> genr
# Top --> top
# Box --> box
# Office --> offic
# Showtimes --> showtim
# & --> &
# Tickets --> ticket
# Movie --> movi
# News --> new
# India --> india
# Movie --> movi
# Spotlight --> spotlight
# TV --> tv
# Shows --> show
# 's --> 's
# TV --> tv
# & --> &
# Streaming --> stream
# Top --> top
# 250 --> 250
# TV --> tv
# Shows --> show
# Popular --> popular
# TV --> tv
# Shows --> show
# Browse --> brows
# TV --> tv
# Shows --> show
# Genre --> genr
# TV --> tv
# News --> new
# Watch --> watch
# Watch --> watch
# Latest --> latest
# Trailers --> trailer
# IMDb --> imdb
# Originals --> origin
# IMDb --> imdb
# Picks --> pick
# IMDb --> imdb
# Podcasts --> podcast
# Awards --> award
# & --> &
# Events --> event
# Oscars --> oscar
# Asian --> asian
# Heritage --> heritag
# Month --> month
# Cannes --> cann
# Star --> star
# Wars --> war
# Celebration --> celebr
# STARmeter --> starmet
# Awards --> award
# Awards --> award
# Central --> central
# Festival --> festiv
# Central --> central
# Events --> event
# Celebs --> celeb
# Born --> born
# Today --> today
# Popular --> popular
# Celebs --> celeb
# Popular --> popular
# Celebs --> celeb
# Celebrity --> celebr
# News --> new
# Community --> commun
# Help --> help
# Center --> center
# Contributor --> contributor
# Zone --> zone
# Polls --> poll
# Industry --> industri
# Professionals --> profession
# Titles --> titl
# TV --> tv
# Episodes --> episod
# Celebs --> celeb
# Companies --> compani
# Keywords --> keyword
# Advanced --> advanc
# Search --> search
# Watchlist --> watchlist
# Sign --> sign
# EN --> en
# Fully --> fulli
# supported --> support
# English --> english
# ( --> (
# United --> unit
# States --> state
# ) --> )
# Partially --> partial
# supported --> support
# Français --> françai
# ( --> (
# Canada --> canada
# ) --> )
# Français --> françai
# ( --> (
# France --> franc
# ) --> )
# Deutsch --> deutsch
# ( --> (
# Deutschland --> deutschland
# ) --> )
# हिंदी --> हिंदी
# ( --> (
# भारत --> भारत
# ) --> )
# Italiano --> italiano
# ( --> (
# Italia --> italia
# ) --> )
# Português --> portuguê
# ( --> (
# Brasil --> brasil
# ) --> )
# Español --> español
# ( --> (
# España --> españa
# ) --> )
# Español --> español
# ( --> (
# México --> méxico
# ) --> )
# inline --> inlin
# wrapper --> wrapper
# style --> style
# based --> base
# orientation --> orient
# 1p --> 1p
# ads --> ad
# begin --> begin
# INLINE20 --> inline20
# SPONSORED --> sponsor
# End --> end
# INLINE20 --> inline20
# Full --> full
# Cast --> cast
# & --> &
# Crew --> crew
# : --> :
# Cars --> car
# ( --> (
# 2006 --> 2006
# ) --> )
# Cast --> cast
# ( --> (
# 86 --> 86
# ) --> )
# Owen --> owen
# Wilson --> wilson
# Lightning --> lightn
# McQueen --> mcqueen
# ( --> (
# voice --> voic
# ) --> )
# Paul --> paul
# Newman --> newman
# Doc --> doc
# Hudson --> hudson
# ( --> (
# voice --> voic
# ) --> )
# Bonnie --> bonni
# Hunt --> hunt
# Sally --> salli
# Carrera --> carrera
# ( --> (
# voice --> voic
# ) --> )
# Larry --> larri
# Cable --> cabl
# Guy --> guy
# Mater --> mater
# ( --> (
# voice --> voic
# ) --> )
# Cheech --> cheech
# Marin --> marin
# Ramone --> ramon
# ( --> (
# voice --> voic
# ) --> )
# Tony --> toni
# Shalhoub --> shalhoub
# Luigi --> luigi
# ( --> (
# voice --> voic
# ) --> )
# Guido --> guido
# Quaroni --> quaroni
# Guido --> guido
# ( --> (
# voice --> voic
# ) --> )
# Jenifer --> jenif
# Lewis --> lewi
# Flo --> flo
# ( --> (
# voice --> voic
# ) --> )
# Paul --> paul
# Dooley --> dooley
# Sarge --> sarg
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Wallis --> walli
# Sheriff --> sheriff
# ( --> (
# voice --> voic
# ) --> )
# George --> georg
# Carlin --> carlin
# Fillmore --> fillmor
# ( --> (
# voice --> voic
# ) --> )
# Katherine --> katherin
# Helmond --> helmond
# Lizzie --> lizzi
# ( --> (
# voice --> voic
# ) --> )
# John --> john
# Ratzenberger --> ratzenberg
# Mack --> mack
# / --> /
# Hamm --> hamm
# Truck --> truck
# / --> /
# Abominable --> abomin
# Snow --> snow
# Plow --> plow
# / --> /
# P.T --> p.t
# . --> .
# Flea --> flea
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Joe --> joe
# Ranft --> ranft
# Red --> red
# / --> /
# Jerry --> jerri
# Recycled --> recycl
# Batteries --> batteri
# / --> /
# Peterbilt --> peterbilt
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Keaton --> keaton
# Chick --> chick
# Hicks --> hick
# ( --> (
# voice --> voic
# ) --> )
# Richard --> richard
# Petty --> petti
# King --> king
# ( --> (
# voice --> voic
# ) --> )
# Jeremy --> jeremi
# Piven --> piven
# Harv --> harv
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Costas --> costa
# Bob --> bob
# Cutlass --> cutlass
# ( --> (
# voice --> voic
# ) --> )
# Darrell --> darrel
# Waltrip --> waltrip
# Darrell --> darrel
# Cartrip --> cartrip
# ( --> (
# voice --> voic
# ) --> )
# Richard --> richard
# Kind --> kind
# Van --> van
# ( --> (
# voice --> voic
# ) --> )
# Edie --> edi
# McClurg --> mcclurg
# Minny --> minni
# ( --> (
# voice --> voic
# ) --> )
# Humpy --> humpi
# Wheeler --> wheeler
# Tex --> tex
# ( --> (
# voice --> voic
# ) --> )
# Tom --> tom
# Magliozzi --> magliozzi
# Rusty --> rusti
# Rust-eze --> rust-ez
# ( --> (
# voice --> voic
# ) --> )
# Ray --> ray
# Magliozzi --> magliozzi
# Dusty --> dusti
# Rust-eze --> rust-ez
# ( --> (
# voice --> voic
# ) --> )
# Lynda --> lynda
# Petty --> petti
# Mrs --> mr
# . --> .
# King --> king
# ( --> (
# voice --> voic
# ) --> )
# Andrew --> andrew
# Stanton --> stanton
# Fred --> fred
# ( --> (
# voice --> voic
# ) --> )
# Dale --> dale
# Earnhardt --> earnhardt
# Jr --> jr
# . --> .
# Junior --> junior
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Schumacher --> schumach
# Michael --> michael
# Schumacher --> schumach
# Ferrari --> ferrari
# ( --> (
# voice --> voic
# ) --> )
# Jay --> jay
# Leno --> leno
# Jay --> jay
# Limo --> limo
# ( --> (
# voice --> voic
# ) --> )
# Mario --> mario
# Andretti --> andretti
# Mario --> mario
# Andretti --> andretti
# ( --> (
# voice --> voic
# ) --> )
# Sarah --> sarah
# Clark --> clark
# Kori --> kori
# Turbowitz --> turbowitz
# ( --> (
# voice --> voic
# ) --> )
# Mike --> mike
# Nelson --> nelson
# Chuck --> chuck
# ( --> (
# voice --> voic
# ) --> )
# ( --> (
# Mike --> mike
# 'No --> 'no
# Name --> name
# ' --> '
# Nelson --> nelson
# ) --> )
# Jonas --> jona
# Rivera --> rivera
# Boost --> boost
# ( --> (
# voice --> voic
# ) --> )
# Lou --> lou
# Romano --> romano
# Snotrod --> snotrod
# ( --> (
# voice --> voic
# ) --> )
# Adrian --> adrian
# Ochoa --> ochoa
# Wingo --> wingo
# ( --> (
# voice --> voic
# ) --> )
# E.J --> e.j
# . --> .
# Holowicki --> holowicki
# DJ --> dj
# ( --> (
# voice --> voic
# ) --> )
# Elissa --> elissa
# Knight --> knight
# Tia --> tia
# ( --> (
# voice --> voic
# ) --> )
# Lindsey --> lindsey
# Collins --> collin
# Mia --> mia
# ( --> (
# voice --> voic
# ) --> )
# Larry --> larri
# Benton --> benton
# Motorhome --> motorhom
# Race --> race
# Fan --> fan
# # --> #
# 1 --> 1
# ( --> (
# voice --> voic
# ) --> )
# Douglas --> dougla
# Keever --> keever
# Motorhome --> motorhom
# Race --> race
# Fan --> fan
# # --> #
# 2 --> 2
# ( --> (
# voice --> voic
# ) --> )
# ( --> (
# Douglas --> dougla
# 'Mater --> 'mater
# ' --> '
# Keener --> keener
# ) --> )
# Tom --> tom
# Hanks --> hank
# Woody --> woodi
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Tim --> tim
# Allen --> allen
# Buzz --> buzz
# Lightyear --> lightyear
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Billy --> billi
# Crystal --> crystal
# Mike --> mike
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# John --> john
# Goodman --> goodman
# Sullivan --> sullivan
# Truck --> truck
# ( --> (
# voice --> voic
# ) --> )
# David --> david
# Foley --> foley
# Flik --> flik
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Jack --> jack
# Angel --> angel
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Bell --> bell
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Bergen --> bergen
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Susan --> susan
# Blu --> blu
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Andrea --> andrea
# Boerries --> boerri
# Andrea --> andrea
# ( --> (
# voice --> voic
# ) --> )
# Marco --> marco
# Boerries --> boerri
# Marco --> marco
# Axelbender --> axelbend
# ( --> (
# voice --> voic
# ) --> )
# Rodger --> rodger
# Bumpass --> bumpass
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Torbin --> torbin
# Xan --> xan
# Bullock --> bullock
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Richard --> richard
# Cawood --> cawood
# Richard --> richard
# Clayton --> clayton
# Kensington --> kensington
# ( --> (
# voice --> voic
# ) --> )
# Scott --> scott
# Clark --> clark
# Sven --> sven
# ( --> (
# voice --> voic
# ) --> )
# Kathy --> kathi
# Coates --> coat
# Kathy --> kathi
# Copter --> copter
# ( --> (
# voice --> voic
# ) --> )
# John --> john
# Cygan --> cygan
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Jennifer --> jennif
# Darling --> darl
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Paul --> paul
# Eiding --> eid
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bill --> bill
# Farmer --> farmer
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Brian --> brian
# Fee --> fee
# Al --> al
# Oft --> oft
# ( --> (
# voice --> voic
# ) --> )
# Teresa --> teresa
# Ganzel --> ganzel
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Craig --> craig
# Good --> good
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Jess --> jess
# Harnell --> harnel
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Artie --> arti
# Kempner --> kempner
# Artie --> arti
# ( --> (
# voice --> voic
# ) --> )
# Hooman --> hooman
# Khalili --> khalili
# Hooman --> hooman
# ( --> (
# voice --> voic
# ) --> )
# Sonoko --> sonoko
# Konishi --> konishi
# Chuki --> chuki
# ( --> (
# voice --> voic
# ) --> )
# Erik --> erik
# Langley --> langley
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Sherry --> sherri
# Lynn --> lynn
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Danny --> danni
# Mann --> mann
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Mickie --> micki
# McGowan --> mcgowan
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# ( --> (
# Mickie --> micki
# T. --> t.
# McGowan --> mcgowan
# ) --> )
# Laraine --> larain
# Newman --> newman
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Teddy --> teddi
# Newton --> newton
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Colleen --> colleen
# O'Shaughnessey --> o'shaughnessey
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Peterson --> peterson
# Wide --> wide
# Chick --> chick
# Pitty --> pitti
# ( --> (
# voice --> voic
# ) --> )
# Steve --> steve
# Purcell --> purcel
# Tractors --> tractor
# / --> /
# Frank --> frank
# ( --> (
# voice --> voic
# ) --> )
# Jan --> jan
# Rabson --> rabson
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# A.J --> a.j
# . --> .
# Riebli --> riebli
# III --> iii
# Albert --> albert
# Hinkey --> hinkey
# ( --> (
# voice --> voic
# ) --> )
# Dan --> dan
# Scanlon --> scanlon
# Dan --> dan
# Sclarkenberg --> sclarkenberg
# ( --> (
# voice --> voic
# ) --> )
# Stephen --> stephen
# Schaffer --> schaffer
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Ken --> ken
# Schretzmann --> schretzmann
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Scott --> scott
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Matt --> matt
# Staudt --> staudt
# Matti --> matti
# ( --> (
# voice --> voic
# ) --> )
# Jay --> jay
# Ward --> ward
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Jim --> jim
# Ward --> ward
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Colette --> colett
# Whitaker --> whitak
# Coriander --> coriand
# Widetrack --> widetrack
# ( --> (
# voice --> voic
# ) --> )
# content --> content
# received --> receiv
# slot --> slot
# : --> :
# inlinebottom --> inlinebottom
# Get --> get
# IMDb --> imdb
# App --> app
# Sign --> sign
# access --> access
# Sign --> sign
# access --> access
# Get --> get
# IMDb --> imdb
# App --> app
# Help --> help
# Site --> site
# Index --> index
# IMDbPro --> imdbpro
# Box --> box
# Office --> offic
# Mojo --> mojo
# IMDb --> imdb
# Developer --> develop
# Press --> press
# Room --> room
# Advertising --> advertis
# Jobs --> job
# Conditions --> condit
# Use --> use
# Privacy --> privaci
# Policy --> polici
# Ads --> ad
# Privacy --> privaci
# Choices --> choic
# © --> ©
# 1990- --> 1990-
# 2023 --> 2023
# IMDb.com --> imdb.com
# , --> ,
# Inc. --> inc.
# begin --> begin
# mobile --> mobil
# ads --> ad
# footer --> footer
# end --> end
# mobile --> mobil
# ads --> ad
# footer --> footer
# end --> end
# mobile --> mobil
# ads --> ad
# header --> header
# begin --> begin
# sis --> sis
# pixel --> pixel
# slot --> slot
# Begin --> begin
# SIS --> sis
# code --> code
# End --> end
# SIS --> sis
# code --> code
# begin --> begin
# comscore --> comscor
# beacon --> beacon
# end --> end
# comscore --> comscor
# beacon --> beacon
# end --> end
# sis --> sis
# pixel --> pixel
# slot --> slot
# Menu --> menu
# Movies --> movi
# Release --> releas
# Calendar --> calendar
# Top --> top
# 250 --> 250
# Movies --> movi
# Popular --> popular
# Movies --> movi
# Browse --> brows
# Movies --> movi
# Genre --> genr
# Top --> top
# Box --> box
# Office --> offic
# Showtimes --> showtim
# & --> &
# Tickets --> ticket
# Movie --> movi
# News --> news
# India --> india
# Movie --> movi
# Spotlight --> spotlight
# TV --> tv
# Shows --> show
# 's --> 's
# TV --> tv
# & --> &
# Streaming --> stream
# Top --> top
# 250 --> 250
# TV --> tv
# Shows --> show
# Popular --> popular
# TV --> tv
# Shows --> show
# Browse --> brows
# TV --> tv
# Shows --> show
# Genre --> genr
# TV --> tv
# News --> news
# Watch --> watch
# Watch --> watch
# Latest --> latest
# Trailers --> trailer
# IMDb --> imdb
# Originals --> origin
# IMDb --> imdb
# Picks --> pick
# IMDb --> imdb
# Podcasts --> podcast
# Awards --> award
# & --> &
# Events --> event
# Oscars --> oscar
# Asian --> asian
# Heritage --> heritag
# Month --> month
# Cannes --> cann
# Star --> star
# Wars --> war
# Celebration --> celebr
# STARmeter --> starmet
# Awards --> award
# Awards --> award
# Central --> central
# Festival --> festiv
# Central --> central
# Events --> event
# Celebs --> celeb
# Born --> born
# Today --> today
# Popular --> popular
# Celebs --> celeb
# Popular --> popular
# Celebs --> celeb
# Celebrity --> celebr
# News --> news
# Community --> communiti
# Help --> help
# Center --> center
# Contributor --> contributor
# Zone --> zone
# Polls --> poll
# Industry --> industri
# Professionals --> profession
# Titles --> titl
# TV --> tv
# Episodes --> episod
# Celebs --> celeb
# Companies --> compani
# Keywords --> keyword
# Advanced --> advanc
# Search --> search
# Watchlist --> watchlist
# Sign --> sign
# EN --> en
# Fully --> fulli
# supported --> support
# English --> english
# ( --> (
# United --> unit
# States --> state
# ) --> )
# Partially --> partial
# supported --> support
# Français --> françai
# ( --> (
# Canada --> canada
# ) --> )
# Français --> françai
# ( --> (
# France --> franc
# ) --> )
# Deutsch --> deutsch
# ( --> (
# Deutschland --> deutschland
# ) --> )
# हिंदी --> हिंदी
# ( --> (
# भारत --> भारत
# ) --> )
# Italiano --> italiano
# ( --> (
# Italia --> italia
# ) --> )
# Português --> portuguê
# ( --> (
# Brasil --> brasil
# ) --> )
# Español --> español
# ( --> (
# España --> españa
# ) --> )
# Español --> español
# ( --> (
# México --> méxico
# ) --> )
# inline --> inlin
# wrapper --> wrapper
# style --> style
# based --> base
# orientation --> orient
# 1p --> 1p
# ads --> ad
# begin --> begin
# INLINE20 --> inline20
# SPONSORED --> sponsor
# End --> end
# INLINE20 --> inline20
# Full --> full
# Cast --> cast
# & --> &
# Crew --> crew
# : --> :
# Cars --> car
# ( --> (
# 2006 --> 2006
# ) --> )
# Cast --> cast
# ( --> (
# 86 --> 86
# ) --> )
# Owen --> owen
# Wilson --> wilson
# Lightning --> lightn
# McQueen --> mcqueen
# ( --> (
# voice --> voic
# ) --> )
# Paul --> paul
# Newman --> newman
# Doc --> doc
# Hudson --> hudson
# ( --> (
# voice --> voic
# ) --> )
# Bonnie --> bonni
# Hunt --> hunt
# Sally --> salli
# Carrera --> carrera
# ( --> (
# voice --> voic
# ) --> )
# Larry --> larri
# Cable --> cabl
# Guy --> guy
# Mater --> mater
# ( --> (
# voice --> voic
# ) --> )
# Cheech --> cheech
# Marin --> marin
# Ramone --> ramon
# ( --> (
# voice --> voic
# ) --> )
# Tony --> toni
# Shalhoub --> shalhoub
# Luigi --> luigi
# ( --> (
# voice --> voic
# ) --> )
# Guido --> guido
# Quaroni --> quaroni
# Guido --> guido
# ( --> (
# voice --> voic
# ) --> )
# Jenifer --> jenif
# Lewis --> lewi
# Flo --> flo
# ( --> (
# voice --> voic
# ) --> )
# Paul --> paul
# Dooley --> dooley
# Sarge --> sarg
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Wallis --> walli
# Sheriff --> sheriff
# ( --> (
# voice --> voic
# ) --> )
# George --> georg
# Carlin --> carlin
# Fillmore --> fillmor
# ( --> (
# voice --> voic
# ) --> )
# Katherine --> katherin
# Helmond --> helmond
# Lizzie --> lizzi
# ( --> (
# voice --> voic
# ) --> )
# John --> john
# Ratzenberger --> ratzenberg
# Mack --> mack
# / --> /
# Hamm --> hamm
# Truck --> truck
# / --> /
# Abominable --> abomin
# Snow --> snow
# Plow --> plow
# / --> /
# P.T --> p.t
# . --> .
# Flea --> flea
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Joe --> joe
# Ranft --> ranft
# Red --> red
# / --> /
# Jerry --> jerri
# Recycled --> recycl
# Batteries --> batteri
# / --> /
# Peterbilt --> peterbilt
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Keaton --> keaton
# Chick --> chick
# Hicks --> hick
# ( --> (
# voice --> voic
# ) --> )
# Richard --> richard
# Petty --> petti
# King --> king
# ( --> (
# voice --> voic
# ) --> )
# Jeremy --> jeremi
# Piven --> piven
# Harv --> harv
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Costas --> costa
# Bob --> bob
# Cutlass --> cutlass
# ( --> (
# voice --> voic
# ) --> )
# Darrell --> darrel
# Waltrip --> waltrip
# Darrell --> darrel
# Cartrip --> cartrip
# ( --> (
# voice --> voic
# ) --> )
# Richard --> richard
# Kind --> kind
# Van --> van
# ( --> (
# voice --> voic
# ) --> )
# Edie --> edi
# McClurg --> mcclurg
# Minny --> minni
# ( --> (
# voice --> voic
# ) --> )
# Humpy --> humpi
# Wheeler --> wheeler
# Tex --> tex
# ( --> (
# voice --> voic
# ) --> )
# Tom --> tom
# Magliozzi --> magliozzi
# Rusty --> rusti
# Rust-eze --> rust-ez
# ( --> (
# voice --> voic
# ) --> )
# Ray --> ray
# Magliozzi --> magliozzi
# Dusty --> dusti
# Rust-eze --> rust-ez
# ( --> (
# voice --> voic
# ) --> )
# Lynda --> lynda
# Petty --> petti
# Mrs --> mrs
# . --> .
# King --> king
# ( --> (
# voice --> voic
# ) --> )
# Andrew --> andrew
# Stanton --> stanton
# Fred --> fred
# ( --> (
# voice --> voic
# ) --> )
# Dale --> dale
# Earnhardt --> earnhardt
# Jr --> jr
# . --> .
# Junior --> junior
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Schumacher --> schumach
# Michael --> michael
# Schumacher --> schumach
# Ferrari --> ferrari
# ( --> (
# voice --> voic
# ) --> )
# Jay --> jay
# Leno --> leno
# Jay --> jay
# Limo --> limo
# ( --> (
# voice --> voic
# ) --> )
# Mario --> mario
# Andretti --> andretti
# Mario --> mario
# Andretti --> andretti
# ( --> (
# voice --> voic
# ) --> )
# Sarah --> sarah
# Clark --> clark
# Kori --> kori
# Turbowitz --> turbowitz
# ( --> (
# voice --> voic
# ) --> )
# Mike --> mike
# Nelson --> nelson
# Chuck --> chuck
# ( --> (
# voice --> voic
# ) --> )
# ( --> (
# Mike --> mike
# 'No --> no
# Name --> name
# ' --> '
# Nelson --> nelson
# ) --> )
# Jonas --> jona
# Rivera --> rivera
# Boost --> boost
# ( --> (
# voice --> voic
# ) --> )
# Lou --> lou
# Romano --> romano
# Snotrod --> snotrod
# ( --> (
# voice --> voic
# ) --> )
# Adrian --> adrian
# Ochoa --> ochoa
# Wingo --> wingo
# ( --> (
# voice --> voic
# ) --> )
# E.J --> e.j
# . --> .
# Holowicki --> holowicki
# DJ --> dj
# ( --> (
# voice --> voic
# ) --> )
# Elissa --> elissa
# Knight --> knight
# Tia --> tia
# ( --> (
# voice --> voic
# ) --> )
# Lindsey --> lindsey
# Collins --> collin
# Mia --> mia
# ( --> (
# voice --> voic
# ) --> )
# Larry --> larri
# Benton --> benton
# Motorhome --> motorhom
# Race --> race
# Fan --> fan
# # --> #
# 1 --> 1
# ( --> (
# voice --> voic
# ) --> )
# Douglas --> dougla
# Keever --> keever
# Motorhome --> motorhom
# Race --> race
# Fan --> fan
# # --> #
# 2 --> 2
# ( --> (
# voice --> voic
# ) --> )
# ( --> (
# Douglas --> dougla
# 'Mater --> mater
# ' --> '
# Keener --> keener
# ) --> )
# Tom --> tom
# Hanks --> hank
# Woody --> woodi
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Tim --> tim
# Allen --> allen
# Buzz --> buzz
# Lightyear --> lightyear
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Billy --> billi
# Crystal --> crystal
# Mike --> mike
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# John --> john
# Goodman --> goodman
# Sullivan --> sullivan
# Truck --> truck
# ( --> (
# voice --> voic
# ) --> )
# David --> david
# Foley --> foley
# Flik --> flik
# Car --> car
# ( --> (
# voice --> voic
# ) --> )
# Jack --> jack
# Angel --> angel
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Michael --> michael
# Bell --> bell
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Bergen --> bergen
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Susan --> susan
# Blu --> blu
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Andrea --> andrea
# Boerries --> boerri
# Andrea --> andrea
# ( --> (
# voice --> voic
# ) --> )
# Marco --> marco
# Boerries --> boerri
# Marco --> marco
# Axelbender --> axelbend
# ( --> (
# voice --> voic
# ) --> )
# Rodger --> rodger
# Bumpass --> bumpass
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Torbin --> torbin
# Xan --> xan
# Bullock --> bullock
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Richard --> richard
# Cawood --> cawood
# Richard --> richard
# Clayton --> clayton
# Kensington --> kensington
# ( --> (
# voice --> voic
# ) --> )
# Scott --> scott
# Clark --> clark
# Sven --> sven
# ( --> (
# voice --> voic
# ) --> )
# Kathy --> kathi
# Coates --> coat
# Kathy --> kathi
# Copter --> copter
# ( --> (
# voice --> voic
# ) --> )
# John --> john
# Cygan --> cygan
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Jennifer --> jennif
# Darling --> darl
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Paul --> paul
# Eiding --> eid
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bill --> bill
# Farmer --> farmer
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Brian --> brian
# Fee --> fee
# Al --> al
# Oft --> oft
# ( --> (
# voice --> voic
# ) --> )
# Teresa --> teresa
# Ganzel --> ganzel
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Craig --> craig
# Good --> good
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Jess --> jess
# Harnell --> harnel
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Artie --> arti
# Kempner --> kempner
# Artie --> arti
# ( --> (
# voice --> voic
# ) --> )
# Hooman --> hooman
# Khalili --> khalili
# Hooman --> hooman
# ( --> (
# voice --> voic
# ) --> )
# Sonoko --> sonoko
# Konishi --> konishi
# Chuki --> chuki
# ( --> (
# voice --> voic
# ) --> )
# Erik --> erik
# Langley --> langley
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Sherry --> sherri
# Lynn --> lynn
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Danny --> danni
# Mann --> mann
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Mickie --> micki
# McGowan --> mcgowan
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# ( --> (
# Mickie --> micki
# T. --> t.
# McGowan --> mcgowan
# ) --> )
# Laraine --> larain
# Newman --> newman
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Teddy --> teddi
# Newton --> newton
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Colleen --> colleen
# O'Shaughnessey --> o'shaughnessey
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Peterson --> peterson
# Wide --> wide
# Chick --> chick
# Pitty --> pitti
# ( --> (
# voice --> voic
# ) --> )
# Steve --> steve
# Purcell --> purcel
# Tractors --> tractor
# / --> /
# Frank --> frank
# ( --> (
# voice --> voic
# ) --> )
# Jan --> jan
# Rabson --> rabson
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# A.J --> a.j
# . --> .
# Riebli --> riebli
# III --> iii
# Albert --> albert
# Hinkey --> hinkey
# ( --> (
# voice --> voic
# ) --> )
# Dan --> dan
# Scanlon --> scanlon
# Dan --> dan
# Sclarkenberg --> sclarkenberg
# ( --> (
# voice --> voic
# ) --> )
# Stephen --> stephen
# Schaffer --> schaffer
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Ken --> ken
# Schretzmann --> schretzmann
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Bob --> bob
# Scott --> scott
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Matt --> matt
# Staudt --> staudt
# Matti --> matti
# ( --> (
# voice --> voic
# ) --> )
# Jay --> jay
# Ward --> ward
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Jim --> jim
# Ward --> ward
# Additional --> addit
# Voices --> voic
# ( --> (
# voice --> voic
# ) --> )
# Colette --> colett
# Whitaker --> whitak
# Coriander --> coriand
# Widetrack --> widetrack
# ( --> (
# voice --> voic
# ) --> )
# content --> content
# received --> receiv
# slot --> slot
# : --> :
# inlinebottom --> inlinebottom
# Get --> get
# IMDb --> imdb
# App --> app
# Sign --> sign
# access --> access
# Sign --> sign
# access --> access
# Get --> get
# IMDb --> imdb
# App --> app
# Help --> help
# Site --> site
# Index --> index
# IMDbPro --> imdbpro
# Box --> box
# Office --> offic
# Mojo --> mojo
# IMDb --> imdb
# Developer --> develop
# Press --> press
# Room --> room
# Advertising --> advertis
# Jobs --> job
# Conditions --> condit
# Use --> use
# Privacy --> privaci
# Policy --> polici
# Ads --> ad
# Privacy --> privaci
# Choices --> choic
# © --> ©
# 1990- --> 1990-
# 2023 --> 2023
# IMDb.com --> imdb.com
# , --> ,
# Inc. --> inc.
# begin --> begin
# mobile --> mobil
# ads --> ad
# footer --> footer
# end --> end
# mobile --> mobil
# ads --> ad
# footer --> footer

# %%
# import pandas as pd
# def tf_idf_analysis(keyword):
#   v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
#   x = v.fit_transform(text)

#   f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
#   d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
#   tf=pd.DataFrame((f>0).sum(axis=0))


#   d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

#   d.columns=['word','average_tfidf','max_tfidf','frequency']

#   d['frequency']=round((d['frequency']/len(text))*100)

#   return(d)


# x= tf_idf_analysis(u)
# x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
# print(x)

import pandas as pd
@app.route('/tfidf/<keyword>')
def tf_idf_analysis(keyword):
    v = TfidfVectorizer(min_df=1, analyzer='word', ngram_range=(1, 2), stop_words=list(stop_words))
    x = v.fit_transform(text)

    f = pd.DataFrame(x.toarray(), columns=v.get_feature_names_out())
    d = pd.concat([pd.DataFrame(f.mean(axis=0)), pd.DataFrame(f.max(axis=0))], axis=1)

    tf = pd.DataFrame((f > 0).sum(axis=0))

    d = d.reset_index().merge(tf.reset_index(), on='index', how='left')

    d.columns = ['word', 'average_tfidf', 'max_tfidf', 'frequency']

    d['frequency'] = round((d['frequency'] / len(text)) * 100)

    json_data = pd.DataFrame.to_json(d)
    return json_data

x = pd.read_json(tf_idf_analysis(u))
json_string = x[x['word'].str.isalpha()].sort_values('max_tfidf', ascending=False).head(35).to_json(orient='records')

# %% [markdown]
# test test tf-idf

# %%
if __name__ == '__main__':
    app.run(host='0.0.0.0',debug=True,port=4000,use_reloader=False)
# def tf_idf_analysis(keyword):
#     # links=google_results(keyword,12)
#     links=scrape_google(keyword)

#     text=[]
#     for i in links:
#         t=get_text(i)
#         if t:
#             text.append(t)
            
#     v = TfidfVectorizer(min_df=2,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
#     x = v.fit_transform(text)

#     f = pd.DataFrame(x.toarray(), columns = v.get_feature_names_out())
#     d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
#     tf=pd.DataFrame((f>0).sum(axis=0))


#     d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

#     d.columns=['word','average_tfidf','max_tfidf','frequency']


# #you can comment the following part if you want the number of URLs that the word occurs. The percentage makes sense
# #when we have a lot of URLs to check

#     d['frequency']=round((d['frequency']/len(text))*100)

#     return(v.get_feature_names())


# x= tf_idf_analysis('tote bags')
# # print(x)
# # x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:4000
#  * Running on http://192.168.1.4:4000
# Press CTRL+C to quit
# 127.0.0.1 - - [12/May/2023 17:50:01] "GET /tfidf/cars HTTP/1.1" 200 -

# %%
# from nltk.stem import PorterStemmer
# from nltk.tokenize import word_tokenize
  
# ps = PorterStemmer()
  
# # choose some words to be stemmed
# #words = ["program", "programs", "programmer", "programming", "programmers"]
# words = get_text('https://google.com')

# for w in words:
#     print(words,':', ps.stem(words))

# %% [markdown]
# -----------------

# %%
# x= tf_idf_analysis('tote bags')

# #remove the numbers and sort by max tfidf and get the top20 words
# #x['word'].str.isalpha().head(35)
# x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)

# %%
# # import required modules
# import spacy
# nlp = spacy.load("en_core_web_sm")

# # taking input
# text = "run writing"

# # returns a document of object
# doc = nlp(text)

# # checking if it is a noun or not
# if(doc[0].tag_ == 'NNP'):
# 	print(text, " is a noun.")
# else:
# 	print(text, " is a verb.")

# %%
pip install fake-useragent
# Out:
# Collecting fake-useragent
#   Using cached fake_useragent-1.1.3-py3-none-any.whl (50 kB)
# Collecting importlib-resources>=5.0; python_version < "3.10"
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting zipp>=3.1.0; python_version < "3.10"
#   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Installing collected packages: zipp, importlib-resources, fake-useragent
# Successfully installed fake-useragent-1.1.3 importlib-resources-5.12.0 zipp-3.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests-html
# Out:
# Collecting requests-html
#   Using cached requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: fake-useragent in c:\users\hanien\miniconda3\lib\site-packages (from requests-html) (1.1.3)
# Collecting w3lib
#   Using cached w3lib-2.1.1-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14
#   Using cached pyppeteer-1.0.2-py3-none-any.whl (83 kB)
# Collecting bs4
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
# Collecting parse
#   Using cached parse-1.19.0.tar.gz (30 kB)
# Requirement already satisfied: requests in c:\users\hanien\miniconda3\lib\site-packages (from requests-html) (2.24.0)
# Collecting pyquery
#   Using cached pyquery-2.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: importlib-resources>=5.0; python_version < "3.10" in c:\users\hanien\miniconda3\lib\site-packages (from fake-useragent->requests-html) (5.12.0)
# Collecting importlib-metadata>=1.4
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\hanien\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (1.25.11)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp38-cp38-win_amd64.whl (101 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\hanien\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (4.51.0)
# Collecting pyee<9.0.0,>=8.1.0
#   Using cached pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting appdirs<2.0.0,>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: certifi>=2021 in c:\users\hanien\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (2023.5.7)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hanien\miniconda3\lib\site-packages (from requests->requests-html) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\hanien\miniconda3\lib\site-packages (from requests->requests-html) (3.0.4)
# Collecting cssselect>=1.2.0
#   Using cached cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting lxml>=2.1
#   Downloading lxml-4.9.2-cp38-cp38-win_amd64.whl (3.9 MB)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\hanien\miniconda3\lib\site-packages (from importlib-resources>=5.0; python_version < "3.10"->fake-useragent->requests-html) (3.15.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Building wheels for collected packages: bs4, parse
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=176cf336b8d8d016fb8f657fcb7be5affa6f30e0768a6251df8815dd072cfa17
#   Stored in directory: c:\users\hanien\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
#   Building wheel for parse (setup.py): started
#   Building wheel for parse (setup.py): finished with status 'done'
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24584 sha256=3f9365ac0d380ce912d5dae81b25cf50ecdff324eebff5a16545a727b163cec3
#   Stored in directory: c:\users\hanien\appdata\local\pip\cache\wheels\e5\33\1f\68392720485b3ecf125a69e700baaab7624616deedea2fa6e2
# Successfully built bs4 parse
# Installing collected packages: w3lib, importlib-metadata, websockets, pyee, appdirs, pyppeteer, soupsieve, beautifulsoup4, bs4, parse, cssselect, lxml, pyquery, requests-html
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.12.2 bs4-0.0.1 cssselect-1.2.0 importlib-metadata-6.6.0 lxml-4.9.2 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests-html-0.10.0 soupsieve-2.4.1 w3lib-2.1.1 websockets-10.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
# !pip install pandas
import urllib
import pandas as pd
from requests_html import HTML
from requests_html import HTMLSession
# Out:
# Collecting pandas
#   Downloading pandas-2.0.1-cp38-cp38-win_amd64.whl (10.8 MB)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hanien\miniconda3\lib\site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.20.3; python_version < "3.10"
#   Downloading numpy-1.24.3-cp38-cp38-win_amd64.whl (14.9 MB)
# Requirement already satisfied: six>=1.5 in c:\users\hanien\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.24.3 pandas-2.0.1 pytz-2023.3 tzdata-2023.3

# %%
# %pip install scikit-learn
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup

def get_text(url):
    try:
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req,timeout=5).read()
        soup = BeautifulSoup(webpage, "html.parser")
        texts = soup.findAll(text=True)
        res=u" ".join(t.strip() for t in texts if t.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]'])
        return(res)
    except:
        return False
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp38-cp38-win_amd64.whl (8.3 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hanien\miniconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2 scipy-1.10.1 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        #  response = requests.get(url)
        # content = response.content
        # soup = BeautifulSoup(content, "html.parser")
       
        return response
    except requests.exceptions.RequestException as e:
        print(e)
def scrape_google(query):

    query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.co.uk/search?q=" + query)
    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.')

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
scrape_google("cars")
# Out:
# ['https://www.cars.com/shopping/',
#  'https://eg.hatla2ee.com/en/car',
#  'https://www.cars.com/research/',
#  'https://www.youtube.com/watch?v=SbXIj2T-_uk',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://egypt.yallamotor.com/new-cars&prev=search&pto=aue',
#  'https://www.cars.com/',
#  'https://m.imdb.com/title/tt0317219/fullcredits/cast',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://www.contactcars.com/en/newcars&prev=search&pto=aue',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://egypt.yallamotor.com/&prev=search&pto=aue',
#  'https://www.olx.com.eg/en/vehicles/cars-for-sale/',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://www.cars.com/&prev=search&pto=aue',
#  'https://www.imdb.com/title/tt1216475/',
#  'https://www.contactcars.com/en/newcars',
#  'https://egypt.yallamotor.com/',
#  'https://egypt.yallamotor.com/new-cars',
#  'https://www.youtube.com/watch?v=-Vui-DhwIAg',
#  'https://www.imdb.com/title/tt0317219/trivia/',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://eg.hatla2ee.com/en/car&prev=search&pto=aue',
#  'https://cars.disney.com/',
#  'https://www.imdb.com/title/tt0317219/fullcredits',
#  'https://www.imdb.com/title/tt0317219/',
#  'https://www.youtube.com/watch?v=fdGWRq1dVBA',
#  'https://www.cars.com/research/compare/',
#  'https://www.cars.com/sell/',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://www.imdb.com/title/tt0317219/&prev=search&pto=aue']

# %%
# !pip install nltk
from nltk.data import url2pathname
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup


stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words

import nltk
nltk.download('punkt')
# example_sent = get_text('https://en.wikipedia.org/wiki/Machine_learning')
stop_words = set(stopwords.words('english'))

links=scrape_google('cars')

text=[]
for i in links:
  t=get_text(i)
  if t:
    text.append(t)

    word_tokens = word_tokenize(t)
# word_tokens = 

    filtered_sentence = [w for w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)

    filtered_sentence = [w for w in word_tokens if not w in stop_words]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

    print(word_tokens)
    print('---------------------------------')
    print(filtered_sentence)
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: tqdm in c:\users\hanien\miniconda3\lib\site-packages (from nltk) (4.51.0)
# Requirement already satisfied: joblib in c:\users\hanien\miniconda3\lib\site-packages (from nltk) (1.2.0)
# Collecting regex>=2021.8.3
#   Downloading regex-2023.5.5-cp38-cp38-win_amd64.whl (267 kB)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\hanien\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.1.3 nltk-3.8.1 regex-2023.5.5
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Hanien\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hanien\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 179
# C:\Users\Hanien\AppData\Local\Temp\ipykernel_2960\4115364693.py:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.findAll(text=True)
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'My', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Other', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'More', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'My', 'Cars', '(', 'My', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Out', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'My', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'More', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Your', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'My', 'Account', 'Settings', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Log', 'Out', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'up', 'Create', 'a', 'New', 'Account', 'Or', ',', 'you', 'already', 'have', 'an', 'account', '!', 'Mobile', 'number', ',', 'Email', 'or', 'Username', 'Password', 'Reset', 'Your', 'Password', 'Cars', 'for', 'sale', 'Find', 'used', 'car', 'for', 'sale', 'in', 'Egypt', 'Choose', 'a', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'For', 'Sale', 'Hyundai', '(', '1683', ')', 'Chevrolet', '(', '1228', ')', 'Nissan', '(', '1058', ')', 'Fiat', '(', '1038', ')', 'Kia', '(', '966', ')', 'Renault', '(', '706', ')', 'Toyota', '(', '651', ')', 'Mitsubishi', '(', '625', ')', 'Mercedes', '(', '543', ')', 'Opel', '(', '478', ')', 'Peugeot', '(', '469', ')', 'Skoda', '(', '457', ')', 'Other', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '10518', ')', 'SUV', '(', '2047', ')', 'Hatchback', '(', '1690', ')', '4x4', '(', '448', ')', 'MiniVans', '(', '335', ')', 'Coupe', '(', '74', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', ' ...
# ---------------------------------
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'Cars', '(', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'Cars', '(', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'Account', 'Settings', 'Cars', '(', 'Ads', ')', 'Log', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'Create', 'New', 'Account', ',', 'already', 'account', '!', 'Mobile', 'number', ',', 'Email', 'Username', 'Password', 'Reset', 'Password', 'Cars', 'sale', 'Find', 'used', 'car', 'sale', 'Egypt', 'Choose', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'Sale', 'Hyundai', '(', '1683', ')', 'Chevrolet', '(', '1228', ')', 'Nissan', '(', '1058', ')', 'Fiat', '(', '1038', ')', 'Kia', '(', '966', ')', 'Renault', '(', '706', ')', 'Toyota', '(', '651', ')', 'Mitsubishi', '(', '625', ')', 'Mercedes', '(', '543', ')', 'Opel', '(', '478', ')', 'Peugeot', '(', '469', ')', 'Skoda', '(', '457', ')', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '10518', ')', 'SUV', '(', '2047', ')', 'Hatchback', '(', '1690', ')', '4x4', '(', '448', ')', 'MiniVans', '(', '335', ')', 'Coupe', '(', '74', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', '3000', 'CC', '72', '4000', 'CC', '83', '5000', 'CC', '5', '6000', 'CC', '13', 'Select', 'make', 'Alfa', 'Romeo', 'Aston', 'Martin', 'Audi', 'Baic', 'Bentley', 'Bestune', 'BMW', 'Brilliance', 'Bugatti', 'Buick', 'Byd', 'Cadil ...
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ---------------------------------
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ['end', 'mobile', 'ads', 'header', 'begin', 'sis', 'pixel', 'slot', 'Begin', 'SIS', 'code', 'End', 'SIS', 'code', 'begin', 'comscore', 'beacon', 'end', 'comscore', 'beacon', 'end', 'sis', 'pixel', 'slot', 'Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'inline', 'wrapper', 'style', 'based', 'on', 'orientation', 'for', '1p', 'ads', 'begin', 'INLINE20', 'SPONSORED', 'End', 'INLINE20', 'Full', 'Cast', '&', 'Crew', ':', 'Cars', '(', '2006', ')', 'Cast', '(', '86', ')', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Larry', 'the', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '/', 'Hamm', 'Truck', '/', 'Abominable', 'Snow', 'Plow', '/', 'P.T', '.', 'Flea', 'Car', '(', 'voice', ')', 'Joe', 'Ranft', 'Red', '/', 'Jerry', 'Recycled', 'Batteries', '/', 'Peterbilt', '(', 'voice', ')', 'Michael', 'Keaton', 'Chick', 'Hicks', '(', 'voice', ')', 'Richard', 'Petty', 'The', 'King', '(', 'voice', ')', 'Jeremy', 'Piven', 'Harv', '(', 'voice', ')', 'Bob', 'Costas', 'Bob', 'Cutlass', '(', 'voice', ')', 'Darrell', 'Waltrip', 'Darrell', 'Cartrip', '(', 'voice', ')', 'Richard', 'Kind', 'Van', '(', 'voice', ')', 'Edie', 'McClurg', 'Minny', '(', 'voice', ')', 'Humpy', 'Wheeler', 'Tex', '(', 'voice', ')', 'Tom', 'Magliozzi', 'Rusty', 'Rust-eze', '(', 'voice', ')', 'Ray', 'Magliozzi', 'Dusty', 'Rust-eze', '(', 'voice', ')', 'Lynda', 'Petty', 'Mrs', '.', 'The', 'King', '(', 'voice', ')', 'Andrew', 'Stanton', 'Fred', '(', 'voice', ')', 'Dale', 'Earnhardt', 'Jr', '.', 'Junior', '(', 'voice', ')', 'Michael', 'Schumacher', 'Michael', 'Schumacher', 'Ferrari', '(', 'voice', ')', 'Jay', 'Leno', 'Jay', 'Limo', '(', 'voice', ')', 'Mario', 'Andretti', 'Mario', 'Andretti', '(', 'voice', ')', 'Sarah', 'Clark', 'Kori', 'Turbowitz', '(', 'voice', ')', 'Mike', 'Nelson', 'Not', 'Chuck', '(', 'voice', ')', '(', 'as', 'Mike', "'No", 'Name', "'", 'Nelson', ')', 'Jonas', 'Rivera', 'Boost', '(', 'voice', ')', 'Lou', 'Romano', 'Snotrod', '(', 'voice', ')', 'Adrian', 'Ochoa', 'Wingo', '(', 'voice', ')', 'E.J', '.', 'Holowicki', 'DJ', '(', 'voice', ')', 'Elissa', 'Knight', 'Tia', '(', 'voice', ')', 'L ...
# ---------------------------------
# ['end', 'mobile', 'ads', 'header', 'begin', 'sis', 'pixel', 'slot', 'Begin', 'SIS', 'code', 'End', 'SIS', 'code', 'begin', 'comscore', 'beacon', 'end', 'comscore', 'beacon', 'end', 'sis', 'pixel', 'slot', 'Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'inline', 'wrapper', 'style', 'based', 'orientation', '1p', 'ads', 'begin', 'INLINE20', 'SPONSORED', 'End', 'INLINE20', 'Full', 'Cast', '&', 'Crew', ':', 'Cars', '(', '2006', ')', 'Cast', '(', '86', ')', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Larry', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '/', 'Hamm', 'Truck', '/', 'Abominable', 'Snow', 'Plow', '/', 'P.T', '.', 'Flea', 'Car', '(', 'voice', ')', 'Joe', 'Ranft', 'Red', '/', 'Jerry', 'Recycled', 'Batteries', '/', 'Peterbilt', '(', 'voice', ')', 'Michael', 'Keaton', 'Chick', 'Hicks', '(', 'voice', ')', 'Richard', 'Petty', 'King', '(', 'voice', ')', 'Jeremy', 'Piven', 'Harv', '(', 'voice', ')', 'Bob', 'Costas', 'Bob', 'Cutlass', '(', 'voice', ')', 'Darrell', 'Waltrip', 'Darrell', 'Cartrip', '(', 'voice', ')', 'Richard', 'Kind', 'Van', '(', 'voice', ')', 'Edie', 'McClurg', 'Minny', '(', 'voice', ')', 'Humpy', 'Wheeler', 'Tex', '(', 'voice', ')', 'Tom', 'Magliozzi', 'Rusty', 'Rust-eze', '(', 'voice', ')', 'Ray', 'Magliozzi', 'Dusty', 'Rust-eze', '(', 'voice', ')', 'Lynda', 'Petty', 'Mrs', '.', 'King', '(', 'voice', ')', 'Andrew', 'Stanton', 'Fred', '(', 'voice', ')', 'Dale', 'Earnhardt', 'Jr', '.', 'Junior', '(', 'voice', ')', 'Michael', 'Schumacher', 'Michael', 'Schumacher', 'Ferrari', '(', 'voice', ')', 'Jay', 'Leno', 'Jay', 'Limo', '(', 'voice', ')', 'Mario', 'Andretti', 'Mario', 'Andretti', '(', 'voice', ')', 'Sarah', 'Clark', 'Kori', 'Turbowitz', '(', 'voice', ')', 'Mike', 'Nelson', 'Chuck', '(', 'voice', ')', '(', 'Mike', "'No", 'Name', "'", 'Nelson', ')', 'Jonas', 'Rivera', 'Boost', '(', 'voice', ')', 'Lou', 'Romano', 'Snotrod', '(', 'voice', ')', 'Adrian', 'Ochoa', 'Wingo', '(', 'voice', ')', 'E.J', '.', 'Holowicki', 'DJ', '(', 'voice', ')', 'Elissa', 'Knight', 'Tia', '(', 'voice', ')', 'Lindsey', 'Collins', 'Mia', '(', 'voice', ')', 'Larry', 'Benton', 'Motorhome', 'Race', 'Fan', '#', '1', '(', 'voice', ')', 'Douglas', 'Keever', 'Motorhome ...
# ['العربية', 'Post', 'Ad', 'Cars', 'for', 'sale', 'Cars', 'for', 'sale', 'All', 'cars', 'New', 'cars', 'Used', 'cars', 'Electric', 'cars', 'Imported', 'cars', 'Cars', 'can', 'be', 'financed', 'New', 'cars', 'catalog', 'Car', 'valuation', 'Finance', 'Insurance', 'Car', 'maintenance', 'Dealers', '&', 'Showrooms', 'News', 'Post', 'Ad', 'Menu', 'Close', 'Login', '/', 'Sign', 'up', 'Cars', 'for', 'sale', 'All', 'cars', 'New', 'cars', 'Used', 'cars', 'Electric', 'cars', 'Imported', 'cars', 'Cars', 'can', 'be', 'financed', 'New', 'cars', 'catalog', 'Valuate', 'your', 'car', 'Car', 'Finance', 'Insurance', 'Car', 'maintennace', 'Dealers', '&', 'Showrooms', 'Articles', 'Post', 'Ad', 'Language', 'العربية', 'Privacy', 'policy', 'Detailed', 'search', 'Select', 'Brand', 'Choose', 'price', 'Sort', 'according', 'to', 'Close', 'Most', 'recent', 'Price', ':', 'Low', 'to', 'High', 'Price', ':', 'High', 'to', 'Low', 'Year', ':', 'High', 'to', 'Low', 'Year', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'High', 'to', 'Low', 'Status', 'Close', 'All', 'New', 'Used', 'Price', 'Close', 'EGP', 'EGP', 'Suggested', 'Price', 'Less', 'Than', '200,000', 'EGP', 'From', '200,000', 'EGP', 'To', '250,000', 'EGP', 'From', '250,000', 'EGP', 'To', '350,000', 'EGP', 'From', '350,000', 'EGP', 'To', '500,000', 'EGP', 'From', '500,000', 'EGP', 'To', '650,000', 'EGP', 'From', '650,000', 'EGP', 'To', '800,000', 'EGP', 'From', '800,000', 'EGP', 'To', '1,000,000', 'EGP', 'More', 'than', '1,000,000', 'EGP', 'Confirm', 'Detailed', 'search', 'Clear', 'All', 'Sort', 'according', 'to', 'Most', 'recent', 'Sort', 'according', 'to', 'Close', 'Most', 'recent', 'Price', ':', 'Low', 'to', 'High', 'Price', ':', 'High', 'to', 'Low', 'Year', ':', 'High', 'to', 'Low', 'Year', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'High', 'to', 'Low', 'Status', 'All', 'New', 'New', 'Cars', 'Used', 'Used', 'Cars', 'Brand', 'and', 'Model', 'Alfa', 'Romeo', 'Audi', 'BAIC', 'BMW', 'BYD', 'View', 'All', '46', 'Brand', 'Select', 'brand', 'Close', 'Alfa', 'Romeo', 'Audi', 'BAIC', 'BMW', 'BYD', 'Bestune', 'Brilliance', 'Changan', 'Chery', 'Chevrolet', 'Chrysler', 'Citroen', 'Cupra', 'DS', 'Dongfeng', 'Fiat', 'Ford', 'Forthing', 'Geely', 'Haval', 'Honda', 'Hyundai', 'JAC', 'JETOUR', 'Jaguar', 'Jeep', 'Kaiyi', 'Kia', 'Lada', 'Land', 'Rover', 'Lexus', 'MG', 'Maserati', 'Mazda', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Opel', 'Peugeot', 'Porsche', 'Proton', 'Range', 'Rover', 'Renault', 'Seat', 'Skoda', 'SsangYong', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen', 'Volvo', 'Clear', 'All', 'Apply', 'Price', '(', 'EGP', ')', 'EGP', 'EGP', 'Transmission', 'All', 'Manual', 'Automatic', 'Dual', 'Clutch', 'CVT', 'PDK', 'Body', 'Shape', 'Sedan', 'Hatchback', 'SUV', 'Coupe', 'Van', 'Station', 'Cabriolet', 'Pickup', 'Fuel', 'type', 'Gas', 'Diesel', 'Natural', 'Gas', 'Hybrid', 'Electric', 'Engine', 'Capacity', '(', 'cc', ')', 'From', '800', 'to', '1200', 'From', '1300', 'to', '1400', 'From', '1500', 'to', '1600', 'From', '1800', 'to', '2000', 'From', '2200', 'to', '3000', 'More', 'than', '3000', 'Additional', 'Specifications', 'Multi', 'function', 'steering', 'wheel', 'Electronic', 'Stability', 'Program', '(', 'ESP', ')', 'Navigation', 'System', 'Rear', 'parking', 'sensors', 'Paddle', 'shifters', 'ex', ':', 'roof', 'hatch', 'or', 'airbags', 'Additional', 'Specifications', 'Close', 'Multi', 'function', 'steering', 'wheel', 'Electronic', 'Stability', 'Program', '(', 'ESP', ')', 'Navigation', 'System', 'Rear', 'parking', 'sensors', 'Paddle', 'shifters', 'Remove', 'all', 'Apply', 'Cars', 'can', 'be', 'financed', 'by', 'Contact', 'Reset', 'Show', 'all', 'Specifications', 'and', 'prices', 'of', 'new', 'cars', 'from', 'the', 'official', 'importer', 'in', 'Egypt', 'Dealers', '&', 'Showrooms', 'Allam', 'Automotive', 'Ellithy', 'Company', 'ELEmam', 'Motors', 'Khaled', 'Aboud', 'Automotive', 'Quick', 'Links', 'New', 'Cars', 'Used', 'Cars', 'Showrooms', 'N ...
# ---------------------------------
# ['العربية', 'Post', 'Ad', 'Cars', 'sale', 'Cars', 'sale', 'cars', 'New', 'cars', 'Used', 'cars', 'Electric', 'cars', 'Imported', 'cars', 'Cars', 'financed', 'New', 'cars', 'catalog', 'Car', 'valuation', 'Finance', 'Insurance', 'Car', 'maintenance', 'Dealers', '&', 'Showrooms', 'News', 'Post', 'Ad', 'Menu', 'Close', 'Login', '/', 'Sign', 'Cars', 'sale', 'cars', 'New', 'cars', 'Used', 'cars', 'Electric', 'cars', 'Imported', 'cars', 'Cars', 'financed', 'New', 'cars', 'catalog', 'Valuate', 'car', 'Car', 'Finance', 'Insurance', 'Car', 'maintennace', 'Dealers', '&', 'Showrooms', 'Articles', 'Post', 'Ad', 'Language', 'العربية', 'Privacy', 'policy', 'Detailed', 'search', 'Select', 'Brand', 'Choose', 'price', 'Sort', 'according', 'Close', 'recent', 'Price', ':', 'Low', 'High', 'Price', ':', 'High', 'Low', 'Year', ':', 'High', 'Low', 'Year', ':', 'Low', 'High', 'Kilometers', ':', 'Low', 'High', 'Kilometers', ':', 'High', 'Low', 'Status', 'Close', 'New', 'Used', 'Price', 'Close', 'EGP', 'EGP', 'Suggested', 'Price', 'Less', '200,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', '250,000', 'EGP', '350,000', 'EGP', '350,000', 'EGP', '500,000', 'EGP', '500,000', 'EGP', '650,000', 'EGP', '650,000', 'EGP', '800,000', 'EGP', '800,000', 'EGP', '1,000,000', 'EGP', '1,000,000', 'EGP', 'Confirm', 'Detailed', 'search', 'Clear', 'Sort', 'according', 'recent', 'Sort', 'according', 'Close', 'recent', 'Price', ':', 'Low', 'High', 'Price', ':', 'High', 'Low', 'Year', ':', 'High', 'Low', 'Year', ':', 'Low', 'High', 'Kilometers', ':', 'Low', 'High', 'Kilometers', ':', 'High', 'Low', 'Status', 'New', 'New', 'Cars', 'Used', 'Used', 'Cars', 'Brand', 'Model', 'Alfa', 'Romeo', 'Audi', 'BAIC', 'BMW', 'BYD', 'View', '46', 'Brand', 'Select', 'brand', 'Close', 'Alfa', 'Romeo', 'Audi', 'BAIC', 'BMW', 'BYD', 'Bestune', 'Brilliance', 'Changan', 'Chery', 'Chevrolet', 'Chrysler', 'Citroen', 'Cupra', 'DS', 'Dongfeng', 'Fiat', 'Ford', 'Forthing', 'Geely', 'Haval', 'Honda', 'Hyundai', 'JAC', 'JETOUR', 'Jaguar', 'Jeep', 'Kaiyi', 'Kia', 'Lada', 'Land', 'Rover', 'Lexus', 'MG', 'Maserati', 'Mazda', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Opel', 'Peugeot', 'Porsche', 'Proton', 'Range', 'Rover', 'Renault', 'Seat', 'Skoda', 'SsangYong', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen', 'Volvo', 'Clear', 'Apply', 'Price', '(', 'EGP', ')', 'EGP', 'EGP', 'Transmission', 'Manual', 'Automatic', 'Dual', 'Clutch', 'CVT', 'PDK', 'Body', 'Shape', 'Sedan', 'Hatchback', 'SUV', 'Coupe', 'Van', 'Station', 'Cabriolet', 'Pickup', 'Fuel', 'type', 'Gas', 'Diesel', 'Natural', 'Gas', 'Hybrid', 'Electric', 'Engine', 'Capacity', '(', 'cc', ')', '800', '1200', '1300', '1400', '1500', '1600', '1800', '2000', '2200', '3000', '3000', 'Additional', 'Specifications', 'Multi', 'function', 'steering', 'wheel', 'Electronic', 'Stability', 'Program', '(', 'ESP', ')', 'Navigation', 'System', 'Rear', 'parking', 'sensors', 'Paddle', 'shifters', 'ex', ':', 'roof', 'hatch', 'airbags', 'Additional', 'Specifications', 'Close', 'Multi', 'function', 'steering', 'wheel', 'Electronic', 'Stability', 'Program', '(', 'ESP', ')', 'Navigation', 'System', 'Rear', 'parking', 'sensors', 'Paddle', 'shifters', 'Remove', 'Apply', 'Cars', 'financed', 'Contact', 'Reset', 'Show', 'Specifications', 'prices', 'new', 'cars', 'official', 'importer', 'Egypt', 'Dealers', '&', 'Showrooms', 'Allam', 'Automotive', 'Ellithy', 'Company', 'ELEmam', 'Motors', 'Khaled', 'Aboud', 'Automotive', 'Quick', 'Links', 'New', 'Cars', 'Used', 'Cars', 'Showrooms', 'News', 'Reviews', 'Services', 'Book', 'Maintenance', 'Finance', 'Insurance', 'Services', 'directory', 'Us', 'contactcars.com', 'Join', 'Us', '!', 'Contact', 'Us', 'Send', 'Follow', 'Us', 'Download', 'free', 'app', 'Rights', 'Reserved', '©contactcars.com', '2023', 'Terms', 'Use', '&', 'Privacy', 'Policy', 'New', 'Cars', 'Used', 'Cars', 'News', 'Book', 'Maintenance', 'Insurance', 'Quick', 'Links', 'Showrooms', 'Reviews', 'Insurance', 'contactcars.com', 'Join', 'Us', '!', 'Services', 'directory', 'Contac ...
# ['Only', 'in', 'Cars', 'for', 'Sale', 'Login', 'Sell', 'Vehicles', 'Cars', 'for', 'Sale', 'Cars', 'for', 'Rent', 'Tyres', ',', 'Batteries', ',', 'Oils', ',', '&', 'Accessories', 'Car', 'Spare', 'Parts', 'Motorcycles', '&', 'Accessories', 'Boats', '-', 'Watercraft', 'Heavy', 'Trucks', ',', 'Buses', '&', 'Other', 'Vehicles', 'Properties', 'Apartments', '&', 'Duplex', 'for', 'Sale', 'Apartments', '&', 'Duplex', 'for', 'Rent', 'Villas', 'For', 'Sale', 'Villas', 'For', 'Rent', 'Vacation', 'Homes', 'for', 'Sale', 'Vacation', 'Homes', 'for', 'Rent', 'Commercial', 'for', 'Sale', 'Commercial', 'for', 'Rent', 'Buildings', '&', 'Lands', 'Mobiles', '&', 'Tablets', 'Mobile', 'Phones', 'Tablets', 'Mobile', '&', 'Tablet', 'Accessories', 'Mobile', 'Numbers', 'Jobs', 'Accounting', ',', 'Finance', '&', 'Banking', 'Engineering', 'Designers', 'Customer', 'Service', '&', 'Call', 'Center', 'Workers', 'and', 'Technicians', 'Management', '&', 'Consulting', 'Drivers', '&', 'Delivery', 'Education', 'HR', 'Tourism', ',', 'Travel', '&', 'Hospitality', 'IT', '-', 'Telecom', 'Marketing', 'and', 'Public', 'Relations', 'Medical', ',', 'Healthcare', ',', '&', 'Nursing', 'Sales', 'Secretarial', 'Guards', 'and', 'Security', 'Legal', '-', 'Lawyers', 'Other', 'Job', 'More', 'Categories', 'Electronics', '&', 'Home', 'Appliances', 'TV', '-', 'Audio', '-', 'Video', ',', 'Computers', '-', 'Accessories', ',', 'Video', 'games', '-', 'Consoles', 'Home', 'Furniture', '-', 'Decor', 'Bathroom', ',', 'Bedroom', ',', 'Dining', 'Room', 'Fashion', '&', 'Beauty', 'Women', '’', 's', 'Clothing', ',', 'Men', '’', 's', 'Clothing', ',', 'Women', '’', 's', 'Accessories', '-', 'Cosmetics', '-', 'Personal', 'Care', 'Pets', '-', 'Accessories', 'Birds', '-', 'Pigeons', ',', 'Cats', ',', 'Dogs', 'Kids', '&', 'Babies', 'Baby', '&', 'Mom', 'Healthcare', ',', 'Baby', 'Clothing', ',', 'Baby', 'Feeding', 'Tools', 'Books', ',', 'Sports', '&', 'Hobbies', 'Antiques', '-', 'Collectibles', ',', 'Bicycles', ',', 'Books', 'Business', '-', 'Industrial', '-', 'Agriculture', 'Agriculture', ',', 'Construction', ',', 'Industrial', 'Equipment', 'Services', 'Business', ',', 'Car', ',', 'Events', 'All', 'in', 'Electronics', '&', 'Home', 'Appliances', 'TV', '-', 'Audio', '-', 'Video', 'Televisions', 'DVD', '-', 'Home', 'Theater', 'Home', 'Audio', 'Mp3', 'Players', '-', 'Portable', 'audio', 'Satellite', 'TV', 'receivers', 'Computers', '-', 'Accessories', 'Desktop', 'computers', 'Laptop', 'computers', 'Computer', 'Accessories', '&', 'Spare', 'Parts', 'Video', 'games', '-', 'Consoles', 'Video', 'Game', 'Consoles', 'Video', 'Games', '&', 'Accessories', 'Cameras', '-', 'Imaging', 'Cameras', 'Security', 'Cameras', 'Camera', 'Accessories', 'Binoculars', '-', 'Telescopes', 'Home', 'Appliances', 'Refrigerators', '-', 'Freezers', 'Ovens', '-', 'Microwaves', 'Dishwashers', 'Cooking', 'Tools', 'Washers', '-', 'Dryers', 'Water', 'Coolers', '&', 'Kettles', 'Air', 'conditioners', '&', 'Fans', 'Cleaning', 'Appliances', 'Other', 'Home', 'Appliances', 'Heaters', 'All', 'in', 'Home', 'Furniture', '-', 'Decor', 'Bathroom', 'Bedroom', 'Dining', 'Room', 'Fabrics', '-', 'Curtains', '-', 'Carpets', 'Garden', '-', 'Outdoor', 'Home', 'Decoration', 'Kitchen', '-', 'Kitchenware', 'Lighting', 'Tools', 'Living', 'Room', 'Multiple/Other', 'Furniture', 'All', 'in', 'Fashion', '&', 'Beauty', 'Women', '’', 's', 'Clothing', 'Men', '’', 's', 'Clothing', 'Women', '’', 's', 'Accessories', '-', 'Cosmetics', '-', 'Personal', 'Care', 'Men', '’', 's', 'Accessories', '-', 'Personal', 'Care', 'All', 'in', 'Pets', '-', 'Accessories', 'Birds', '-', 'Pigeons', 'Cats', 'Dogs', 'Other', 'Pets', '&', 'Animals', 'Accessories', '-', 'Pet', 'Care', 'Products', 'All', 'in', 'Kids', '&', 'Babies', 'Baby', '&', 'Mom', 'Healthcare', 'Baby', 'Clothing', 'Baby', 'Feeding', 'Tools', 'Cribs', '-', 'Strollers', '-', 'Carriers', 'Toys', 'Other', 'Baby', 'Items', 'All', 'in', 'Books', ',', 'Sports', '&', 'Hobbies', 'Antiques', '-', 'Collectibles', 'Bicycles', 'Books', 'Bo ...
# ---------------------------------
# ['Cars', 'Sale', 'Login', 'Sell', 'Vehicles', 'Cars', 'Sale', 'Cars', 'Rent', 'Tyres', ',', 'Batteries', ',', 'Oils', ',', '&', 'Accessories', 'Car', 'Spare', 'Parts', 'Motorcycles', '&', 'Accessories', 'Boats', '-', 'Watercraft', 'Heavy', 'Trucks', ',', 'Buses', '&', 'Vehicles', 'Properties', 'Apartments', '&', 'Duplex', 'Sale', 'Apartments', '&', 'Duplex', 'Rent', 'Villas', 'Sale', 'Villas', 'Rent', 'Vacation', 'Homes', 'Sale', 'Vacation', 'Homes', 'Rent', 'Commercial', 'Sale', 'Commercial', 'Rent', 'Buildings', '&', 'Lands', 'Mobiles', '&', 'Tablets', 'Mobile', 'Phones', 'Tablets', 'Mobile', '&', 'Tablet', 'Accessories', 'Mobile', 'Numbers', 'Jobs', 'Accounting', ',', 'Finance', '&', 'Banking', 'Engineering', 'Designers', 'Customer', 'Service', '&', 'Call', 'Center', 'Workers', 'Technicians', 'Management', '&', 'Consulting', 'Drivers', '&', 'Delivery', 'Education', 'HR', 'Tourism', ',', 'Travel', '&', 'Hospitality', '-', 'Telecom', 'Marketing', 'Public', 'Relations', 'Medical', ',', 'Healthcare', ',', '&', 'Nursing', 'Sales', 'Secretarial', 'Guards', 'Security', 'Legal', '-', 'Lawyers', 'Job', 'Categories', 'Electronics', '&', 'Home', 'Appliances', 'TV', '-', 'Audio', '-', 'Video', ',', 'Computers', '-', 'Accessories', ',', 'Video', 'games', '-', 'Consoles', 'Home', 'Furniture', '-', 'Decor', 'Bathroom', ',', 'Bedroom', ',', 'Dining', 'Room', 'Fashion', '&', 'Beauty', 'Women', '’', 'Clothing', ',', 'Men', '’', 'Clothing', ',', 'Women', '’', 'Accessories', '-', 'Cosmetics', '-', 'Personal', 'Care', 'Pets', '-', 'Accessories', 'Birds', '-', 'Pigeons', ',', 'Cats', ',', 'Dogs', 'Kids', '&', 'Babies', 'Baby', '&', 'Mom', 'Healthcare', ',', 'Baby', 'Clothing', ',', 'Baby', 'Feeding', 'Tools', 'Books', ',', 'Sports', '&', 'Hobbies', 'Antiques', '-', 'Collectibles', ',', 'Bicycles', ',', 'Books', 'Business', '-', 'Industrial', '-', 'Agriculture', 'Agriculture', ',', 'Construction', ',', 'Industrial', 'Equipment', 'Services', 'Business', ',', 'Car', ',', 'Events', 'Electronics', '&', 'Home', 'Appliances', 'TV', '-', 'Audio', '-', 'Video', 'Televisions', 'DVD', '-', 'Home', 'Theater', 'Home', 'Audio', 'Mp3', 'Players', '-', 'Portable', 'audio', 'Satellite', 'TV', 'receivers', 'Computers', '-', 'Accessories', 'Desktop', 'computers', 'Laptop', 'computers', 'Computer', 'Accessories', '&', 'Spare', 'Parts', 'Video', 'games', '-', 'Consoles', 'Video', 'Game', 'Consoles', 'Video', 'Games', '&', 'Accessories', 'Cameras', '-', 'Imaging', 'Cameras', 'Security', 'Cameras', 'Camera', 'Accessories', 'Binoculars', '-', 'Telescopes', 'Home', 'Appliances', 'Refrigerators', '-', 'Freezers', 'Ovens', '-', 'Microwaves', 'Dishwashers', 'Cooking', 'Tools', 'Washers', '-', 'Dryers', 'Water', 'Coolers', '&', 'Kettles', 'Air', 'conditioners', '&', 'Fans', 'Cleaning', 'Appliances', 'Home', 'Appliances', 'Heaters', 'Home', 'Furniture', '-', 'Decor', 'Bathroom', 'Bedroom', 'Dining', 'Room', 'Fabrics', '-', 'Curtains', '-', 'Carpets', 'Garden', '-', 'Outdoor', 'Home', 'Decoration', 'Kitchen', '-', 'Kitchenware', 'Lighting', 'Tools', 'Living', 'Room', 'Multiple/Other', 'Furniture', 'Fashion', '&', 'Beauty', 'Women', '’', 'Clothing', 'Men', '’', 'Clothing', 'Women', '’', 'Accessories', '-', 'Cosmetics', '-', 'Personal', 'Care', 'Men', '’', 'Accessories', '-', 'Personal', 'Care', 'Pets', '-', 'Accessories', 'Birds', '-', 'Pigeons', 'Cats', 'Dogs', 'Pets', '&', 'Animals', 'Accessories', '-', 'Pet', 'Care', 'Products', 'Kids', '&', 'Babies', 'Baby', '&', 'Mom', 'Healthcare', 'Baby', 'Clothing', 'Baby', 'Feeding', 'Tools', 'Cribs', '-', 'Strollers', '-', 'Carriers', 'Toys', 'Baby', 'Items', 'Books', ',', 'Sports', '&', 'Hobbies', 'Antiques', '-', 'Collectibles', 'Bicycles', 'Books', 'Board', '-', 'Card', 'Games', 'Movies', '-', 'Music', 'Musical', 'Instruments', 'Sports', 'Equipment', 'Study', 'Tools', 'Tickets', '-', 'Vouchers', 'Luggage', 'Items', 'Business', '-', 'Industrial', '-', 'Agriculture', 'Agriculture', 'Construction', 'Industrial', 'Equipment', 'Medical ...
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'Sign', 'In', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'All', 'topics', 'Cars', '2', '2011', 'G', '1h', '46m', 'IMDb', 'RATING', '6.2', '/', '10', '200K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '2,123', '28', 'Play', 'trailer', '0', ':', '44', '50', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'and', 'his', 'pal', 'Mater', 'head', 'overseas', 'to', 'compete', 'in', 'the', 'World', 'Grand', 'Prix', 'race', '.', 'But', 'the', 'road', 'to', 'the', 'championship', 'becomes', 'rocky', 'as', 'Mater', 'gets', 'caught', 'up', 'in', 'an', 'intrigui', '...', 'Read', 'all', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'and', 'his', 'pal', 'Mater', 'head', 'overseas', 'to', 'compete', 'in', 'the', 'World', 'Grand', 'Prix', 'race', '.', 'But', 'the', 'road', 'to', 'the', 'championship', 'becomes', 'rocky', 'as', 'Mater', 'gets', 'caught', 'up', 'in', 'an', 'intriguing', 'adventure', 'of', 'his', 'own', ':', 'international', 'espionage', '.', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'and', 'his', 'pal', 'Mater', 'head', 'overseas', 'to', 'compete', 'in', 'the', 'World', 'Grand', 'Prix', 'race', '.', 'But', 'the', 'road', 'to', 'the', 'championship', 'becomes', 'rocky', 'as', 'Mater', 'gets', 'caught', 'up', 'in', 'an', 'intriguing', 'adventure', 'of', 'his', 'own', ':', 'international', 'espionage', '.', 'Directors', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Writers', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Dan', 'Fogelman', 'Stars', 'Owen', 'Wilson', 'Larry', 'the', 'Cable', 'Guy', 'Michael', 'Caine', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '6.2', '/', '10', '200K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '2,123', '28', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Writers', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Dan', 'Fogelman', 'Stars', 'Owen', 'Wilson', 'Larry', 'the', 'Cable', 'Guy', 'Michael', 'Caine', '436', 'User', 'reviews', '315', 'Critic', 'reviews', '57', 'Metascore', 'See', 'more', 'at', 'IMDbPro', 'Awards', '1', 'win', '&', '19', 'nominations', 'Videos', '50', 'Trailer', '0:44', 'Watch', 'Â', '“', 'Tokyo', 'PartyÂ', '”', 'Trailer', '2:31', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '3', 'Trailer', '2:10', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '2', 'Trailer', '2:15', 'Watch', 'Cars', '2', ':', 'International', 'Trailer', 'Trailer', '1:27', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '1', 'Trailer', '0:35', 'Watch', 'Cars' ...
# ---------------------------------
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'Sign', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'topics', 'Cars', '2', '2011', 'G', '1h', '46m', 'IMDb', 'RATING', '6.2', '/', '10', '200K', 'RATING', 'Rate', 'POPULARITY', '2,123', '28', 'Play', 'trailer', '0', ':', '44', '50', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'pal', 'Mater', 'head', 'overseas', 'compete', 'World', 'Grand', 'Prix', 'race', '.', 'road', 'championship', 'becomes', 'rocky', 'Mater', 'gets', 'caught', 'intrigui', '...', 'Read', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'pal', 'Mater', 'head', 'overseas', 'compete', 'World', 'Grand', 'Prix', 'race', '.', 'road', 'championship', 'becomes', 'rocky', 'Mater', 'gets', 'caught', 'intriguing', 'adventure', ':', 'international', 'espionage', '.', 'Star', 'race', 'car', 'Lightning', 'McQueen', 'pal', 'Mater', 'head', 'overseas', 'compete', 'World', 'Grand', 'Prix', 'race', '.', 'road', 'championship', 'becomes', 'rocky', 'Mater', 'gets', 'caught', 'intriguing', 'adventure', ':', 'international', 'espionage', '.', 'Directors', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Writers', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Dan', 'Fogelman', 'Stars', 'Owen', 'Wilson', 'Larry', 'Cable', 'Guy', 'Michael', 'Caine', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '6.2', '/', '10', '200K', 'RATING', 'Rate', 'POPULARITY', '2,123', '28', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Writers', 'John', 'Lasseter', 'Bradford', 'Lewis', 'Dan', 'Fogelman', 'Stars', 'Owen', 'Wilson', 'Larry', 'Cable', 'Guy', 'Michael', 'Caine', '436', 'User', 'reviews', '315', 'Critic', 'reviews', '57', 'Metascore', 'See', 'IMDbPro', 'Awards', '1', 'win', '&', '19', 'nominations', 'Videos', '50', 'Trailer', '0:44', 'Watch', 'Â', '“', 'Tokyo', 'PartyÂ', '”', 'Trailer', '2:31', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '3', 'Trailer', '2:10', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '2', 'Trailer', '2:15', 'Watch', 'Cars', '2', ':', 'International', 'Trailer', 'Trailer', '1:27', 'Watch', 'Cars', '2', ':', 'Trailer', '#', '1', 'Trailer', '0:35', 'Watch', 'Cars', '2', ':', 'Logo', 'Reveal', 'Clip', '0:41', 'Watch', 'Â', '“', 'Lewis', 'Hamilton/Jeff', 'Gorvette', 'CameosÂ', '”', 'Clip', '1:21', 'Watch', '``', 'Carmac', "''", 'Clip', '0:31', 'Watch', 'Â', '“', 'Meet', 'FinnÂ', '”', 'Clip', '0:57', 'Watch', 'Cars', '2', '--', 'WonderCon', 'Footage', 'Clip', '0:31', 'Watch', 'Cars', '2', ':', 'Meet', 'Finn', 'Clip', '0:25', 'Watch', 'Cars', '2', ':', 'Showroom', 'Turntable', 'Brent', 'Mustangburger', 'Photos', '188', ' ...
# ['العربية', 'Post', 'Ad', 'Cars', 'for', 'sale', 'Cars', 'for', 'sale', 'All', 'cars', 'New', 'cars', 'Used', 'cars', 'Electric', 'cars', 'Imported', 'cars', 'Cars', 'can', 'be', 'financed', 'New', 'cars', 'catalog', 'Car', 'valuation', 'Finance', 'Insurance', 'Car', 'maintenance', 'Dealers', '&', 'Showrooms', 'News', 'Post', 'Ad', 'Menu', 'Close', 'Login', '/', 'Sign', 'up', 'Cars', 'for', 'sale', 'All', 'cars', 'New', 'cars', 'Used', 'cars', 'Electric', 'cars', 'Imported', 'cars', 'Cars', 'can', 'be', 'financed', 'New', 'cars', 'catalog', 'Valuate', 'your', 'car', 'Car', 'Finance', 'Insurance', 'Car', 'maintennace', 'Dealers', '&', 'Showrooms', 'Articles', 'Post', 'Ad', 'Language', 'العربية', 'Privacy', 'policy', 'Detailed', 'search', 'Select', 'Brand', 'Choose', 'price', 'Sort', 'according', 'to', 'Close', 'Most', 'recent', 'Price', ':', 'Low', 'to', 'High', 'Price', ':', 'High', 'to', 'Low', 'Year', ':', 'High', 'to', 'Low', 'Year', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'High', 'to', 'Low', 'Status', 'Close', 'All', 'New', 'Used', 'Price', 'Close', 'EGP', 'EGP', 'Suggested', 'Price', 'Less', 'Than', '200,000', 'EGP', 'From', '200,000', 'EGP', 'To', '250,000', 'EGP', 'From', '250,000', 'EGP', 'To', '350,000', 'EGP', 'From', '350,000', 'EGP', 'To', '500,000', 'EGP', 'From', '500,000', 'EGP', 'To', '650,000', 'EGP', 'From', '650,000', 'EGP', 'To', '800,000', 'EGP', 'From', '800,000', 'EGP', 'To', '1,000,000', 'EGP', 'More', 'than', '1,000,000', 'EGP', 'Confirm', 'Detailed', 'search', 'Clear', 'All', 'Sort', 'according', 'to', 'Most', 'recent', 'Sort', 'according', 'to', 'Close', 'Most', 'recent', 'Price', ':', 'Low', 'to', 'High', 'Price', ':', 'High', 'to', 'Low', 'Year', ':', 'High', 'to', 'Low', 'Year', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'Low', 'to', 'High', 'Kilometers', ':', 'High', 'to', 'Low', 'Status', 'All', 'New', 'New', 'Cars', 'Used', 'Used', 'Cars', 'Brand', 'and', 'Model', 'Alfa', 'Romeo', 'Audi', 'BAIC', 'BMW', 'BYD', 'View', 'All', '46', 'Brand', 'Select', 'brand', 'Close', 'Alfa', 'Romeo', 'Audi', 'BAIC', 'BMW', 'BYD', 'Bestune', 'Brilliance', 'Changan', 'Chery', 'Chevrolet', 'Chrysler', 'Citroen', 'Cupra', 'DS', 'Dongfeng', 'Fiat', 'Ford', 'Forthing', 'Geely', 'Haval', 'Honda', 'Hyundai', 'JAC', 'JETOUR', 'Jaguar', 'Jeep', 'Kaiyi', 'Kia', 'Lada', 'Land', 'Rover', 'Lexus', 'MG', 'Maserati', 'Mazda', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Opel', 'Peugeot', 'Porsche', 'Proton', 'Range', 'Rover', 'Renault', 'Seat', 'Skoda', 'SsangYong', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen', 'Volvo', 'Clear', 'All', 'Apply', 'Price', '(', 'EGP', ')', 'EGP', 'EGP', 'Transmission', 'All', 'Manual', 'Automatic', 'Dual', 'Clutch', 'CVT', 'PDK', 'Body', 'Shape', 'Sedan', 'Hatchback', 'SUV', 'Coupe', 'Van', 'Station', 'Cabriolet', 'Pickup', 'Fuel', 'type', 'Gas', 'Diesel', 'Natural', 'Gas', 'Hybrid', 'Electric', 'Engine', 'Capacity', '(', 'cc', ')', 'From', '800', 'to', '1200', 'From', '1300', 'to', '1400', 'From', '1500', 'to', '1600', 'From', '1800', 'to', '2000', 'From', '2200', 'to', '3000', 'More', 'than', '3000', 'Additional', 'Specifications', 'Multi', 'function', 'steering', 'wheel', 'Electronic', 'Stability', 'Program', '(', 'ESP', ')', 'Navigation', 'System', 'Rear', 'parking', 'sensors', 'Paddle', 'shifters', 'ex', ':', 'roof', 'hatch', 'or', 'airbags', 'Additional', 'Specifications', 'Close', 'Multi', 'function', 'steering', 'wheel', 'Electronic', 'Stability', 'Program', '(', 'ESP', ')', 'Navigation', 'System', 'Rear', 'parking', 'sensors', 'Paddle', 'shifters', 'Remove', 'all', 'Apply', 'Cars', 'can', 'be', 'financed', 'by', 'Contact', 'Reset', 'Show', 'all', 'Specifications', 'and', 'prices', 'of', 'new', 'cars', 'from', 'the', 'official', 'importer', 'in', 'Egypt', 'Dealers', '&', 'Showrooms', 'Allam', 'Automotive', 'Ellithy', 'Company', 'ELEmam', 'Motors', 'Khaled', 'Aboud', 'Automotive', 'Quick', 'Links', 'New', 'Cars', 'Used', 'Cars', 'Showrooms', 'N ...
# ---------------------------------
# ...
# ---------------------------------
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'Sign', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'topics', 'Cars', '2006', 'G', '1h', '57m', 'IMDb', 'RATING', '7.2', '/', '10', '437K', 'RATING', 'Rate', 'POPULARITY', '443', '15', 'Play', 'clip', '4', ':', '37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', '7', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '7.2', '/', '10', '437K', 'RATING', 'Rate', 'POPULARITY', '443', '15', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', '776', 'User', 'reviews', '253', 'Critic', 'reviews', '73', 'Metascore', 'See', 'IMDbPro', 'Nominated', '2', 'Oscars', '28', 'wins', '&', '34', 'nominations', 'total', 'Videos', '7', 'Clip', '4:37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', 'Clip', '0:34', 'Watch', 'Cars', ':', '3D', 'Clip', '0:46', 'Watch', 'Cars', ':', '3D', 'Clip', '1:23', 'Watch', 'Cars', ':', '3D', 'Clip', '0:51', 'Watch', 'Cars', ':', '3D', 'Clip', '1:12', 'Watch', 'Cars', ':', '3D', 'Clip', '1:18', 'Watch', 'Cars', ':', '3D', 'Photos', '277', 'Top', 'cast', 'Edit', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Larry', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '(', 'voice', ')', '…', ' ...
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ---------------------------------
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'Sign', 'In', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'All', 'topics', 'Cars', '2006', 'G', '1h', '57m', 'IMDb', 'RATING', '7.2', '/', '10', '437K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '443', '15', 'Play', 'clip', '4', ':', '37', 'Watch', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', '7', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '7.2', '/', '10', '437K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '443', '15', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', '776', 'User', 'reviews', '253', 'Critic', 'reviews', '73', 'Metascore', 'See', 'more', 'at', 'IMDbPro', 'Nominated', 'for', '2', 'Oscars', '28', 'wins', '&', '34', 'nominations', 'total', 'Videos', '7', 'Clip', '4:37', 'Watch', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', 'Clip', '0:34', 'Watch', 'Cars', ':', '3D', 'Clip', '0:46', 'Watch', 'Cars', ':', '3D', 'Clip', '1:23', 'Watch', 'Cars', ':', '3D', 'Clip', '0:51', 'Watch', 'Cars', ':', '3D', 'Clip', '1:12', 'Watch', 'Cars', ':', '3D', 'Clip', '1:18', 'Watch', 'Cars', ':', '3D', 'Photos', '277', 'Top', 'cast', 'Edit', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Larry', 'the', 'Cable', 'Guy', 'Mater', '(', 'voice', ') ...
# ---------------------------------
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'Asian', 'Heritage', 'Month', 'Cannes', 'Star', 'Wars', 'Celebration', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'Sign', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'topics', 'Cars', '2006', 'G', '1h', '57m', 'IMDb', 'RATING', '7.2', '/', '10', '437K', 'RATING', 'Rate', 'POPULARITY', '443', '15', 'Play', 'clip', '4', ':', '37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', '7', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '7.2', '/', '10', '437K', 'RATING', 'Rate', 'POPULARITY', '443', '15', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', '776', 'User', 'reviews', '253', 'Critic', 'reviews', '73', 'Metascore', 'See', 'IMDbPro', 'Nominated', '2', 'Oscars', '28', 'wins', '&', '34', 'nominations', 'total', 'Videos', '7', 'Clip', '4:37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', 'Clip', '0:34', 'Watch', 'Cars', ':', '3D', 'Clip', '0:46', 'Watch', 'Cars', ':', '3D', 'Clip', '1:23', 'Watch', 'Cars', ':', '3D', 'Clip', '0:51', 'Watch', 'Cars', ':', '3D', 'Clip', '1:12', 'Watch', 'Cars', ':', '3D', 'Clip', '1:18', 'Watch', 'Cars', ':', '3D', 'Photos', '277', 'Top', 'cast', 'Edit', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Larry', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '(', 'voice', ')', '…', ' ...

# %%
import nltk
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')
p_stemmer = PorterStemmer()

for word in filtered_sentence:
    if len(word) >= 3:
        print(word+' --> '+p_stemmer.stem(word))
        print(word+' --> '+s_stemmer.stem(word))
# for word in  filtered_sentence:
#     print(word+' --> '+p_stemmer.stem(word))

# for word in filtered_sentence:
#     print(word+' --> '+s_stemmer.stem(word))
u=p_stemmer.stem(word) + s_stemmer.stem(word)
# Out:
# Release --> releas
# Release --> releas
# Calendar --> calendar
# Calendar --> calendar
# Popular --> popular
# Popular --> popular
# Showtimes --> showtim
# Showtimes --> showtim
# Tickets --> ticket
# Tickets --> ticket
# Spotlight --> spotlight
# Spotlight --> spotlight
# Streaming --> stream
# Streaming --> stream
# Popular --> popular
# Popular --> popular
# Spotlight --> spotlight
# Spotlight --> spotlight
# Trailers --> trailer
# Trailers --> trailer
# Originals --> origin
# Originals --> origin
# Podcasts --> podcast
# Podcasts --> podcast
# Heritage --> heritag
# Heritage --> heritag
# Celebration --> celebr
# Celebration --> celebr
# STARmeter --> starmet
# STARmeter --> starmet
# Central --> central
# Central --> central
# Festival --> festiv
# Festival --> festiv
# Central --> central
# Central --> central
# Popular --> popular
# Popular --> popular
# Popular --> popular
# Popular --> popular
# Celebrity --> celebr
# Celebrity --> celebr
# Community --> commun
# Community --> communiti
# Contributor --> contributor
# Contributor --> contributor
# Industry --> industri
# Industry --> industri
# Professionals --> profession
# Professionals --> profession
# Episodes --> episod
# Episodes --> episod
# Companies --> compani
# Companies --> compani
# Keywords --> keyword
# Keywords --> keyword
# Advanced --> advanc
# Advanced --> advanc
# Watchlist --> watchlist
# Watchlist --> watchlist
# Customer --> custom
# Customer --> custom
# account --> account
# account --> account
# supported --> support
# supported --> support
# English --> english
# English --> english
# Partially --> partial
# Partially --> partial
# supported --> support
# supported --> support
# Français --> françai
# Français --> françai
# Français --> françai
# Français --> françai
# Deutsch --> deutsch
# Deutsch --> deutsch
# Deutschland --> deutschland
# Deutschland --> deutschland
# Italiano --> italiano
# Italiano --> italiano
# Português --> portuguê
# Português --> portuguê
# Español --> español
# Español --> español
# Español --> español
# Español --> español
# reviews --> review
# reviews --> review
# IMDbPro --> imdbpro
# IMDbPro --> imdbpro
# POPULARITY --> popular
# POPULARITY --> popular
# Animation --> anim
# Animation --> anim
# Adventure --> adventur
# Adventure --> adventur
# biggest --> biggest
# biggest --> biggest
# hotshot --> hotshot
# hotshot --> hotshot
# stranded --> strand
# stranded --> strand
# rundown --> rundown
# rundown --> rundown
# winning --> win
# winning --> win
# everything --> everyth
# everything --> everyth
# biggest --> biggest
# biggest --> biggest
# hotshot --> hotshot
# hotshot --> hotshot
# stranded --> strand
# stranded --> strand
# rundown --> rundown
# rundown --> rundown
# winning --> win
# winning --> win
# everything --> everyth
# everything --> everyth
# biggest --> biggest
# biggest --> biggest
# hotshot --> hotshot
# hotshot --> hotshot
# stranded --> strand
# stranded --> strand
# rundown --> rundown
# rundown --> rundown
# winning --> win
# winning --> win
# everything --> everyth
# everything --> everyth
# Directors --> director
# Directors --> director
# Lasseter --> lasset
# Lasseter --> lasset
# Writers --> writer
# Writers --> writer
# Lasseter --> lasset
# Lasseter --> lasset
# Klubien --> klubien
# Klubien --> klubien
# production --> product
# production --> product
# company --> compani
# company --> compani
# POPULARITY --> popular
# POPULARITY --> popular
# credits --> credit
# credits --> credit
# Directors --> director
# Directors --> director
# Lasseter --> lasset
# Lasseter --> lasset
# Writers --> writer
# Writers --> writer
# Lasseter --> lasset
# Lasseter --> lasset
# Klubien --> klubien
# Klubien --> klubien
# reviews --> review
# reviews --> review
# reviews --> review
# reviews --> review
# Metascore --> metascor
# Metascore --> metascor
# IMDbPro --> imdbpro
# IMDbPro --> imdbpro
# Nominated --> nomin
# Nominated --> nomin
# nominations --> nomin
# nominations --> nomin
# Lightning --> lightn
# Lightning --> lightn
# McQueen --> mcqueen
# McQueen --> mcqueen
# Carrera --> carrera
# Carrera --> carrera
# Shalhoub --> shalhoub
# Shalhoub --> shalhoub
# Quaroni --> quaroni
# Quaroni --> quaroni
# Jenifer --> jenif
# Jenifer --> jenif
# Michael --> michael
# Michael --> michael
# Sheriff --> sheriff
# Sheriff --> sheriff
# Fillmore --> fillmor
# Fillmore --> fillmor
# Katherine --> katherin
# Katherine --> katherin
# Helmond --> helmond
# Helmond --> helmond
# Ratzenberger --> ratzenberg
# Ratzenberger --> ratzenberg
# Michael --> michael
# Michael --> michael
# Richard --> richard
# Richard --> richard
# Cutlass --> cutlass
# Cutlass --> cutlass
# Directors --> director
# Directors --> director
# Lasseter --> lasset
# Lasseter --> lasset
# co-director --> co-director
# co-director --> co-director
# Writers --> writer
# Writers --> writer
# Lasseter --> lasset
# Lasseter --> lasset
# original --> origin
# original --> origin
# screenplay --> screenplay
# screenplay --> screenplay
# original --> origin
# original --> origin
# screenplay --> screenplay
# screenplay --> screenplay
# Klubien --> klubien
# Klubien --> klubien
# original --> origin
# original --> origin
# screenplay --> screenplay
# screenplay --> screenplay
# Production --> product
# Production --> product
# IMDbPro --> imdbpro
# IMDbPro --> imdbpro
# Monsters --> monster
# Monsters --> monster
# University --> univers
# University --> univers
# Madagascar --> madagascar
# Madagascar --> madagascar
# Despicable --> despic
# Despicable --> despic
# Monsters --> monster
# Monsters --> monster
# Incredibles --> incred
# Incredibles --> incred
# Finding --> find
# Finding --> find
# Storyline --> storylin
# Storyline --> storylin
# computers --> comput
# computers --> comput
# Incredibles --> incred
# Incredibles --> incred
# average --> averag
# average --> averag
# processor --> processor
# processor --> processor
# tractors --> tractor
# tractors --> tractor
# McQueen --> mcqueen
# McQueen --> mcqueen
# attempts --> attempt
# attempts --> attempt
# tractors --> tractor
# tractors --> tractor
# tipping --> tip
# tipping --> tip
# initially --> initi
# initially --> initi
# nowhere --> nowher
# nowhere --> nowher
# appreciably --> appreci
# appreciably --> appreci
# tractors --> tractor
# tractors --> tractor
# on-screen --> on-screen
# on-screen --> on-screen
# Lightning --> lightn
# Lightning --> lightn
# McQueen --> mcqueen
# McQueen --> mcqueen
# credits --> credit
# credits --> credit
# credits --> credit
# credits --> credit
# contain --> contain
# contain --> contain
# dedication --> dedic
# dedication --> dedic
# retrospective --> retrospect
# retrospective --> retrospect
# characters --> charact
# characters --> charact
# Alternate --> altern
# Alternate --> altern
# versions --> version
# versions --> version
# version --> version
# version --> version
# features --> featur
# features --> featur
# Clarkson --> clarkson
# Clarkson --> clarkson
# instead --> instead
# instead --> instead
# version --> version
# version --> version
# available --> avail
# available --> avail
# worldwide --> worldwid
# worldwide --> worldwid
# Disney+ --> disney+
# Disney+ --> disney+
# Connections --> connect
# Connections --> connect
# Featured --> featur
# Featured --> featur
# Anniversary --> anniversari
# Anniversary --> anniversari
# Special --> special
# Special --> special
# Soundtracks --> soundtrack
# Soundtracks --> soundtrack
# Highway --> highway
# Highway --> highway
# Written --> written
# Written --> written
# Cochrane --> cochran
# Cochrane --> cochran
# Cochrane --> cochran
# Cochrane --> cochran
# Performed --> perform
# Performed --> perform
# Produced --> produc
# Produced --> produc
# Recorded --> record
# Recorded --> record
# Niebank --> niebank
# Niebank --> niebank
# Niebank --> niebank
# Niebank --> niebank
# courtesy --> courtesi
# courtesy --> courtesi
# Records --> record
# Records --> record
# reviews --> review
# reviews --> review
# Featured --> featur
# Featured --> featur
# enjoyable --> enjoy
# enjoyable --> enjoy
# previous --> previou
# previous --> previous
# Incredibles --> incred
# Incredibles --> incred
# entertaining --> entertain
# entertaining --> entertain
# likable --> likabl
# likable --> likabl
# characters --> charact
# characters --> charact
# Despite --> despit
# Despite --> despit
# strangeness --> strang
# strangeness --> strang
# premise --> premis
# premise --> premis
# inhabited --> inhabit
# inhabited --> inhabit
# execution --> execut
# execution --> execut
# convincing --> convinc
# convincing --> convinc
# character --> charact
# character --> charact
# development --> develop
# development --> develop
# heartwarming --> heartwarm
# heartwarming --> heartwarm
# moments --> moment
# moments --> moment
# Without --> without
# Without --> without
# perfect --> perfect
# perfect --> perfect
# managed --> manag
# managed --> manag
# something --> someth
# something --> someth
# totally --> total
# totally --> total
# worth-watching --> worth-watch
# worth-watching --> worth-watch
# beginning --> begin
# beginning --> begin
# considered --> consid
# considered --> consid
# animated --> anim
# animated --> anim
# terrible --> terribl
# terrible --> terribl
# opinion --> opinion
# opinion --> opinion
# helpful --> help
# helpful --> help
# Rectangular_businessman --> rectangular_businessman
# Rectangular_businessman --> rectangular_businessman
# Watchlist --> watchlist
# Watchlist --> watchlist
# personalized --> person
# personalized --> person
# recommendations --> recommend
# recommendations --> recommend
# intended --> intend
# intended --> intend
# sporting --> sport
# sporting --> sport
# Budweiser --> budweis
# Budweiser --> budweis
# product --> product
# product --> product
# placement --> placement
# placement --> placement
# Angeles --> angel
# Angeles --> angel
# International --> intern
# International --> intern
# Speedway --> speedway
# Speedway --> speedway
# Speedway --> speedway
# Speedway --> speedway
# Details --> detail
# Details --> detail
# Release --> releas
# Release --> releas
# September --> septemb
# September --> septemb
# Country --> countri
# Country --> countri
# Official --> offici
# Official --> offici
# Official --> offici
# Official --> offici
# Languages --> languag
# Languages --> languag
# English --> english
# English --> english
# Italian --> italian
# Italian --> italian
# Japanese --> japanes
# Japanese --> japanes
# Yiddish --> yiddish
# Yiddish --> yiddish
# Sayarat --> sayarat
# Sayarat --> sayarat
# Filming --> film
# Filming --> film
# locations --> locat
# locations --> locat
# Animation --> anim
# Animation --> anim
# Studios --> studio
# Studios --> studio
# Emeryville --> emeryvil
# Emeryville --> emeryvill
# California --> california
# California --> california
# Production --> product
# Production --> product
# companies --> compani
# companies --> compani
# Animation --> anim
# Animation --> anim
# Studios --> studio
# Studios --> studio
# Pictures --> pictur
# Pictures --> pictur
# company --> compani
# company --> compani
# credits --> credit
# credits --> credit
# IMDbPro --> imdbpro
# IMDbPro --> imdbpro
# 120,000,000 --> 120,000,000
# 120,000,000 --> 120,000,000
# estimated --> estim
# estimated --> estim
# 244,082,982 --> 244,082,982
# 244,082,982 --> 244,082,982
# Opening --> open
# Opening --> open
# weekend --> weekend
# weekend --> weekend
# 60,119,509 --> 60,119,509
# 60,119,509 --> 60,119,509
# worldwide --> worldwid
# worldwide --> worldwid
# 461,991,867 --> 461,991,867
# 461,991,867 --> 461,991,867
# detailed --> detail
# detailed --> detail
# IMDbPro --> imdbpro
# IMDbPro --> imdbpro
# Technical --> technic
# Technical --> technic
# Runtime --> runtim
# Runtime --> runtim
# minutes --> minut
# minutes --> minut
# Digital --> digit
# Digital --> digit
# Related --> relat
# Related --> relat
# Contribute --> contribut
# Contribute --> contribut
# Suggest --> suggest
# Suggest --> suggest
# missing --> miss
# missing --> miss
# content --> content
# content --> content
# Answers --> answer
# Answers --> answer
# contributing --> contribut
# contributing --> contribut
# explore --> explor
# explore --> explor
# Recently --> recent
# Recently --> recent
# recently --> recent
# recently --> recent
# IMDbPro --> imdbpro
# IMDbPro --> imdbpro
# Developer --> develop
# Developer --> develop
# Advertising --> advertis
# Advertising --> advertis
# Conditions --> condit
# Conditions --> condit
# Privacy --> privaci
# Privacy --> privaci
# Privacy --> privaci
# Privacy --> privaci
# Choices --> choic
# Choices --> choic
# IMDb.com --> imdb.com
# IMDb.com --> imdb.com

# %%
# import pandas as pd
# def tf_idf_analysis(keyword):
#   v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
#   x = v.fit_transform(text)

#   f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
#   d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
#   tf=pd.DataFrame((f>0).sum(axis=0))


#   d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

#   d.columns=['word','average_tfidf','max_tfidf','frequency']

#   d['frequency']=round((d['frequency']/len(text))*100)

#   return(d)


# x= tf_idf_analysis(u)
# x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
# print(x)

import pandas as pd
def tf_idf_analysis(keyword):
    v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=list(stop_words))
    x = v.fit_transform(text)

    f = pd.DataFrame(x.toarray(), columns = v.get_feature_names_out())
    d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    tf=pd.DataFrame((f>0).sum(axis=0))


    d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

    d.columns=['word','average_tfidf','max_tfidf','frequency']

    d['frequency']=round((d['frequency']/len(text))*100)

    return(d)

x= tf_idf_analysis(u)
x = x[x['word'].str.isalpha() & (x['word'].str.len() >= 4)].sort_values('max_tfidf', ascending=False).head(35)
print(x)
# Out:
#                word  average_tfidf  max_tfidf  frequency
# 14705         voice       0.095671   0.712135       31.0
# 12541         share       0.025670   0.410717        6.0
# 7589    interesting       0.025620   0.409920        6.0
# 13020          span       0.032493   0.315648       12.0
# 14826        voices       0.018242   0.288398       12.0
# 4533   customizable       0.017727   0.283634        6.0
# 4865         disney       0.022434   0.280989       31.0
# 10973         price       0.046644   0.269678       44.0
# 4649           days       0.016031   0.254419       12.0
# 5322          egypt       0.033418   0.252177       56.0
# 3089          cairo       0.022436   0.249685       19.0
# 3378           cars       0.085132   0.247731       81.0
# 7053           high       0.030613   0.243658       19.0
# 3886          class       0.027358   0.243606       19.0
# 1794     additional       0.018272   0.215297       31.0
# 10568     permalink       0.012810   0.204960        6.0
# 14330       twitter       0.012810   0.204960        6.0
# 10129       options       0.011669   0.178494       12.0
# 14171       trailer       0.010615   0.166362       12.0
# 7046           hide       0.011652   0.159717       19.0
# 6348          found       0.012110   0.159095       19.0
# 8996          mater       0.026592   0.156567       38.0
# 13225          star       0.023687   0.154008       50.0
# 14804        voiced       0.011617   0.147584       25.0
# 8419      lightning       0.020233   0.146122       38.0
# 5775       facebook       0.010852   0.145151       25.0
# 7393           imdb       0.029049   0.144628       31.0
# 15405       الأحكام       0.026077   0.139075       19.0
# 15407       الإعلان       0.026077   0.139075       19.0
# 15413       البرامج       0.026077   0.139075       19.0
# 15421       التواصل       0.026077   0.139075       19.0
# 15423       الجديدة       0.026077   0.139075       19.0
# 15338       youtube       0.026077   0.139075       19.0
# 15427      الخصوصية       0.026077   0.139075       19.0
# 15435       السياسة       0.026077   0.139075       19.0

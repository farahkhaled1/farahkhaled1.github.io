# %%
pip install fake-useragent
# Out:
# Requirement already satisfied: fake-useragent in /opt/homebrew/lib/python3.10/site-packages (1.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests-html
# Out:
# Requirement already satisfied: requests-html in /opt/homebrew/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.10/site-packages (from requests-html) (2.28.2)
# Requirement already satisfied: pyquery in /opt/homebrew/lib/python3.10/site-packages (from requests-html) (2.0.0)
# Requirement already satisfied: fake-useragent in /opt/homebrew/lib/python3.10/site-packages (from requests-html) (1.1.3)
# Requirement already satisfied: parse in /opt/homebrew/lib/python3.10/site-packages (from requests-html) (1.19.0)
# Requirement already satisfied: bs4 in /opt/homebrew/lib/python3.10/site-packages (from requests-html) (0.0.1)
# Requirement already satisfied: w3lib in /opt/homebrew/lib/python3.10/site-packages (from requests-html) (2.1.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /opt/homebrew/lib/python3.10/site-packages (from requests-html) (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /opt/homebrew/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /opt/homebrew/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html) (2022.12.7)
# Requirement already satisfied: importlib-metadata>=1.4 in /opt/homebrew/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html) (6.5.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /opt/homebrew/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /opt/homebrew/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /opt/homebrew/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html) (1.26.15)
# Requirement already satisfied: websockets<11.0,>=10.0 in /opt/homebrew/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html) (10.4)
# Requirement already satisfied: beautifulsoup4 in /Users/farahkhaled/Library/Python/3.10/lib/python/site-packages (from bs4->requests-html) (4.11.1)
# Requirement already satisfied: lxml>=2.1 in /opt/homebrew/lib/python3.10/site-packages (from pyquery->requests-html) (4.9.2)
# Requirement already satisfied: cssselect>=1.2.0 in /opt/homebrew/lib/python3.10/site-packages (from pyquery->requests-html) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests->requests-html) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests->requests-html) (3.4)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.10/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.15.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/farahkhaled/Library/Python/3.10/lib/python/site-packages (from beautifulsoup4->bs4->requests-html) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import urllib
import pandas as pd
from requests_html import HTML
from requests_html import HTMLSession

# %%
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup

def get_text(url):
    try:
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req,timeout=5).read()
        soup = BeautifulSoup(webpage, "html.parser")
        texts = soup.findAll(text=True)
        res=u" ".join(t.strip() for t in texts if t.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]'])
        return(res)
    except:
        return False

# %%
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        #  response = requests.get(url)
        # content = response.content
        # soup = BeautifulSoup(content, "html.parser")
       
        return response
    except requests.exceptions.RequestException as e:
        print(e)
def scrape_google(query):

    query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.co.uk/search?q=" + query)
    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.')

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
scrape_google("cars")
# Out:
# ['https://www.cars.com/research/',
#  'https://eg.hatla2ee.com/en/car',
#  'https://www.youtube.com/watch?v=fdGWRq1dVBA',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://eg.hatla2ee.com/en/car&prev=search&pto=aue',
#  'https://www.imdb.com/title/tt0317219/',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://www.imdb.com/title/tt0317219/&prev=search&pto=aue',
#  'https://egypt.yallamotor.com/',
#  'https://www.olx.com.eg/en/vehicles/cars-for-sale/',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://egypt.yallamotor.com/&prev=search&pto=aue',
#  'https://www.cars.com/',
#  'https://www.youtube.com/watch?v=SbXIj2T-_uk',
#  'https://egypt.yallamotor.com/new-cars',
#  'https://www.youtube.com/watch?v=-Vui-DhwIAg',
#  'https://www.contactcars.com/en/newcars',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://www.contactcars.com/en/newcars&prev=search&pto=aue',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://egypt.yallamotor.com/new-cars&prev=search&pto=aue',
#  'https://translate.google.co.uk/translate?hl=ar&sl=en&u=https://www.cars.com/&prev=search&pto=aue',
#  'https://www.cars.com/sell/',
#  'https://www.cars.com/shopping/advanced-search/',
#  'https://www.cars.com/shopping/',
#  'https://cars.disney.com/']

# %%
from nltk.data import url2pathname
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
from fake_useragent import UserAgent
import re
from urllib.request import Request, urlopen
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import math

from bs4 import BeautifulSoup


stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words

import nltk
nltk.download('punkt')
# example_sent = get_text('https://en.wikipedia.org/wiki/Machine_learning')
stop_words = set(stopwords.words('english'))

links=scrape_google('cars')

text=[]
for i in links:
  t=get_text(i)
  if t:
    text.append(t)

    word_tokens = word_tokenize(t)
# word_tokens = 

    filtered_sentence = [w for w in word_tokens]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)

    filtered_sentence = [w for w in word_tokens if not w in stop_words]

    # print(word_tokens)
    # print('---------------------------------')
    # print(filtered_sentence)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

    print(word_tokens)
    print('---------------------------------')
    print(filtered_sentence)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/farahkhaled/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/farahkhaled/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 179
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'My', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Other', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'More', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'My', 'Cars', '(', 'My', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Out', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'My', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'More', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Your', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'My', 'Account', 'Settings', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Log', 'Out', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'up', 'Create', 'a', 'New', 'Account', 'Or', ',', 'you', 'already', 'have', 'an', 'account', '!', 'Mobile', 'number', ',', 'Email', 'or', 'Username', 'Password', 'Reset', 'Your', 'Password', 'Cars', 'for', 'sale', 'Find', 'used', 'car', 'for', 'sale', 'in', 'Egypt', 'Choose', 'a', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'For', 'Sale', 'Hyundai', '(', '1768', ')', 'Chevrolet', '(', '1274', ')', 'Nissan', '(', '1117', ')', 'Fiat', '(', '1114', ')', 'Kia', '(', '1085', ')', 'Renault', '(', '788', ')', 'Toyota', '(', '723', ')', 'Mitsubishi', '(', '654', ')', 'Mercedes', '(', '603', ')', 'Opel', '(', '530', ')', 'Skoda', '(', '522', ')', 'Peugeot', '(', '506', ')', 'Other', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '11353', ')', 'SUV', '(', '2316', ')', 'Hatchback', '(', '1808', ')', '4x4', '(', '499', ')', 'MiniVans', '(', '366', ')', 'Coupe', '(', '90', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298',  ...
# ---------------------------------
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'Cars', '(', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'Cars', '(', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'Account', 'Settings', 'Cars', '(', 'Ads', ')', 'Log', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'Create', 'New', 'Account', ',', 'already', 'account', '!', 'Mobile', 'number', ',', 'Email', 'Username', 'Password', 'Reset', 'Password', 'Cars', 'sale', 'Find', 'used', 'car', 'sale', 'Egypt', 'Choose', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'Sale', 'Hyundai', '(', '1768', ')', 'Chevrolet', '(', '1274', ')', 'Nissan', '(', '1117', ')', 'Fiat', '(', '1114', ')', 'Kia', '(', '1085', ')', 'Renault', '(', '788', ')', 'Toyota', '(', '723', ')', 'Mitsubishi', '(', '654', ')', 'Mercedes', '(', '603', ')', 'Opel', '(', '530', ')', 'Skoda', '(', '522', ')', 'Peugeot', '(', '506', ')', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '11353', ')', 'SUV', '(', '2316', ')', 'Hatchback', '(', '1808', ')', '4x4', '(', '499', ')', 'MiniVans', '(', '366', ')', 'Coupe', '(', '90', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', '3000', 'CC', '72', '4000', 'CC', '83', '5000', 'CC', '5', '6000', 'CC', '13', 'Select', 'make', 'Alfa', 'Romeo', 'Aston', 'Martin', 'Audi', 'Baic', 'Bentley', 'Bestune', 'BMW', 'Brilliance', 'Bugatti', 'Buick', 'Byd', 'Cadi ...
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ---------------------------------
# ['حول', 'الصحافة', 'حقوق', 'الطبع', 'والنشر', 'التواصل', 'معنا', 'صنّاع', 'المحتوى', 'الإعلان', 'مطوّرو', 'البرامج', 'الأحكام', 'الخصوصية', 'السياسة', 'والأمان', 'آلية', 'عمل', 'YouTube', 'تجربة', 'الميزات', 'الجديدة', '©', '2023', 'Google', 'LLC']
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'My', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Other', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'More', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'My', 'Cars', '(', 'My', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Out', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'in', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Other', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'My', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'More', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Your', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'My', 'Account', 'Settings', 'My', 'Cars', '(', 'My', 'Ads', ')', 'Log', 'Out', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'up', 'Create', 'a', 'New', 'Account', 'Or', ',', 'you', 'already', 'have', 'an', 'account', '!', 'Mobile', 'number', ',', 'Email', 'or', 'Username', 'Password', 'Reset', 'Your', 'Password', 'Cars', 'for', 'sale', 'Find', 'used', 'car', 'for', 'sale', 'in', 'Egypt', 'Choose', 'a', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'For', 'Sale', 'Hyundai', '(', '1768', ')', 'Chevrolet', '(', '1274', ')', 'Nissan', '(', '1117', ')', 'Fiat', '(', '1114', ')', 'Kia', '(', '1085', ')', 'Renault', '(', '788', ')', 'Toyota', '(', '723', ')', 'Mitsubishi', '(', '654', ')', 'Mercedes', '(', '603', ')', 'Opel', '(', '530', ')', 'Skoda', '(', '522', ')', 'Peugeot', '(', '506', ')', 'Other', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '11353', ')', 'SUV', '(', '2316', ')', 'Hatchback', '(', '1808', ')', '4x4', '(', '499', ')', 'MiniVans', '(', '366', ')', 'Coupe', '(', '90', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298',  ...
# ---------------------------------
# ['menu', 'search', 'add_circle_outline', '×', 'Find', 'used', 'car', 'keyboard_arrow_right', 'account_circle', 'Account', 'keyboard_arrow_right', 'account_circle', 'Login', '/', 'Register', 'time_to_leave', 'Cars', '(', 'Ads', ')', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Get', 'Hatla2ee', 'App', 'Download', 'Mobile', 'App', 'Vehicles', 'keyboard_arrow_right', 'more_horiz', 'keyboard_arrow_right', 'keyboard_backspace', 'Choose', 'Country', 'keyboard_backspace', 'Welcome', 'settings', 'Settings', 'account_circle', 'Cars', '(', 'Ads', ')', 'call_missed_outgoing', 'Log', 'Used', 'Cars', 'New', 'Cars', 'Imported', 'Cars', 'Car', 'Evaluation', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'android', 'Download', 'Mobile', 'App', 'phone_iphone', 'Download', 'Mobile', 'App', 'Car', 'Prices', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Changes', 'New', 'Car', 'Prices', 'Car', 'Maintenance', 'Prices', '2022', '-', '2023', 'Car', 'Financing', 'Used', 'Car', 'Financing', 'New', 'Car', 'Financing', 'Vehicles', 'New', 'Trucks', 'New', 'Truck', 'Prices', '2022', '-', '2023', 'New', 'Buses', 'New', 'Bus', 'Prices', '2022', '-', '2023', 'New', 'Motorcycles', 'New', 'Motorcycle', 'Prices', '2022', '-', '2023', 'Sell', 'Car', 'more_horiz', 'Car', 'Showrooms', 'Used', 'Car', 'Showrooms', 'New', 'Car', 'Showrooms', 'Authorized', 'Car', 'Dealers', 'Car', 'Insurance', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Low', 'KM', 'Cars', 'Tow', 'Trucks', 'more_horiz', 'Car', 'Insurance', 'Disabled', 'Cars', 'Maintenance', 'Centers', 'News', 'Car', 'Review', 'Classic', 'Cars', 'Disabled', 'Cars', 'Car', 'Evaluation', 'Recently', 'Viewed', 'Cars', 'Favorite', 'Cars', 'Tips', 'Car', 'Forum', 'عربي', 'Account', 'Settings', 'Cars', '(', 'Ads', ')', 'Log', 'account_circle', 'Login', 'account_circle', 'Login', '/', 'Sign', 'Create', 'New', 'Account', ',', 'already', 'account', '!', 'Mobile', 'number', ',', 'Email', 'Username', 'Password', 'Reset', 'Password', 'Cars', 'sale', 'Find', 'used', 'car', 'sale', 'Egypt', 'Choose', 'make', 'prices', 'body', 'styles', 'slow_motion_video', 'Special', 'Condition', 'CC', 'Range', 'Find', 'Car', 'Sale', 'Hyundai', '(', '1768', ')', 'Chevrolet', '(', '1274', ')', 'Nissan', '(', '1117', ')', 'Fiat', '(', '1114', ')', 'Kia', '(', '1085', ')', 'Renault', '(', '788', ')', 'Toyota', '(', '723', ')', 'Mitsubishi', '(', '654', ')', 'Mercedes', '(', '603', ')', 'Opel', '(', '530', ')', 'Skoda', '(', '522', ')', 'Peugeot', '(', '506', ')', 'brands', '10,000', 'EGP', '20,000', 'EGP', '30,000', 'EGP', '50,000', 'EGP', '75,000', 'EGP', '100,000', 'EGP', '120,000', 'EGP', '150,000', 'EGP', '200,000', 'EGP', '250,000', 'EGP', 'Used', 'Car', 'Prices', 'New', 'Car', 'Prices', '2022', '-', '2023', 'Sedan', '(', '11353', ')', 'SUV', '(', '2316', ')', 'Hatchback', '(', '1808', ')', '4x4', '(', '499', ')', 'MiniVans', '(', '366', ')', 'Coupe', '(', '90', ')', 'slow_motion_video', 'Low', 'KM', 'local_taxi', 'Taxi', 'monetization_on', 'Financed', 'drive_eta', 'Classic', 'accessible', 'Disabled', 'input', 'Imported', 'Car', 'flash_on', 'Electric', 'cars', '1000', 'CC', '214', '1100', 'CC', '163', '1200', 'CC', '107', '1300', 'CC', '631', '1400', 'CC', '329', '1500', 'CC', '838', '1600', 'CC', '3071', '1700', 'CC', '6', '1800', 'CC', '82', '1900', 'CC', '5', '2000', 'CC', '298', '3000', 'CC', '72', '4000', 'CC', '83', '5000', 'CC', '5', '6000', 'CC', '13', 'Select', 'make', 'Alfa', 'Romeo', 'Aston', 'Martin', 'Audi', 'Baic', 'Bentley', 'Bestune', 'BMW', 'Brilliance', 'Bugatti', 'Buick', 'Byd', 'Cadi ...
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'SXSW', 'Star', 'Wars', 'Celebration', 'Cannes', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'Sign', 'In', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'All', 'topics', 'Cars', '2006', 'G', '1h', '57m', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Play', 'clip', '4', ':', '37', 'Watch', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', '7', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', '775', 'User', 'reviews', '253', 'Critic', 'reviews', '73', 'Metascore', 'See', 'more', 'at', 'IMDbPro', 'Nominated', 'for', '2', 'Oscars', '28', 'wins', '&', '34', 'nominations', 'total', 'Videos', '7', 'Clip', '4:37', 'Watch', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', 'Clip', '0:34', 'Watch', 'Cars', ':', '3D', 'Clip', '0:46', 'Watch', 'Cars', ':', '3D', 'Clip', '1:23', 'Watch', 'Cars', ':', '3D', 'Clip', '0:51', 'Watch', 'Cars', ':', '3D', 'Clip', '1:12', 'Watch', 'Cars', ':', '3D', 'Clip', '1:18', 'Watch', 'Cars', ':', '3D', 'Photos', '275', 'Top', 'cast', 'Edit', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Larry', 'the', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin',  ...
# ---------------------------------
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'SXSW', 'Star', 'Wars', 'Celebration', 'Cannes', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'Sign', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'topics', 'Cars', '2006', 'G', '1h', '57m', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Play', 'clip', '4', ':', '37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', '7', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', '775', 'User', 'reviews', '253', 'Critic', 'reviews', '73', 'Metascore', 'See', 'IMDbPro', 'Nominated', '2', 'Oscars', '28', 'wins', '&', '34', 'nominations', 'total', 'Videos', '7', 'Clip', '4:37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', 'Clip', '0:34', 'Watch', 'Cars', ':', '3D', 'Clip', '0:46', 'Watch', 'Cars', ':', '3D', 'Clip', '1:23', 'Watch', 'Cars', ':', '3D', 'Clip', '0:51', 'Watch', 'Cars', ':', '3D', 'Clip', '1:12', 'Watch', 'Cars', ':', '3D', 'Clip', '1:18', 'Watch', 'Cars', ':', '3D', 'Photos', '275', 'Top', 'cast', 'Edit', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Larry', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '(', 'voice', ')', '…', 'Joe', 'Ranft', 'Red',  ...
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Most', 'Popular', 'Movies', 'Browse', 'Movies', 'by', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', 'What', "'s", 'on', 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Most', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'by', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'What', 'to', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'SXSW', 'Star', 'Wars', 'Celebration', 'Cannes', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'All', 'Events', 'Celebs', 'Born', 'Today', 'Most', 'Popular', 'Celebs', 'Most', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'For', 'Industry', 'Professionals', 'All', 'All', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'In', 'Sign', 'In', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'All', 'topics', 'Cars', '2006', 'G', '1h', '57m', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Play', 'clip', '4', ':', '37', 'Watch', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', '7', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'On', 'the', 'way', 'to', 'the', 'biggest', 'race', 'of', 'his', 'life', ',', 'a', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'in', 'a', 'rundown', 'town', ',', 'and', 'learns', 'that', 'winning', 'is', "n't", 'everything', 'in', 'life', '.', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'YOUR', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', '775', 'User', 'reviews', '253', 'Critic', 'reviews', '73', 'Metascore', 'See', 'more', 'at', 'IMDbPro', 'Nominated', 'for', '2', 'Oscars', '28', 'wins', '&', '34', 'nominations', 'total', 'Videos', '7', 'Clip', '4:37', 'Watch', 'How', 'the', 'Best', 'Racing', 'Films', 'Raise', 'the', 'Stakes', 'Clip', '0:34', 'Watch', 'Cars', ':', '3D', 'Clip', '0:46', 'Watch', 'Cars', ':', '3D', 'Clip', '1:23', 'Watch', 'Cars', ':', '3D', 'Clip', '0:51', 'Watch', 'Cars', ':', '3D', 'Clip', '1:12', 'Watch', 'Cars', ':', '3D', 'Clip', '1:18', 'Watch', 'Cars', ':', '3D', 'Photos', '275', 'Top', 'cast', 'Edit', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Larry', 'the', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin',  ...
# ---------------------------------
# ['Menu', 'Movies', 'Release', 'Calendar', 'Top', '250', 'Movies', 'Popular', 'Movies', 'Browse', 'Movies', 'Genre', 'Top', 'Box', 'Office', 'Showtimes', '&', 'Tickets', 'Movie', 'News', 'India', 'Movie', 'Spotlight', 'TV', 'Shows', "'s", 'TV', '&', 'Streaming', 'Top', '250', 'TV', 'Shows', 'Popular', 'TV', 'Shows', 'Browse', 'TV', 'Shows', 'Genre', 'TV', 'News', 'India', 'TV', 'Spotlight', 'Watch', 'Watch', 'Latest', 'Trailers', 'IMDb', 'Originals', 'IMDb', 'Picks', 'IMDb', 'Podcasts', 'Awards', '&', 'Events', 'Oscars', 'SXSW', 'Star', 'Wars', 'Celebration', 'Cannes', 'STARmeter', 'Awards', 'Awards', 'Central', 'Festival', 'Central', 'Events', 'Celebs', 'Born', 'Today', 'Popular', 'Celebs', 'Popular', 'Celebs', 'Celebrity', 'News', 'Community', 'Help', 'Center', 'Contributor', 'Zone', 'Polls', 'Industry', 'Professionals', 'Titles', 'TV', 'Episodes', 'Celebs', 'Companies', 'Keywords', 'Advanced', 'Search', 'Watchlist', 'Sign', 'Sign', 'New', 'Customer', '?', 'Create', 'account', 'EN', 'Fully', 'supported', 'English', '(', 'United', 'States', ')', 'Partially', 'supported', 'Français', '(', 'Canada', ')', 'Français', '(', 'France', ')', 'Deutsch', '(', 'Deutschland', ')', 'हिंदी', '(', 'भारत', ')', 'Italiano', '(', 'Italia', ')', 'Português', '(', 'Brasil', ')', 'Español', '(', 'España', ')', 'Español', '(', 'México', ')', 'Cast', '&', 'crew', 'User', 'reviews', 'Trivia', 'IMDbPro', 'topics', 'Cars', '2006', 'G', '1h', '57m', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Play', 'clip', '4', ':', '37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', '7', 'Videos', '99+', 'Photos', 'Animation', 'Adventure', 'Comedy', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'way', 'biggest', 'race', 'life', ',', 'hotshot', 'rookie', 'race', 'car', 'gets', 'stranded', 'rundown', 'town', ',', 'learns', 'winning', "n't", 'everything', 'life', '.', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', 'See', 'production', ',', 'box', 'office', '&', 'company', 'info', 'IMDb', 'RATING', '7.2', '/', '10', '436K', 'RATING', 'Rate', 'POPULARITY', '447', '58', 'Top', 'credits', 'Directors', 'John', 'Lasseter', 'Joe', 'Ranft', 'Writers', 'John', 'Lasseter', 'Joe', 'Ranft', 'Jorgen', 'Klubien', 'Stars', 'Owen', 'Wilson', 'Bonnie', 'Hunt', 'Paul', 'Newman', '775', 'User', 'reviews', '253', 'Critic', 'reviews', '73', 'Metascore', 'See', 'IMDbPro', 'Nominated', '2', 'Oscars', '28', 'wins', '&', '34', 'nominations', 'total', 'Videos', '7', 'Clip', '4:37', 'Watch', 'Best', 'Racing', 'Films', 'Raise', 'Stakes', 'Clip', '0:34', 'Watch', 'Cars', ':', '3D', 'Clip', '0:46', 'Watch', 'Cars', ':', '3D', 'Clip', '1:23', 'Watch', 'Cars', ':', '3D', 'Clip', '0:51', 'Watch', 'Cars', ':', '3D', 'Clip', '1:12', 'Watch', 'Cars', ':', '3D', 'Clip', '1:18', 'Watch', 'Cars', ':', '3D', 'Photos', '275', 'Top', 'cast', 'Edit', 'Owen', 'Wilson', 'Lightning', 'McQueen', '(', 'voice', ')', 'Bonnie', 'Hunt', 'Sally', 'Carrera', '(', 'voice', ')', 'Paul', 'Newman', 'Doc', 'Hudson', '(', 'voice', ')', 'Larry', 'Cable', 'Guy', 'Mater', '(', 'voice', ')', 'Cheech', 'Marin', 'Ramone', '(', 'voice', ')', 'Tony', 'Shalhoub', 'Luigi', '(', 'voice', ')', 'Guido', 'Quaroni', 'Guido', '(', 'voice', ')', 'Jenifer', 'Lewis', 'Flo', '(', 'voice', ')', 'Paul', 'Dooley', 'Sarge', '(', 'voice', ')', 'Michael', 'Wallis', 'Sheriff', '(', 'voice', ')', 'George', 'Carlin', 'Fillmore', '(', 'voice', ')', 'Katherine', 'Helmond', 'Lizzie', '(', 'voice', ')', 'John', 'Ratzenberger', 'Mack', '(', 'voice', ')', '…', 'Joe', 'Ranft', 'Red',  ...
# ['Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'AdWords', ':', '830020857', 'EGYPT', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'العربية', 'New', 'Used', 'Reviews', 'Car', 'News', 'Car', 'Videos', 'Services', 'Car', 'Import', 'More', 'Advertise', 'With', 'Us', 'Auto', 'Companies', 'Sell', 'My', 'Car', 'Login', '|', 'Register', 'sidebar', 'Login', '|', 'Register', 'Sell', 'My', 'Car', 'FREE', 'New', 'Cars', 'Used', 'Cars', 'Car', 'Import', 'New', 'Car', 'News', 'Car', 'Videos', 'More', 'EGYPT', 'العربية', 'single', 'items', 'sideoverlay', 'Used', 'Cars', 'Search', 'Used', 'Cars', 'Browse', 'Used', 'Cars', 'Used', 'Cars', 'For', 'Export', 'New', 'Cars', 'Browse', 'New', 'Car', 'Guide', 'Search', 'New', 'Cars', 'Compare', 'New', 'Cars', 'Car', 'Prices', 'Car', 'Dictionary', 'Car', 'News', 'Latest', 'Posts', 'Auto', 'Industry', 'News', 'First', 'Drives', 'New', 'Car', 'Launches', 'Road', 'Tests', 'More', 'Advertise', 'With', 'Us', 'Auto', 'Companies', 'Select', 'Region', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'Search', 'Used', 'Cars', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Browse', 'Used', 'Cars', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Used', 'Cars', 'For', 'Import', 'New', 'Introducing', 'the', 'all', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'with', 'sellers', 'through', 'Phone', ',', 'SMS', 'or', 'WhatsApp', '.', 'Looking', 'to', 'sell', 'your', 'car', '?', 'Browse', 'New', 'Car', 'Guide', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Search', 'New', 'Cars', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Compare', 'New', 'Cars', 'POPULAR', 'NEW', 'CARS', 'COMPARISON', 'VS', 'Mitsubishi', 'Pajero', '2020', 'From', 'EGP', '1,650,000', 'Toyota', 'Fortuner', '2020', 'From', 'EGP', '739,900', 'Compare', 'VS', 'Toyota', 'Land', 'Cruiser', '2020', 'TBD', 'Nissan', 'Patrol', '2020', 'From', 'EGP', '3,500,000', 'Compare', 'VS', 'Renault', 'Duster', '2018', 'From', 'EGP', '210,000', 'Daihatsu', 'Terios', '2018', 'TBD', 'Compare', 'VS', 'Mitsubishi', 'Pajero', '2018', 'From', 'EGP', '1,000,000', 'Toyota', 'Fortuner', '2018', 'From', 'EGP', '1,000,000', 'Compare', 'See', 'all', 'New', 'Car', 'Comparisons', 'Car', 'Prices', 'NEW', 'CAR', 'BRANDS', 'PRICES', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Car', 'Prices', 'New', 'Introducing', 'the', 'all', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'with', 'sellers', 'through', 'Phone', ',', 'SMS', 'or', 'WhatsApp', '.', 'Car', 'Dictionary', 'FIND', 'CAR', 'DEFINITIONS', 'Bluetooth', 'System', 'CD', 'Player', 'Security', 'System', 'Aux/Audio', 'Input', 'ABS', '(', 'Anti-lock', 'Brake', 'System', ')', 'See', 'all', 'Car', 'Definitions', 'New', ' ...
# ---------------------------------
# ['Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'AdWords', ':', '830020857', 'EGYPT', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'العربية', 'New', 'Used', 'Reviews', 'Car', 'News', 'Car', 'Videos', 'Services', 'Car', 'Import', 'Advertise', 'Us', 'Auto', 'Companies', 'Sell', 'Car', 'Login', '|', 'Register', 'sidebar', 'Login', '|', 'Register', 'Sell', 'Car', 'FREE', 'New', 'Cars', 'Used', 'Cars', 'Car', 'Import', 'New', 'Car', 'News', 'Car', 'Videos', 'EGYPT', 'العربية', 'single', 'items', 'sideoverlay', 'Used', 'Cars', 'Search', 'Used', 'Cars', 'Browse', 'Used', 'Cars', 'Used', 'Cars', 'Export', 'New', 'Cars', 'Browse', 'New', 'Car', 'Guide', 'Search', 'New', 'Cars', 'Compare', 'New', 'Cars', 'Car', 'Prices', 'Car', 'Dictionary', 'Car', 'News', 'Latest', 'Posts', 'Auto', 'Industry', 'News', 'First', 'Drives', 'New', 'Car', 'Launches', 'Road', 'Tests', 'Advertise', 'Us', 'Auto', 'Companies', 'Select', 'Region', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'Search', 'Used', 'Cars', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Browse', 'Used', 'Cars', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Used', 'Cars', 'Import', 'New', 'Introducing', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'sellers', 'Phone', ',', 'SMS', 'WhatsApp', '.', 'Looking', 'sell', 'car', '?', 'Browse', 'New', 'Car', 'Guide', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Search', 'New', 'Cars', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Compare', 'New', 'Cars', 'POPULAR', 'NEW', 'CARS', 'COMPARISON', 'VS', 'Mitsubishi', 'Pajero', '2020', 'EGP', '1,650,000', 'Toyota', 'Fortuner', '2020', 'EGP', '739,900', 'Compare', 'VS', 'Toyota', 'Land', 'Cruiser', '2020', 'TBD', 'Nissan', 'Patrol', '2020', 'EGP', '3,500,000', 'Compare', 'VS', 'Renault', 'Duster', '2018', 'EGP', '210,000', 'Daihatsu', 'Terios', '2018', 'TBD', 'Compare', 'VS', 'Mitsubishi', 'Pajero', '2018', 'EGP', '1,000,000', 'Toyota', 'Fortuner', '2018', 'EGP', '1,000,000', 'Compare', 'See', 'New', 'Car', 'Comparisons', 'Car', 'Prices', 'NEW', 'CAR', 'BRANDS', 'PRICES', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Car', 'Prices', 'New', 'Introducing', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'sellers', 'Phone', ',', 'SMS', 'WhatsApp', '.', 'Car', 'Dictionary', 'FIND', 'CAR', 'DEFINITIONS', 'Bluetooth', 'System', 'CD', 'Player', 'Security', 'System', 'Aux/Audio', 'Input', 'ABS', '(', 'Anti-lock', 'Brake', 'System', ')', 'See', 'Car', 'Definitions', 'New', 'Introducing', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'sellers', 'Phone', ',', 'SMS', 'WhatsApp', '.', 'Looking', 'sell', 'car', '?', 'scroll', 'sticky', 'header', 'show/hide', 'new', 'cars', 'versions', 'model', 'scroll', 'sticky', 'header', 'show/hide', 'used', 'cars', 'vdp', 'inventory', 'scroll', 'sticky', 'header', 'show/hide', 'searc ...
# []
# ---------------------------------
# []
# ['Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'AdWords', ':', '830020857', 'EGYPT', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'العربية', 'New', 'Used', 'Reviews', 'Car', 'News', 'Car', 'Videos', 'Services', 'Car', 'Import', 'More', 'Advertise', 'With', 'Us', 'Auto', 'Companies', 'Sell', 'My', 'Car', 'Login', '|', 'Register', 'sidebar', 'Login', '|', 'Register', 'Sell', 'My', 'Car', 'FREE', 'New', 'Cars', 'Used', 'Cars', 'Car', 'Import', 'New', 'Car', 'News', 'Car', 'Videos', 'More', 'EGYPT', 'العربية', 'single', 'items', 'sideoverlay', 'Used', 'Cars', 'Search', 'Used', 'Cars', 'Browse', 'Used', 'Cars', 'Used', 'Cars', 'For', 'Export', 'New', 'Cars', 'Browse', 'New', 'Car', 'Guide', 'Search', 'New', 'Cars', 'Compare', 'New', 'Cars', 'Car', 'Prices', 'Car', 'Dictionary', 'Car', 'News', 'Latest', 'Posts', 'Auto', 'Industry', 'News', 'First', 'Drives', 'New', 'Car', 'Launches', 'Road', 'Tests', 'More', 'Advertise', 'With', 'Us', 'Auto', 'Companies', 'Select', 'Region', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'Search', 'Used', 'Cars', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Browse', 'Used', 'Cars', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Used', 'Cars', 'For', 'Import', 'New', 'Introducing', 'the', 'all', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'with', 'sellers', 'through', 'Phone', ',', 'SMS', 'or', 'WhatsApp', '.', 'Looking', 'to', 'sell', 'your', 'car', '?', 'Browse', 'New', 'Car', 'Guide', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Search', 'New', 'Cars', 'Browse', 'Cars', 'by', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Up', 'Truck', 'Wagon', 'Van', 'See', 'all', 'Body', 'Styles', 'Browse', 'Cars', 'by', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Brands', 'Compare', 'New', 'Cars', 'POPULAR', 'NEW', 'CARS', 'COMPARISON', 'VS', 'Mitsubishi', 'Pajero', '2020', 'From', 'EGP', '1,650,000', 'Toyota', 'Fortuner', '2020', 'From', 'EGP', '739,900', 'Compare', 'VS', 'Toyota', 'Land', 'Cruiser', '2020', 'TBD', 'Nissan', 'Patrol', '2020', 'From', 'EGP', '3,500,000', 'Compare', 'VS', 'Renault', 'Duster', '2018', 'From', 'EGP', '210,000', 'Daihatsu', 'Terios', '2018', 'TBD', 'Compare', 'VS', 'Mitsubishi', 'Pajero', '2018', 'From', 'EGP', '1,000,000', 'Toyota', 'Fortuner', '2018', 'From', 'EGP', '1,000,000', 'Compare', 'See', 'all', 'New', 'Car', 'Comparisons', 'Car', 'Prices', 'NEW', 'CAR', 'BRANDS', 'PRICES', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'all', 'Car', 'Prices', 'New', 'Introducing', 'the', 'all', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'with', 'sellers', 'through', 'Phone', ',', 'SMS', 'or', 'WhatsApp', '.', 'Car', 'Dictionary', 'FIND', 'CAR', 'DEFINITIONS', 'Bluetooth', 'System', 'CD', 'Player', 'Security', 'System', 'Aux/Audio', 'Input', 'ABS', '(', 'Anti-lock', 'Brake', 'System', ')', 'See', 'all', 'Car', 'Definitions', 'New', ' ...
# ---------------------------------
# ...
# ---------------------------------
# ['Global', 'site', 'tag', '(', 'gtag.js', ')', '-', 'Google', 'AdWords', ':', '830020857', 'EGYPT', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'العربية', 'New', 'Used', 'Reviews', 'Car', 'News', 'Car', 'Videos', 'Services', 'Car', 'Import', 'Advertise', 'Us', 'Auto', 'Companies', 'Sell', 'Car', 'Login', '|', 'Register', 'sidebar', 'Login', '|', 'Register', 'Sell', 'Car', 'FREE', 'New', 'Cars', 'Used', 'Cars', 'Car', 'Import', 'New', 'Car', 'News', 'Car', 'Videos', 'EGYPT', 'العربية', 'single', 'items', 'sideoverlay', 'Used', 'Cars', 'Search', 'Used', 'Cars', 'Browse', 'Used', 'Cars', 'Used', 'Cars', 'Export', 'New', 'Cars', 'Browse', 'New', 'Car', 'Guide', 'Search', 'New', 'Cars', 'Compare', 'New', 'Cars', 'Car', 'Prices', 'Car', 'Dictionary', 'Car', 'News', 'Latest', 'Posts', 'Auto', 'Industry', 'News', 'First', 'Drives', 'New', 'Car', 'Launches', 'Road', 'Tests', 'Advertise', 'Us', 'Auto', 'Companies', 'Select', 'Region', 'UAE', 'KSA', 'QATAR', 'OMAN', 'KUWAIT', 'BAHRAIN', 'Search', 'Used', 'Cars', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Browse', 'Used', 'Cars', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Used', 'Cars', 'Import', 'New', 'Introducing', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'sellers', 'Phone', ',', 'SMS', 'WhatsApp', '.', 'Looking', 'sell', 'car', '?', 'Browse', 'New', 'Car', 'Guide', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Search', 'New', 'Cars', 'Browse', 'Cars', 'Body', 'Style', 'Sedan', 'Hatchback', 'Convertible', 'Crossover', 'Minivan', 'SUV', 'Coupe', 'Pick', 'Truck', 'Wagon', 'Van', 'See', 'Body', 'Styles', 'Browse', 'Cars', 'Brand', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Brands', 'Compare', 'New', 'Cars', 'POPULAR', 'NEW', 'CARS', 'COMPARISON', 'VS', 'Mitsubishi', 'Pajero', '2020', 'EGP', '1,650,000', 'Toyota', 'Fortuner', '2020', 'EGP', '739,900', 'Compare', 'VS', 'Toyota', 'Land', 'Cruiser', '2020', 'TBD', 'Nissan', 'Patrol', '2020', 'EGP', '3,500,000', 'Compare', 'VS', 'Renault', 'Duster', '2018', 'EGP', '210,000', 'Daihatsu', 'Terios', '2018', 'TBD', 'Compare', 'VS', 'Mitsubishi', 'Pajero', '2018', 'EGP', '1,000,000', 'Toyota', 'Fortuner', '2018', 'EGP', '1,000,000', 'Compare', 'See', 'New', 'Car', 'Comparisons', 'Car', 'Prices', 'NEW', 'CAR', 'BRANDS', 'PRICES', 'Hyundai', 'Chevrolet', 'Toyota', 'Kia', 'Mitsubishi', 'Nissan', 'Mercedes-Benz', 'BMW', 'MG', 'Renault', 'See', 'Car', 'Prices', 'New', 'Introducing', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'sellers', 'Phone', ',', 'SMS', 'WhatsApp', '.', 'Car', 'Dictionary', 'FIND', 'CAR', 'DEFINITIONS', 'Bluetooth', 'System', 'CD', 'Player', 'Security', 'System', 'Aux/Audio', 'Input', 'ABS', '(', 'Anti-lock', 'Brake', 'System', ')', 'See', 'Car', 'Definitions', 'New', 'Introducing', 'new', 'YallaMotor', 'App', '!', 'Easily', 'connect', 'sellers', 'Phone', ',', 'SMS', 'WhatsApp', '.', 'Looking', 'sell', 'car', '?', 'scroll', 'sticky', 'header', 'show/hide', 'new', 'cars', 'versions', 'model', 'scroll', 'sticky', 'header', 'show/hide', 'used', 'cars', 'vdp', 'inventory', 'scroll', 'sticky', 'header', 'show/hide', 'searc ...
# ['Sign', 'In', 'My', 'Account', 'Account', 'Settings', 'Sign', 'Out', 'Disney.com', 'Disney+', 'Home', 'On', 'Disney+', 'The', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Home', 'Walt', 'Disney', 'World', 'Walt', 'Disney', 'World', 'Disneyland', 'Disney', 'Cruise', 'Line', 'Aulani', 'All', 'Parks', '&', 'Travel', 'Movies', 'Home', 'Movies', 'Anywhere', 'All', 'Movies', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'All', 'Disney', 'News', 'D23', 'Live', 'Shows', 'Home', 'Disney', 'on', 'Broadway', 'Disney', 'on', 'Ice', 'Disney', 'Live', '!', 'Skip', 'Navigation', 'Disney.com', 'Disney+', 'On', 'Disney+', 'The', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Walt', 'Disney', 'World', 'Resort', 'Disneyland', 'Resort', 'Disney', 'Cruise', 'Line', 'Aulani', '-', 'A', 'Disney', 'Resort', 'and', 'Spa', 'Adventures', 'by', 'Disney', 'Disney', 'Vacation', 'Club', 'Movies', 'Movies', 'Anywhere', 'All', 'Movies', 'Disney', 'Movie', 'Club', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'All', 'More', 'Disney', 'News', 'D23', ':', 'The', 'Official', 'Disney', 'Fan', 'Club', 'Live', 'Shows', 'Sign', 'In', 'My', 'Account', 'Account', 'Settings', 'Sign', 'Out', 'Search', 'Video', 'Galleries', 'Movies', 'RSN', 'Shop', 'Parks', 'Cancel', 'Skip', 'Navigation', 'Movies', 'Video', 'Galleries', 'RSN', 'Parks', 'More', 'Explore', 'More', 'STREAM', 'CARS', 'NOW', 'ON', 'DISNEY+', 'End', 'of', 'video_wrapper', 'End', '#', 'video_watch_container', 'Up', 'Next', 'End', 'of', 'bound', 'Shop', 'See', 'All', 'Cars', 'on', 'the', 'Road', 'Swim', 'Bag', '$', '19.99', '$', '13.99', 'Cars', 'on', 'the', 'Road', 'Swim', 'Trunks', 'for', 'Kids', '$', '24.99', '$', '17.49', 'Cars', 'on', 'the', 'Road', 'Sweatshirt', 'for', 'Kids', '$', '34.99', 'Cars', 'on', 'the', 'Road', 'Rolling', 'Luggage', '–', 'Small', '$', '49.99', 'Cars', 'Racing', 'Insignia', 'T-Shirt', 'for', 'Adults', '–', 'Customized', '$', '24.99', 'Cars', 'Disney', 'Gift', 'Card', '$', '500.00', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'for', 'Men', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Mousepad', '–', 'Customizable', '$', '12.95', 'Cars', 'on', 'the', 'Road', 'Sunglasses', 'for', 'Kids', '$', '16.99', '$', '11.89', 'Cars', 'on', 'the', 'Road', 'Bodysuit', 'for', 'Baby', '$', '19.99', 'Cars', 'on', 'the', 'Road', 'Rash', 'Guard', 'for', 'Kids', '$', '24.99', '$', '17.49', 'Cars', 'on', 'the', 'Road', 'Beach', 'Towel', '–', 'Personalized', '$', '19.99', '$', '15.00', 'Cars', '3', 'Piston', 'Cup', 'Pattern', 'iPhone', '6/6S', 'Case', '–', 'Customizable', '$', '39.95', 'Cars', 'on', 'the', 'Road', 'PJ', 'PALS', 'for', 'Kids', '$', '24.99', '$', '14.98', 'Cars', 'on', 'the', 'Road', 'Stainless', 'Steel', 'Water', 'Bottle', 'with', 'Built-In', 'Straw', '$', '19.99', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'for', 'Kids', '–', 'Customizable', '$', '16.95', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Mug', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Rust-eze', 'Tee', 'for', 'Girls', '–', 'Customizable', '$', '18.95', 'Cars', 'Time', 'Teacher', 'Watch', 'for', 'Kids', '$', '31.99', 'Cars', 'Aquarium', 'Train', 'Car', 'by', 'Lionel', '$', '119.99', 'Radiator', 'Springs', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Rust-eze', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Lightning', 'McQueen', 'Tee', 'for', 'Kids', '–', 'Cars', '$', '22.99', 'Heavy', 'Metal', 'Mater', 'Die', 'Cast', 'Set', '–', 'Cars', '$', '24.99', 'Cruz', 'Ramirez', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Lightning', 'McQueen', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Smokey', "'s", 'Garage', 'Morphing', 'Mug', '–', 'Cars', '3', '–', 'Customizable', '$', '19.95', 'Ivy', 'Die', 'Cast', 'Set', '–', 'Cars', 'on', 'the', 'Road', '$', '16.99', 'Lightning', 'McQueen', 'Time', 'Teacher', 'Watch', 'for',  ...
# ---------------------------------
# ['Sign', 'Account', 'Account', 'Settings', 'Sign', 'Disney.com', 'Disney+', 'Home', 'Disney+', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Home', 'Walt', 'Disney', 'World', 'Walt', 'Disney', 'World', 'Disneyland', 'Disney', 'Cruise', 'Line', 'Aulani', 'Parks', '&', 'Travel', 'Movies', 'Home', 'Movies', 'Anywhere', 'Movies', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'Disney', 'News', 'D23', 'Live', 'Shows', 'Home', 'Disney', 'Broadway', 'Disney', 'Ice', 'Disney', 'Live', '!', 'Skip', 'Navigation', 'Disney.com', 'Disney+', 'Disney+', 'Disney', 'Bundle', 'Parks', '&', 'Travel', 'Walt', 'Disney', 'World', 'Resort', 'Disneyland', 'Resort', 'Disney', 'Cruise', 'Line', 'Aulani', '-', 'Disney', 'Resort', 'Spa', 'Adventures', 'Disney', 'Disney', 'Vacation', 'Club', 'Movies', 'Movies', 'Anywhere', 'Movies', 'Disney', 'Movie', 'Club', 'Disney', 'Movie', 'Insiders', '20th', 'Century', 'Studios', 'Shop', 'Sale', 'Clothes', 'Accessories', 'Toys', 'Shop', 'Disney', 'News', 'D23', ':', 'Official', 'Disney', 'Fan', 'Club', 'Live', 'Shows', 'Sign', 'Account', 'Account', 'Settings', 'Sign', 'Search', 'Video', 'Galleries', 'Movies', 'RSN', 'Shop', 'Parks', 'Cancel', 'Skip', 'Navigation', 'Movies', 'Video', 'Galleries', 'RSN', 'Parks', 'Explore', 'STREAM', 'CARS', 'DISNEY+', 'End', 'video_wrapper', 'End', '#', 'video_watch_container', 'Next', 'End', 'bound', 'Shop', 'See', 'Cars', 'Road', 'Swim', 'Bag', '$', '19.99', '$', '13.99', 'Cars', 'Road', 'Swim', 'Trunks', 'Kids', '$', '24.99', '$', '17.49', 'Cars', 'Road', 'Sweatshirt', 'Kids', '$', '34.99', 'Cars', 'Road', 'Rolling', 'Luggage', '–', 'Small', '$', '49.99', 'Cars', 'Racing', 'Insignia', 'T-Shirt', 'Adults', '–', 'Customized', '$', '24.99', 'Cars', 'Disney', 'Gift', 'Card', '$', '500.00', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'Men', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Mousepad', '–', 'Customizable', '$', '12.95', 'Cars', 'Road', 'Sunglasses', 'Kids', '$', '16.99', '$', '11.89', 'Cars', 'Road', 'Bodysuit', 'Baby', '$', '19.99', 'Cars', 'Road', 'Rash', 'Guard', 'Kids', '$', '24.99', '$', '17.49', 'Cars', 'Road', 'Beach', 'Towel', '–', 'Personalized', '$', '19.99', '$', '15.00', 'Cars', '3', 'Piston', 'Cup', 'Pattern', 'iPhone', '6/6S', 'Case', '–', 'Customizable', '$', '39.95', 'Cars', 'Road', 'PJ', 'PALS', 'Kids', '$', '24.99', '$', '14.98', 'Cars', 'Road', 'Stainless', 'Steel', 'Water', 'Bottle', 'Built-In', 'Straw', '$', '19.99', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Tee', 'Kids', '–', 'Customizable', '$', '16.95', 'Cars', '3', 'Piston', 'Cup', 'Champions', 'Mug', '–', 'Customizable', '$', '19.95', 'Cars', '3', 'Rust-eze', 'Tee', 'Girls', '–', 'Customizable', '$', '18.95', 'Cars', 'Time', 'Teacher', 'Watch', 'Kids', '$', '31.99', 'Cars', 'Aquarium', 'Train', 'Car', 'Lionel', '$', '119.99', 'Radiator', 'Springs', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Rust-eze', 'Metal', 'Sign', '–', 'Cars', '$', '150.00', 'Lightning', 'McQueen', 'Tee', 'Kids', '–', 'Cars', '$', '22.99', 'Heavy', 'Metal', 'Mater', 'Die', 'Cast', 'Set', '–', 'Cars', '$', '24.99', 'Cruz', 'Ramirez', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Lightning', 'McQueen', 'Water', 'Bottle', '–', 'Cars', '3', '–', 'Customizable', '$', '21.95', 'Smokey', "'s", 'Garage', 'Morphing', 'Mug', '–', 'Cars', '3', '–', 'Customizable', '$', '19.95', 'Ivy', 'Die', 'Cast', 'Set', '–', 'Cars', 'Road', '$', '16.99', 'Lightning', 'McQueen', 'Time', 'Teacher', 'Watch', 'Kids', '–', 'Cars', '$', '31.99', 'Mater', 'Die', 'Cast', 'Set', '–', 'Cars', 'Road', '$', '16.99', 'Lightning', 'McQueen', 'T-Shirt', 'Kids', '–', 'Cars', '–', 'Customized', '$', '19.99', 'Lightning', 'McQueen', 'Bedding', 'Set', '–', 'Cars', '–', 'Twin', '/', 'Full', '$', '84.99', 'Lightning', 'McQueen', 'Sheet', 'Set', '–', 'Cars', '–', 'Twin', '/', 'Full', '$', '29.99', 'Smokey', "'s", 'Garage', 'Tee', 'Kids', '–', 'Cars', '3', '–', 'Cus ...

# %%
import nltk

from nltk.stem.porter import *
p_stemmer = PorterStemmer()




for word in  filtered_sentence:
    print(word+' --> '+p_stemmer.stem(word))

from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')



for word in filtered_sentence:
    print(word+' --> '+s_stemmer.stem(word))
u=p_stemmer.stem(word)
# Out:
# Sign --> sign
# Account --> account
# Account --> account
# Settings --> set
# Sign --> sign
# Disney.com --> disney.com
# Disney+ --> disney+
# Home --> home
# Disney+ --> disney+
# Disney --> disney
# Bundle --> bundl
# Parks --> park
# & --> &
# Travel --> travel
# Home --> home
# Walt --> walt
# Disney --> disney
# World --> world
# Walt --> walt
# Disney --> disney
# World --> world
# Disneyland --> disneyland
# Disney --> disney
# Cruise --> cruis
# Line --> line
# Aulani --> aulani
# Parks --> park
# & --> &
# Travel --> travel
# Movies --> movi
# Home --> home
# Movies --> movi
# Anywhere --> anywher
# Movies --> movi
# Disney --> disney
# Movie --> movi
# Insiders --> insid
# 20th --> 20th
# Century --> centuri
# Studios --> studio
# Shop --> shop
# Sale --> sale
# Clothes --> cloth
# Accessories --> accessori
# Toys --> toy
# Shop --> shop
# Disney --> disney
# News --> new
# D23 --> d23
# Live --> live
# Shows --> show
# Home --> home
# Disney --> disney
# Broadway --> broadway
# Disney --> disney
# Ice --> ice
# Disney --> disney
# Live --> live
# ! --> !
# Skip --> skip
# Navigation --> navig
# Disney.com --> disney.com
# Disney+ --> disney+
# Disney+ --> disney+
# Disney --> disney
# Bundle --> bundl
# Parks --> park
# & --> &
# Travel --> travel
# Walt --> walt
# Disney --> disney
# World --> world
# Resort --> resort
# Disneyland --> disneyland
# Resort --> resort
# Disney --> disney
# Cruise --> cruis
# Line --> line
# Aulani --> aulani
# - --> -
# Disney --> disney
# Resort --> resort
# Spa --> spa
# Adventures --> adventur
# Disney --> disney
# Disney --> disney
# Vacation --> vacat
# Club --> club
# Movies --> movi
# Movies --> movi
# Anywhere --> anywher
# Movies --> movi
# Disney --> disney
# Movie --> movi
# Club --> club
# Disney --> disney
# Movie --> movi
# Insiders --> insid
# 20th --> 20th
# Century --> centuri
# Studios --> studio
# Shop --> shop
# Sale --> sale
# Clothes --> cloth
# Accessories --> accessori
# Toys --> toy
# Shop --> shop
# Disney --> disney
# News --> new
# D23 --> d23
# : --> :
# Official --> offici
# Disney --> disney
# Fan --> fan
# Club --> club
# Live --> live
# Shows --> show
# Sign --> sign
# Account --> account
# Account --> account
# Settings --> set
# Sign --> sign
# Search --> search
# Video --> video
# Galleries --> galleri
# Movies --> movi
# RSN --> rsn
# Shop --> shop
# Parks --> park
# Cancel --> cancel
# Skip --> skip
# Navigation --> navig
# Movies --> movi
# Video --> video
# Galleries --> galleri
# RSN --> rsn
# Parks --> park
# Explore --> explor
# STREAM --> stream
# CARS --> car
# DISNEY+ --> disney+
# End --> end
# video_wrapper --> video_wrapp
# End --> end
# # --> #
# video_watch_container --> video_watch_contain
# Next --> next
# End --> end
# bound --> bound
# Shop --> shop
# See --> see
# Cars --> car
# Road --> road
# Swim --> swim
# Bag --> bag
# $ --> $
# 19.99 --> 19.99
# $ --> $
# 13.99 --> 13.99
# Cars --> car
# Road --> road
# Swim --> swim
# Trunks --> trunk
# Kids --> kid
# $ --> $
# 24.99 --> 24.99
# $ --> $
# 17.49 --> 17.49
# Cars --> car
# Road --> road
# Sweatshirt --> sweatshirt
# Kids --> kid
# $ --> $
# 34.99 --> 34.99
# Cars --> car
# Road --> road
# Rolling --> roll
# Luggage --> luggag
# – --> –
# Small --> small
# $ --> $
# 49.99 --> 49.99
# Cars --> car
# Racing --> race
# Insignia --> insignia
# T-Shirt --> t-shirt
# Adults --> adult
# – --> –
# Customized --> custom
# $ --> $
# 24.99 --> 24.99
# Cars --> car
# Disney --> disney
# Gift --> gift
# Card --> card
# $ --> $
# 500.00 --> 500.00
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Champions --> champion
# Tee --> tee
# Men --> men
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Cars --> car
# 3 --> 3
# Mousepad --> mousepad
# – --> –
# Customizable --> customiz
# $ --> $
# 12.95 --> 12.95
# Cars --> car
# Road --> road
# Sunglasses --> sunglass
# Kids --> kid
# $ --> $
# 16.99 --> 16.99
# $ --> $
# 11.89 --> 11.89
# Cars --> car
# Road --> road
# Bodysuit --> bodysuit
# Baby --> babi
# $ --> $
# 19.99 --> 19.99
# Cars --> car
# Road --> road
# Rash --> rash
# Guard --> guard
# Kids --> kid
# $ --> $
# 24.99 --> 24.99
# $ --> $
# 17.49 --> 17.49
# Cars --> car
# Road --> road
# Beach --> beach
# Towel --> towel
# – --> –
# Personalized --> person
# $ --> $
# 19.99 --> 19.99
# $ --> $
# 15.00 --> 15.00
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Pattern --> pattern
# iPhone --> iphon
# 6/6S --> 6/6
# Case --> case
# – --> –
# Customizable --> customiz
# $ --> $
# 39.95 --> 39.95
# Cars --> car
# Road --> road
# PJ --> pj
# PALS --> pal
# Kids --> kid
# $ --> $
# 24.99 --> 24.99
# $ --> $
# 14.98 --> 14.98
# Cars --> car
# Road --> road
# Stainless --> stainless
# Steel --> steel
# Water --> water
# Bottle --> bottl
# Built-In --> built-in
# Straw --> straw
# $ --> $
# 19.99 --> 19.99
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Champions --> champion
# Tee --> tee
# Kids --> kid
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Champions --> champion
# Mug --> mug
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Cars --> car
# 3 --> 3
# Rust-eze --> rust-ez
# Tee --> tee
# Girls --> girl
# – --> –
# Customizable --> customiz
# $ --> $
# 18.95 --> 18.95
# Cars --> car
# Time --> time
# Teacher --> teacher
# Watch --> watch
# Kids --> kid
# $ --> $
# 31.99 --> 31.99
# Cars --> car
# Aquarium --> aquarium
# Train --> train
# Car --> car
# Lionel --> lionel
# $ --> $
# 119.99 --> 119.99
# Radiator --> radiat
# Springs --> spring
# Metal --> metal
# Sign --> sign
# – --> –
# Cars --> car
# $ --> $
# 150.00 --> 150.00
# Rust-eze --> rust-ez
# Metal --> metal
# Sign --> sign
# – --> –
# Cars --> car
# $ --> $
# 150.00 --> 150.00
# Lightning --> lightn
# McQueen --> mcqueen
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# $ --> $
# 22.99 --> 22.99
# Heavy --> heavi
# Metal --> metal
# Mater --> mater
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# $ --> $
# 24.99 --> 24.99
# Cruz --> cruz
# Ramirez --> ramirez
# Water --> water
# Bottle --> bottl
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 21.95 --> 21.95
# Lightning --> lightn
# McQueen --> mcqueen
# Water --> water
# Bottle --> bottl
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 21.95 --> 21.95
# Smokey --> smokey
# 's --> 's
# Garage --> garag
# Morphing --> morph
# Mug --> mug
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Ivy --> ivi
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# Road --> road
# $ --> $
# 16.99 --> 16.99
# Lightning --> lightn
# McQueen --> mcqueen
# Time --> time
# Teacher --> teacher
# Watch --> watch
# Kids --> kid
# – --> –
# Cars --> car
# $ --> $
# 31.99 --> 31.99
# Mater --> mater
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# Road --> road
# $ --> $
# 16.99 --> 16.99
# Lightning --> lightn
# McQueen --> mcqueen
# T-Shirt --> t-shirt
# Kids --> kid
# – --> –
# Cars --> car
# – --> –
# Customized --> custom
# $ --> $
# 19.99 --> 19.99
# Lightning --> lightn
# McQueen --> mcqueen
# Bedding --> bed
# Set --> set
# – --> –
# Cars --> car
# – --> –
# Twin --> twin
# / --> /
# Full --> full
# $ --> $
# 84.99 --> 84.99
# Lightning --> lightn
# McQueen --> mcqueen
# Sheet --> sheet
# Set --> set
# – --> –
# Cars --> car
# – --> –
# Twin --> twin
# / --> /
# Full --> full
# $ --> $
# 29.99 --> 29.99
# Smokey --> smokey
# 's --> 's
# Garage --> garag
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# River --> river
# Scott --> scott
# Tee --> tee
# Women --> women
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 24.95 --> 24.95
# Lightning --> lightn
# McQueen --> mcqueen
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# Road --> road
# $ --> $
# 16.99 --> 16.99
# Rust-eze --> rust-ez
# Tee --> tee
# Men --> men
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Jackson --> jackson
# Storm --> storm
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# Rust-eze --> rust-ez
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# River --> river
# Scott --> scott
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# See --> see
# Race --> race
# Day --> day
# Radiator --> radiat
# Springs --> spring
# comes --> come
# watch --> watch
# Doc --> doc
# Lightning --> lightn
# ’ --> ’
# big --> big
# race --> race
# . --> .
# Pit --> pit
# Crew --> crew
# Team --> team
# McQueen --> mcqueen
# cheers --> cheer
# Lightning --> lightn
# first --> first
# leg --> leg
# World --> world
# Grand --> grand
# Prix --> prix
# . --> .
# Cruisin --> cruisin
# ’ --> ’
# Lightning --> lightn
# ’ --> ’
# new --> new
# road --> road
# inspires --> inspir
# everyone --> everyon
# Radiator --> radiat
# Springs --> spring
# spruce --> spruce
# town --> town
# . --> .
# Flo --> flo
# ’ --> ’
# sure --> sure
# stop --> stop
# Flo --> flo
# ’ --> ’
# V-8 --> v-8
# Cafe --> cafe
# finest --> finest
# fuel --> fuel
# Route --> rout
# 66. --> 66.
# Fillmore --> fillmor
# Sarge --> sarg
# “ --> “
# sixties --> sixti
# ’ --> ’
# good --> good
# , --> ,
# ? --> ?
# ” --> ”
# Fillmore --> fillmor
# ’ --> ’
# Taste-In --> taste-in
# “ --> “
# really --> realli
# need --> need
# sweet --> sweet
# taste --> tast
# homemade --> homemad
# , --> ,
# organic --> organ
# fuel. --> fuel.
# ” --> ”
# Mater --> mater
# Lawyer --> lawyer
# “ --> “
# Boy --> boy
# , --> ,
# ’ --> ’
# purty --> purti
# good --> good
# lawyerin --> lawyerin
# ’ --> ’
# stuff --> stuff
# ! --> !
# ” --> ”
# Mater --> mater
# Meets --> meet
# Finn --> finn
# “ --> “
# Finn --> finn
# McMissile --> mcmissil
# , --> ,
# British --> british
# Intelligence. --> intelligence.
# ” --> ”
# “ --> “
# Tow --> tow
# Mater --> mater
# , --> ,
# average --> averag
# intelligence. --> intelligence.
# ” --> ”
# Teammates --> teammat
# Pals --> pal
# Mater --> mater
# , --> ,
# Lightning --> lightn
# ’ --> ’
# race --> race
# car --> car
# , --> ,
# ’ --> ’
# friend --> friend
# . --> .
# Secret --> secret
# Agent --> agent
# Mater --> mater
# Mater --> mater
# saves --> save
# day --> day
# last --> last
# stop --> stop
# World --> world
# Grand --> grand
# Prix --> prix
# . --> .
# Hurry --> hurri
# Lightning --> lightn
# , --> ,
# Mater --> mater
# , --> ,
# Finn --> finn
# McMissile --> mcmissil
# run --> run
# couple --> coupl
# no-good --> no-good
# lemons --> lemon
# . --> .
# Radiator --> radiat
# Springs --> spring
# Anymore --> anymor
# Mater --> mater
# learns --> learn
# important --> import
# lesson --> lesson
# Japan --> japan
# : --> :
# wasabi --> wasabi
# pistachio --> pistachio
# ice --> ice
# cream --> cream
# . --> .
# Lookin --> lookin
# ’ --> ’
# Good --> good
# need --> need
# paint --> paint
# job --> job
# , --> ,
# Ramone --> ramon
# paint --> paint
# right --> right
# . --> .
# ( --> (
# especially --> especi
# loves --> love
# paint --> paint
# flames --> flame
# . --> .
# ) --> )
# Crazy --> crazi
# Old --> old
# Lizzy --> lizzi
# “ --> “
# keep --> keep
# talking --> talk
# , --> ,
# people --> peopl
# think --> think
# ’ --> ’
# crazy --> crazi
# ! --> !
# ” --> ”
# Lightning --> lightn
# McQueen --> mcqueen
# Lightning --> lightn
# McQueen --> mcqueen
# , --> ,
# # --> #
# 95 --> 95
# , --> ,
# hotshot --> hotshot
# rookie --> rooki
# race --> race
# car --> car
# loves --> love
# going --> go
# faster --> faster
# fast --> fast
# . --> .
# ’ --> ’
# racing --> race
# , --> ,
# spends --> spend
# time --> time
# Radiator --> radiat
# Springs --> spring
# best --> best
# pal --> pal
# , --> ,
# Mater --> mater
# . --> .
# Mater --> mater
# Mater --> mater
# rustiest --> rustiest
# , --> ,
# trustiest --> trustiest
# tow --> tow
# truck --> truck
# Radiator --> radiat
# Springs --> spring
# . --> .
# loves --> love
# tractor --> tractor
# tippin --> tippin
# ’ --> ’
# , --> ,
# helping --> help
# stranded --> strand
# cars --> car
# , --> ,
# , --> ,
# hanging --> hang
# best --> best
# friend --> friend
# , --> ,
# Lightning --> lightn
# McQueen --> mcqueen
# . --> .
# Mater --> mater
# great --> great
# driving --> drive
# backwards --> backward
# , --> ,
# ’ --> ’
# need --> need
# know --> know
# ’ --> ’
# going --> go
# long --> long
# knows --> know
# ’ --> ’
# . --> .
# Sally --> salli
# Sally --> salli
# beautiful --> beauti
# baby --> babi
# blue --> blue
# Porsche --> porsch
# fell --> fell
# love --> love
# small --> small
# town --> town
# life --> life
# Radiator --> radiat
# Springs --> spring
# . --> .
# runs --> run
# Cozy --> cozi
# Cone --> cone
# , --> ,
# town --> town
# attorney --> attorney
# , --> ,
# dedicated --> dedic
# preserving --> preserv
# favorite --> favorit
# place --> place
# live --> live
# . --> .
# loves --> love
# cruisin --> cruisin
# ’ --> ’
# slow --> slow
# lane --> lane
# Lightning --> lightn
# McQueen --> mcqueen
# . --> .
# Luigi --> luigi
# Luigi --> luigi
# 1959 --> 1959
# Fiat --> fiat
# 500 --> 500
# runs --> run
# local --> local
# tire --> tire
# shop --> shop
# , --> ,
# Luigi --> luigi
# ’ --> ’
# Casa --> casa
# Della --> della
# Tires --> tire
# , --> ,
# “ --> “
# Home --> home
# Leaning --> lean
# Tower --> tower
# Tires. --> tires.
# ” --> ”
# loves --> love
# changing --> chang
# tires --> tire
# racecars --> racecar
# like --> like
# Lightning --> lightn
# McQueen --> mcqueen
# , --> ,
# nothing --> noth
# makes --> make
# happier --> happier
# real --> real
# Ferrari --> ferrari
# comes --> come
# door --> door
# . --> .
# Guido --> guido
# Guido --> guido
# little --> littl
# Italian --> italian
# forklift --> forklift
# Luigi --> luigi
# ’ --> ’
# assistant --> assist
# best --> best
# buddy --> buddi
# -- --> --
# ’ --> ’
# hardly --> hardli
# ever --> ever
# see --> see
# two --> two
# pals --> pal
# apart --> apart
# . --> .
# Like --> like
# Luigi --> luigi
# , --> ,
# Guido --> guido
# avid --> avid
# Ferrari --> ferrari
# racing --> race
# fan --> fan
# dreams --> dream
# performing --> perform
# real --> real
# pit --> pit
# stop --> stop
# real --> real
# Ferrari --> ferrari
# . --> .
# Sarge --> sarg
# Sarge --> sarg
# , --> ,
# 1942 --> 1942
# WW2 --> ww2
# Willy --> willi
# ’ --> ’
# Army --> armi
# Jeep --> jeep
# patriotic --> patriot
# resident --> resid
# Radiator --> radiat
# Springs --> spring
# . --> .
# runs --> run
# local --> local
# army --> armi
# surplus --> surplu
# store --> store
# , --> ,
# Sarge --> sarg
# ’ --> ’
# Surplus --> surplu
# Hut --> hut
# , --> ,
# always --> alway
# starts --> start
# day --> day
# rendition --> rendit
# Reveille --> reveil
# . --> .
# Fillmore --> fillmor
# Fillmore --> fillmor
# 1960 --> 1960
# VW --> vw
# Bus --> bu
# , --> ,
# naturally --> natur
# , --> ,
# also --> also
# Radiator --> radiat
# Springs --> spring
# ’ --> ’
# resident --> resid
# Hippie --> hippi
# clean --> clean
# fuel --> fuel
# aficionado --> aficionado
# . --> .
# brews --> brew
# organic --> organ
# fuel --> fuel
# tie-dyed --> tie-di
# , --> ,
# geometric --> geometr
# dome --> dome
# , --> ,
# unkempt --> unkempt
# yard --> yard
# tends --> tend
# bug --> bug
# veteran --> veteran
# army --> armi
# jeep --> jeep
# neighbor --> neighbor
# , --> ,
# Sarge --> sarg
# . --> .
# Ramone --> ramon
# Ramone --> ramon
# 1951 --> 1951
# Impala --> impala
# low-rider --> low-rid
# loves --> love
# riding --> ride
# “ --> “
# low --> low
# slow. --> slow.
# ” --> ”
# runs --> run
# Ramone --> ramon
# ’ --> ’
# House --> hous
# Body --> bodi
# Art --> art
# , --> ,
# local --> local
# custom --> custom
# body --> bodi
# paint --> paint
# shop --> shop
# . --> .
# true --> true
# artist --> artist
# , --> ,
# without --> without
# many --> mani
# customers --> custom
# paint --> paint
# , --> ,
# Ramone --> ramon
# changes --> chang
# paint --> paint
# job --> job
# every --> everi
# day --> day
# . --> .
# Doc --> doc
# Hudson --> hudson
# Doc --> doc
# wise --> wise
# , --> ,
# quiet --> quiet
# country --> countri
# doctor --> doctor
# run --> run
# Radiator --> radiat
# Springs --> spring
# ’ --> ’
# medical --> medic
# clinic --> clinic
# . --> .
# Doc --> doc
# slowed --> slow
# Radiator --> radiat
# Springs --> spring
# , --> ,
# Fabulous --> fabul
# Hudson --> hudson
# Hornet --> hornet
# . --> .
# uses --> use
# knowledge --> knowledg
# racing --> race
# teach --> teach
# hotshots --> hotshot
# like --> like
# Lightning --> lightn
# race --> race
# smart --> smart
# , --> ,
# fast --> fast
# . --> .
# Flo --> flo
# Flo --> flo
# sassy --> sassi
# , --> ,
# no-nonsense --> no-nonsens
# 1950 --> 1950
# ’ --> ’
# show --> show
# car --> car
# enjoys --> enjoy
# traveling --> travel
# cross-country --> cross-countri
# . --> .
# runs --> run
# local --> local
# diner --> diner
# , --> ,
# Flo --> flo
# ’ --> ’
# V-8 --> v-8
# Cafe --> cafe
# , --> ,
# gas --> ga
# station --> station
# miles --> mile
# around --> around
# . --> .
# Show --> show
# Videos --> video
# Cars --> car
# See --> see
# favorite --> favorit
# characters --> charact
# action --> action
# 1:20 --> 1:20
# Close --> close
# Call --> call
# 0:58 --> 0:58
# Tractor --> tractor
# Tipping --> tip
# 0:37 --> 0:37
# Mater --> mater
# Drives --> drive
# Backwards --> backward
# 1:42 --> 1:42
# Lightning --> lightn
# McQueen --> mcqueen
# Focuses --> focus
# Recommended --> recommend
# Movies --> movi
# Cars --> car
# Cars --> car
# 2 --> 2
# Planes --> plane
# Toy --> toy
# Story --> stori
# pageview_candidate --> pageview_candid
# comscorekw=cars --> comscorekw=car
# Footer --> footer
# Help --> help
# Legal --> legal
# Disney --> disney
# Disney --> disney
# Help --> help
# Careers --> career
# Contact --> contact
# Us --> us
# Advertise --> advertis
# Us --> us
# Disney® --> disney®
# Premier --> premier
# Visa® --> visa®
# Card --> card
# Terms --> term
# Use --> use
# Additional --> addit
# Content --> content
# Information --> inform
# Privacy --> privaci
# Policy --> polici
# US --> us
# State --> state
# Privacy --> privaci
# Rights --> right
# Children --> children
# 's --> 's
# Online --> onlin
# Privacy --> privaci
# Policy --> polici
# Sell --> sell
# Personal --> person
# Information --> inform
# Interest-Based --> interest-bas
# Ads --> ad
# © --> ©
# Disney --> disney
# , --> ,
# Rights --> right
# Reserved --> reserv
# , --> ,
# Disney --> disney
# Entertainment --> entertain
# Sign --> sign
# Account --> account
# Account --> account
# Settings --> set
# Sign --> sign
# Disney.com --> disney.com
# Disney+ --> disney+
# Home --> home
# Disney+ --> disney+
# Disney --> disney
# Bundle --> bundl
# Parks --> park
# & --> &
# Travel --> travel
# Home --> home
# Walt --> walt
# Disney --> disney
# World --> world
# Walt --> walt
# Disney --> disney
# World --> world
# Disneyland --> disneyland
# Disney --> disney
# Cruise --> cruis
# Line --> line
# Aulani --> aulani
# Parks --> park
# & --> &
# Travel --> travel
# Movies --> movi
# Home --> home
# Movies --> movi
# Anywhere --> anywher
# Movies --> movi
# Disney --> disney
# Movie --> movi
# Insiders --> insid
# 20th --> 20th
# Century --> centuri
# Studios --> studio
# Shop --> shop
# Sale --> sale
# Clothes --> cloth
# Accessories --> accessori
# Toys --> toy
# Shop --> shop
# Disney --> disney
# News --> news
# D23 --> d23
# Live --> live
# Shows --> show
# Home --> home
# Disney --> disney
# Broadway --> broadway
# Disney --> disney
# Ice --> ice
# Disney --> disney
# Live --> live
# ! --> !
# Skip --> skip
# Navigation --> navig
# Disney.com --> disney.com
# Disney+ --> disney+
# Disney+ --> disney+
# Disney --> disney
# Bundle --> bundl
# Parks --> park
# & --> &
# Travel --> travel
# Walt --> walt
# Disney --> disney
# World --> world
# Resort --> resort
# Disneyland --> disneyland
# Resort --> resort
# Disney --> disney
# Cruise --> cruis
# Line --> line
# Aulani --> aulani
# - --> -
# Disney --> disney
# Resort --> resort
# Spa --> spa
# Adventures --> adventur
# Disney --> disney
# Disney --> disney
# Vacation --> vacat
# Club --> club
# Movies --> movi
# Movies --> movi
# Anywhere --> anywher
# Movies --> movi
# Disney --> disney
# Movie --> movi
# Club --> club
# Disney --> disney
# Movie --> movi
# Insiders --> insid
# 20th --> 20th
# Century --> centuri
# Studios --> studio
# Shop --> shop
# Sale --> sale
# Clothes --> cloth
# Accessories --> accessori
# Toys --> toy
# Shop --> shop
# Disney --> disney
# News --> news
# D23 --> d23
# : --> :
# Official --> offici
# Disney --> disney
# Fan --> fan
# Club --> club
# Live --> live
# Shows --> show
# Sign --> sign
# Account --> account
# Account --> account
# Settings --> set
# Sign --> sign
# Search --> search
# Video --> video
# Galleries --> galleri
# Movies --> movi
# RSN --> rsn
# Shop --> shop
# Parks --> park
# Cancel --> cancel
# Skip --> skip
# Navigation --> navig
# Movies --> movi
# Video --> video
# Galleries --> galleri
# RSN --> rsn
# Parks --> park
# Explore --> explor
# STREAM --> stream
# CARS --> car
# DISNEY+ --> disney+
# End --> end
# video_wrapper --> video_wrapp
# End --> end
# # --> #
# video_watch_container --> video_watch_contain
# Next --> next
# End --> end
# bound --> bound
# Shop --> shop
# See --> see
# Cars --> car
# Road --> road
# Swim --> swim
# Bag --> bag
# $ --> $
# 19.99 --> 19.99
# $ --> $
# 13.99 --> 13.99
# Cars --> car
# Road --> road
# Swim --> swim
# Trunks --> trunk
# Kids --> kid
# $ --> $
# 24.99 --> 24.99
# $ --> $
# 17.49 --> 17.49
# Cars --> car
# Road --> road
# Sweatshirt --> sweatshirt
# Kids --> kid
# $ --> $
# 34.99 --> 34.99
# Cars --> car
# Road --> road
# Rolling --> roll
# Luggage --> luggag
# – --> –
# Small --> small
# $ --> $
# 49.99 --> 49.99
# Cars --> car
# Racing --> race
# Insignia --> insignia
# T-Shirt --> t-shirt
# Adults --> adult
# – --> –
# Customized --> custom
# $ --> $
# 24.99 --> 24.99
# Cars --> car
# Disney --> disney
# Gift --> gift
# Card --> card
# $ --> $
# 500.00 --> 500.00
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Champions --> champion
# Tee --> tee
# Men --> men
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Cars --> car
# 3 --> 3
# Mousepad --> mousepad
# – --> –
# Customizable --> customiz
# $ --> $
# 12.95 --> 12.95
# Cars --> car
# Road --> road
# Sunglasses --> sunglass
# Kids --> kid
# $ --> $
# 16.99 --> 16.99
# $ --> $
# 11.89 --> 11.89
# Cars --> car
# Road --> road
# Bodysuit --> bodysuit
# Baby --> babi
# $ --> $
# 19.99 --> 19.99
# Cars --> car
# Road --> road
# Rash --> rash
# Guard --> guard
# Kids --> kid
# $ --> $
# 24.99 --> 24.99
# $ --> $
# 17.49 --> 17.49
# Cars --> car
# Road --> road
# Beach --> beach
# Towel --> towel
# – --> –
# Personalized --> person
# $ --> $
# 19.99 --> 19.99
# $ --> $
# 15.00 --> 15.00
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Pattern --> pattern
# iPhone --> iphon
# 6/6S --> 6/6s
# Case --> case
# – --> –
# Customizable --> customiz
# $ --> $
# 39.95 --> 39.95
# Cars --> car
# Road --> road
# PJ --> pj
# PALS --> pal
# Kids --> kid
# $ --> $
# 24.99 --> 24.99
# $ --> $
# 14.98 --> 14.98
# Cars --> car
# Road --> road
# Stainless --> stainless
# Steel --> steel
# Water --> water
# Bottle --> bottl
# Built-In --> built-in
# Straw --> straw
# $ --> $
# 19.99 --> 19.99
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Champions --> champion
# Tee --> tee
# Kids --> kid
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# Cars --> car
# 3 --> 3
# Piston --> piston
# Cup --> cup
# Champions --> champion
# Mug --> mug
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Cars --> car
# 3 --> 3
# Rust-eze --> rust-ez
# Tee --> tee
# Girls --> girl
# – --> –
# Customizable --> customiz
# $ --> $
# 18.95 --> 18.95
# Cars --> car
# Time --> time
# Teacher --> teacher
# Watch --> watch
# Kids --> kid
# $ --> $
# 31.99 --> 31.99
# Cars --> car
# Aquarium --> aquarium
# Train --> train
# Car --> car
# Lionel --> lionel
# $ --> $
# 119.99 --> 119.99
# Radiator --> radiat
# Springs --> spring
# Metal --> metal
# Sign --> sign
# – --> –
# Cars --> car
# $ --> $
# 150.00 --> 150.00
# Rust-eze --> rust-ez
# Metal --> metal
# Sign --> sign
# – --> –
# Cars --> car
# $ --> $
# 150.00 --> 150.00
# Lightning --> lightn
# McQueen --> mcqueen
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# $ --> $
# 22.99 --> 22.99
# Heavy --> heavi
# Metal --> metal
# Mater --> mater
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# $ --> $
# 24.99 --> 24.99
# Cruz --> cruz
# Ramirez --> ramirez
# Water --> water
# Bottle --> bottl
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 21.95 --> 21.95
# Lightning --> lightn
# McQueen --> mcqueen
# Water --> water
# Bottle --> bottl
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 21.95 --> 21.95
# Smokey --> smokey
# 's --> 's
# Garage --> garag
# Morphing --> morph
# Mug --> mug
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Ivy --> ivi
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# Road --> road
# $ --> $
# 16.99 --> 16.99
# Lightning --> lightn
# McQueen --> mcqueen
# Time --> time
# Teacher --> teacher
# Watch --> watch
# Kids --> kid
# – --> –
# Cars --> car
# $ --> $
# 31.99 --> 31.99
# Mater --> mater
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# Road --> road
# $ --> $
# 16.99 --> 16.99
# Lightning --> lightn
# McQueen --> mcqueen
# T-Shirt --> t-shirt
# Kids --> kid
# – --> –
# Cars --> car
# – --> –
# Customized --> custom
# $ --> $
# 19.99 --> 19.99
# Lightning --> lightn
# McQueen --> mcqueen
# Bedding --> bed
# Set --> set
# – --> –
# Cars --> car
# – --> –
# Twin --> twin
# / --> /
# Full --> full
# $ --> $
# 84.99 --> 84.99
# Lightning --> lightn
# McQueen --> mcqueen
# Sheet --> sheet
# Set --> set
# – --> –
# Cars --> car
# – --> –
# Twin --> twin
# / --> /
# Full --> full
# $ --> $
# 29.99 --> 29.99
# Smokey --> smokey
# 's --> 's
# Garage --> garag
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# River --> river
# Scott --> scott
# Tee --> tee
# Women --> women
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 24.95 --> 24.95
# Lightning --> lightn
# McQueen --> mcqueen
# Die --> die
# Cast --> cast
# Set --> set
# – --> –
# Cars --> car
# Road --> road
# $ --> $
# 16.99 --> 16.99
# Rust-eze --> rust-ez
# Tee --> tee
# Men --> men
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 19.95 --> 19.95
# Jackson --> jackson
# Storm --> storm
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# Rust-eze --> rust-ez
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# River --> river
# Scott --> scott
# Tee --> tee
# Kids --> kid
# – --> –
# Cars --> car
# 3 --> 3
# – --> –
# Customizable --> customiz
# $ --> $
# 16.95 --> 16.95
# See --> see
# Race --> race
# Day --> day
# Radiator --> radiat
# Springs --> spring
# comes --> come
# watch --> watch
# Doc --> doc
# Lightning --> lightn
# ’ --> ’
# big --> big
# race --> race
# . --> .
# Pit --> pit
# Crew --> crew
# Team --> team
# McQueen --> mcqueen
# cheers --> cheer
# Lightning --> lightn
# first --> first
# leg --> leg
# World --> world
# Grand --> grand
# Prix --> prix
# . --> .
# Cruisin --> cruisin
# ’ --> ’
# Lightning --> lightn
# ’ --> ’
# new --> new
# road --> road
# inspires --> inspir
# everyone --> everyon
# Radiator --> radiat
# Springs --> spring
# spruce --> spruce
# town --> town
# . --> .
# Flo --> flo
# ’ --> ’
# sure --> sure
# stop --> stop
# Flo --> flo
# ’ --> ’
# V-8 --> v-8
# Cafe --> cafe
# finest --> finest
# fuel --> fuel
# Route --> rout
# 66. --> 66.
# Fillmore --> fillmor
# Sarge --> sarg
# “ --> “
# sixties --> sixti
# ’ --> ’
# good --> good
# , --> ,
# ? --> ?
# ” --> ”
# Fillmore --> fillmor
# ’ --> ’
# Taste-In --> taste-in
# “ --> “
# really --> realli
# need --> need
# sweet --> sweet
# taste --> tast
# homemade --> homemad
# , --> ,
# organic --> organ
# fuel. --> fuel.
# ” --> ”
# Mater --> mater
# Lawyer --> lawyer
# “ --> “
# Boy --> boy
# , --> ,
# ’ --> ’
# purty --> purti
# good --> good
# lawyerin --> lawyerin
# ’ --> ’
# stuff --> stuff
# ! --> !
# ” --> ”
# Mater --> mater
# Meets --> meet
# Finn --> finn
# “ --> “
# Finn --> finn
# McMissile --> mcmissil
# , --> ,
# British --> british
# Intelligence. --> intelligence.
# ” --> ”
# “ --> “
# Tow --> tow
# Mater --> mater
# , --> ,
# average --> averag
# intelligence. --> intelligence.
# ” --> ”
# Teammates --> teammat
# Pals --> pal
# Mater --> mater
# , --> ,
# Lightning --> lightn
# ’ --> ’
# race --> race
# car --> car
# , --> ,
# ’ --> ’
# friend --> friend
# . --> .
# Secret --> secret
# Agent --> agent
# Mater --> mater
# Mater --> mater
# saves --> save
# day --> day
# last --> last
# stop --> stop
# World --> world
# Grand --> grand
# Prix --> prix
# . --> .
# Hurry --> hurri
# Lightning --> lightn
# , --> ,
# Mater --> mater
# , --> ,
# Finn --> finn
# McMissile --> mcmissil
# run --> run
# couple --> coupl
# no-good --> no-good
# lemons --> lemon
# . --> .
# Radiator --> radiat
# Springs --> spring
# Anymore --> anymor
# Mater --> mater
# learns --> learn
# important --> import
# lesson --> lesson
# Japan --> japan
# : --> :
# wasabi --> wasabi
# pistachio --> pistachio
# ice --> ice
# cream --> cream
# . --> .
# Lookin --> lookin
# ’ --> ’
# Good --> good
# need --> need
# paint --> paint
# job --> job
# , --> ,
# Ramone --> ramon
# paint --> paint
# right --> right
# . --> .
# ( --> (
# especially --> especi
# loves --> love
# paint --> paint
# flames --> flame
# . --> .
# ) --> )
# Crazy --> crazi
# Old --> old
# Lizzy --> lizzi
# “ --> “
# keep --> keep
# talking --> talk
# , --> ,
# people --> peopl
# think --> think
# ’ --> ’
# crazy --> crazi
# ! --> !
# ” --> ”
# Lightning --> lightn
# McQueen --> mcqueen
# Lightning --> lightn
# McQueen --> mcqueen
# , --> ,
# # --> #
# 95 --> 95
# , --> ,
# hotshot --> hotshot
# rookie --> rooki
# race --> race
# car --> car
# loves --> love
# going --> go
# faster --> faster
# fast --> fast
# . --> .
# ’ --> ’
# racing --> race
# , --> ,
# spends --> spend
# time --> time
# Radiator --> radiat
# Springs --> spring
# best --> best
# pal --> pal
# , --> ,
# Mater --> mater
# . --> .
# Mater --> mater
# Mater --> mater
# rustiest --> rustiest
# , --> ,
# trustiest --> trustiest
# tow --> tow
# truck --> truck
# Radiator --> radiat
# Springs --> spring
# . --> .
# loves --> love
# tractor --> tractor
# tippin --> tippin
# ’ --> ’
# , --> ,
# helping --> help
# stranded --> strand
# cars --> car
# , --> ,
# , --> ,
# hanging --> hang
# best --> best
# friend --> friend
# , --> ,
# Lightning --> lightn
# McQueen --> mcqueen
# . --> .
# Mater --> mater
# great --> great
# driving --> drive
# backwards --> backward
# , --> ,
# ’ --> ’
# need --> need
# know --> know
# ’ --> ’
# going --> go
# long --> long
# knows --> know
# ’ --> ’
# . --> .
# Sally --> salli
# Sally --> salli
# beautiful --> beauti
# baby --> babi
# blue --> blue
# Porsche --> porsch
# fell --> fell
# love --> love
# small --> small
# town --> town
# life --> life
# Radiator --> radiat
# Springs --> spring
# . --> .
# runs --> run
# Cozy --> cozi
# Cone --> cone
# , --> ,
# town --> town
# attorney --> attorney
# , --> ,
# dedicated --> dedic
# preserving --> preserv
# favorite --> favorit
# place --> place
# live --> live
# . --> .
# loves --> love
# cruisin --> cruisin
# ’ --> ’
# slow --> slow
# lane --> lane
# Lightning --> lightn
# McQueen --> mcqueen
# . --> .
# Luigi --> luigi
# Luigi --> luigi
# 1959 --> 1959
# Fiat --> fiat
# 500 --> 500
# runs --> run
# local --> local
# tire --> tire
# shop --> shop
# , --> ,
# Luigi --> luigi
# ’ --> ’
# Casa --> casa
# Della --> della
# Tires --> tire
# , --> ,
# “ --> “
# Home --> home
# Leaning --> lean
# Tower --> tower
# Tires. --> tires.
# ” --> ”
# loves --> love
# changing --> chang
# tires --> tire
# racecars --> racecar
# like --> like
# Lightning --> lightn
# McQueen --> mcqueen
# , --> ,
# nothing --> noth
# makes --> make
# happier --> happier
# real --> real
# Ferrari --> ferrari
# comes --> come
# door --> door
# . --> .
# Guido --> guido
# Guido --> guido
# little --> littl
# Italian --> italian
# forklift --> forklift
# Luigi --> luigi
# ’ --> ’
# assistant --> assist
# best --> best
# buddy --> buddi
# -- --> --
# ’ --> ’
# hardly --> hard
# ever --> ever
# see --> see
# two --> two
# pals --> pal
# apart --> apart
# . --> .
# Like --> like
# Luigi --> luigi
# , --> ,
# Guido --> guido
# avid --> avid
# Ferrari --> ferrari
# racing --> race
# fan --> fan
# dreams --> dream
# performing --> perform
# real --> real
# pit --> pit
# stop --> stop
# real --> real
# Ferrari --> ferrari
# . --> .
# Sarge --> sarg
# Sarge --> sarg
# , --> ,
# 1942 --> 1942
# WW2 --> ww2
# Willy --> willi
# ’ --> ’
# Army --> armi
# Jeep --> jeep
# patriotic --> patriot
# resident --> resid
# Radiator --> radiat
# Springs --> spring
# . --> .
# runs --> run
# local --> local
# army --> armi
# surplus --> surplus
# store --> store
# , --> ,
# Sarge --> sarg
# ’ --> ’
# Surplus --> surplus
# Hut --> hut
# , --> ,
# always --> alway
# starts --> start
# day --> day
# rendition --> rendit
# Reveille --> reveill
# . --> .
# Fillmore --> fillmor
# Fillmore --> fillmor
# 1960 --> 1960
# VW --> vw
# Bus --> bus
# , --> ,
# naturally --> natur
# , --> ,
# also --> also
# Radiator --> radiat
# Springs --> spring
# ’ --> ’
# resident --> resid
# Hippie --> hippi
# clean --> clean
# fuel --> fuel
# aficionado --> aficionado
# . --> .
# brews --> brew
# organic --> organ
# fuel --> fuel
# tie-dyed --> tie-di
# , --> ,
# geometric --> geometr
# dome --> dome
# , --> ,
# unkempt --> unkempt
# yard --> yard
# tends --> tend
# bug --> bug
# veteran --> veteran
# army --> armi
# jeep --> jeep
# neighbor --> neighbor
# , --> ,
# Sarge --> sarg
# . --> .
# Ramone --> ramon
# Ramone --> ramon
# 1951 --> 1951
# Impala --> impala
# low-rider --> low-rid
# loves --> love
# riding --> ride
# “ --> “
# low --> low
# slow. --> slow.
# ” --> ”
# runs --> run
# Ramone --> ramon
# ’ --> ’
# House --> hous
# Body --> bodi
# Art --> art
# , --> ,
# local --> local
# custom --> custom
# body --> bodi
# paint --> paint
# shop --> shop
# . --> .
# true --> true
# artist --> artist
# , --> ,
# without --> without
# many --> mani
# customers --> custom
# paint --> paint
# , --> ,
# Ramone --> ramon
# changes --> chang
# paint --> paint
# job --> job
# every --> everi
# day --> day
# . --> .
# Doc --> doc
# Hudson --> hudson
# Doc --> doc
# wise --> wise
# , --> ,
# quiet --> quiet
# country --> countri
# doctor --> doctor
# run --> run
# Radiator --> radiat
# Springs --> spring
# ’ --> ’
# medical --> medic
# clinic --> clinic
# . --> .
# Doc --> doc
# slowed --> slow
# Radiator --> radiat
# Springs --> spring
# , --> ,
# Fabulous --> fabul
# Hudson --> hudson
# Hornet --> hornet
# . --> .
# uses --> use
# knowledge --> knowledg
# racing --> race
# teach --> teach
# hotshots --> hotshot
# like --> like
# Lightning --> lightn
# race --> race
# smart --> smart
# , --> ,
# fast --> fast
# . --> .
# Flo --> flo
# Flo --> flo
# sassy --> sassi
# , --> ,
# no-nonsense --> no-nonsens
# 1950 --> 1950
# ’ --> ’
# show --> show
# car --> car
# enjoys --> enjoy
# traveling --> travel
# cross-country --> cross-countri
# . --> .
# runs --> run
# local --> local
# diner --> diner
# , --> ,
# Flo --> flo
# ’ --> ’
# V-8 --> v-8
# Cafe --> cafe
# , --> ,
# gas --> gas
# station --> station
# miles --> mile
# around --> around
# . --> .
# Show --> show
# Videos --> video
# Cars --> car
# See --> see
# favorite --> favorit
# characters --> charact
# action --> action
# 1:20 --> 1:20
# Close --> close
# Call --> call
# 0:58 --> 0:58
# Tractor --> tractor
# Tipping --> tip
# 0:37 --> 0:37
# Mater --> mater
# Drives --> drive
# Backwards --> backward
# 1:42 --> 1:42
# Lightning --> lightn
# McQueen --> mcqueen
# Focuses --> focus
# Recommended --> recommend
# Movies --> movi
# Cars --> car
# Cars --> car
# 2 --> 2
# Planes --> plane
# Toy --> toy
# Story --> stori
# pageview_candidate --> pageview_candid
# comscorekw=cars --> comscorekw=car
# Footer --> footer
# Help --> help
# Legal --> legal
# Disney --> disney
# Disney --> disney
# Help --> help
# Careers --> career
# Contact --> contact
# Us --> us
# Advertise --> advertis
# Us --> us
# Disney® --> disney®
# Premier --> premier
# Visa® --> visa®
# Card --> card
# Terms --> term
# Use --> use
# Additional --> addit
# Content --> content
# Information --> inform
# Privacy --> privaci
# Policy --> polici
# US --> us
# State --> state
# Privacy --> privaci
# Rights --> right
# Children --> children
# 's --> 's
# Online --> onlin
# Privacy --> privaci
# Policy --> polici
# Sell --> sell
# Personal --> person
# Information --> inform
# Interest-Based --> interest-bas
# Ads --> ad
# © --> ©
# Disney --> disney
# , --> ,
# Rights --> right
# Reserved --> reserv
# , --> ,
# Disney --> disney
# Entertainment --> entertain

# %%
# import pandas as pd
# def tf_idf_analysis(keyword):
#   v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=stop_words)
#   x = v.fit_transform(text)

#   f = pd.DataFrame(x.toarray(), columns = v.get_feature_names())
#   d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
#   tf=pd.DataFrame((f>0).sum(axis=0))


#   d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

#   d.columns=['word','average_tfidf','max_tfidf','frequency']

#   d['frequency']=round((d['frequency']/len(text))*100)

#   return(d)


# x= tf_idf_analysis(u)
# x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
# print(x)

import pandas as pd
def tf_idf_analysis(keyword):
    v = TfidfVectorizer(min_df=1,analyzer='word',ngram_range=(1,2),stop_words=list(stop_words))
    x = v.fit_transform(text)

    f = pd.DataFrame(x.toarray(), columns = v.get_feature_names_out())
    d=pd.concat([pd.DataFrame(f.mean(axis=0)),pd.DataFrame(f.max(axis=0))],axis=1)
    
    
    tf=pd.DataFrame((f>0).sum(axis=0))


    d=d.reset_index().merge(tf.reset_index(),on='index',how='left')

    d.columns=['word','average_tfidf','max_tfidf','frequency']

    d['frequency']=round((d['frequency']/len(text))*100)

    return(d)

x= tf_idf_analysis(u)
x[x['word'].str.isalpha()].sort_values('max_tfidf',ascending=False).head(35)
# Out:
#               word  average_tfidf  max_tfidf  frequency
# 5947         voice       0.042939   0.322044       13.0
# 2125        disney       0.024543   0.318156       20.0
# 3444            km       0.041902   0.314265       13.0
# 5273          span       0.064832   0.297945       27.0
# 1457          cars       0.113156   0.284875       73.0
# 4513         price       0.085400   0.282329       53.0
# 2341         egypt       0.069598   0.263963       67.0
# 2257           egp       0.121464   0.254688       53.0
# 1711         class       0.060350   0.253253       27.0
# 5364          star       0.031641   0.225981       27.0
# 3043          high       0.030956   0.220872       27.0
# 3726           low       0.030827   0.202256       33.0
# 1994  customizable       0.012830   0.192455        7.0
# 3628     lightning       0.020924   0.188905       20.0
# 3427          kids       0.011975   0.179625        7.0
# 4409         pixar       0.022403   0.168023       13.0
# 1389           car       0.068135   0.158064       73.0
# 3824         mater       0.021605   0.149135       20.0
# 3168          imdb       0.018669   0.140019       13.0
# 6180       البرامج       0.027841   0.139205       20.0
# 6178       الإعلان       0.027841   0.139205       20.0
# 6139       youtube       0.027841   0.139205       20.0
# 6176       الأحكام       0.027841   0.139205       20.0
# 6174            اع       0.027841   0.139205       20.0
# 6172          آلية       0.027841   0.139205       20.0
# 3670           llc       0.027841   0.139205       20.0
# 6182       التواصل       0.027841   0.139205       20.0
# 6188       السياسة       0.027841   0.139205       20.0
# 6184       الجديدة       0.027841   0.139205       20.0
# 6208           حول       0.027841   0.139205       20.0
# 6220          معنا       0.027841   0.139205       20.0
# 6218           مطو       0.027841   0.139205       20.0
# 6216           عمل       0.027841   0.139205       20.0
# 6186      الخصوصية       0.027841   0.139205       20.0
# 6224        والنشر       0.027841   0.139205       20.0
